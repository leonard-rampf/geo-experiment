# %% [markdown]
# # Notebook 3D — Generation Stage (Range 75%–100%)
#
# Processes 75%–100% of all runs.
# Run A, B, C, D in parallel — each writes to its own parquet file.
#
# **Input:** `data/retail/retail_geo_detailed_results_v2.csv`
#
# **Output:** `data/retail/generation_results_D.parquet`
#
# ## Instructions
# 1. Run **Setup**
# 2. Run **Data Preparation**
# 3. Run **Helper Functions**
# 4. Run **Parameters** — range is set automatically
# 5. Run **Generation**
# 6. Run **Inspect Results**
# 7. Run **Summary**
# 8. After all 4 notebooks finish: run **Merge Results** in any one notebook

# %% [markdown]
# ## Setup

# %%
import json
import os
import re
import sys
import time
from datetime import datetime

import pandas as pd
import numpy as np

notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, ".."))
sys.path.insert(0, os.path.join(project_root, "src"))

from llms import OpenAIHelper

config_path = os.path.join(project_root, "config.json")
with open(config_path, "r") as f:
    config = json.load(f)
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

data_dir = os.path.join(project_root, "data", "retail")

print("Setup complete.")
print(f"Project root: {project_root}")
# Out:
# Setup complete.
# Project root: /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment

# %% [markdown]
# ## Data Preparation
#
# Load the retrieval CSV and extract `original_query_id` and `method` from `query_id`.
# Example: `50881_Fluency(doc)` → `original_query_id=50881`, `method=Fluency(doc)`

# %%
retrieval_csv_path = os.path.join(data_dir, "retail_geo_detailed_results_v2.csv")
df = pd.read_csv(retrieval_csv_path)

# Extract original_query_id and method from query_id
df["original_query_id"] = df["query_id"].str.extract(r"^(\d+)_")
df["method"]            = df["query_id"].str.extract(r"^\d+_(.+)$")

# Flag runs that have no target document — these will be skipped
target_per_run = df.groupby("query_id")["is_target"].sum()
runs_with_target    = set(target_per_run[target_per_run == 1].index)
runs_without_target = set(target_per_run[target_per_run == 0].index)

# Save runs without target to a separate file for documentation
runs_without_target_path = os.path.join(data_dir, "runs_without_target.json")
with open(runs_without_target_path, "w") as f:
    json.dump(sorted(list(runs_without_target)), f, indent=4)

print(f"Total rows:              {len(df)}")
print(f"Unique runs (query_ids): {df['query_id'].nunique()}")
print(f"Unique original queries: {df['original_query_id'].nunique()}")
print(f"Unique methods:          {df['method'].nunique()}")
print(f"Runs with target:        {len(runs_with_target)}")
print(f"Runs without target:     {len(runs_without_target)} — saved to runs_without_target.json")
print()
print("Methods found:")
for m in sorted(df['method'].unique()):
    print(f"  {m}")
# Out:
# Total rows:              109535
# Unique runs (query_ids): 10997
# Unique original queries: 500
# Unique methods:          22
# Runs with target:        10940
# Runs without target:     57 — saved to runs_without_target.json
#
# Methods found:
#   Authoritative(doc)
#   CQ(doc)
#   CQS(doc)
#   CS(doc)
#   Citations(doc)
#   ContentImprovement(doc)
#   FC(doc)
#   FCQ(doc)
#   FCQS(doc)
#   FCS(doc)
#   FQ(doc)
#   FQS(doc)
#   FS(doc)
#   Fluency(doc)
#   LLMstxt(doc)
#   QS(doc)
#   Quotes(doc)
#   SimpleLanguage(doc)
#   Statistics(doc)
#   TechnicalTerms(doc)
#   UniqueWords(doc)
#   doc

# %% [markdown]
# ## Helper Functions

# %%
DEVELOPER_PROMPT = """Your are a product recommender system for an online marketplace. Write an accurate and concise answer for the given user question, using _only_ the provided summarized web search results. The answer should be correct, high-quality, and written by an expert using an unbiased and journalistic tone. The answer should be informative, interesting, and engaging. The answer's logic and reasoning should be rigorous and defensible. Every sentence in the answer should be _immediately followed_ by an in-line citation to the search result(s). The cited search result(s) should fully support _all_ the information in the sentence. Search results need to be cited using [index]. When citing several search results, use [1][2][3] format rather than [1, 2, 3]. You can use multiple search results to respond comprehensively while avoiding irrelevant search results. Search results are not sorted."""
DOC_TYPE = "Product Description"


def build_context(group):
    """
    Takes all rows for one query_id, sorts by rank, re-numbers 1..N.
    Returns:
        docs: list of doc_text in retrieval order
        target_new_position: 0-based position of target doc after re-numbering
    """
    group = group.sort_values("rank").reset_index(drop=True)
    docs = group["doc_text"].tolist()

    # Find 0-based position of target doc
    target_new_position = None
    for i, row in group.iterrows():
        if row["is_target"] == 1:
            target_new_position = i  # 0-based
            break

    return docs, target_new_position


def build_user_prompt(query, docs):
    """
    Builds the user prompt for the LLM.
    docs: list of doc_text strings, numbered 1..N
    """
    sources = ""
    for i, doc_text in enumerate(docs, start=1):
        sources += f"[{i}] {DOC_TYPE}: {doc_text}\n\n"
    return f"Question: {query}\n\nSearch Results:\n{sources}"


def extract_citation_order(response_text):
    """
    Extracts citation indices in order of first appearance.
    0-based like Puerto: [1] in text -> index 0, [2] -> index 1, etc.
    e.g. "...product [2] is great [1][2]..." -> [1, 0]
    """
    citations = re.findall(r"\[(\d+)\]", response_text)
    seen = []
    for c in citations:
        idx = int(c) - 1  # 0-based
        if idx not in seen:
            seen.append(idx)
    return seen


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## Parameters

# %%
# LLM
LLM_NAME = "gpt-4o-mini-2024-07-18"

# Notebook ID
NOTEBOOK_ID = "D"

# Output file for this notebook
output_path = os.path.join(data_dir, "generation_results_D.parquet")

# All runs to process (only those with a target doc)
all_run_ids_full = sorted(runs_with_target)
total = len(all_run_ids_full)
start_idx = int(total * 75/100)
end_idx   = int(total * 100/100)
all_run_ids = all_run_ids_full[start_idx:end_idx]

# Check already done
if os.path.exists(output_path):
    df_done = pd.read_parquet(output_path)
    done_keys = set(df_done["query_id"].tolist())
    already_done = len(done_keys)
else:
    done_keys = set()
    already_done = 0

llm = OpenAIHelper(LLM_NAME)

remaining = len(all_run_ids) - already_done
print(f"Notebook:      {NOTEBOOK_ID}")
print(f"LLM:           {LLM_NAME}")
print(f"Range:         75%–100% ({start_idx}–{end_idx} of {total})")
print(f"Runs in range: {len(all_run_ids)}")
print(f"Already done:  {already_done}")
print(f"Remaining:     {remaining}")
print(f"Estimated time: ~{remaining * 9.5 / 3600:.1f} hours")
print(f"Estimated cost: ~${remaining * 0.0003:.2f}")
# Out:
# Notebook:      D
# LLM:           gpt-4o-mini-2024-07-18
# Range:         75%–100% (8205–10940 of 10940)
# Runs in range: 2735
# Already done:  0
# Remaining:     2735
# Estimated time: ~7.2 hours
# Estimated cost: ~$0.82

# %% [markdown]
# ## Generation
#
# For each run (query_id):
# 1. Sort docs by rank and re-number 1..N
# 2. Build LLM prompt
# 3. Generate response with inline citations
# 4. Extract citation order
# 5. Save incrementally
#
# Runs without a target doc are skipped.
# Safe to interrupt and resume.

# %%
llm = OpenAIHelper(LLM_NAME)

# Load existing results if any
if os.path.exists(output_path):
    results_df = pd.read_parquet(output_path)
    results = results_df.to_dict("records")
else:
    results = []

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%H:%M:%S')}")
print(f"Total runs to process: {len(all_run_ids)}")
print()

for i, query_id in enumerate(all_run_ids):

    # Skip if already done
    if query_id in done_keys:
        continue

    # Get all rows for this run
    group = df[df["query_id"] == query_id]
    query_text         = group["query"].iloc[0]
    original_query_id  = group["original_query_id"].iloc[0]
    method             = group["method"].iloc[0]

    # Build context
    docs, target_new_position = build_context(group)

    if target_new_position is None:
        print(f"  [{i+1}] {query_id}: no target — skipping")
        continue

    # Build prompt
    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    try:
        response, _ = llm.generate(messages)
        response_text    = response.content
        citation_order   = extract_citation_order(response_text)

        results.append({
            "query_id":            query_id,
            "original_query_id":   original_query_id,
            "method":              method,
            "query":               query_text,
            "target_new_position": target_new_position,
            "num_docs":            len(docs),
            "citation_order":      citation_order,
            "llm_response":        response_text,
        })
        done_keys.add(query_id)
        pd.DataFrame(results).to_parquet(output_path, index=False)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    except Exception as e:
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: ERROR — {e}")
        time.sleep(10)
        try:
            response, _    = llm.generate(messages)
            response_text  = response.content
            citation_order = extract_citation_order(response_text)
            results.append({
                "query_id":            query_id,
                "original_query_id":   original_query_id,
                "method":              method,
                "query":               query_text,
                "target_new_position": target_new_position,
                "num_docs":            len(docs),
                "citation_order":      citation_order,
                "llm_response":        response_text,
            })
            done_keys.add(query_id)
            pd.DataFrame(results).to_parquet(output_path, index=False)
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: done (retry OK)")
        except Exception as e2:
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: FAILED — {e2}")

end_time = datetime.now()
elapsed  = end_time - start_time
print(f"{'='*60}")
print(f"GENERATION COMPLETE")
print(f"Started:    {start_time.strftime('%H:%M:%S')}")
print(f"Finished:   {end_time.strftime('%H:%M:%S')}")
print(f"Total time: {str(elapsed).split('.')[0]}")
print(f"Results:    {len(results)} rows saved to {output_path}")
# Out:
# Started at: 12:51:13
# Total runs to process: 2735
#
#   [1/2735] 74897_Quotes(doc): target at [2] | cited: [0, 4, 2, 3, 5]
#   [2/2735] 74897_SimpleLanguage(doc): target at [2] | cited: [0, 4, 1, 2, 8]
#   [3/2735] 74897_Statistics(doc): target at [2] | cited: [0, 4, 9, 2, 8]
#   [4/2735] 74897_TechnicalTerms(doc): target at [2] | cited: [0, 4, 1, 2, 3]
#   [5/2735] 74897_UniqueWords(doc): target at [2] | cited: [0, 4, 2, 5, 9]
#   [6/2735] 74897_doc: target at [2] | cited: [0, 4, 2, 9, 1]
#   [7/2735] 749_Authoritative(doc): target at [6] | cited: [0, 1, 2]
#   [8/2735] 749_CQ(doc): target at [6] | cited: [0, 1]
#   [9/2735] 749_CQS(doc): target at [6] | cited: [0, 1, 2]
#   [10/2735] 749_CS(doc): target at [6] | cited: [0, 1, 2]
#   [11/2735] 749_Citations(doc): target at [6] | cited: [0, 1, 2]
#   [12/2735] 749_ContentImprovement(doc): target at [6] | cited: [0, 1, 2]
#   [13/2735] 749_FC(doc): target at [6] | cited: [0, 1, 2]
#   [14/2735] 749_FCQ(doc): target at [6] | cited: [0, 1, 2]
#   [15/2735] 749_FCQS(doc): target at [6] | cited: [0, 1, 2]
#   [16/2735] 749_FCS(doc): target at [6] | cited: [0, 1]
#   [17/2735] 749_FQ(doc): target at [6] | cited: [0, 1, 2]
#   [18/2735] 749_FQS(doc): target at [6] | cited: [0, 1, 2]
#   [19/2735] 749_FS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [20/2735] 749_Fluency(doc): target at [6] | cited: [0, 1, 2]
#   [21/2735] 749_LLMstxt(doc): target at [6] | cited: [0, 1, 2, 4]
#   [22/2735] 749_QS(doc): target at [6] | cited: [0, 1, 2]
#   [23/2735] 749_Quotes(doc): target at [6] | cited: [0, 1, 2, 5]
#   [24/2735] 749_SimpleLanguage(doc): target at [6] | cited: [0, 1, 2]
#   [25/2735] 749_Statistics(doc): target at [5] | cited: [0, 1, 2]
#   [26/2735] 749_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2]
#   [27/2735] 749_UniqueWords(doc): target at [6] | cited: [0, 1, 2]
#   [28/2735] 749_doc: target at [6] | cited: [0, 1, 2]
#   [29/2735] 75000_Authoritative(doc): target at [5] | cited: [0, 1, 2, 5, 6]
#   [30/2735] 75000_CQ(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [31/2735] 75000_CQS(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [32/2735] 75000_CS(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [33/2735] 75000_Citations(doc): target at [5] | cited: [0, 1, 2, 5, 4]
#   [34/2735] 75000_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 6, 4]
#   [35/2735] 75000_FC(doc): target at [9] | cited: [0, 9, 1, 2, 5]
#   [36/2735] 75000_FCQ(doc): target at [9] | cited: [0, 1, 2, 9, 5]
#   [37/2735] 75000_FCQS(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [38/2735] 75000_FCS(doc): target at [6] | cited: [0, 1, 2, 7, 4]
#   [39/2735] 75000_FQ(doc): target at [8] | cited: [0, 6, 4]
#   [40/2735] 75000_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [41/2735] 75000_FS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [42/2735] 75000_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 7]
#   [43/2735] 75000_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [44/2735] 75000_QS(doc): target at [7] | cited: [0, 1, 2, 6, 8]
#   [45/2735] 75000_Quotes(doc): target at [6] | cited: [0, 1, 2, 7, 4]
#   [46/2735] 75000_SimpleLanguage(doc): target at [5] | cited: [0, 1, 7]
#   [47/2735] 75000_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [48/2735] 75000_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 5, 4]
#   [49/2735] 75000_UniqueWords(doc): target at [6] | cited: [0, 1, 2, 7, 4]
#   [50/2735] 75000_doc: target at [5] | cited: [0, 1, 2, 6, 7]
#   [51/2735] 75276_Authoritative(doc): target at [8] | cited: [0]
#   [52/2735] 75276_CQ(doc): target at [1] | cited: [0, 8, 1, 4, 5]
#   [53/2735] 75276_CQS(doc): target at [1] | cited: [0, 8, 2, 5, 1]
#   [54/2735] 75276_CS(doc): target at [2] | cited: [0, 5, 1, 2, 7]
#   [55/2735] 75276_Citations(doc): target at [8] | cited: [0, 8]
#   [56/2735] 75276_ContentImprovement(doc): target at [8] | cited: [0, 5, 6, 1, 2]
#   [57/2735] 75276_FC(doc): target at [1] | cited: [0, 5, 1, 4, 8]
#   [58/2735] 75276_FCQ(doc): target at [7] | cited: [0, 3, 4, 1, 9]
#   [59/2735] 75276_FCQS(doc): target at [7] | cited: [0, 5, 8, 7]
#   [60/2735] 75276_FCS(doc): target at [7] | cited: [0, 6, 7, 1, 3]
#   [61/2735] 75276_FQ(doc): target at [1] | cited: [0, 2, 1, 3, 4]
#   [62/2735] 75276_FQS(doc): target at [5] | cited: [0, 1, 4, 5, 3]
#   [63/2735] 75276_FS(doc): target at [7] | cited: [0, 4, 2, 1, 5]
#   [64/2735] 75276_Fluency(doc): target at [8] | cited: [0, 5, 8, 2, 4]
#   [65/2735] 75276_LLMstxt(doc): target at [7] | cited: [0, 5, 4, 3, 8]
#   [66/2735] 75276_QS(doc): target at [2] | cited: [0, 7, 9, 1, 2]
#   [67/2735] 75276_Quotes(doc): target at [7] | cited: [0, 2, 5, 7, 4]
#   [68/2735] 75276_SimpleLanguage(doc): target at [1] | cited: [0, 1]
#   [69/2735] 75276_Statistics(doc): target at [2] | cited: [0, 3, 6, 8, 4]
#   [70/2735] 75276_TechnicalTerms(doc): target at [1] | cited: [0, 2, 1, 4, 5]
#   [71/2735] 75276_UniqueWords(doc): target at [3] | cited: [0, 8, 7, 1, 6]
#   [72/2735] 75276_doc: target at [2] | cited: [0]
#   [73/2735] 75438_Authoritative(doc): target at [8] | cited: [1, 9, 0, 5, 2]
#   [74/2735] 75438_CQ(doc): target at [9] | cited: [1, 2, 8, 0, 4]
#   [75/2735] 75438_CQS(doc): target at [9] | cited: [1, 4, 8, 2, 3]
#   [76/2735] 75438_Citations(doc): target at [8] | cited: [1, 2, 3, 9, 0]
#   [77/2735] 75438_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [78/2735] 75438_FC(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [79/2735] 75438_FCQ(doc): target at [9] | cited: [1, 2, 9, 0, 4]
#   [80/2735] 75438_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [81/2735] 75438_FCS(doc): target at [9] | cited: [1, 2, 8, 5, 9]
#   [82/2735] 75438_FQ(doc): target at [9] | cited: [1, 3, 4, 9, 5]
#   [83/2735] 75438_FQS(doc): target at [9] | cited: [1, 3, 8, 5, 0]
#   [84/2735] 75438_FS(doc): target at [9] | cited: [1, 4, 2, 8, 0]
#   [85/2735] 75438_Fluency(doc): target at [9] | cited: [1, 2, 9, 8, 6]
#   [86/2735] 75438_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 8, 4]
#   [87/2735] 75438_QS(doc): target at [9] | cited: [1, 3, 4, 0, 2]
#   [88/2735] 75438_Quotes(doc): target at [9] | cited: [1, 2, 8, 0, 5]
#   [89/2735] 75438_SimpleLanguage(doc): target at [6] | cited: [1, 2, 3, 5, 9]
#   [90/2735] 75438_Statistics(doc): target at [9] | cited: [0, 2, 8, 4, 5]
#   [91/2735] 75438_TechnicalTerms(doc): target at [9] | cited: [0, 1, 3, 8, 4]
#   [92/2735] 75438_UniqueWords(doc): target at [9] | cited: [1, 8, 5, 9, 2]
#   [93/2735] 75438_doc: target at [9] | cited: [0, 1, 2, 3, 4]
#   [94/2735] 75810_Authoritative(doc): target at [4] | cited: [0, 1, 3, 2, 7]
#   [95/2735] 75810_CQ(doc): target at [4] | cited: [0, 3, 8, 2, 1]
#   [96/2735] 75810_CQS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [97/2735] 75810_CS(doc): target at [4] | cited: [0, 1, 2, 8, 3]
#   [98/2735] 75810_Citations(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [99/2735] 75810_ContentImprovement(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [100/2735] 75810_FC(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [101/2735] 75810_FCQ(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [102/2735] 75810_FCQS(doc): target at [4] | cited: [0, 2, 3, 9, 7]
#   [103/2735] 75810_FCS(doc): target at [4] | cited: [0, 1, 2, 3]
#   [104/2735] 75810_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [105/2735] 75810_FQS(doc): target at [4] | cited: [0, 1, 4, 2, 5]
#   [106/2735] 75810_FS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [107/2735] 75810_Fluency(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [108/2735] 75810_LLMstxt(doc): target at [6] | cited: [0, 1, 2]
#   [109/2735] 75810_QS(doc): target at [4] | cited: [0, 1, 2, 4, 7]
#   [110/2735] 75810_Quotes(doc): target at [4] | cited: [0, 1, 2, 7, 9]
#   [111/2735] 75810_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 4, 9]
#   [112/2735] 75810_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [113/2735] 75810_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [114/2735] 75810_UniqueWords(doc): target at [4] | cited: [0, 2, 3, 8, 1]
#   [115/2735] 75810_doc: target at [4] | cited: [0, 2, 9, 1, 5]
#   [116/2735] 76077_Authoritative(doc): target at [8] | cited: [0, 5, 9, 2, 1]
#   [117/2735] 76077_CQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [118/2735] 76077_CQS(doc): target at [8] | cited: [1, 4, 8, 9, 0]
#   [119/2735] 76077_CS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [120/2735] 76077_Citations(doc): target at [8] | cited: [0, 3, 5, 1, 2]
#   [121/2735] 76077_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [122/2735] 76077_FC(doc): target at [8] | cited: [0, 5, 1, 2, 4]
#   [123/2735] 76077_FCQ(doc): target at [9] | cited: [0, 1, 2, 5, 3]
#   [124/2735] 76077_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 6]
#   [125/2735] 76077_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [126/2735] 76077_FQ(doc): target at [8] | cited: [0, 2, 1, 5, 3]
#   [127/2735] 76077_FQS(doc): target at [8] | cited: [0, 3, 8, 9, 1]
#   [128/2735] 76077_FS(doc): target at [8] | cited: [0, 5, 9, 4, 1]
#   [129/2735] 76077_Fluency(doc): target at [8] | cited: [0, 1, 5, 9, 2]
#   [130/2735] 76077_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [131/2735] 76077_QS(doc): target at [8] | cited: [0, 5, 9, 1, 2]
#   [132/2735] 76077_Quotes(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [133/2735] 76077_SimpleLanguage(doc): target at [8] | cited: [0, 2, 5, 8, 9]
#   [134/2735] 76077_Statistics(doc): target at [8] | cited: [0, 5, 7, 9, 1]
#   [135/2735] 76077_TechnicalTerms(doc): target at [8] | cited: [0, 1, 4, 2, 5]
#   [136/2735] 76077_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 6, 9]
#   [137/2735] 76077_doc: target at [8] | cited: [0, 2, 8, 9, 1]
#   [138/2735] 7626_Authoritative(doc): target at [0] | cited: [0, 1, 2]
#   [139/2735] 7626_CQ(doc): target at [0] | cited: [0, 1, 6, 3]
#   [140/2735] 7626_CQS(doc): target at [1] | cited: [0, 1, 5, 2, 3]
#   [141/2735] 7626_CS(doc): target at [0] | cited: [0, 1, 5, 3, 2]
#   [142/2735] 7626_Citations(doc): target at [3] | cited: [0, 1, 2, 5, 6]
#   [143/2735] 7626_ContentImprovement(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [144/2735] 7626_FC(doc): target at [7] | cited: [0, 1, 2, 3, 7]
#   [145/2735] 7626_FCQ(doc): target at [8] | cited: [0, 1, 2]
#   [146/2735] 7626_FCQS(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [147/2735] 7626_FCS(doc): target at [0] | cited: [0, 1, 2, 5, 3]
#   [148/2735] 7626_FQ(doc): target at [1] | cited: [0, 3, 4, 5, 1]
#   [149/2735] 7626_FQS(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [150/2735] 7626_FS(doc): target at [4] | cited: [0, 1, 2, 3]
#   [151/2735] 7626_Fluency(doc): target at [0] | cited: [0, 1, 8, 2, 3]
#   [152/2735] 7626_LLMstxt(doc): target at [0] | cited: [0, 4, 6, 1, 2]
#   [153/2735] 7626_QS(doc): target at [5] | cited: [0, 1, 2, 5, 3]
#   [154/2735] 7626_Quotes(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [155/2735] 7626_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 6, 3]
#   [156/2735] 7626_Statistics(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [157/2735] 7626_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [158/2735] 7626_UniqueWords(doc): target at [3] | cited: [0, 2, 4, 1, 3]
#   [159/2735] 7626_doc: target at [2] | cited: [0, 2, 1, 5, 3]
#   [160/2735] 76487_Authoritative(doc): target at [8] | cited: [1, 3, 7, 2, 8]
#   [161/2735] 76487_CQ(doc): target at [8] | cited: [0, 1, 2, 8, 3]
#   [162/2735] 76487_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [163/2735] 76487_CS(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [164/2735] 76487_Citations(doc): target at [8] | cited: [0, 1, 5, 2, 7]
#   [165/2735] 76487_ContentImprovement(doc): target at [7] | cited: [0, 1, 4, 7, 2]
#   [166/2735] 76487_FC(doc): target at [8] | cited: [0, 1, 3, 2, 5]
#   [167/2735] 76487_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [168/2735] 76487_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [169/2735] 76487_FCS(doc): target at [8] | cited: [0, 8, 1, 2, 9]
#   [170/2735] 76487_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [171/2735] 76487_FQS(doc): target at [8] | cited: [0, 1, 2, 4, 9]
#   [172/2735] 76487_FS(doc): target at [8] | cited: [0, 3, 2, 4, 7]
#   [173/2735] 76487_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [174/2735] 76487_LLMstxt(doc): target at [4] | cited: [0, 4, 2, 5, 7]
#   [175/2735] 76487_QS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [176/2735] 76487_Quotes(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [177/2735] 76487_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [178/2735] 76487_Statistics(doc): target at [8] | cited: [0, 1, 3, 6, 5]
#   [179/2735] 76487_TechnicalTerms(doc): target at [3] | cited: [0, 1, 3, 6, 7]
#   [180/2735] 76487_UniqueWords(doc): target at [8] | cited: [0, 5, 3, 9, 4]
#   [181/2735] 76487_doc: target at [3] | cited: [0, 1, 2, 3, 8]
#   [182/2735] 76620_Authoritative(doc): target at [6] | cited: [0, 1, 5, 2, 4]
#   [183/2735] 76620_CQ(doc): target at [6] | cited: [0, 1, 2, 5, 4]
#   [184/2735] 76620_CQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [185/2735] 76620_CS(doc): target at [6] | cited: [0, 1, 2, 5, 3]
#   [186/2735] 76620_Citations(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [187/2735] 76620_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [188/2735] 76620_FCQ(doc): target at [9] | cited: [0, 1, 3, 9, 2]
#   [189/2735] 76620_FCQS(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [190/2735] 76620_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [191/2735] 76620_FQ(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [192/2735] 76620_FQS(doc): target at [6] | cited: [0, 1, 3, 5, 2]
#   [193/2735] 76620_FS(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [194/2735] 76620_Fluency(doc): target at [6] | cited: [0, 1, 5, 6, 2]
#   [195/2735] 76620_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [196/2735] 76620_QS(doc): target at [6] | cited: [0, 5, 7, 1, 2]
#   [197/2735] 76620_Quotes(doc): target at [6] | cited: [0, 1, 2, 5, 6]
#   [198/2735] 76620_SimpleLanguage(doc): target at [6] | cited: [0, 1, 2, 5, 6]
#   [199/2735] 76620_Statistics(doc): target at [9] | cited: [0, 1, 5, 9, 4]
#   [200/2735] 76620_TechnicalTerms(doc): target at [6] | cited: [0, 1, 5, 7]
#   [201/2735] 76620_UniqueWords(doc): target at [6] | cited: [0, 1, 3, 2, 4]
#   [202/2735] 76620_doc: target at [6] | cited: []
#   [203/2735] 76633_Authoritative(doc): target at [7] | cited: [1, 0, 3, 2, 5]
#   [204/2735] 76633_CQ(doc): target at [7] | cited: [0, 1, 2, 4, 7]
#   [205/2735] 76633_CQS(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [206/2735] 76633_CS(doc): target at [7] | cited: [0, 1, 2, 6, 7]
#   [207/2735] 76633_Citations(doc): target at [7] | cited: [0, 1, 2, 7, 6]
#   [208/2735] 76633_ContentImprovement(doc): target at [7] | cited: [0, 3, 1, 4, 9]
#   [209/2735] 76633_FC(doc): target at [7] | cited: [0, 1, 2, 4, 8]
#   [210/2735] 76633_FCQ(doc): target at [6] | cited: [0, 1, 2, 6, 4]
#   [211/2735] 76633_FCQS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [212/2735] 76633_FCS(doc): target at [7] | cited: [0, 1, 2, 7]
#   [213/2735] 76633_FQ(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [214/2735] 76633_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [215/2735] 76633_FS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [216/2735] 76633_Fluency(doc): target at [6] | cited: [1, 0, 2, 3, 4]
#   [217/2735] 76633_LLMstxt(doc): target at [7] | cited: [0, 3, 1, 2, 4]
#   [218/2735] 76633_QS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [219/2735] 76633_Quotes(doc): target at [7] | cited: [0, 2, 3, 4, 5]
#   [220/2735] 76633_SimpleLanguage(doc): target at [6] | cited: [0, 1, 3, 2, 7]
#   [221/2735] 76633_Statistics(doc): target at [7] | cited: [0, 1, 3, 7, 5]
#   [222/2735] 76633_UniqueWords(doc): target at [7] | cited: [0, 3, 1, 4, 2]
#   [223/2735] 76633_doc: target at [5] | cited: [0, 1, 2, 6, 4]
#   [224/2735] 76803_Authoritative(doc): target at [9] | cited: [0, 1, 2, 5, 8]
#   [225/2735] 76803_CQ(doc): target at [9] | cited: [0, 1, 4, 8]
#   [226/2735] 76803_CQS(doc): target at [9] | cited: [0, 1, 9, 5, 7]
#   [227/2735] 76803_CS(doc): target at [9] | cited: [0, 9, 2, 6, 5]
#   [228/2735] 76803_Citations(doc): target at [9] | cited: [0, 1, 4, 2, 8]
#   [229/2735] 76803_ContentImprovement(doc): target at [9] | cited: [0, 9, 1, 2, 3]
#   [230/2735] 76803_FC(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [231/2735] 76803_FCQ(doc): target at [9] | cited: [0, 1, 4, 2, 6]
#   [232/2735] 76803_FCQS(doc): target at [9] | cited: [0, 2, 1, 3]
#   [233/2735] 76803_FCS(doc): target at [9] | cited: [0, 2, 1, 3, 7]
#   [234/2735] 76803_FQ(doc): target at [9] | cited: [0, 1, 2, 4]
#   [235/2735] 76803_FQS(doc): target at [9] | cited: [0, 1, 4, 3, 5]
#   [236/2735] 76803_FS(doc): target at [9] | cited: [0, 2, 1, 3, 4]
#   [237/2735] 76803_Fluency(doc): target at [9] | cited: [0, 2, 1, 9, 4]
#   [238/2735] 76803_LLMstxt(doc): target at [9] | cited: [0, 5, 1, 3, 4]
#   [239/2735] 76803_QS(doc): target at [9] | cited: [0, 2, 5, 1, 3]
#   [240/2735] 76803_Quotes(doc): target at [9] | cited: [0, 2, 5, 1, 3]
#   [241/2735] 76803_SimpleLanguage(doc): target at [9] | cited: [0, 1, 9, 4, 2]
#   [242/2735] 76803_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [243/2735] 76803_TechnicalTerms(doc): target at [9] | cited: [0, 1, 9, 4, 6]
#   [244/2735] 76803_UniqueWords(doc): target at [9] | cited: [0, 1, 9, 2, 4]
#   [245/2735] 76803_doc: target at [9] | cited: [0, 1, 4, 8]
#   [246/2735] 77193_Authoritative(doc): target at [5] | cited: [0, 1, 2, 3, 6]
#   [247/2735] 77193_CQ(doc): target at [5] | cited: [0, 1, 3, 8, 2]
#   [248/2735] 77193_CQS(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [249/2735] 77193_CS(doc): target at [5] | cited: [0, 1, 2, 4]
#   [250/2735] 77193_Citations(doc): target at [0] | cited: [0, 2, 1, 4, 7]
#   [251/2735] 77193_ContentImprovement(doc): target at [1] | cited: [0, 2, 3, 6, 4]
#   [252/2735] 77193_FC(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [253/2735] 77193_FCQ(doc): target at [5] | cited: [0, 2, 1, 5, 7]
#   [254/2735] 77193_FCQS(doc): target at [5] | cited: [0, 7, 2, 4, 1]
#   [255/2735] 77193_FCS(doc): target at [5] | cited: [0, 2, 3, 1, 7]
#   [256/2735] 77193_FQ(doc): target at [5] | cited: [0, 1, 3, 6, 9]
#   [257/2735] 77193_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [258/2735] 77193_FS(doc): target at [4] | cited: [0, 3, 1, 2, 5]
#   [259/2735] 77193_Fluency(doc): target at [4] | cited: [0, 2, 3, 9, 1]
#   [260/2735] 77193_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 9]
#   [261/2735] 77193_QS(doc): target at [5] | cited: [0, 2, 1, 7, 4]
#   [262/2735] 77193_Quotes(doc): target at [5] | cited: [0, 1, 2, 9]
#   [263/2735] 77193_SimpleLanguage(doc): target at [2] | cited: [0, 3, 1, 4, 5]
#   [264/2735] 77193_Statistics(doc): target at [7] | cited: [0, 1, 6, 2, 4]
#   [265/2735] 77193_TechnicalTerms(doc): target at [4] | cited: [0, 3, 1, 2, 8]
#   [266/2735] 77193_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [267/2735] 77193_doc: target at [1] | cited: [0, 2, 9]
#   [268/2735] 77354_Authoritative(doc): target at [2] | cited: [0, 2, 3, 1, 4]
#   [269/2735] 77354_CQ(doc): target at [1] | cited: [0, 2, 1, 3, 4]
#   [270/2735] 77354_CQS(doc): target at [0] | cited: [0, 1, 5, 3, 4]
#   [271/2735] 77354_CS(doc): target at [1] | cited: [1, 2, 5, 0, 3]
#   [272/2735] 77354_Citations(doc): target at [2] | cited: [0, 2, 3, 4, 5]
#   [273/2735] 77354_ContentImprovement(doc): target at [0] | cited: [0, 2, 5, 1, 3]
#   [274/2735] 77354_FC(doc): target at [0] | cited: [0, 1, 4, 2, 3]
#   [275/2735] 77354_FCQ(doc): target at [3] | cited: [0, 5, 6, 1, 3]
#   [276/2735] 77354_FCQS(doc): target at [2] | cited: [0, 2, 3, 1, 4]
#   [277/2735] 77354_FCS(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [278/2735] 77354_FQ(doc): target at [3] | cited: [0, 1, 3, 5, 4]
#   [279/2735] 77354_FQS(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [280/2735] 77354_FS(doc): target at [0] | cited: [0, 3, 1, 5, 4]
#   [281/2735] 77354_Fluency(doc): target at [3] | cited: [0, 3, 4, 1, 2]
#   [282/2735] 77354_LLMstxt(doc): target at [0] | cited: [0, 3, 4, 2, 6]
#   [283/2735] 77354_QS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [284/2735] 77354_Quotes(doc): target at [0] | cited: [0, 3, 1, 2, 5]
#   [285/2735] 77354_SimpleLanguage(doc): target at [3] | cited: [1, 3, 4, 0, 2]
#   [286/2735] 77354_Statistics(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [287/2735] 77354_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [288/2735] 77354_UniqueWords(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [289/2735] 77354_doc: target at [3] | cited: [0, 2, 4, 1, 5]
#   [290/2735] 7760_Authoritative(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [291/2735] 7760_CQ(doc): target at [4] | cited: [0, 3, 2, 1, 4]
#   [292/2735] 7760_CQS(doc): target at [4] | cited: [0, 2, 1, 3, 4]
#   [293/2735] 7760_CS(doc): target at [4] | cited: [0, 2, 3, 1, 7]
#   [294/2735] 7760_Citations(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [295/2735] 7760_ContentImprovement(doc): target at [0] | cited: [0, 1, 4, 3, 5]
#   [296/2735] 7760_FC(doc): target at [3] | cited: [0, 2, 4, 1, 3]
#   [297/2735] 7760_FCQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [298/2735] 7760_FCQS(doc): target at [0] | cited: [0, 1, 4, 2, 3]
#   [299/2735] 7760_FCS(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [300/2735] 7760_FQ(doc): target at [0] | cited: [0, 1, 2, 4, 3]
#   [301/2735] 7760_FQS(doc): target at [5] | cited: []
#   [302/2735] 7760_FS(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [303/2735] 7760_Fluency(doc): target at [2] | cited: [0, 1, 3, 4, 2]
#   [304/2735] 7760_LLMstxt(doc): target at [2] | cited: [0, 1, 3, 4, 2]
#   [305/2735] 7760_QS(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [306/2735] 7760_Quotes(doc): target at [4] | cited: [0, 1, 2, 6, 8]
#   [307/2735] 7760_SimpleLanguage(doc): target at [1] | cited: [0, 1, 3, 7, 6]
#   [308/2735] 7760_Statistics(doc): target at [5] | cited: [0, 2, 1, 3, 4]
#   [309/2735] 7760_TechnicalTerms(doc): target at [1] | cited: [3, 4, 0, 1, 5]
#   [310/2735] 7760_UniqueWords(doc): target at [2] | cited: [0, 1, 3, 4, 2]
#   [311/2735] 7760_doc: target at [1] | cited: [0, 3, 1, 2, 4]
#   [312/2735] 77767_Authoritative(doc): target at [3] | cited: [0, 1, 3]
#   [313/2735] 77767_CQ(doc): target at [3] | cited: [0, 3, 1]
#   [314/2735] 77767_CQS(doc): target at [3] | cited: [0, 1, 4, 3]
#   [315/2735] 77767_CS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [316/2735] 77767_Citations(doc): target at [2] | cited: [0, 1, 4, 2, 3]
#   [317/2735] 77767_ContentImprovement(doc): target at [2] | cited: [0, 1, 5, 2, 6]
#   [318/2735] 77767_FC(doc): target at [2] | cited: [0, 2, 1, 3, 9]
#   [319/2735] 77767_FCQ(doc): target at [2] | cited: [0, 1, 3, 5, 2]
#   [320/2735] 77767_FCQS(doc): target at [2] | cited: [0, 1, 2, 4]
#   [321/2735] 77767_FCS(doc): target at [3] | cited: [0, 1, 4, 3, 9]
#   [322/2735] 77767_FQ(doc): target at [2] | cited: [0, 1, 2, 4, 5]
#   [323/2735] 77767_FQS(doc): target at [2] | cited: [0, 1, 2, 3]
#   [324/2735] 77767_FS(doc): target at [2] | cited: [0, 1, 2]
#   [325/2735] 77767_Fluency(doc): target at [2] | cited: [0, 1, 4, 2, 5]
#   [326/2735] 77767_LLMstxt(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [327/2735] 77767_QS(doc): target at [2] | cited: [0, 1, 2, 3]
#   [328/2735] 77767_Quotes(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [329/2735] 77767_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [330/2735] 77767_Statistics(doc): target at [2] | cited: [0, 1, 2]
#   [331/2735] 77767_TechnicalTerms(doc): target at [2] | cited: [0, 1, 3, 4, 2]
#   [332/2735] 77767_UniqueWords(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [333/2735] 77767_doc: target at [2] | cited: [0, 1, 2, 3]
#   [334/2735] 77938_Authoritative(doc): target at [5] | cited: []
#   [335/2735] 77938_CQ(doc): target at [5] | cited: [1, 3, 5, 4]
#   [336/2735] 77938_CQS(doc): target at [5] | cited: []
#   [337/2735] 77938_CS(doc): target at [5] | cited: []
#   [338/2735] 77938_Citations(doc): target at [5] | cited: []
#   [339/2735] 77938_ContentImprovement(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 192869, Requested 8314. Please try again in 354ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [339/2735] 77938_ContentImprovement(doc): done (retry OK)
#   [340/2735] 77938_FC(doc): target at [5] | cited: [0, 3]
#   [341/2735] 77938_FCQ(doc): target at [5] | cited: [0, 4]
#   [342/2735] 77938_FCQS(doc): target at [5] | cited: [1, 2, 3, 4]
#   [343/2735] 77938_FCS(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [344/2735] 77938_FQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [345/2735] 77938_FQS(doc): target at [5] | cited: [1, 5]
#   [346/2735] 77938_FS(doc): target at [5] | cited: []
#   [347/2735] 77938_Fluency(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 192042, Requested 8236. Please try again in 83ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [347/2735] 77938_Fluency(doc): done (retry OK)
#   [348/2735] 77938_LLMstxt(doc): target at [8] | cited: [1, 2]
#   [349/2735] 77938_QS(doc): target at [5] | cited: []
#   [350/2735] 77938_Quotes(doc): target at [5] | cited: []
#   [351/2735] 77938_SimpleLanguage(doc): target at [6] | cited: []
#   [352/2735] 77938_Statistics(doc): target at [1] | cited: [0, 1, 2]
#   [353/2735] 77938_TechnicalTerms(doc): target at [5] | cited: [8, 5]
#   [354/2735] 77938_UniqueWords(doc): target at [2] | cited: []
#   [355/2735] 77938_doc: target at [5] | cited: []
#   [356/2735] 77969_Authoritative(doc): target at [0] | cited: [0, 1, 2]
#   [357/2735] 77969_CQ(doc): target at [0] | cited: [0, 1, 2]
#   [358/2735] 77969_CQS(doc): target at [1] | cited: [0, 1, 2, 3]
#   [359/2735] 77969_CS(doc): target at [2] | cited: [0, 2, 3, 1]
#   [360/2735] 77969_Citations(doc): target at [0] | cited: [0, 1, 2, 3]
#   [361/2735] 77969_ContentImprovement(doc): target at [0] | cited: [0, 1, 2, 3]
#   [362/2735] 77969_FC(doc): target at [0] | cited: [0, 1, 2, 3]
#   [363/2735] 77969_FCQ(doc): target at [2] | cited: [0, 2, 3, 1]
#   [364/2735] 77969_FCQS(doc): target at [1] | cited: [0, 1, 2, 3]
#   [365/2735] 77969_FCS(doc): target at [0] | cited: [0, 1, 2]
#   [366/2735] 77969_FQ(doc): target at [0] | cited: [0, 1, 2]
#   [367/2735] 77969_FQS(doc): target at [0] | cited: [0, 2, 1, 3]
#   [368/2735] 77969_FS(doc): target at [3] | cited: [0, 1, 2, 3]
#   [369/2735] 77969_Fluency(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [370/2735] 77969_LLMstxt(doc): target at [0] | cited: [0, 1, 2]
#   [371/2735] 77969_QS(doc): target at [0] | cited: [0, 1, 2, 3]
#   [372/2735] 77969_Quotes(doc): target at [0] | cited: [0, 1, 2, 3]
#   [373/2735] 77969_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3]
#   [374/2735] 77969_Statistics(doc): target at [0] | cited: [0, 1, 2, 3]
#   [375/2735] 77969_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 3]
#   [376/2735] 77969_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 3]
#   [377/2735] 77969_doc: target at [0] | cited: [0, 1, 2, 3]
#   [378/2735] 78144_Authoritative(doc): target at [4] | cited: [0]
#   [379/2735] 78144_CQ(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [380/2735] 78144_CQS(doc): target at [2] | cited: [0, 1]
#   [381/2735] 78144_CS(doc): target at [2] | cited: [1, 0]
#   [382/2735] 78144_Citations(doc): target at [2] | cited: [0, 1]
#   [383/2735] 78144_ContentImprovement(doc): target at [3] | cited: [0, 1]
#   [384/2735] 78144_FC(doc): target at [3] | cited: [0, 1, 8]
#   [385/2735] 78144_FCQ(doc): target at [6] | cited: [0, 1, 2]
#   [386/2735] 78144_FCQS(doc): target at [6] | cited: [0, 1, 2, 9]
#   [387/2735] 78144_FCS(doc): target at [6] | cited: [0, 1, 7, 2]
#   [388/2735] 78144_FQ(doc): target at [5] | cited: [0]
#   [389/2735] 78144_FQS(doc): target at [5] | cited: [0]
#   [390/2735] 78144_FS(doc): target at [2] | cited: [0, 1, 2, 3]
#   [391/2735] 78144_Fluency(doc): target at [2] | cited: [0, 1]
#   [392/2735] 78144_LLMstxt(doc): target at [6] | cited: [0, 1]
#   [393/2735] 78144_QS(doc): target at [3] | cited: [0, 1]
#   [394/2735] 78144_Quotes(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 200000, Requested 9277. Please try again in 2.783s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [394/2735] 78144_Quotes(doc): done (retry OK)
#   [395/2735] 78144_SimpleLanguage(doc): target at [2] | cited: [0]
#   [396/2735] 78144_Statistics(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 200000, Requested 9407. Please try again in 2.822s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [396/2735] 78144_Statistics(doc): done (retry OK)
#   [397/2735] 78144_TechnicalTerms(doc): target at [3] | cited: [0, 5, 1]
#   [398/2735] 78144_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 3]
#   [399/2735] 78144_doc: target at [4] | cited: [0, 6, 1]
#   [400/2735] 78145_Authoritative(doc): target at [9] | cited: [0]
#   [401/2735] 78145_CQ(doc): target at [3] | cited: [0, 1, 5]
#   [402/2735] 78145_CQS(doc): target at [9] | cited: [0]
#   [403/2735] 78145_CS(doc): target at [9] | cited: [0]
#   [404/2735] 78145_Citations(doc): target at [9] | cited: [0]
#   [405/2735] 78145_ContentImprovement(doc): target at [9] | cited: [0]
#   [406/2735] 78145_FC(doc): target at [9] | cited: [0]
#   [407/2735] 78145_FCQ(doc): target at [9] | cited: [0, 4, 3, 5]
#   [408/2735] 78145_FCQS(doc): target at [9] | cited: [0, 1]
#   [409/2735] 78145_FCS(doc): target at [8] | cited: [0]
#   [410/2735] 78145_FQ(doc): target at [9] | cited: [0]
#   [411/2735] 78145_FQS(doc): target at [3] | cited: [0]
#   [412/2735] 78145_FS(doc): target at [9] | cited: [0]
#   [413/2735] 78145_Fluency(doc): target at [4] | cited: [0]
#   [414/2735] 78145_LLMstxt(doc): target at [9] | cited: [0]
#   [415/2735] 78145_QS(doc): target at [9] | cited: [0]
#   [416/2735] 78145_Quotes(doc): target at [4] | cited: [0]
#   [417/2735] 78145_SimpleLanguage(doc): target at [9] | cited: [0]
#   [418/2735] 78145_Statistics(doc): target at [3] | cited: [0]
#   [419/2735] 78145_TechnicalTerms(doc): target at [9] | cited: [0]
#   [420/2735] 78145_UniqueWords(doc): target at [3] | cited: [0]
#   [421/2735] 78145_doc: target at [9] | cited: [0]
#   [422/2735] 78146_Authoritative(doc): target at [6] | cited: [1, 3, 4, 5, 8]
#   [423/2735] 78146_CQ(doc): target at [1] | cited: [1, 2, 4, 3]
#   [424/2735] 78146_CQS(doc): target at [1] | cited: [1, 4, 0, 2, 3]
#   [425/2735] 78146_CS(doc): target at [1] | cited: [2, 5, 6, 3, 7]
#   [426/2735] 78146_Citations(doc): target at [1] | cited: [6, 1, 2, 4]
#   [427/2735] 78146_ContentImprovement(doc): target at [1] | cited: [1, 2, 6, 4, 8]
#   [428/2735] 78146_FC(doc): target at [1] | cited: [1, 3, 2, 4]
#   [429/2735] 78146_FCQ(doc): target at [5] | cited: [1, 3, 8, 5, 0]
#   [430/2735] 78146_FCQS(doc): target at [6] | cited: [0, 4, 7, 6, 8]
#   [431/2735] 78146_FCS(doc): target at [6] | cited: [6, 1, 5, 3, 2]
#   [432/2735] 78146_FQ(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 192373, Requested 8123. Please try again in 148ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [432/2735] 78146_FQ(doc): done (retry OK)
#   [433/2735] 78146_FQS(doc): target at [6] | cited: []
#   [434/2735] 78146_FS(doc): target at [6] | cited: [1, 3, 6, 5]
#   [435/2735] 78146_Fluency(doc): target at [1] | cited: [1, 4, 2]
#   [436/2735] 78146_LLMstxt(doc): target at [1] | cited: [2, 1, 6]
#   [437/2735] 78146_QS(doc): target at [1] | cited: [1, 2, 6, 3]
#   [438/2735] 78146_Quotes(doc): target at [1] | cited: [1, 6, 2, 8]
#   [439/2735] 78146_SimpleLanguage(doc): target at [0] | cited: [0, 2, 4]
#   [440/2735] 78146_Statistics(doc): target at [1] | cited: [1, 4, 2, 5, 6]
#   [441/2735] 78146_TechnicalTerms(doc): target at [1] | cited: [1, 2, 4, 0, 6]
#   [442/2735] 78146_UniqueWords(doc): target at [5] | cited: [1, 4, 8, 3, 2]
#   [443/2735] 78146_doc: target at [1] | cited: [1, 2, 3, 6, 4]
#   [444/2735] 78646_Authoritative(doc): target at [7] | cited: [0, 1, 5, 2, 3]
#   [445/2735] 78646_CQ(doc): target at [5] | cited: [0, 4, 5, 1, 2]
#   [446/2735] 78646_CQS(doc): target at [2] | cited: [0, 5, 1, 2, 3]
#   [447/2735] 78646_CS(doc): target at [7] | cited: [0, 1, 3, 6, 2]
#   [448/2735] 78646_Citations(doc): target at [2] | cited: [0, 2, 1, 3, 4]
#   [449/2735] 78646_ContentImprovement(doc): target at [4] | cited: [0, 2, 4, 1, 5]
#   [450/2735] 78646_FC(doc): target at [7] | cited: [0, 3, 6, 2, 4]
#   [451/2735] 78646_FCQ(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [452/2735] 78646_FCQS(doc): target at [3] | cited: [0, 2, 3, 4, 1]
#   [453/2735] 78646_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [454/2735] 78646_FQ(doc): target at [9] | cited: [0, 1, 3, 9, 2]
#   [455/2735] 78646_FQS(doc): target at [1] | cited: [0, 1, 5, 2, 4]
#   [456/2735] 78646_FS(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [457/2735] 78646_Fluency(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [458/2735] 78646_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [459/2735] 78646_QS(doc): target at [7] | cited: [0, 1, 4, 7, 2]
#   [460/2735] 78646_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [461/2735] 78646_SimpleLanguage(doc): target at [4] | cited: [0, 1, 3, 4, 2]
#   [462/2735] 78646_Statistics(doc): target at [9] | cited: [0, 3, 5, 1, 4]
#   [463/2735] 78646_TechnicalTerms(doc): target at [3] | cited: [0, 3, 4, 2, 8]
#   [464/2735] 78646_UniqueWords(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [465/2735] 78646_doc: target at [2] | cited: [0, 7, 1, 3, 2]
#   [466/2735] 79110_Authoritative(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [467/2735] 79110_CQ(doc): target at [2] | cited: [0, 2, 1, 3, 6]
#   [468/2735] 79110_CQS(doc): target at [0] | cited: [0, 2, 1, 3, 4]
#   [469/2735] 79110_CS(doc): target at [2] | cited: [0, 2, 1, 5, 9]
#   [470/2735] 79110_Citations(doc): target at [2] | cited: [0, 2, 1, 5, 4]
#   [471/2735] 79110_ContentImprovement(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [472/2735] 79110_FC(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [473/2735] 79110_FCQ(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [474/2735] 79110_FCQS(doc): target at [2] | cited: [0, 2, 1, 3, 6]
#   [475/2735] 79110_FCS(doc): target at [2] | cited: [1, 4, 5, 0, 2]
#   [476/2735] 79110_FQ(doc): target at [2] | cited: [0, 2, 1, 3, 5]
#   [477/2735] 79110_FQS(doc): target at [4] | cited: [0, 4, 1, 5, 2]
#   [478/2735] 79110_FS(doc): target at [3] | cited: [0, 1, 2, 6]
#   [479/2735] 79110_Fluency(doc): target at [3] | cited: [0, 1, 2, 5, 4]
#   [480/2735] 79110_LLMstxt(doc): target at [3] | cited: [0, 3, 2, 7, 4]
#   [481/2735] 79110_QS(doc): target at [3] | cited: [0, 1, 3, 2, 5]
#   [482/2735] 79110_Quotes(doc): target at [3] | cited: [0, 3, 1, 2, 6]
#   [483/2735] 79110_SimpleLanguage(doc): target at [0] | cited: [0, 2, 1, 3, 5]
#   [484/2735] 79110_Statistics(doc): target at [3] | cited: [0, 3, 1, 2, 5]
#   [485/2735] 79110_TechnicalTerms(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [486/2735] 79110_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 4, 3]
#   [487/2735] 79110_doc: target at [2] | cited: [0, 2, 1, 5, 4]
#   [488/2735] 79316_Authoritative(doc): target at [6] | cited: [0, 1, 2, 4]
#   [489/2735] 79316_CQ(doc): target at [5] | cited: [0, 1, 2, 6]
#   [490/2735] 79316_CQS(doc): target at [5] | cited: [0, 1, 2, 7, 4]
#   [491/2735] 79316_CS(doc): target at [7] | cited: [0, 1, 2, 3]
#   [492/2735] 79316_Citations(doc): target at [4] | cited: [0, 1, 2, 7, 9]
#   [493/2735] 79316_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 6, 4]
#   [494/2735] 79316_FC(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [495/2735] 79316_FCQ(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [496/2735] 79316_FCQS(doc): target at [6] | cited: [0, 1, 2, 6, 8]
#   [497/2735] 79316_FCS(doc): target at [7] | cited: [0, 1, 2]
#   [498/2735] 79316_FQ(doc): target at [7] | cited: [0, 1, 2]
#   [499/2735] 79316_FQS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [500/2735] 79316_FS(doc): target at [6] | cited: [0, 1, 2, 6, 7]
#   [501/2735] 79316_Fluency(doc): target at [6] | cited: [0, 2, 1, 3, 6]
#   [502/2735] 79316_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 6]
#   [503/2735] 79316_QS(doc): target at [6] | cited: [0, 1, 2, 6, 9]
#   [504/2735] 79316_Quotes(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [505/2735] 79316_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [506/2735] 79316_Statistics(doc): target at [7] | cited: [0, 1, 2]
#   [507/2735] 79316_TechnicalTerms(doc): target at [6] | cited: [0, 2, 1, 4, 5]
#   [508/2735] 79316_UniqueWords(doc): target at [5] | cited: [0, 1, 2, 7, 6]
#   [509/2735] 79316_doc: target at [6] | cited: [0, 1, 2, 8, 6]
#   [510/2735] 79600_Authoritative(doc): target at [8] | cited: [0, 6, 4, 8, 1]
#   [511/2735] 79600_CQ(doc): target at [3] | cited: [0, 4, 7, 3, 5]
#   [512/2735] 79600_CQS(doc): target at [3] | cited: [0, 4, 3, 5, 1]
#   [513/2735] 79600_CS(doc): target at [3] | cited: [0, 7, 3, 5, 1]
#   [514/2735] 79600_Citations(doc): target at [3] | cited: [0, 4, 7, 3, 5]
#   [515/2735] 79600_ContentImprovement(doc): target at [6] | cited: [0, 3, 7, 4, 6]
#   [516/2735] 79600_FC(doc): target at [9] | cited: [0, 3, 6, 4, 9]
#   [517/2735] 79600_FCQ(doc): target at [9] | cited: [0, 3, 6, 1, 2]
#   [518/2735] 79600_FCQS(doc): target at [6] | cited: [0, 3, 7, 4, 6]
#   [519/2735] 79600_FCS(doc): target at [6] | cited: [0, 7, 4, 6, 1]
#   [520/2735] 79600_FQ(doc): target at [9] | cited: [0, 3, 6, 4, 9]
#   [521/2735] 79600_FQS(doc): target at [9] | cited: [0, 3, 6, 4, 9]
#   [522/2735] 79600_FS(doc): target at [8] | cited: [0, 3, 6, 4, 8]
#   [523/2735] 79600_Fluency(doc): target at [9] | cited: [0, 3, 6, 4, 9]
#   [524/2735] 79600_LLMstxt(doc): target at [3] | cited: [0, 4, 7, 3, 5]
#   [525/2735] 79600_QS(doc): target at [3] | cited: [0, 4, 7, 3, 5]
#   [526/2735] 79600_Quotes(doc): target at [4] | cited: [0, 3, 7, 4, 5]
#   [527/2735] 79600_SimpleLanguage(doc): target at [3] | cited: [0, 4, 7, 3, 5]
#   [528/2735] 79600_Statistics(doc): target at [8] | cited: [0, 3, 6, 1, 4]
#   [529/2735] 79600_TechnicalTerms(doc): target at [3] | cited: [0, 4, 3, 5, 1]
#   [530/2735] 79600_UniqueWords(doc): target at [4] | cited: [0, 3, 7, 1, 2]
#   [531/2735] 79600_doc: target at [3] | cited: [0, 7, 3, 5, 1]
#   [532/2735] 79695_Authoritative(doc): target at [0] | cited: [0, 3, 5, 6, 1]
#   [533/2735] 79695_CQ(doc): target at [0] | cited: [0, 5, 3, 8, 1]
#   [534/2735] 79695_CQS(doc): target at [0] | cited: [0, 3, 8, 5, 1]
#   [535/2735] 79695_CS(doc): target at [1] | cited: [0, 1, 3, 8, 7]
#   [536/2735] 79695_Citations(doc): target at [0] | cited: [0, 3, 8, 1, 2]
#   [537/2735] 79695_ContentImprovement(doc): target at [0] | cited: [0, 3, 5, 1, 7]
#   [538/2735] 79695_FC(doc): target at [0] | cited: [0, 3, 8, 1, 2]
#   [539/2735] 79695_FCQ(doc): target at [0] | cited: [0, 3, 8, 5, 1]
#   [540/2735] 79695_FCQS(doc): target at [0] | cited: [0, 3, 8, 1, 7]
#   [541/2735] 79695_FCS(doc): target at [0] | cited: [0, 2, 8, 1, 7]
#   [542/2735] 79695_FQ(doc): target at [0] | cited: [0, 3, 8, 1, 5]
#   [543/2735] 79695_FQS(doc): target at [0] | cited: [0, 2, 8, 1, 3]
#   [544/2735] 79695_FS(doc): target at [1] | cited: [0, 1, 2, 4, 3]
#   [545/2735] 79695_Fluency(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [546/2735] 79695_LLMstxt(doc): target at [0] | cited: [0, 2, 8, 1, 7]
#   [547/2735] 79695_QS(doc): target at [1] | cited: [0, 1, 3, 8, 2]
#   [548/2735] 79695_Quotes(doc): target at [0] | cited: [0, 2, 3, 5, 1]
#   [549/2735] 79695_SimpleLanguage(doc): target at [1] | cited: [0, 1, 6, 3, 4]
#   [550/2735] 79695_Statistics(doc): target at [0] | cited: [0, 2, 1, 3, 4]
#   [551/2735] 79695_TechnicalTerms(doc): target at [0] | cited: [0, 6, 8, 1, 3]
#   [552/2735] 79695_UniqueWords(doc): target at [0] | cited: [0, 2, 5, 8, 1]
#   [553/2735] 79695_doc: target at [0] | cited: [0, 2, 5, 8, 1]
#   [554/2735] 79736_Authoritative(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [555/2735] 79736_CQ(doc): target at [8] | cited: [0, 4, 5, 7, 1]
#   [556/2735] 79736_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [557/2735] 79736_CS(doc): target at [9] | cited: [0, 1, 3, 4, 2]
#   [558/2735] 79736_Citations(doc): target at [6] | cited: [0, 2, 5, 1, 3]
#   [559/2735] 79736_ContentImprovement(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [560/2735] 79736_FC(doc): target at [5] | cited: [0, 1, 4, 2, 5]
#   [561/2735] 79736_FCQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [562/2735] 79736_FCQS(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [563/2735] 79736_FCS(doc): target at [6] | cited: []
#   [564/2735] 79736_FQ(doc): target at [5] | cited: [0, 1, 2, 4, 8]
#   [565/2735] 79736_FQS(doc): target at [5] | cited: [0, 1, 6, 4, 5]
#   [566/2735] 79736_FS(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [567/2735] 79736_Fluency(doc): target at [9] | cited: [0, 4, 9, 1, 2]
#   [568/2735] 79736_LLMstxt(doc): target at [4] | cited: [0, 4, 7, 1, 3]
#   [569/2735] 79736_QS(doc): target at [5] | cited: [0, 4, 1, 3, 7]
#   [570/2735] 79736_Quotes(doc): target at [5] | cited: [0, 4, 1, 3, 2]
#   [571/2735] 79736_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [572/2735] 79736_Statistics(doc): target at [9] | cited: [0, 1, 6, 3, 7]
#   [573/2735] 79736_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 5, 7]
#   [574/2735] 79736_UniqueWords(doc): target at [5] | cited: [0, 2, 1, 5, 4]
#   [575/2735] 79736_doc: target at [3] | cited: [0, 1, 2, 5, 3]
#   [576/2735] 8020_Authoritative(doc): target at [3] | cited: [0, 3, 1, 2, 6]
#   [577/2735] 8020_CQ(doc): target at [2] | cited: [0, 2, 3, 8, 1]
#   [578/2735] 8020_CQS(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [579/2735] 8020_CS(doc): target at [7] | cited: [0, 1, 2, 5, 8]
#   [580/2735] 8020_Citations(doc): target at [4] | cited: [1, 2, 6, 9, 0]
#   [581/2735] 8020_ContentImprovement(doc): target at [9] | cited: [0, 4, 8, 2, 3]
#   [582/2735] 8020_FC(doc): target at [2] | cited: [0, 1, 2, 3, 6]
#   [583/2735] 8020_FCQ(doc): target at [2] | cited: [1, 2, 3, 6, 4]
#   [584/2735] 8020_FCQS(doc): target at [0] | cited: [0, 1, 2, 6, 7]
#   [585/2735] 8020_FCS(doc): target at [7] | cited: [0, 1, 5, 8, 2]
#   [586/2735] 8020_FQ(doc): target at [4] | cited: [1, 3, 4, 8, 0]
#   [587/2735] 8020_FQS(doc): target at [0] | cited: [0, 3, 6, 1, 7]
#   [588/2735] 8020_FS(doc): target at [4] | cited: [0, 2, 7, 9, 4]
#   [589/2735] 8020_Fluency(doc): target at [9] | cited: [0, 5, 9, 1, 3]
#   [590/2735] 8020_LLMstxt(doc): target at [3] | cited: [1, 2, 3, 6, 0]
#   [591/2735] 8020_QS(doc): target at [7] | cited: [0, 1, 5, 2, 3]
#   [592/2735] 8020_Quotes(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [593/2735] 8020_SimpleLanguage(doc): target at [9] | cited: [0, 5, 8, 1, 2]
#   [594/2735] 8020_Statistics(doc): target at [6] | cited: [0, 1, 5, 9, 2]
#   [595/2735] 8020_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [596/2735] 8020_UniqueWords(doc): target at [9] | cited: [2, 5, 8, 3, 7]
#   [597/2735] 8020_doc: target at [9] | cited: [1, 4, 0, 2, 6]
#   [598/2735] 80415_Authoritative(doc): target at [1] | cited: [0, 1, 3, 2, 6]
#   [599/2735] 80415_CQ(doc): target at [5] | cited: [0, 2, 7, 4, 3]
#   [600/2735] 80415_CQS(doc): target at [1] | cited: [0, 1, 4, 5, 7]
#   [601/2735] 80415_CS(doc): target at [1] | cited: [0, 1, 3, 6, 2]
#   [602/2735] 80415_Citations(doc): target at [5] | cited: [0, 1, 4, 6, 2]
#   [603/2735] 80415_ContentImprovement(doc): target at [5] | cited: [0, 1, 4, 8, 2]
#   [604/2735] 80415_FC(doc): target at [6] | cited: [0, 2, 4, 7, 3]
#   [605/2735] 80415_FCQ(doc): target at [7] | cited: [0, 1, 2, 6]
#   [606/2735] 80415_FCQS(doc): target at [6] | cited: [0, 1, 2, 7, 5]
#   [607/2735] 80415_FCS(doc): target at [7] | cited: [0, 1, 4, 6, 2]
#   [608/2735] 80415_FQ(doc): target at [6] | cited: [0, 2, 4, 7, 1]
#   [609/2735] 80415_FQS(doc): target at [6] | cited: [0, 5, 1, 2, 3]
#   [610/2735] 80415_FS(doc): target at [6] | cited: [0, 1, 3, 7, 2]
#   [611/2735] 80415_Fluency(doc): target at [5] | cited: [0, 1, 3, 4, 2]
#   [612/2735] 80415_LLMstxt(doc): target at [6] | cited: [0, 1, 4, 3, 7]
#   [613/2735] 80415_QS(doc): target at [1] | cited: [0, 3, 5, 2, 6]
#   [614/2735] 80415_Quotes(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [615/2735] 80415_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [616/2735] 80415_Statistics(doc): target at [5] | cited: [0, 2, 1, 7, 3]
#   [617/2735] 80415_TechnicalTerms(doc): target at [5] | cited: [0, 1, 4, 7, 2]
#   [618/2735] 80415_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 7, 6]
#   [619/2735] 80415_doc: target at [4] | cited: [0, 2, 1, 3, 4]
#   [620/2735] 80681_Authoritative(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [621/2735] 80681_CQ(doc): target at [9] | cited: [0, 2, 3, 5, 9]
#   [622/2735] 80681_CQS(doc): target at [9] | cited: [0, 5, 8, 2, 9]
#   [623/2735] 80681_CS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [624/2735] 80681_Citations(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [625/2735] 80681_ContentImprovement(doc): target at [9] | cited: [0, 2, 5, 6, 1]
#   [626/2735] 80681_FC(doc): target at [9] | cited: [0, 2, 4, 5, 1]
#   [627/2735] 80681_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [628/2735] 80681_FCQS(doc): target at [9] | cited: [0, 2, 5, 1, 3]
#   [629/2735] 80681_FCS(doc): target at [8] | cited: [0, 5, 1, 3, 2]
#   [630/2735] 80681_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [631/2735] 80681_FQS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [632/2735] 80681_FS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [633/2735] 80681_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [634/2735] 80681_LLMstxt(doc): target at [9] | cited: [0, 2, 5, 1, 4]
#   [635/2735] 80681_QS(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [636/2735] 80681_Quotes(doc): target at [9] | cited: [0, 2, 3, 9, 1]
#   [637/2735] 80681_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [638/2735] 80681_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [639/2735] 80681_TechnicalTerms(doc): target at [9] | cited: [0, 3, 5, 1, 2]
#   [640/2735] 80681_UniqueWords(doc): target at [9] | cited: [0, 2, 3, 1, 4]
#   [641/2735] 80681_doc: target at [9] | cited: [0, 2, 4, 1, 5]
#   [642/2735] 8070_Authoritative(doc): target at [8] | cited: [0, 1, 3, 4, 2]
#   [643/2735] 8070_CQ(doc): target at [7] | cited: [2, 7, 6, 9, 5]
#   [644/2735] 8070_CQS(doc): target at [8] | cited: [0, 3, 1, 5, 9]
#   [645/2735] 8070_CS(doc): target at [8] | cited: [1, 3, 2, 8, 0]
#   [646/2735] 8070_Citations(doc): target at [8] | cited: [5, 8, 4, 2, 6]
#   [647/2735] 8070_ContentImprovement(doc): target at [9] | cited: [0, 1, 3, 5, 2]
#   [648/2735] 8070_FC(doc): target at [9] | cited: [1, 2, 9, 6, 3]
#   [649/2735] 8070_FCQ(doc): target at [7] | cited: [0, 3, 1, 2, 5]
#   [650/2735] 8070_FCQS(doc): target at [8] | cited: [7, 8, 3, 6, 5]
#   [651/2735] 8070_FCS(doc): target at [9] | cited: [0, 1, 3, 6, 2]
#   [652/2735] 8070_FQ(doc): target at [8] | cited: [0, 2, 3, 5, 1]
#   [653/2735] 8070_FQS(doc): target at [7] | cited: [0, 5, 8, 1, 6]
#   [654/2735] 8070_FS(doc): target at [8] | cited: [0, 3, 5, 8, 1]
#   [655/2735] 8070_LLMstxt(doc): target at [8] | cited: [1, 2, 8, 6, 4]
#   [656/2735] 8070_QS(doc): target at [8] | cited: [2, 8, 1, 3, 5]
#   [657/2735] 8070_Quotes(doc): target at [8] | cited: [0, 5, 9, 1, 3]
#   [658/2735] 8070_SimpleLanguage(doc): target at [8] | cited: [0, 5, 9, 3, 4]
#   [659/2735] 8070_Statistics(doc): target at [8] | cited: [0, 3, 5, 1, 2]
#   [660/2735] 8070_TechnicalTerms(doc): target at [7] | cited: [2, 7, 1, 3, 6]
#   [661/2735] 8070_UniqueWords(doc): target at [7] | cited: [1, 3, 2, 6, 9]
#   [662/2735] 8070_doc: target at [8] | cited: [0, 3, 1, 2, 5]
#   [663/2735] 8074_Authoritative(doc): target at [5] | cited: [0, 1, 5, 2, 6]
# ...
#   [2518/2735] 97155_CQ(doc): target at [8] | cited: [0, 1, 2, 6, 4]
#   [2519/2735] 97155_CQS(doc): target at [7] | cited: [0, 1, 2, 7, 8]
#   [2520/2735] 97155_CS(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [2521/2735] 97155_Citations(doc): target at [7] | cited: [0, 1, 2, 4, 8]
#   [2522/2735] 97155_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2523/2735] 97155_FC(doc): target at [8] | cited: [0, 1, 5, 2, 8]
#   [2524/2735] 97155_FCQ(doc): target at [9] | cited: [0, 1, 2, 5, 6]
#   [2525/2735] 97155_FCQS(doc): target at [8] | cited: [0, 1, 2, 8, 7]
#   [2526/2735] 97155_FCS(doc): target at [9] | cited: [0, 1, 5, 2, 3]
#   [2527/2735] 97155_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [2528/2735] 97155_FQS(doc): target at [9] | cited: [0, 1, 2, 7, 9]
#   [2529/2735] 97155_FS(doc): target at [8] | cited: [0, 1, 2, 7, 8]
#   [2530/2735] 97155_Fluency(doc): target at [8] | cited: [0, 1, 2, 4, 8]
#   [2531/2735] 97155_LLMstxt(doc): target at [9] | cited: [0, 1, 5, 6, 7]
#   [2532/2735] 97155_QS(doc): target at [7] | cited: [0, 1, 4, 2, 6]
#   [2533/2735] 97155_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 7]
#   [2534/2735] 97155_SimpleLanguage(doc): target at [8] | cited: [0, 1, 4, 2, 6]
#   [2535/2735] 97155_Statistics(doc): target at [8] | cited: [0, 1, 2, 5, 8]
#   [2536/2735] 97155_TechnicalTerms(doc): target at [8] | cited: [0, 1, 5, 7, 8]
#   [2537/2735] 97155_UniqueWords(doc): target at [7] | cited: [0, 1, 5, 2, 9]
#   [2538/2735] 97155_doc: target at [7] | cited: [0, 1, 2, 4, 7]
#   [2539/2735] 97418_Authoritative(doc): target at [8] | cited: [0, 1, 2, 5, 8]
#   [2540/2735] 97418_CQ(doc): target at [8] | cited: [0, 4, 1, 2, 3]
#   [2541/2735] 97418_CQS(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [2542/2735] 97418_CS(doc): target at [8] | cited: [0, 1, 4, 3, 2]
#   [2543/2735] 97418_Citations(doc): target at [8] | cited: [0, 1, 4, 2, 3]
#   [2544/2735] 97418_ContentImprovement(doc): target at [8] | cited: [0, 1, 4, 3, 2]
#   [2545/2735] 97418_FC(doc): target at [9] | cited: [0, 1, 2, 5, 9]
#   [2546/2735] 97418_FCQ(doc): target at [8] | cited: [0, 1, 4, 2, 3]
#   [2547/2735] 97418_FCQS(doc): target at [8] | cited: [0, 1, 4, 2, 3]
#   [2548/2735] 97418_FCS(doc): target at [8] | cited: [0, 1, 4, 2, 3]
#   [2549/2735] 97418_FQ(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2550/2735] 97418_FQS(doc): target at [9] | cited: [0, 1, 4, 2, 7]
#   [2551/2735] 97418_FS(doc): target at [9] | cited: [0, 1, 4, 2, 3]
#   [2552/2735] 97418_Fluency(doc): target at [9] | cited: [0, 1, 4, 2, 3]
#   [2553/2735] 97418_LLMstxt(doc): target at [7] | cited: [0, 1, 4, 2, 3]
#   [2554/2735] 97418_QS(doc): target at [8] | cited: [0, 1, 4, 2, 6]
#   [2555/2735] 97418_Quotes(doc): target at [8] | cited: [0, 1, 4, 3, 2]
#   [2556/2735] 97418_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 3, 6]
#   [2557/2735] 97418_Statistics(doc): target at [5] | cited: [0, 4, 1, 2, 3]
#   [2558/2735] 97418_TechnicalTerms(doc): target at [8] | cited: [0, 4, 1, 3, 8]
#   [2559/2735] 97418_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 5, 3]
#   [2560/2735] 97418_doc: target at [8] | cited: [0, 1, 2, 5, 9]
#   [2561/2735] 97429_Authoritative(doc): target at [5] | cited: [0, 5, 2, 3, 4]
#   [2562/2735] 97429_CQ(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [2563/2735] 97429_CQS(doc): target at [4] | cited: [0, 4, 1, 2, 3]
#   [2564/2735] 97429_CS(doc): target at [3] | cited: [0, 3, 1, 2, 4]
#   [2565/2735] 97429_Citations(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2566/2735] 97429_ContentImprovement(doc): target at [4] | cited: [0, 1, 3, 4, 6]
#   [2567/2735] 97429_FC(doc): target at [3] | cited: [0, 3, 2, 4, 1]
#   [2568/2735] 97429_FCQ(doc): target at [4] | cited: [4, 1, 2, 3, 7]
#   [2569/2735] 97429_FCQS(doc): target at [0] | cited: [0, 1, 2, 4, 6]
#   [2570/2735] 97429_FCS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [2571/2735] 97429_FQ(doc): target at [4] | cited: [0, 4, 1, 2, 3]
#   [2572/2735] 97429_FQS(doc): target at [4] | cited: [0, 1, 3, 2, 6]
#   [2573/2735] 97429_FS(doc): target at [0] | cited: [0, 1, 3, 2, 4]
#   [2574/2735] 97429_Fluency(doc): target at [4] | cited: [0, 4, 1, 2, 3]
#   [2575/2735] 97429_LLMstxt(doc): target at [6] | cited: [0, 6, 1, 2, 3]
#   [2576/2735] 97429_QS(doc): target at [0] | cited: [0, 1, 2, 4, 3]
#   [2577/2735] 97429_Quotes(doc): target at [4] | cited: [0, 4, 1, 3, 6]
#   [2578/2735] 97429_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2579/2735] 97429_Statistics(doc): target at [7] | cited: [0, 1, 5, 7, 3]
#   [2580/2735] 97429_TechnicalTerms(doc): target at [2] | cited: [0, 2, 1, 3, 4]
#   [2581/2735] 97429_UniqueWords(doc): target at [3] | cited: [0, 2, 3, 5, 1]
#   [2582/2735] 97429_doc: target at [5] | cited: [0, 5, 4, 2, 3]
#   [2583/2735] 97457_Authoritative(doc): target at [6] | cited: [0, 1, 2, 5, 3]
#   [2584/2735] 97457_CQ(doc): target at [5] | cited: [0, 1, 2, 6, 7]
#   [2585/2735] 97457_CQS(doc): target at [3] | cited: [0, 1, 2, 6, 7]
#   [2586/2735] 97457_Citations(doc): target at [4] | cited: [0, 2, 6, 1, 3]
#   [2587/2735] 97457_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 6, 3]
#   [2588/2735] 97457_FC(doc): target at [4] | cited: [0, 1, 2, 6, 7]
#   [2589/2735] 97457_FCQ(doc): target at [4] | cited: [0, 1, 2, 6, 7]
#   [2590/2735] 97457_FCQS(doc): target at [4] | cited: [0, 1, 2, 6, 7]
#   [2591/2735] 97457_FCS(doc): target at [4] | cited: [0, 2, 6, 1, 3]
#   [2592/2735] 97457_FQ(doc): target at [4] | cited: [0, 1, 2, 6, 7]
#   [2593/2735] 97457_FQS(doc): target at [4] | cited: [0, 1, 2, 6, 7]
#   [2594/2735] 97457_FS(doc): target at [4] | cited: [0, 1, 2, 6, 3]
#   [2595/2735] 97457_Fluency(doc): target at [3] | cited: [0, 1, 2, 6, 7]
#   [2596/2735] 97457_LLMstxt(doc): target at [3] | cited: [0, 2, 6, 1, 4]
#   [2597/2735] 97457_QS(doc): target at [6] | cited: [0, 1, 2, 5, 7]
#   [2598/2735] 97457_Quotes(doc): target at [6] | cited: [0, 2, 5, 1, 3]
#   [2599/2735] 97457_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 6, 7]
#   [2600/2735] 97457_Statistics(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [2601/2735] 97457_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 6, 4]
#   [2602/2735] 97457_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 6, 7]
#   [2603/2735] 97457_doc: target at [4] | cited: [0, 1, 2, 6]
#   [2604/2735] 97522_Authoritative(doc): target at [8] | cited: [1, 7, 6, 8, 5]
#   [2605/2735] 97522_CQ(doc): target at [8] | cited: [1, 7, 6, 2, 3]
#   [2606/2735] 97522_CQS(doc): target at [8] | cited: [1, 2, 3, 7, 6]
#   [2607/2735] 97522_CS(doc): target at [8] | cited: [1, 4, 3, 2, 7]
#   [2608/2735] 97522_Citations(doc): target at [7] | cited: [1, 2, 6, 7, 8]
#   [2609/2735] 97522_ContentImprovement(doc): target at [7] | cited: [1, 2, 7, 3, 6]
#   [2610/2735] 97522_FC(doc): target at [6] | cited: [1, 6, 8, 2, 3]
#   [2611/2735] 97522_FCQ(doc): target at [6] | cited: [1, 4, 2, 3, 7]
#   [2612/2735] 97522_FCQS(doc): target at [7] | cited: [1, 7, 4, 8]
#   [2613/2735] 97522_FCS(doc): target at [6] | cited: [1, 2, 6, 8, 4]
#   [2614/2735] 97522_FQ(doc): target at [6] | cited: [1, 6, 8, 9, 3]
#   [2615/2735] 97522_FQS(doc): target at [9] | cited: [1, 2, 3, 7, 4]
#   [2616/2735] 97522_FS(doc): target at [6] | cited: [1, 6, 2, 3, 8]
#   [2617/2735] 97522_Fluency(doc): target at [9] | cited: [1, 2, 7, 5, 9]
#   [2618/2735] 97522_LLMstxt(doc): target at [3] | cited: [1, 2, 4, 8, 9]
#   [2619/2735] 97522_QS(doc): target at [7] | cited: [1, 7, 9, 4, 6]
#   [2620/2735] 97522_Quotes(doc): target at [9] | cited: [1, 2, 3, 7, 5]
#   [2621/2735] 97522_SimpleLanguage(doc): target at [8] | cited: [1, 8, 3, 2, 6]
#   [2622/2735] 97522_Statistics(doc): target at [6] | cited: [1, 2, 3, 6, 8]
#   [2623/2735] 97522_TechnicalTerms(doc): target at [7] | cited: [1, 6, 7, 4, 9]
#   [2624/2735] 97522_UniqueWords(doc): target at [8] | cited: [1, 4, 6, 3, 8]
#   [2625/2735] 97522_doc: target at [8] | cited: [1, 2, 7]
#   [2626/2735] 97572_Authoritative(doc): target at [1] | cited: [1, 2, 3, 4, 5]
#   [2627/2735] 97572_CQ(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [2628/2735] 97572_CQS(doc): target at [4] | cited: [0, 2, 3, 4, 5]
#   [2629/2735] 97572_CS(doc): target at [2] | cited: [2, 3, 0, 4]
#   [2630/2735] 97572_Citations(doc): target at [1] | cited: [0, 3, 6]
#   [2631/2735] 97572_ContentImprovement(doc): target at [6] | cited: [0, 2, 5, 7, 9]
#   [2632/2735] 97572_FC(doc): target at [3] | cited: [2, 1, 0]
#   [2633/2735] 97572_FCQ(doc): target at [2] | cited: [1, 3, 4, 5, 9]
#   [2634/2735] 97572_FCQS(doc): target at [2] | cited: [0, 3, 1, 4]
#   [2635/2735] 97572_FCS(doc): target at [1] | cited: [0, 1, 4, 5, 6]
#   [2636/2735] 97572_FQ(doc): target at [3] | cited: [2, 3, 1, 4, 5]
#   [2637/2735] 97572_FQS(doc): target at [3] | cited: [0, 2, 4, 6, 3]
#   [2638/2735] 97572_FS(doc): target at [3] | cited: [1, 2, 4]
#   [2639/2735] 97572_Fluency(doc): target at [3] | cited: [2, 3, 4, 5, 0]
#   [2640/2735] 97572_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2641/2735] 97572_QS(doc): target at [1] | cited: [3, 1, 2, 4, 5]
#   [2642/2735] 97572_Quotes(doc): target at [1] | cited: [0, 4, 2, 3, 5]
#   [2643/2735] 97572_SimpleLanguage(doc): target at [2] | cited: [0, 3, 1, 2, 5]
#   [2644/2735] 97572_Statistics(doc): target at [1] | cited: [0, 2, 4, 3, 5]
#   [2645/2735] 97572_TechnicalTerms(doc): target at [1] | cited: [0, 3, 1, 2, 5]
#   [2646/2735] 97572_UniqueWords(doc): target at [1] | cited: [0, 1, 3, 4, 2]
#   [2647/2735] 97572_doc: target at [1] | cited: [0, 2, 3, 1, 4]
#   [2648/2735] 97593_Authoritative(doc): target at [7] | cited: [0, 1, 5, 3, 7]
#   [2649/2735] 97593_CQ(doc): target at [9] | cited: [0, 1, 5, 3, 7]
#   [2650/2735] 97593_CQS(doc): target at [9] | cited: [0, 1, 6, 3, 9]
#   [2651/2735] 97593_CS(doc): target at [8] | cited: [0, 1, 5, 3, 7]
#   [2652/2735] 97593_Citations(doc): target at [9] | cited: [0, 1, 5, 3, 7]
#   [2653/2735] 97593_ContentImprovement(doc): target at [8] | cited: [0, 1, 5, 3, 7]
#   [2654/2735] 97593_FC(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [2655/2735] 97593_FCQ(doc): target at [8] | cited: [0, 1, 5, 3, 7]
#   [2656/2735] 97593_FCQS(doc): target at [3] | cited: [0, 1, 6, 3, 4]
#   [2657/2735] 97593_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [2658/2735] 97593_FQ(doc): target at [9] | cited: [0, 1, 3]
#   [2659/2735] 97593_FQS(doc): target at [9] | cited: [0, 1, 6, 8, 9]
#   [2660/2735] 97593_FS(doc): target at [9] | cited: [0, 1, 5, 7, 4]
#   [2661/2735] 97593_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [2662/2735] 97593_LLMstxt(doc): target at [5] | cited: [0, 1, 7, 8, 4]
#   [2663/2735] 97593_QS(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [2664/2735] 97593_Quotes(doc): target at [9] | cited: [0, 1, 5, 7, 4]
#   [2665/2735] 97593_SimpleLanguage(doc): target at [9] | cited: [0, 1, 5, 7, 3]
#   [2666/2735] 97593_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 8]
#   [2667/2735] 97593_TechnicalTerms(doc): target at [8] | cited: [0, 1, 5, 7, 3]
#   [2668/2735] 97593_UniqueWords(doc): target at [8] | cited: [0, 1, 5, 7, 3]
#   [2669/2735] 97593_doc: target at [7] | cited: [0, 1, 5, 3, 9]
#   [2670/2735] 97601_Authoritative(doc): target at [2] | cited: [0, 3, 2, 6, 4]
#   [2671/2735] 97601_CQ(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [2672/2735] 97601_CQS(doc): target at [3] | cited: [0, 3, 1, 2, 4]
#   [2673/2735] 97601_CS(doc): target at [1] | cited: [0, 1, 6, 4]
#   [2674/2735] 97601_Citations(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [2675/2735] 97601_ContentImprovement(doc): target at [1] | cited: [0, 1, 9, 3, 6]
#   [2676/2735] 97601_FC(doc): target at [2] | cited: [0, 1, 2, 3, 6]
#   [2677/2735] 97601_FCQ(doc): target at [0] | cited: [0, 1, 3, 6, 9]
#   [2678/2735] 97601_FCQS(doc): target at [0] | cited: [0, 1, 2, 3, 6]
#   [2679/2735] 97601_FCS(doc): target at [2] | cited: [0, 2, 1, 3, 6]
#   [2680/2735] 97601_FQ(doc): target at [1] | cited: [0, 1, 3, 6, 4]
#   [2681/2735] 97601_FQS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2682/2735] 97601_FS(doc): target at [2] | cited: [0, 1, 2, 4, 3]
#   [2683/2735] 97601_Fluency(doc): target at [0] | cited: [0, 1, 9, 3, 6]
#   [2684/2735] 97601_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 4, 3]
#   [2685/2735] 97601_QS(doc): target at [1] | cited: [0, 1, 2, 3, 6]
#   [2686/2735] 97601_Quotes(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [2687/2735] 97601_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [2688/2735] 97601_Statistics(doc): target at [1] | cited: [0, 3, 1, 4, 6]
#   [2689/2735] 97601_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 3, 6]
#   [2690/2735] 97601_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [2691/2735] 97601_doc: target at [1] | cited: [0, 1, 3, 6, 9]
#   [2692/2735] 98244_Authoritative(doc): target at [4] | cited: [0, 1, 2, 5, 3]
#   [2693/2735] 98244_CQ(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [2694/2735] 98244_CQS(doc): target at [4] | cited: [0, 1, 3, 5]
#   [2695/2735] 98244_CS(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [2696/2735] 98244_Citations(doc): target at [4] | cited: [0, 2, 1, 3, 5]
#   [2697/2735] 98244_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2698/2735] 98244_FC(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2699/2735] 98244_FCQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [2700/2735] 98244_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2701/2735] 98244_FCS(doc): target at [8] | cited: [0, 1, 3, 5, 7]
#   [2702/2735] 98244_FQ(doc): target at [8] | cited: []
#   [2703/2735] 98244_FQS(doc): target at [8] | cited: [0, 8, 1, 2, 4]
#   [2704/2735] 98244_FS(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [2705/2735] 98244_Fluency(doc): target at [5] | cited: [0, 1, 2, 3, 6]
#   [2706/2735] 98244_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2707/2735] 98244_QS(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [2708/2735] 98244_Quotes(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [2709/2735] 98244_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2710/2735] 98244_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [2711/2735] 98244_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 5, 6]
#   [2712/2735] 98244_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [2713/2735] 98244_doc: target at [4] | cited: [0, 1, 2, 3, 5]
#   [2714/2735] 98676_Authoritative(doc): target at [8] | cited: [0, 2, 1]
#   [2715/2735] 98676_CQ(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2716/2735] 98676_CQS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2717/2735] 98676_CS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2718/2735] 98676_Citations(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2719/2735] 98676_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2720/2735] 98676_FC(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2721/2735] 98676_FCQ(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2722/2735] 98676_FCQS(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2723/2735] 98676_FCS(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2724/2735] 98676_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2725/2735] 98676_FQS(doc): target at [8] | cited: [2, 3, 1, 0, 4]
#   [2726/2735] 98676_FS(doc): target at [8] | cited: [0, 1, 2, 6, 8]
#   [2727/2735] 98676_Fluency(doc): target at [8] | cited: [2, 3, 1, 4, 6]
#   [2728/2735] 98676_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 4, 6]
#   [2729/2735] 98676_QS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2730/2735] 98676_Quotes(doc): target at [8] | cited: [2, 3, 0, 1, 4]
#   [2731/2735] 98676_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2732/2735] 98676_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 6]
#   [2733/2735] 98676_TechnicalTerms(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2734/2735] 98676_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2735/2735] 98676_doc: target at [8] | cited: []
# ============================================================
# GENERATION COMPLETE
# Started:    12:51:13
# Finished:   22:08:54
# Total time: 9:17:41
# Results:    2735 rows saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation_results_D.parquet

# %% [markdown]
# ## Inspect Results

# %%
df_results = pd.read_parquet(output_path)

INSPECT_QUERY_ID = df_results["query_id"].iloc[0]  # <- change to inspect other runs

row = df_results[df_results["query_id"] == INSPECT_QUERY_ID].iloc[0]

print(f"Run (query_id):    {row['query_id']}")
print(f"Original query:    {row['original_query_id']}")
print(f"Method:            {row['method']}")
print(f"Query:             {row['query']}")
print(f"Num docs:          {row['num_docs']}")
print(f"Target position:   {row['target_new_position']} (0-based)")
print(f"Citation order:    {row['citation_order']}")
print(f"Target cited:      {'YES' if row['target_new_position'] in row['citation_order'] else 'NO'}")
print(f"\n--- LLM Response ---")
print(row["llm_response"][:800])
# Out:
# Run (query_id):    74897_Quotes(doc)
# Original query:    74897
# Method:            Quotes(doc)
# Query:             nylon sunshade for cars
# Num docs:          9
# Target position:   2 (0-based)
# Citation order:    [0 4 2 3 5 8]
# Target cited:      YES
#
# --- LLM Response ---
# For those seeking a nylon sunshade for cars, there are several excellent options available that not only block sunlight but also protect your vehicle's interior from UV damage.
#
# 1. **Big Hippo Front Car Sun Shade**: This sunshade is made of high-quality polyamide nylon and is known for its durability and effectiveness in blocking 99% of UV rays. It measures 63.3 x 35 inches and is suitable for a variety of vehicles, including SUVs, trucks, and vans. The shade is easy to use, folds into a compact pouch, and provides effective cooling for your vehicle's interior by significantly reducing the temperature inside when parked under the sun [1][5].
#
# 2. **A1 Sun Shade**: Crafted from durable 210T nylon, this sun shade is designed to block harmful UV rays and heat effectively. It comes in multiple

# %% [markdown]
# ## Merge Results
#
# **Run only after all 4 notebooks (A, B, C, D) are complete.**

# %%
# Merge all 4 parquet files into one
NOTEBOOK_IDS = ["A", "B", "C", "D"]
dfs = []
for nb in NOTEBOOK_IDS:
    path = os.path.join(data_dir, f"generation_results_{nb}.parquet")
    if os.path.exists(path):
        dfs.append(pd.read_parquet(path))
        print(f"Loaded generation_results_{nb}.parquet ({len(dfs[-1])} rows)")
    else:
        print(f"WARNING: generation_results_{nb}.parquet not found — skipping")

merged = pd.concat(dfs, ignore_index=True)
merged_path = os.path.join(data_dir, "generation_results.parquet")
merged.to_parquet(merged_path, index=False)
print(f"\nMerged {len(merged)} rows into generation_results.parquet")

# %% [markdown]
# ## Summary

# %%
df_results = pd.read_parquet(output_path)

print(f"Total runs done:  {len(df_results)}")
print(f"Total runs expected: {len(all_run_ids)}")
print(f"Remaining:        {len(all_run_ids) - len(df_results)}")
print()

# Citation rate per method
df_results["target_cited"] = df_results.apply(
    lambda row: 1 if row["target_new_position"] in row["citation_order"] else 0, axis=1
)

citation_rates = df_results.groupby("method")["target_cited"].mean().sort_values(ascending=False)
print("Citation rate per method (% runs where target was cited):")
for method, rate in citation_rates.items():
    bar = "\u2588" * int(rate * 20) + "\u2591" * (20 - int(rate * 20))
    print(f"  {method:30} [{bar}] {rate:.1%}")
