# %% [markdown]
# # Notebook 3A — Generation Stage (Range 0%–25%)
#
# Processes 0%–25% of all runs.
# Run A, B, C, D in parallel — each writes to its own parquet file.
#
# **Input:** `data/retail/retail_geo_detailed_results_v2.csv`
#
# **Output:** `data/retail/generation_results_A.parquet`
#
# ## Instructions
# 1. Run **Setup**
# 2. Run **Data Preparation**
# 3. Run **Helper Functions**
# 4. Run **Parameters** — range is set automatically
# 5. Run **Generation**
# 6. Run **Inspect Results**
# 7. Run **Summary**
# 8. After all 4 notebooks finish: run **Merge Results** in any one notebook

# %% [markdown]
# ## Setup

# %%
import json
import os
import re
import sys
import time
from datetime import datetime

import pandas as pd
import numpy as np

notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, ".."))
sys.path.insert(0, os.path.join(project_root, "src"))

from llms import OpenAIHelper

config_path = os.path.join(project_root, "config.json")
with open(config_path, "r") as f:
    config = json.load(f)
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

data_dir = os.path.join(project_root, "data", "retail")

print("Setup complete.")
print(f"Project root: {project_root}")
# Out:
# Setup complete.
# Project root: /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment

# %% [markdown]
# ## Data Preparation
#
# Load the retrieval CSV and extract `original_query_id` and `method` from `query_id`.
# Example: `50881_Fluency(doc)` → `original_query_id=50881`, `method=Fluency(doc)`

# %%
retrieval_csv_path = os.path.join(data_dir, "retail_geo_detailed_results_v2.csv")
df = pd.read_csv(retrieval_csv_path)

# Extract original_query_id and method from query_id
df["original_query_id"] = df["query_id"].str.extract(r"^(\d+)_")
df["method"]            = df["query_id"].str.extract(r"^\d+_(.+)$")

# Flag runs that have no target document — these will be skipped
target_per_run = df.groupby("query_id")["is_target"].sum()
runs_with_target    = set(target_per_run[target_per_run == 1].index)
runs_without_target = set(target_per_run[target_per_run == 0].index)

# Save runs without target to a separate file for documentation
runs_without_target_path = os.path.join(data_dir, "runs_without_target.json")
with open(runs_without_target_path, "w") as f:
    json.dump(sorted(list(runs_without_target)), f, indent=4)

print(f"Total rows:              {len(df)}")
print(f"Unique runs (query_ids): {df['query_id'].nunique()}")
print(f"Unique original queries: {df['original_query_id'].nunique()}")
print(f"Unique methods:          {df['method'].nunique()}")
print(f"Runs with target:        {len(runs_with_target)}")
print(f"Runs without target:     {len(runs_without_target)} — saved to runs_without_target.json")
print()
print("Methods found:")
for m in sorted(df['method'].unique()):
    print(f"  {m}")
# Out:
# Total rows:              109535
# Unique runs (query_ids): 10997
# Unique original queries: 500
# Unique methods:          22
# Runs with target:        10940
# Runs without target:     57 — saved to runs_without_target.json
#
# Methods found:
#   Authoritative(doc)
#   CQ(doc)
#   CQS(doc)
#   CS(doc)
#   Citations(doc)
#   ContentImprovement(doc)
#   FC(doc)
#   FCQ(doc)
#   FCQS(doc)
#   FCS(doc)
#   FQ(doc)
#   FQS(doc)
#   FS(doc)
#   Fluency(doc)
#   LLMstxt(doc)
#   QS(doc)
#   Quotes(doc)
#   SimpleLanguage(doc)
#   Statistics(doc)
#   TechnicalTerms(doc)
#   UniqueWords(doc)
#   doc

# %% [markdown]
# ## Helper Functions

# %%
DEVELOPER_PROMPT = """Your are a product recommender system for an online marketplace. Write an accurate and concise answer for the given user question, using _only_ the provided summarized web search results. The answer should be correct, high-quality, and written by an expert using an unbiased and journalistic tone. The answer should be informative, interesting, and engaging. The answer's logic and reasoning should be rigorous and defensible. Every sentence in the answer should be _immediately followed_ by an in-line citation to the search result(s). The cited search result(s) should fully support _all_ the information in the sentence. Search results need to be cited using [index]. When citing several search results, use [1][2][3] format rather than [1, 2, 3]. You can use multiple search results to respond comprehensively while avoiding irrelevant search results. Search results are not sorted."""
DOC_TYPE = "Product Description"


def build_context(group):
    """
    Takes all rows for one query_id, sorts by rank, re-numbers 1..N.
    Returns:
        docs: list of doc_text in retrieval order
        target_new_position: 0-based position of target doc after re-numbering
    """
    group = group.sort_values("rank").reset_index(drop=True)
    docs = group["doc_text"].tolist()

    # Find 0-based position of target doc
    target_new_position = None
    for i, row in group.iterrows():
        if row["is_target"] == 1:
            target_new_position = i  # 0-based
            break

    return docs, target_new_position


def build_user_prompt(query, docs):
    """
    Builds the user prompt for the LLM.
    docs: list of doc_text strings, numbered 1..N
    """
    sources = ""
    for i, doc_text in enumerate(docs, start=1):
        sources += f"[{i}] {DOC_TYPE}: {doc_text}\n\n"
    return f"Question: {query}\n\nSearch Results:\n{sources}"


def extract_citation_order(response_text):
    """
    Extracts citation indices in order of first appearance.
    0-based like Puerto: [1] in text -> index 0, [2] -> index 1, etc.
    e.g. "...product [2] is great [1][2]..." -> [1, 0]
    """
    citations = re.findall(r"\[(\d+)\]", response_text)
    seen = []
    for c in citations:
        idx = int(c) - 1  # 0-based
        if idx not in seen:
            seen.append(idx)
    return seen


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## Parameters

# %%
# LLM
LLM_NAME = "gpt-4o-mini-2024-07-18"

# Notebook ID
NOTEBOOK_ID = "A"

# Output file for this notebook
output_path = os.path.join(data_dir, "generation_results_A.parquet")

# All runs to process (only those with a target doc)
all_run_ids_full = sorted(runs_with_target)
total = len(all_run_ids_full)
start_idx = int(total * 0/100)
end_idx   = int(total * 25/100)
all_run_ids = all_run_ids_full[start_idx:end_idx]

# Check already done
if os.path.exists(output_path):
    df_done = pd.read_parquet(output_path)
    done_keys = set(df_done["query_id"].tolist())
    already_done = len(done_keys)
else:
    done_keys = set()
    already_done = 0

llm = OpenAIHelper(LLM_NAME)

remaining = len(all_run_ids) - already_done
print(f"Notebook:      {NOTEBOOK_ID}")
print(f"LLM:           {LLM_NAME}")
print(f"Range:         0%–25% ({start_idx}–{end_idx} of {total})")
print(f"Runs in range: {len(all_run_ids)}")
print(f"Already done:  {already_done}")
print(f"Remaining:     {remaining}")
print(f"Estimated time: ~{remaining * 9.5 / 3600:.1f} hours")
print(f"Estimated cost: ~${remaining * 0.0003:.2f}")
# Out:
# Notebook:      A
# LLM:           gpt-4o-mini-2024-07-18
# Range:         0%–25% (0–2735 of 10940)
# Runs in range: 2735
# Already done:  0
# Remaining:     2735
# Estimated time: ~7.2 hours
# Estimated cost: ~$0.82

# %% [markdown]
# ## Generation
#
# For each run (query_id):
# 1. Sort docs by rank and re-number 1..N
# 2. Build LLM prompt
# 3. Generate response with inline citations
# 4. Extract citation order
# 5. Save incrementally
#
# Runs without a target doc are skipped.
# Safe to interrupt and resume.

# %%
llm = OpenAIHelper(LLM_NAME)

# Load existing results if any
if os.path.exists(output_path):
    results_df = pd.read_parquet(output_path)
    results = results_df.to_dict("records")
else:
    results = []

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%H:%M:%S')}")
print(f"Total runs to process: {len(all_run_ids)}")
print()

for i, query_id in enumerate(all_run_ids):

    # Skip if already done
    if query_id in done_keys:
        continue

    # Get all rows for this run
    group = df[df["query_id"] == query_id]
    query_text         = group["query"].iloc[0]
    original_query_id  = group["original_query_id"].iloc[0]
    method             = group["method"].iloc[0]

    # Build context
    docs, target_new_position = build_context(group)

    if target_new_position is None:
        print(f"  [{i+1}] {query_id}: no target — skipping")
        continue

    # Build prompt
    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    try:
        response, _ = llm.generate(messages)
        response_text    = response.content
        citation_order   = extract_citation_order(response_text)

        results.append({
            "query_id":            query_id,
            "original_query_id":   original_query_id,
            "method":              method,
            "query":               query_text,
            "target_new_position": target_new_position,
            "num_docs":            len(docs),
            "citation_order":      citation_order,
            "llm_response":        response_text,
        })
        done_keys.add(query_id)
        pd.DataFrame(results).to_parquet(output_path, index=False)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    except Exception as e:
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: ERROR — {e}")
        time.sleep(10)
        try:
            response, _    = llm.generate(messages)
            response_text  = response.content
            citation_order = extract_citation_order(response_text)
            results.append({
                "query_id":            query_id,
                "original_query_id":   original_query_id,
                "method":              method,
                "query":               query_text,
                "target_new_position": target_new_position,
                "num_docs":            len(docs),
                "citation_order":      citation_order,
                "llm_response":        response_text,
            })
            done_keys.add(query_id)
            pd.DataFrame(results).to_parquet(output_path, index=False)
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: done (retry OK)")
        except Exception as e2:
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: FAILED — {e2}")

end_time = datetime.now()
elapsed  = end_time - start_time
print(f"{'='*60}")
print(f"GENERATION COMPLETE")
print(f"Started:    {start_time.strftime('%H:%M:%S')}")
print(f"Finished:   {end_time.strftime('%H:%M:%S')}")
print(f"Total time: {str(elapsed).split('.')[0]}")
print(f"Results:    {len(results)} rows saved to {output_path}")
# Out:
# Started at: 12:48:04
# Total runs to process: 2735
#
#   [1/2735] 100162_Authoritative(doc): target at [7] | cited: [0, 5, 9, 1, 3]
#   [2/2735] 100162_CQ(doc): target at [9] | cited: [0, 1, 5, 2, 4]
#   [3/2735] 100162_CQS(doc): target at [9] | cited: [0, 1, 2, 4, 9]
#   [4/2735] 100162_CS(doc): target at [9] | cited: [0, 5, 1, 4, 9]
#   [5/2735] 100162_Citations(doc): target at [8] | cited: [0, 1, 2, 5, 3]
#   [6/2735] 100162_ContentImprovement(doc): target at [9] | cited: [0, 5, 1, 4, 9]
#   [7/2735] 100162_FC(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [8/2735] 100162_FCQ(doc): target at [9] | cited: [0, 1, 6, 2, 4]
#   [9/2735] 100162_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [10/2735] 100162_FCS(doc): target at [9] | cited: [0, 5, 1, 2, 4]
#   [11/2735] 100162_FQ(doc): target at [9] | cited: [0, 5, 1, 3, 4]
#   [12/2735] 100162_FQS(doc): target at [9] | cited: [0, 5, 1, 7, 9]
#   [13/2735] 100162_FS(doc): target at [9] | cited: [0, 5, 1, 4, 6]
#   [14/2735] 100162_Fluency(doc): target at [9] | cited: [1, 5, 8, 9, 3]
#   [15/2735] 100162_LLMstxt(doc): target at [8] | cited: [0, 5, 1, 4, 7]
#   [16/2735] 100162_QS(doc): target at [9] | cited: [0, 5, 1, 4, 9]
#   [17/2735] 100162_Quotes(doc): target at [9] | cited: [0, 1, 4, 7, 3]
#   [18/2735] 100162_SimpleLanguage(doc): target at [1] | cited: [0, 1, 2, 7, 3]
#   [19/2735] 100162_Statistics(doc): target at [9] | cited: [0, 5, 1, 4, 3]
#   [20/2735] 100162_TechnicalTerms(doc): target at [9] | cited: [0, 5, 8, 1, 2]
#   [21/2735] 100162_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 4, 9]
#   [22/2735] 100162_doc: target at [9] | cited: [0, 5, 1, 3, 4]
#   [23/2735] 100212_Authoritative(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [24/2735] 100212_CQ(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [25/2735] 100212_CQS(doc): target at [5] | cited: [0, 1, 2, 4, 6]
#   [26/2735] 100212_CS(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [27/2735] 100212_Citations(doc): target at [4] | cited: [0, 1, 4, 5, 6]
#   [28/2735] 100212_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [29/2735] 100212_FC(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [30/2735] 100212_FCQ(doc): target at [5] | cited: [0, 4, 5, 2, 3]
#   [31/2735] 100212_FCQS(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [32/2735] 100212_FCS(doc): target at [5] | cited: [0, 1, 4, 5, 2]
#   [33/2735] 100212_FQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [34/2735] 100212_FQS(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [35/2735] 100212_FS(doc): target at [5] | cited: [0, 1, 2, 4, 6]
#   [36/2735] 100212_Fluency(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [37/2735] 100212_LLMstxt(doc): target at [6] | cited: [0, 2, 3, 4, 5]
#   [38/2735] 100212_QS(doc): target at [4] | cited: [0, 1, 4, 5, 8]
#   [39/2735] 100212_Quotes(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [40/2735] 100212_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [41/2735] 100212_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [42/2735] 100212_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3]
#   [43/2735] 100212_UniqueWords(doc): target at [4] | cited: [1, 7, 2, 4, 0]
#   [44/2735] 100212_doc: target at [4] | cited: [0, 1, 2, 4, 5]
#   [45/2735] 100255_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [46/2735] 100255_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 9]
#   [47/2735] 100255_CQS(doc): target at [5] | cited: [0, 7, 1, 2, 3]
#   [48/2735] 100255_CS(doc): target at [5] | cited: [0, 2, 8, 1, 7]
#   [49/2735] 100255_Citations(doc): target at [6] | cited: [0, 1, 3, 4, 2]
#   [50/2735] 100255_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [51/2735] 100255_FC(doc): target at [6] | cited: [0, 1, 8, 4, 2]
#   [52/2735] 100255_FCQ(doc): target at [0] | cited: [0, 2, 3, 4, 6]
#   [53/2735] 100255_FCQS(doc): target at [6] | cited: [0, 1, 7, 2, 9]
#   [54/2735] 100255_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [55/2735] 100255_FQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [56/2735] 100255_FQS(doc): target at [6] | cited: [0, 7, 1, 2, 4]
#   [57/2735] 100255_FS(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [58/2735] 100255_Fluency(doc): target at [2] | cited: [0, 2, 3, 1, 4]
#   [59/2735] 100255_LLMstxt(doc): target at [1] | cited: [0, 1, 4, 2, 5]
#   [60/2735] 100255_QS(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [61/2735] 100255_Quotes(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [62/2735] 100255_SimpleLanguage(doc): target at [2] | cited: [0, 8, 1, 2, 7]
#   [63/2735] 100255_Statistics(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [64/2735] 100255_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [65/2735] 100255_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [66/2735] 100255_doc: target at [1] | cited: [0, 1, 2, 3, 4]
#   [67/2735] 100275_Authoritative(doc): target at [8] | cited: [0, 1, 6, 2, 3]
#   [68/2735] 100275_CQ(doc): target at [8] | cited: [0, 3, 1, 4, 8]
#   [69/2735] 100275_CQS(doc): target at [8] | cited: [0, 2, 8, 6, 3]
#   [70/2735] 100275_CS(doc): target at [8] | cited: [0, 1, 4, 3, 8]
#   [71/2735] 100275_Citations(doc): target at [8] | cited: [0, 3, 1, 2, 4]
#   [72/2735] 100275_ContentImprovement(doc): target at [8] | cited: [0, 8, 6, 1, 3]
#   [73/2735] 100275_FC(doc): target at [8] | cited: [0, 2, 8, 1, 3]
#   [74/2735] 100275_FCQ(doc): target at [9] | cited: [0, 2, 1, 5, 7]
#   [75/2735] 100275_FCQS(doc): target at [8] | cited: [0, 8, 4, 2, 3]
#   [76/2735] 100275_FCS(doc): target at [8] | cited: [0, 2, 3, 1, 4]
#   [77/2735] 100275_FQ(doc): target at [9] | cited: [0, 3, 1, 9, 4]
#   [78/2735] 100275_FQS(doc): target at [9] | cited: [1, 4, 9, 0, 3]
#   [79/2735] 100275_FS(doc): target at [8] | cited: []
#   [80/2735] 100275_Fluency(doc): target at [7] | cited: [0, 1, 3, 7, 6]
#   [81/2735] 100275_LLMstxt(doc): target at [8] | cited: [0, 1, 4, 8, 5]
#   [82/2735] 100275_QS(doc): target at [8] | cited: [1, 4, 3, 8, 6]
#   [83/2735] 100275_Quotes(doc): target at [8] | cited: [0, 1, 3, 2, 6]
#   [84/2735] 100275_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 4, 8]
#   [85/2735] 100275_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 6]
#   [86/2735] 100275_TechnicalTerms(doc): target at [8] | cited: [0, 1, 8, 6, 7]
#   [87/2735] 100275_UniqueWords(doc): target at [8] | cited: [0, 3, 8, 6, 5]
#   [88/2735] 100275_doc: target at [5] | cited: [1, 4, 2, 5, 7]
#   [89/2735] 100344_Authoritative(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [90/2735] 100344_CQ(doc): target at [8] | cited: [0, 1, 4, 6, 8]
#   [91/2735] 100344_CQS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [92/2735] 100344_CS(doc): target at [8] | cited: [0, 1, 3, 4, 6]
#   [93/2735] 100344_Citations(doc): target at [8] | cited: [0, 1, 3, 4, 7]
#   [94/2735] 100344_ContentImprovement(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [95/2735] 100344_FC(doc): target at [8] | cited: [0, 1, 3, 8, 6]
#   [96/2735] 100344_FCQ(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [97/2735] 100344_FCQS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [98/2735] 100344_FCS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [99/2735] 100344_FQ(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [100/2735] 100344_FQS(doc): target at [8] | cited: [0, 1, 3, 4, 6]
#   [101/2735] 100344_FS(doc): target at [9] | cited: [0, 1, 3, 4, 8]
#   [102/2735] 100344_Fluency(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [103/2735] 100344_LLMstxt(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [104/2735] 100344_QS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [105/2735] 100344_Quotes(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [106/2735] 100344_SimpleLanguage(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [107/2735] 100344_Statistics(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [108/2735] 100344_TechnicalTerms(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [109/2735] 100344_UniqueWords(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [110/2735] 100344_doc: target at [8] | cited: [0, 1, 3, 4, 8]
#   [111/2735] 100479_Authoritative(doc): target at [8] | cited: [0, 1, 2, 6, 8]
#   [112/2735] 100479_CQ(doc): target at [9] | cited: [2, 7, 3, 4]
#   [113/2735] 100479_CQS(doc): target at [8] | cited: [0, 4, 1, 2, 6]
#   [114/2735] 100479_CS(doc): target at [9] | cited: [0, 1, 8, 9, 6]
#   [115/2735] 100479_Citations(doc): target at [8] | cited: [0, 1, 2, 4]
#   [116/2735] 100479_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [117/2735] 100479_FC(doc): target at [9] | cited: [1, 2, 5, 3, 0]
#   [118/2735] 100479_FCQ(doc): target at [9] | cited: [0, 1, 2, 7, 4]
#   [119/2735] 100479_FCQS(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [120/2735] 100479_FCS(doc): target at [9] | cited: [0, 1, 6, 9]
#   [121/2735] 100479_FQ(doc): target at [9] | cited: [0, 1, 6, 2]
#   [122/2735] 100479_FQS(doc): target at [9] | cited: [0, 1, 7, 2, 9]
#   [123/2735] 100479_FS(doc): target at [9] | cited: [0, 1, 2, 7, 4]
#   [124/2735] 100479_Fluency(doc): target at [9] | cited: [0, 3, 8, 1, 5]
#   [125/2735] 100479_LLMstxt(doc): target at [9] | cited: [0, 4, 5, 8]
#   [126/2735] 100479_QS(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [127/2735] 100479_Quotes(doc): target at [8] | cited: [0, 1, 3, 6, 4]
#   [128/2735] 100479_SimpleLanguage(doc): target at [1] | cited: [0, 2, 8, 1, 4]
#   [129/2735] 100479_Statistics(doc): target at [9] | cited: [0, 1, 6, 5]
#   [130/2735] 100479_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 9]
#   [131/2735] 100479_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [132/2735] 100479_doc: target at [9] | cited: [0, 1, 2, 4, 3]
#   [133/2735] 100631_Authoritative(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [134/2735] 100631_CQ(doc): target at [0] | cited: [0, 1, 3, 4, 5]
#   [135/2735] 100631_CQS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [136/2735] 100631_CS(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [137/2735] 100631_Citations(doc): target at [0] | cited: [0, 1, 3, 4, 2]
#   [138/2735] 100631_ContentImprovement(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [139/2735] 100631_FC(doc): target at [7] | cited: [0, 5, 1, 4, 2]
#   [140/2735] 100631_FCQ(doc): target at [0] | cited: [0, 1, 3, 4, 2]
#   [141/2735] 100631_FCQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [142/2735] 100631_FCS(doc): target at [3] | cited: [0, 6, 1, 3, 2]
#   [143/2735] 100631_FQ(doc): target at [0] | cited: [0, 1, 3, 4, 2]
#   [144/2735] 100631_FQS(doc): target at [1] | cited: [0, 6, 1, 2, 4]
#   [145/2735] 100631_FS(doc): target at [0] | cited: [0, 1, 6, 3, 4]
#   [146/2735] 100631_Fluency(doc): target at [0] | cited: [0, 2, 1, 3, 4]
#   [147/2735] 100631_LLMstxt(doc): target at [1] | cited: [1, 5, 0, 2, 3]
#   [148/2735] 100631_QS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [149/2735] 100631_Quotes(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [150/2735] 100631_SimpleLanguage(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [151/2735] 100631_Statistics(doc): target at [6] | cited: [0, 5, 1, 4, 2]
#   [152/2735] 100631_TechnicalTerms(doc): target at [0] | cited: [0, 2, 1, 3, 4]
#   [153/2735] 100631_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [154/2735] 100631_doc: target at [0] | cited: [0, 2, 1, 6, 3]
#   [155/2735] 100638_Authoritative(doc): target at [9] | cited: [1, 2, 0, 4, 3]
#   [156/2735] 100638_CQ(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [157/2735] 100638_CQS(doc): target at [9] | cited: [0, 7, 1, 2, 3]
#   [158/2735] 100638_CS(doc): target at [9] | cited: [0, 2, 3, 4, 5]
#   [159/2735] 100638_Citations(doc): target at [9] | cited: [0, 7, 1, 2, 3]
#   [160/2735] 100638_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [161/2735] 100638_FC(doc): target at [9] | cited: [0, 4, 8, 2, 5]
#   [162/2735] 100638_FCQ(doc): target at [9] | cited: [0, 7, 1, 2, 3]
#   [163/2735] 100638_FCQS(doc): target at [9] | cited: [1, 2, 0, 7, 3]
#   [164/2735] 100638_FCS(doc): target at [9] | cited: [0, 7, 1, 2, 3]
#   [165/2735] 100638_FQ(doc): target at [8] | cited: [0, 7, 1, 2, 3]
#   [166/2735] 100638_FQS(doc): target at [9] | cited: [0, 7, 4, 1, 2]
#   [167/2735] 100638_FS(doc): target at [9] | cited: [1, 2, 0, 3, 4]
#   [168/2735] 100638_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [169/2735] 100638_LLMstxt(doc): target at [9] | cited: [0, 3, 4, 6]
#   [170/2735] 100638_QS(doc): target at [5] | cited: [1, 2, 0, 3, 4]
#   [171/2735] 100638_Quotes(doc): target at [9] | cited: [0, 2, 1, 7, 5]
#   [172/2735] 100638_SimpleLanguage(doc): target at [0] | cited: [0, 2, 3, 4, 6]
#   [173/2735] 100638_Statistics(doc): target at [9] | cited: [0, 8, 3, 4, 5]
#   [174/2735] 100638_TechnicalTerms(doc): target at [9] | cited: [0, 7, 1, 2, 5]
#   [175/2735] 100638_UniqueWords(doc): target at [0] | cited: [0, 1, 5, 2, 3]
#   [176/2735] 100638_doc: target at [9] | cited: [0, 1, 2, 3, 5]
#   [177/2735] 100685_Authoritative(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [178/2735] 100685_CQ(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [179/2735] 100685_CQS(doc): target at [0] | cited: [0, 3, 5, 1, 2]
#   [180/2735] 100685_CS(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [181/2735] 100685_Citations(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [182/2735] 100685_ContentImprovement(doc): target at [1] | cited: []
#   [183/2735] 100685_FC(doc): target at [4] | cited: [0, 1, 2, 6, 3]
#   [184/2735] 100685_FCQ(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [185/2735] 100685_FCQS(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [186/2735] 100685_FCS(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [187/2735] 100685_FQ(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [188/2735] 100685_FQS(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [189/2735] 100685_FS(doc): target at [1] | cited: [0, 1, 3, 2, 5]
#   [190/2735] 100685_Fluency(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [191/2735] 100685_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 5, 4]
#   [192/2735] 100685_QS(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [193/2735] 100685_Quotes(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [194/2735] 100685_SimpleLanguage(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [195/2735] 100685_Statistics(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [196/2735] 100685_TechnicalTerms(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [197/2735] 100685_UniqueWords(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [198/2735] 100685_doc: target at [0] | cited: [0, 3, 6, 1, 2]
#   [199/2735] 101512_Authoritative(doc): target at [4] | cited: [8, 9, 4, 5, 1]
#   [200/2735] 101512_CQ(doc): target at [6] | cited: [0, 8, 9, 1, 2]
#   [201/2735] 101512_CQS(doc): target at [6] | cited: [0, 9, 1, 2, 7]
#   [202/2735] 101512_CS(doc): target at [6] | cited: [0, 9, 1, 7, 4]
#   [203/2735] 101512_Citations(doc): target at [4] | cited: [0, 9, 1, 2, 4]
#   [204/2735] 101512_ContentImprovement(doc): target at [4] | cited: [0, 1, 5, 6, 3]
#   [205/2735] 101512_FC(doc): target at [6] | cited: []
#   [206/2735] 101512_FCQ(doc): target at [6] | cited: [0, 8, 9, 1, 2]
#   [207/2735] 101512_FCQS(doc): target at [4] | cited: [0, 1, 2, 6, 9]
#   [208/2735] 101512_FCS(doc): target at [6] | cited: [0, 1, 4, 3, 5]
#   [209/2735] 101512_FQ(doc): target at [6] | cited: [0, 8, 9, 1, 2]
#   [210/2735] 101512_FQS(doc): target at [6] | cited: [0, 1, 7, 4, 6]
#   [211/2735] 101512_FS(doc): target at [6] | cited: [0, 9, 1, 2, 3]
#   [212/2735] 101512_Fluency(doc): target at [6] | cited: [0, 8, 9, 1, 2]
#   [213/2735] 101512_LLMstxt(doc): target at [4] | cited: [0, 8, 9, 1, 2]
#   [214/2735] 101512_QS(doc): target at [6] | cited: [0, 1, 3, 7, 2]
#   [215/2735] 101512_Quotes(doc): target at [4] | cited: [0, 8, 9, 1, 3]
#   [216/2735] 101512_SimpleLanguage(doc): target at [4] | cited: [0, 9, 1, 2, 4]
#   [217/2735] 101512_Statistics(doc): target at [4] | cited: [0, 1, 5, 3, 6]
#   [218/2735] 101512_TechnicalTerms(doc): target at [4] | cited: [0, 8, 9, 1, 2]
#   [219/2735] 101512_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [220/2735] 101512_doc: target at [4] | cited: [8, 9, 1, 3, 5]
#   [221/2735] 102578_Authoritative(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [222/2735] 102578_CQ(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [223/2735] 102578_CQS(doc): target at [2] | cited: [0, 1, 2, 4, 6]
#   [224/2735] 102578_CS(doc): target at [2] | cited: [0, 2, 8, 1, 9]
#   [225/2735] 102578_Citations(doc): target at [1] | cited: [0, 1, 2, 5, 9]
#   [226/2735] 102578_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [227/2735] 102578_FC(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [228/2735] 102578_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [229/2735] 102578_FCQS(doc): target at [3] | cited: [0, 1, 2, 4, 6]
#   [230/2735] 102578_FCS(doc): target at [3] | cited: []
#   [231/2735] 102578_FQ(doc): target at [3] | cited: [0, 1, 3, 2, 5]
#   [232/2735] 102578_FQS(doc): target at [5] | cited: [0, 1, 2, 5, 3]
#   [233/2735] 102578_FS(doc): target at [5] | cited: [0, 5, 9, 1, 2]
#   [234/2735] 102578_Fluency(doc): target at [3] | cited: [0, 1, 2, 4, 6]
#   [235/2735] 102578_LLMstxt(doc): target at [9] | cited: [0, 1, 4, 9, 3]
#   [236/2735] 102578_QS(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [237/2735] 102578_Quotes(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [238/2735] 102578_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [239/2735] 102578_Statistics(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [240/2735] 102578_TechnicalTerms(doc): target at [1] | cited: [0, 1, 5, 9, 2]
#   [241/2735] 102578_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 4, 6]
#   [242/2735] 102578_doc: target at [1] | cited: [0, 1, 2, 4, 6]
#   [243/2735] 10331_Authoritative(doc): target at [3] | cited: [0, 1, 5, 4, 9]
#   [244/2735] 10331_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [245/2735] 10331_CQS(doc): target at [3] | cited: [0, 1, 3, 4]
#   [246/2735] 10331_CS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [247/2735] 10331_Citations(doc): target at [3] | cited: [0, 1, 4, 8, 5]
#   [248/2735] 10331_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 5, 9]
#   [249/2735] 10331_FC(doc): target at [4] | cited: [0, 3, 1, 2, 5]
#   [250/2735] 10331_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [251/2735] 10331_FCQS(doc): target at [3] | cited: [0, 1, 2, 4]
#   [252/2735] 10331_FCS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [253/2735] 10331_FQ(doc): target at [6] | cited: [0, 1, 3, 4, 2]
#   [254/2735] 10331_FQS(doc): target at [3] | cited: [0, 1, 2, 4, 8]
#   [255/2735] 10331_FS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [256/2735] 10331_Fluency(doc): target at [4] | cited: [0, 1, 2, 9, 4]
#   [257/2735] 10331_LLMstxt(doc): target at [3] | cited: [0, 1, 5, 6, 4]
#   [258/2735] 10331_QS(doc): target at [3] | cited: [0, 3, 1, 2]
#   [259/2735] 10331_Quotes(doc): target at [3] | cited: [0, 1]
#   [260/2735] 10331_SimpleLanguage(doc): target at [6] | cited: [0, 1, 4, 9, 3]
#   [261/2735] 10331_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [262/2735] 10331_TechnicalTerms(doc): target at [5] | cited: [0, 1, 4, 3, 5]
#   [263/2735] 10331_UniqueWords(doc): target at [4] | cited: [0, 1, 3, 5, 9]
#   [264/2735] 10331_doc: target at [3] | cited: [0, 1, 2, 3, 5]
#   [265/2735] 103379_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [266/2735] 103379_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [267/2735] 103379_CQS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [268/2735] 103379_CS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [269/2735] 103379_Citations(doc): target at [3] | cited: [0, 1, 2, 4, 6]
#   [270/2735] 103379_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [271/2735] 103379_FC(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [272/2735] 103379_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [273/2735] 103379_FCQS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [274/2735] 103379_FCS(doc): target at [3] | cited: [0, 1, 2, 4, 7]
#   [275/2735] 103379_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [276/2735] 103379_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [277/2735] 103379_FS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [278/2735] 103379_Fluency(doc): target at [3] | cited: [0, 1, 2, 4, 3]
#   [279/2735] 103379_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [280/2735] 103379_QS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [281/2735] 103379_Quotes(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [282/2735] 103379_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [283/2735] 103379_Statistics(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [284/2735] 103379_TechnicalTerms(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [285/2735] 103379_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [286/2735] 103379_doc: target at [3] | cited: [0, 1, 2, 3, 4]
#   [287/2735] 103782_Authoritative(doc): target at [1] | cited: [1, 4, 5, 6, 9]
#   [288/2735] 103782_CQ(doc): target at [0] | cited: [0, 1, 5, 6, 8]
#   [289/2735] 103782_CQS(doc): target at [0] | cited: [0, 2, 6, 3, 8]
#   [290/2735] 103782_CS(doc): target at [0] | cited: [0, 4, 2, 6, 7]
#   [291/2735] 103782_Citations(doc): target at [2] | cited: [0, 3, 1, 5, 2]
#   [292/2735] 103782_ContentImprovement(doc): target at [4] | cited: [0, 5, 7, 8, 9]
#   [293/2735] 103782_FC(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [294/2735] 103782_FCQ(doc): target at [5] | cited: [3, 5, 6, 1, 4]
#   [295/2735] 103782_FCQS(doc): target at [5] | cited: [0, 6, 3, 4, 9]
#   [296/2735] 103782_FCS(doc): target at [5] | cited: [3, 1, 7, 9, 8]
#   [297/2735] 103782_FQ(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 196944, Requested 9729. Please try again in 2.001s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [297/2735] 103782_FQ(doc): done (retry OK)
#   [298/2735] 103782_FQS(doc): target at [6] | cited: [0, 2, 4, 7, 9]
#   [299/2735] 103782_FS(doc): target at [5] | cited: [0, 6, 7, 3, 9]
#   [300/2735] 103782_Fluency(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [301/2735] 103782_LLMstxt(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 200000, Requested 10246. Please try again in 3.073s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [301/2735] 103782_LLMstxt(doc): done (retry OK)
#   [302/2735] 103782_QS(doc): target at [3] | cited: [0, 4, 3, 1, 5]
#   [303/2735] 103782_Quotes(doc): target at [3] | cited: [0, 3, 5, 6, 1]
#   [304/2735] 103782_SimpleLanguage(doc): target at [2] | cited: [0, 3, 2, 9, 8]
#   [305/2735] 103782_Statistics(doc): target at [5] | cited: [0, 5, 6, 3, 7]
#   [306/2735] 103782_TechnicalTerms(doc): target at [1] | cited: [0, 1, 4, 3, 7]
#   [307/2735] 103782_UniqueWords(doc): target at [1] | cited: [8, 3, 7, 1, 9]
#   [308/2735] 103782_doc: ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 200000, Requested 9636. Please try again in 2.89s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [308/2735] 103782_doc: done (retry OK)
#   [309/2735] 103863_Authoritative(doc): target at [0] | cited: [0, 1, 4, 9, 3]
#   [310/2735] 103863_CQ(doc): target at [0] | cited: [4, 9, 1, 2, 3]
#   [311/2735] 103863_CQS(doc): target at [0] | cited: [1, 4, 9, 3, 2]
#   [312/2735] 103863_CS(doc): target at [0] | cited: []
#   [313/2735] 103863_Citations(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [314/2735] 103863_ContentImprovement(doc): ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 200000, Requested 8041. Please try again in 2.412s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [314/2735] 103863_ContentImprovement(doc): FAILED — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 192284, Requested 8041. Please try again in 97ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [315/2735] 103863_FC(doc): target at [6] | cited: [0, 3, 4, 2, 1]
#   [316/2735] 103863_FCQ(doc): target at [6] | cited: [0, 2, 4, 5, 1]
#   [317/2735] 103863_FCQS(doc): target at [1] | cited: [0, 4, 6, 9, 3]
#   [318/2735] 103863_FCS(doc): target at [1] | cited: [0, 3, 4, 6, 5]
#   [319/2735] 103863_FQ(doc): target at [2] | cited: [0, 4, 6, 3, 2]
#   [320/2735] 103863_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [321/2735] 103863_FS(doc): target at [1] | cited: [0, 4, 5, 2, 9]
#   [322/2735] 103863_Fluency(doc): target at [0] | cited: [0, 1, 4, 6, 2]
#   [323/2735] 103863_LLMstxt(doc): target at [5] | cited: [0, 2, 3, 4, 1]
#   [324/2735] 103863_QS(doc): target at [0] | cited: [4, 6, 9, 1, 3]
#   [325/2735] 103863_Quotes(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [326/2735] 103863_SimpleLanguage(doc): target at [0] | cited: [4, 5, 9, 1, 3]
#   [327/2735] 103863_Statistics(doc): target at [0] | cited: [4, 9, 1, 2, 3]
#   [328/2735] 103863_TechnicalTerms(doc): target at [1] | cited: [0, 4, 6, 3, 2]
#   [329/2735] 103863_UniqueWords(doc): target at [0] | cited: [0, 1, 4, 6, 3]
#   [330/2735] 103863_doc: ERROR — Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini-2024-07-18 (for limit gpt-4o-mini) in organization org-WOI5PMNk4y5INXa3AbJeOhtr on tokens per min (TPM): Limit 200000, Used 200000, Requested 7844. Please try again in 2.353s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
#   [330/2735] 103863_doc: done (retry OK)
#   [331/2735] 104055_Authoritative(doc): target at [1] | cited: [0, 2, 3, 1, 5]
#   [332/2735] 104055_CQ(doc): target at [1] | cited: [0, 6, 1, 2, 3]
#   [333/2735] 104055_CQS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [334/2735] 104055_CS(doc): target at [1] | cited: [1, 2, 0, 3, 4]
#   [335/2735] 104055_Citations(doc): target at [1] | cited: [0, 5, 1, 8, 3]
#   [336/2735] 104055_ContentImprovement(doc): target at [2] | cited: [0, 1, 3, 2, 4]
#   [337/2735] 104055_FC(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [338/2735] 104055_FCQ(doc): target at [1] | cited: [0, 1, 8, 5, 9]
#   [339/2735] 104055_FCQS(doc): target at [1] | cited: [0, 1, 2, 3, 7]
#   [340/2735] 104055_FCS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [341/2735] 104055_FQ(doc): target at [1] | cited: [0, 1, 2, 3, 9]
#   [342/2735] 104055_FQS(doc): target at [2] | cited: [2, 3, 6, 1, 5]
#   [343/2735] 104055_FS(doc): target at [2] | cited: [0, 1, 2, 4, 5]
#   [344/2735] 104055_Fluency(doc): target at [2] | cited: [0, 1, 3, 2, 5]
#   [345/2735] 104055_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 5, 9]
#   [346/2735] 104055_QS(doc): target at [1] | cited: [0, 1, 5, 2, 3]
#   [347/2735] 104055_Quotes(doc): target at [1] | cited: [0, 2, 1, 3, 7]
#   [348/2735] 104055_SimpleLanguage(doc): target at [1] | cited: [0, 1, 7, 2, 3]
#   [349/2735] 104055_Statistics(doc): target at [2] | cited: [2, 3, 0, 1, 7]
#   [350/2735] 104055_TechnicalTerms(doc): target at [1] | cited: [0, 2, 3, 5, 7]
#   [351/2735] 104055_UniqueWords(doc): target at [2] | cited: [0, 1, 3, 7, 2]
#   [352/2735] 104055_doc: target at [1] | cited: [0, 2, 8, 1, 3]
#   [353/2735] 104590_Authoritative(doc): target at [2] | cited: [0, 2, 5, 1, 8]
#   [354/2735] 104590_CQ(doc): target at [6] | cited: [0, 3, 1, 5, 2]
#   [355/2735] 104590_CQS(doc): target at [2] | cited: [0, 2, 4, 5, 1]
#   [356/2735] 104590_CS(doc): target at [2] | cited: [0, 1, 2, 7, 8]
#   [357/2735] 104590_Citations(doc): target at [2] | cited: [0, 2, 1, 8, 5]
#   [358/2735] 104590_ContentImprovement(doc): target at [2] | cited: [0, 5, 1, 2, 8]
#   [359/2735] 104590_FC(doc): target at [5] | cited: [0, 5, 8, 6, 1]
#   [360/2735] 104590_FCQ(doc): target at [2] | cited: [0, 5, 2, 1, 3]
#   [361/2735] 104590_FCQS(doc): target at [4] | cited: [0, 4, 5, 1, 8]
#   [362/2735] 104590_FCS(doc): target at [4] | cited: [0, 4, 5, 1, 8]
#   [363/2735] 104590_FQ(doc): target at [4] | cited: [0, 8, 2, 1, 5]
#   [364/2735] 104590_FQS(doc): target at [4] | cited: [0, 4, 1, 7, 5]
#   [365/2735] 104590_FS(doc): target at [1] | cited: [0, 1, 5, 2, 7]
#   [366/2735] 104590_Fluency(doc): target at [2] | cited: [0, 5, 2, 1, 8]
#   [367/2735] 104590_LLMstxt(doc): target at [4] | cited: [0, 1, 3, 4, 2]
#   [368/2735] 104590_QS(doc): target at [1] | cited: [0, 1, 7, 2, 5]
#   [369/2735] 104590_Quotes(doc): target at [2] | cited: [0, 1, 2, 6, 8]
#   [370/2735] 104590_SimpleLanguage(doc): target at [2] | cited: [1, 2, 7, 3, 8]
#   [371/2735] 104590_Statistics(doc): target at [3] | cited: [0, 3, 4, 1, 8]
#   [372/2735] 104590_TechnicalTerms(doc): target at [2] | cited: [0, 4, 5, 2, 1]
#   [373/2735] 104590_UniqueWords(doc): target at [2] | cited: [0, 4, 5, 1, 2]
#   [374/2735] 104590_doc: target at [2] | cited: [0, 2, 4, 7, 5]
#   [375/2735] 104865_Authoritative(doc): target at [3] | cited: [0, 2, 1, 3, 5]
#   [376/2735] 104865_CQ(doc): target at [5] | cited: [0, 3, 4, 1, 9]
#   [377/2735] 104865_CQS(doc): target at [5] | cited: [0, 2, 1, 4, 5]
#   [378/2735] 104865_CS(doc): target at [5] | cited: [0, 2, 3, 4, 1]
#   [379/2735] 104865_Citations(doc): target at [4] | cited: [0, 2, 1, 9, 3]
#   [380/2735] 104865_ContentImprovement(doc): target at [2] | cited: [0, 2, 3, 4, 1]
#   [381/2735] 104865_FC(doc): target at [5] | cited: [0, 2, 3, 1, 9]
#   [382/2735] 104865_FCQ(doc): target at [5] | cited: [0, 2, 1, 9, 3]
#   [383/2735] 104865_FCQS(doc): target at [5] | cited: [0, 1, 3, 9, 7]
#   [384/2735] 104865_FCS(doc): target at [2] | cited: [0, 3, 4, 1, 9]
#   [385/2735] 104865_FQ(doc): target at [6] | cited: [0, 2, 6, 1, 9]
#   [386/2735] 104865_FQS(doc): target at [6] | cited: [0, 2, 1, 9, 3]
#   [387/2735] 104865_FS(doc): target at [5] | cited: [0, 2, 9, 3, 4]
#   [388/2735] 104865_Fluency(doc): target at [5] | cited: [0, 3, 1, 9, 7]
#   [389/2735] 104865_LLMstxt(doc): target at [2] | cited: [0, 3, 2, 4, 5]
#   [390/2735] 104865_QS(doc): target at [4] | cited: [0, 2, 1, 3, 5]
#   [391/2735] 104865_Quotes(doc): target at [5] | cited: [0, 2, 1, 3, 5]
#   [392/2735] 104865_SimpleLanguage(doc): target at [2] | cited: [0, 4, 5, 1, 9]
#   [393/2735] 104865_Statistics(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [394/2735] 104865_TechnicalTerms(doc): target at [0] | cited: [0, 1, 4, 5, 6]
#   [395/2735] 104865_UniqueWords(doc): target at [5] | cited: [0, 2, 1, 9, 7]
#   [396/2735] 104865_doc: target at [4] | cited: [0, 2, 1, 9, 3]
#   [397/2735] 104931_Authoritative(doc): target at [6] | cited: [1, 5, 3, 0, 4]
#   [398/2735] 104931_CQ(doc): target at [6] | cited: [0, 1, 6, 5]
#   [399/2735] 104931_CQS(doc): target at [6] | cited: [0, 1, 6, 5]
#   [400/2735] 104931_CS(doc): target at [6] | cited: [1, 3, 2, 6, 5]
#   [401/2735] 104931_Citations(doc): target at [6] | cited: [0, 1, 3, 5, 2]
#   [402/2735] 104931_ContentImprovement(doc): target at [6] | cited: [0, 1, 6]
#   [403/2735] 104931_FC(doc): target at [6] | cited: [0, 1, 5, 6, 7]
#   [404/2735] 104931_FCQ(doc): target at [6] | cited: [1, 5, 3, 9, 2]
#   [405/2735] 104931_FCQS(doc): target at [6] | cited: [0, 5, 1, 2, 3]
#   [406/2735] 104931_FCS(doc): target at [6] | cited: [0, 1, 5, 6]
#   [407/2735] 104931_FQ(doc): target at [6] | cited: [0, 1, 5]
#   [408/2735] 104931_FQS(doc): target at [6] | cited: [1, 0, 2, 6, 5]
#   [409/2735] 104931_FS(doc): target at [6] | cited: [0, 1, 5, 6]
#   [410/2735] 104931_Fluency(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [411/2735] 104931_LLMstxt(doc): target at [9] | cited: [1, 5, 3, 4, 2]
#   [412/2735] 104931_QS(doc): target at [6] | cited: [0, 1, 5, 6]
#   [413/2735] 104931_Quotes(doc): target at [6] | cited: [0, 1, 5, 9, 6]
#   [414/2735] 104931_SimpleLanguage(doc): target at [6] | cited: [0, 1, 5, 3, 2]
#   [415/2735] 104931_Statistics(doc): target at [6] | cited: [0, 1, 5, 3]
#   [416/2735] 104931_TechnicalTerms(doc): target at [6] | cited: [0, 1, 5, 2, 3]
#   [417/2735] 104931_UniqueWords(doc): target at [6] | cited: [1, 5, 3, 0, 2]
#   [418/2735] 104931_doc: target at [6] | cited: [1, 5, 6, 0, 4]
#   [419/2735] 105061_Authoritative(doc): target at [7] | cited: [0, 1, 2, 5, 3]
#   [420/2735] 105061_CQ(doc): target at [6] | cited: [0, 1, 3, 2, 4]
#   [421/2735] 105061_CQS(doc): target at [6] | cited: [0, 1, 2, 5, 7]
#   [422/2735] 105061_CS(doc): target at [6] | cited: [0, 2, 1, 4, 6]
#   [423/2735] 105061_Citations(doc): target at [6] | cited: [0, 3, 1, 2, 7]
#   [424/2735] 105061_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [425/2735] 105061_FC(doc): target at [6] | cited: [0, 1, 2, 5, 7]
#   [426/2735] 105061_FCQ(doc): target at [1] | cited: [0, 2, 1, 3, 5]
#   [427/2735] 105061_FCQS(doc): target at [6] | cited: [0, 1, 2, 5, 7]
#   [428/2735] 105061_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [429/2735] 105061_FQ(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [430/2735] 105061_FQS(doc): target at [6] | cited: [0, 2, 3, 1, 4]
#   [431/2735] 105061_FS(doc): target at [1] | cited: [0, 6, 3, 4, 1]
#   [432/2735] 105061_Fluency(doc): target at [6] | cited: [0, 1, 2, 4, 3]
#   [433/2735] 105061_LLMstxt(doc): target at [9] | cited: [0, 3, 1, 2, 6]
#   [434/2735] 105061_QS(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [435/2735] 105061_Quotes(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [436/2735] 105061_SimpleLanguage(doc): target at [6] | cited: [0, 2, 3, 1, 5]
#   [437/2735] 105061_Statistics(doc): target at [7] | cited: [0, 1, 2, 5, 9]
#   [438/2735] 105061_TechnicalTerms(doc): target at [1] | cited: [0, 3, 4, 1, 8]
#   [439/2735] 105061_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 5, 3]
#   [440/2735] 105061_doc: target at [7] | cited: [0, 4, 2, 1, 3]
#   [441/2735] 105517_Authoritative(doc): target at [8] | cited: [9, 0, 4, 8, 7]
#   [442/2735] 105517_CQ(doc): target at [8] | cited: [0, 9, 8, 7]
#   [443/2735] 105517_CQS(doc): target at [8] | cited: [0, 9, 4, 2]
#   [444/2735] 105517_CS(doc): target at [8] | cited: [0, 9, 2, 4, 8]
#   [445/2735] 105517_Citations(doc): target at [8] | cited: [9, 4, 0]
#   [446/2735] 105517_ContentImprovement(doc): target at [8] | cited: [6, 0, 7, 8, 9]
#   [447/2735] 105517_FC(doc): target at [8] | cited: [0, 4, 7, 9, 6]
#   [448/2735] 105517_FCQ(doc): target at [7] | cited: [0, 1, 4, 5, 8]
#   [449/2735] 105517_FCQS(doc): target at [2] | cited: [0, 1, 2, 6, 7]
#   [450/2735] 105517_FCS(doc): target at [8] | cited: [0, 1, 6, 4, 8]
#   [451/2735] 105517_FQ(doc): target at [8] | cited: [0, 4, 7, 8, 6]
#   [452/2735] 105517_FQS(doc): target at [8] | cited: [0, 7, 8, 4, 9]
#   [453/2735] 105517_FS(doc): target at [9] | cited: [0, 8, 2, 4, 5]
#   [454/2735] 105517_Fluency(doc): target at [8] | cited: [0, 6, 7, 9]
#   [455/2735] 105517_LLMstxt(doc): target at [9] | cited: [0, 7, 9, 6, 8]
#   [456/2735] 105517_QS(doc): target at [8] | cited: [0, 6, 7, 8, 9]
#   [457/2735] 105517_Quotes(doc): target at [8] | cited: [0, 6, 8, 7, 9]
#   [458/2735] 105517_SimpleLanguage(doc): target at [7] | cited: [0, 3, 6, 7, 8]
#   [459/2735] 105517_Statistics(doc): target at [9] | cited: [6, 0, 2, 5, 7]
#   [460/2735] 105517_TechnicalTerms(doc): target at [8] | cited: [0, 7, 2, 9, 6]
#   [461/2735] 105517_UniqueWords(doc): target at [8] | cited: [0, 7, 8, 6, 5]
#   [462/2735] 105517_doc: target at [8] | cited: [0, 7, 6, 8, 9]
#   [463/2735] 105770_Authoritative(doc): target at [7] | cited: [0, 1, 2, 7, 3]
#   [464/2735] 105770_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [465/2735] 105770_CQS(doc): target at [7] | cited: [0, 3, 6, 1, 2]
#   [466/2735] 105770_CS(doc): target at [7] | cited: [0, 3, 7, 2, 5]
#   [467/2735] 105770_Citations(doc): target at [7] | cited: [0, 3, 6, 5, 7]
#   [468/2735] 105770_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [469/2735] 105770_FC(doc): target at [7] | cited: [0, 2, 3, 5, 4]
#   [470/2735] 105770_FCQ(doc): target at [7] | cited: [0, 2, 3, 7, 9]
#   [471/2735] 105770_FCQS(doc): target at [7] | cited: [0, 1, 3, 7, 2]
#   [472/2735] 105770_FCS(doc): target at [7] | cited: [0, 3, 4, 6, 1]
#   [473/2735] 105770_FQ(doc): target at [7] | cited: [0, 1, 4, 6, 3]
#   [474/2735] 105770_FQS(doc): target at [7] | cited: [0, 2, 3, 5, 1]
#   [475/2735] 105770_FS(doc): target at [7] | cited: [0, 1, 3, 5, 2]
#   [476/2735] 105770_Fluency(doc): target at [7] | cited: [0, 2, 3, 4, 1]
#   [477/2735] 105770_LLMstxt(doc): target at [7] | cited: [3, 4, 0, 2, 9]
#   [478/2735] 105770_QS(doc): target at [7] | cited: [0, 2, 3, 1, 5]
#   [479/2735] 105770_Quotes(doc): target at [7] | cited: [0, 2, 9, 1, 3]
#   [480/2735] 105770_SimpleLanguage(doc): target at [7] | cited: [0, 1, 3, 7, 5]
#   [481/2735] 105770_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 7]
#   [482/2735] 105770_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [483/2735] 105770_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [484/2735] 105770_doc: target at [7] | cited: [0, 3, 4, 5, 1]
#   [485/2735] 105809_Authoritative(doc): target at [7] | cited: [0, 2, 4, 5]
#   [486/2735] 105809_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [487/2735] 105809_CQS(doc): target at [9] | cited: [0, 2, 1, 3, 4]
#   [488/2735] 105809_CS(doc): target at [9] | cited: [0, 1, 2, 8, 4]
#   [489/2735] 105809_Citations(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [490/2735] 105809_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 4]
#   [491/2735] 105809_FC(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [492/2735] 105809_FCQ(doc): target at [9] | cited: [0, 2, 1, 3, 4]
#   [493/2735] 105809_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [494/2735] 105809_FCS(doc): target at [7] | cited: [0, 1, 3, 4]
#   [495/2735] 105809_FQ(doc): target at [7] | cited: [0, 1, 2, 4, 9]
#   [496/2735] 105809_FQS(doc): target at [7] | cited: [0, 5, 1, 3]
#   [497/2735] 105809_FS(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [498/2735] 105809_Fluency(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [499/2735] 105809_LLMstxt(doc): target at [7] | cited: [0, 2, 1, 4, 3]
#   [500/2735] 105809_QS(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [501/2735] 105809_Quotes(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [502/2735] 105809_SimpleLanguage(doc): target at [7] | cited: [0, 1, 3, 2, 4]
#   [503/2735] 105809_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [504/2735] 105809_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 4, 9]
#   [505/2735] 105809_UniqueWords(doc): target at [7] | cited: [0, 2, 1, 4, 3]
#   [506/2735] 105809_doc: target at [7] | cited: [0, 1, 2, 3, 4]
#   [507/2735] 105896_Authoritative(doc): target at [1] | cited: [0, 5, 1, 9, 6]
#   [508/2735] 105896_CQ(doc): target at [1] | cited: [0, 6, 1, 3, 7]
#   [509/2735] 105896_CQS(doc): target at [0] | cited: [0, 1, 2, 3, 7]
#   [510/2735] 105896_CS(doc): target at [2] | cited: [0, 2, 1, 5, 7]
#   [511/2735] 105896_Citations(doc): target at [0] | cited: [0, 3, 1, 6, 5]
#   [512/2735] 105896_ContentImprovement(doc): target at [0] | cited: [0, 3, 1, 6, 7]
#   [513/2735] 105896_FC(doc): target at [2] | cited: [0, 6, 1, 3, 7]
#   [514/2735] 105896_FCQ(doc): target at [6] | cited: [0, 4, 1, 5, 6]
#   [515/2735] 105896_FCQS(doc): target at [6] | cited: [0, 5, 1, 2, 7]
#   [516/2735] 105896_FCS(doc): target at [6] | cited: [0, 5, 1, 4, 7]
#   [517/2735] 105896_FQ(doc): target at [7] | cited: [0, 5, 1, 3, 6]
#   [518/2735] 105896_FQS(doc): target at [6] | cited: [0, 5, 1, 4, 7]
#   [519/2735] 105896_FS(doc): target at [2] | cited: [0, 1, 7, 8]
#   [520/2735] 105896_Fluency(doc): target at [2] | cited: [0, 6, 1, 7]
#   [521/2735] 105896_LLMstxt(doc): target at [0] | cited: [0, 3, 1, 2]
#   [522/2735] 105896_QS(doc): target at [0] | cited: [0, 2, 3, 1, 6]
#   [523/2735] 105896_Quotes(doc): target at [0] | cited: [0, 1, 2, 3, 7]
#   [524/2735] 105896_SimpleLanguage(doc): target at [0] | cited: [0, 1, 6, 7]
#   [525/2735] 105896_Statistics(doc): target at [2] | cited: [1, 3, 5, 9, 4]
#   [526/2735] 105896_TechnicalTerms(doc): target at [2] | cited: [0, 6, 1, 7, 5]
#   [527/2735] 105896_UniqueWords(doc): target at [0] | cited: [0, 1, 7, 5, 4]
#   [528/2735] 105896_doc: target at [0] | cited: [0, 1, 2, 7, 9]
#   [529/2735] 106226_Authoritative(doc): target at [6] | cited: [0, 3, 4, 5, 8]
#   [530/2735] 106226_CQ(doc): target at [6] | cited: [0, 1, 3, 6, 4]
#   [531/2735] 106226_CQS(doc): target at [6] | cited: [0, 1, 8, 3, 4]
#   [532/2735] 106226_CS(doc): target at [5] | cited: [0, 5, 2, 8]
#   [533/2735] 106226_Citations(doc): target at [5] | cited: [0, 5, 1, 3, 7]
#   [534/2735] 106226_ContentImprovement(doc): target at [6] | cited: [0, 1, 3, 8, 6]
#   [535/2735] 106226_FC(doc): target at [0] | cited: [0, 1, 3, 2, 4]
#   [536/2735] 106226_FCQ(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [537/2735] 106226_FCQS(doc): target at [6] | cited: [0, 1, 8, 2, 3]
#   [538/2735] 106226_FCS(doc): target at [6] | cited: [0, 1, 2, 8, 6]
#   [539/2735] 106226_FQ(doc): target at [6] | cited: [0, 1, 6, 8, 3]
#   [540/2735] 106226_FQS(doc): target at [6] | cited: [1, 3, 8, 0, 2]
#   [541/2735] 106226_FS(doc): target at [6] | cited: [0, 1, 3, 7, 6]
#   [542/2735] 106226_Fluency(doc): target at [5] | cited: [0, 1, 5, 3, 8]
#   [543/2735] 106226_LLMstxt(doc): target at [8] | cited: [0, 1, 3, 2, 5]
#   [544/2735] 106226_QS(doc): target at [5] | cited: [0, 2, 4, 1, 5]
#   [545/2735] 106226_Quotes(doc): target at [6] | cited: [0, 1, 2, 6, 3]
#   [546/2735] 106226_SimpleLanguage(doc): target at [3] | cited: [0, 3, 1, 4, 8]
#   [547/2735] 106226_Statistics(doc): target at [3] | cited: [0, 1, 3, 4, 7]
#   [548/2735] 106226_TechnicalTerms(doc): target at [0] | cited: [0, 2, 4, 7, 1]
#   [549/2735] 106226_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [550/2735] 106226_doc: target at [1] | cited: [1, 0, 2, 3, 4]
#   [551/2735] 106227_Authoritative(doc): target at [7] | cited: [0, 5, 6, 1, 3]
#   [552/2735] 106227_CQ(doc): target at [6] | cited: [0, 1, 4, 7, 2]
#   [553/2735] 106227_CQS(doc): target at [7] | cited: [0, 1, 2, 3, 8]
#   [554/2735] 106227_CS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [555/2735] 106227_Citations(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [556/2735] 106227_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 4, 7]
#   [557/2735] 106227_FC(doc): target at [6] | cited: [0, 2, 8, 1, 4]
#   [558/2735] 106227_FCQ(doc): target at [7] | cited: [0, 2, 3, 7, 5]
#   [559/2735] 106227_FCQS(doc): target at [6] | cited: [0, 1, 3, 2, 5]
#   [560/2735] 106227_FCS(doc): target at [6] | cited: [0, 1, 2, 7, 5]
#   [561/2735] 106227_FQ(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [562/2735] 106227_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [563/2735] 106227_FS(doc): target at [7] | cited: [1, 3, 8, 0, 4]
#   [564/2735] 106227_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [565/2735] 106227_LLMstxt(doc): target at [9] | cited: [0, 1, 3, 6, 2]
#   [566/2735] 106227_QS(doc): target at [7] | cited: [0, 4, 1, 8, 2]
#   [567/2735] 106227_Quotes(doc): target at [7] | cited: [0, 1, 2, 4, 3]
#   [568/2735] 106227_SimpleLanguage(doc): target at [7] | cited: [0, 2, 7, 3, 5]
#   [569/2735] 106227_Statistics(doc): target at [7] | cited: [0, 2, 4, 1, 8]
#   [570/2735] 106227_TechnicalTerms(doc): target at [6] | cited: [0, 5, 2, 3, 4]
#   [571/2735] 106227_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 6, 5]
#   [572/2735] 106227_doc: target at [6] | cited: [0, 1, 3, 2, 5]
#   [573/2735] 106228_Authoritative(doc): target at [7] | cited: [0, 1, 7, 8, 6]
#   [574/2735] 106228_CQ(doc): target at [7] | cited: [0, 1, 7, 8]
#   [575/2735] 106228_CQS(doc): target at [7] | cited: [0, 2, 4, 1, 3]
#   [576/2735] 106228_CS(doc): target at [7] | cited: [0, 1, 7, 3]
#   [577/2735] 106228_Citations(doc): target at [3] | cited: [0, 1, 3, 8, 7]
#   [578/2735] 106228_ContentImprovement(doc): target at [7] | cited: [0, 1, 8, 6]
#   [579/2735] 106228_FC(doc): target at [7] | cited: [0, 1, 3, 8, 7]
#   [580/2735] 106228_FCQ(doc): target at [7] | cited: [0, 1, 5, 3]
#   [581/2735] 106228_FCQS(doc): target at [7] | cited: [0, 1, 3, 8]
#   [582/2735] 106228_FCS(doc): target at [7] | cited: [0, 1, 8]
#   [583/2735] 106228_FQ(doc): target at [7] | cited: [0, 1, 7, 8, 6]
#   [584/2735] 106228_FQS(doc): target at [8] | cited: [0, 1, 7, 8, 6]
#   [585/2735] 106228_FS(doc): target at [7] | cited: [0, 1, 7]
#   [586/2735] 106228_Fluency(doc): target at [7] | cited: [0, 1, 7, 3, 8]
#   [587/2735] 106228_LLMstxt(doc): target at [3] | cited: [0, 3, 8, 1, 5]
#   [588/2735] 106228_QS(doc): target at [6] | cited: [0, 1, 6, 8, 7]
#   [589/2735] 106228_Quotes(doc): target at [5] | cited: [0, 1, 3, 5, 8]
#   [590/2735] 106228_SimpleLanguage(doc): target at [7] | cited: [0, 1, 8, 7, 9]
#   [591/2735] 106228_Statistics(doc): target at [7] | cited: [0, 1, 3, 8]
#   [592/2735] 106228_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 4, 7]
#   [593/2735] 106228_UniqueWords(doc): target at [7] | cited: [0, 1, 7, 8, 6]
#   [594/2735] 106228_doc: target at [3] | cited: [0, 1, 3, 4]
#   [595/2735] 106325_Authoritative(doc): target at [9] | cited: [0, 1]
#   [596/2735] 106325_CQ(doc): target at [9] | cited: [0, 1]
#   [597/2735] 106325_CQS(doc): target at [9] | cited: [0, 2, 1]
#   [598/2735] 106325_CS(doc): target at [8] | cited: [0]
#   [599/2735] 106325_Citations(doc): target at [9] | cited: [1]
#   [600/2735] 106325_ContentImprovement(doc): target at [8] | cited: [0, 3]
#   [601/2735] 106325_FC(doc): target at [9] | cited: [0, 1, 2, 3]
#   [602/2735] 106325_FCQ(doc): target at [9] | cited: [0, 1]
#   [603/2735] 106325_FCQS(doc): target at [9] | cited: [1]
#   [604/2735] 106325_FCS(doc): target at [9] | cited: [0, 1]
#   [605/2735] 106325_FQ(doc): target at [9] | cited: [0, 1]
#   [606/2735] 106325_FQS(doc): target at [8] | cited: [0, 2]
#   [607/2735] 106325_FS(doc): target at [9] | cited: []
#   [608/2735] 106325_Fluency(doc): target at [9] | cited: [0, 2]
#   [609/2735] 106325_LLMstxt(doc): target at [8] | cited: [1, 2, 8]
#   [610/2735] 106325_QS(doc): target at [9] | cited: [1]
#   [611/2735] 106325_Quotes(doc): target at [8] | cited: [0, 1, 2]
#   [612/2735] 106325_SimpleLanguage(doc): target at [9] | cited: [0, 1]
#   [613/2735] 106325_Statistics(doc): target at [9] | cited: [0, 1]
#   [614/2735] 106325_TechnicalTerms(doc): target at [9] | cited: [1]
#   [615/2735] 106325_UniqueWords(doc): target at [9] | cited: [0, 1, 3, 2]
#   [616/2735] 106325_doc: target at [9] | cited: [1]
#   [617/2735] 106340_Authoritative(doc): target at [2] | cited: [0, 2, 1, 3, 8]
#   [618/2735] 106340_CQ(doc): target at [2] | cited: [0, 1, 8, 4, 9]
#   [619/2735] 106340_CQS(doc): target at [2] | cited: [0, 2, 1, 3]
#   [620/2735] 106340_CS(doc): target at [1] | cited: [0, 8, 4, 9, 5]
#   [621/2735] 106340_Citations(doc): target at [2] | cited: [0, 5, 1, 3, 8]
#   [622/2735] 106340_ContentImprovement(doc): target at [2] | cited: [0, 1, 2, 8, 9]
#   [623/2735] 106340_FC(doc): target at [2] | cited: [0, 2, 1, 3, 4]
#   [624/2735] 106340_FCQ(doc): target at [4] | cited: [0, 1, 8, 3, 4]
#   [625/2735] 106340_FCQS(doc): target at [2] | cited: [0, 1, 8, 9, 5]
#   [626/2735] 106340_FCS(doc): target at [2] | cited: [0, 4, 8, 5, 9]
#   [627/2735] 106340_FQ(doc): target at [2] | cited: [0, 2, 1, 3, 8]
#   [628/2735] 106340_FQS(doc): target at [5] | cited: [0, 4, 5, 3, 8]
#   [629/2735] 106340_FS(doc): target at [5] | cited: [0, 2, 8, 1, 4]
#   [630/2735] 106340_Fluency(doc): target at [2] | cited: [0, 1, 5, 3, 8]
#   [631/2735] 106340_LLMstxt(doc): target at [7] | cited: [0, 2, 3, 4, 8]
#   [632/2735] 106340_QS(doc): target at [1] | cited: [0, 8, 5, 9, 4]
#   [633/2735] 106340_Quotes(doc): target at [1] | cited: [0, 1, 5, 8, 3]
#   [634/2735] 106340_SimpleLanguage(doc): target at [1] | cited: [0, 4, 7, 8, 9]
#   [635/2735] 106340_Statistics(doc): target at [2] | cited: [3, 9]
#   [636/2735] 106340_TechnicalTerms(doc): target at [2] | cited: [0, 2, 8, 5, 6]
#   [637/2735] 106340_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 8, 4]
#   [638/2735] 106340_doc: target at [1] | cited: [0, 3, 6, 8, 9]
#   [639/2735] 106580_Authoritative(doc): target at [3] | cited: [0, 1, 2, 5, 6]
# ...
#   [2518/2735] 15770_FS(doc): target at [7] | cited: [0, 3, 6, 2, 7]
#   [2519/2735] 15770_Fluency(doc): target at [6] | cited: [0, 1, 2, 7, 3]
#   [2520/2735] 15770_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [2521/2735] 15770_QS(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2522/2735] 15770_Quotes(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2523/2735] 15770_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2524/2735] 15770_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2525/2735] 15770_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2526/2735] 15770_UniqueWords(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2527/2735] 15770_doc: target at [6] | cited: [0, 1, 9, 2, 3]
#   [2528/2735] 16033_Authoritative(doc): target at [9] | cited: [0, 4, 3, 7, 8]
#   [2529/2735] 16033_CQ(doc): target at [9] | cited: [0, 1, 3, 4, 2]
#   [2530/2735] 16033_CQS(doc): target at [9] | cited: [0, 1, 4, 2, 3]
#   [2531/2735] 16033_CS(doc): target at [9] | cited: [0, 4, 2, 8, 3]
#   [2532/2735] 16033_Citations(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2533/2735] 16033_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2534/2735] 16033_FC(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2535/2735] 16033_FCQ(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2536/2735] 16033_FCQS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2537/2735] 16033_FCS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2538/2735] 16033_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [2539/2735] 16033_FQS(doc): target at [9] | cited: [0, 4, 2, 3, 1]
#   [2540/2735] 16033_FS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2541/2735] 16033_Fluency(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2542/2735] 16033_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2543/2735] 16033_QS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2544/2735] 16033_Quotes(doc): target at [9] | cited: [0, 2, 3, 7, 8]
#   [2545/2735] 16033_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2546/2735] 16033_Statistics(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2547/2735] 16033_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2548/2735] 16033_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 5, 3]
#   [2549/2735] 16033_doc: target at [9] | cited: [0, 1, 2, 4, 3]
#   [2550/2735] 16339_Authoritative(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2551/2735] 16339_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 8]
#   [2552/2735] 16339_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [2553/2735] 16339_CS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2554/2735] 16339_Citations(doc): target at [5] | cited: [0, 1, 9, 2, 3]
#   [2555/2735] 16339_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2556/2735] 16339_FC(doc): target at [6] | cited: [0, 1, 3, 4, 9]
#   [2557/2735] 16339_FCQ(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [2558/2735] 16339_FCQS(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2559/2735] 16339_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2560/2735] 16339_FQ(doc): target at [7] | cited: [0, 8, 1, 2, 4]
#   [2561/2735] 16339_FQS(doc): target at [7] | cited: [0, 9, 1, 2, 3]
#   [2562/2735] 16339_FS(doc): target at [7] | cited: [0, 1, 2, 9, 5]
#   [2563/2735] 16339_Fluency(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2564/2735] 16339_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [2565/2735] 16339_QS(doc): target at [6] | cited: [0, 9, 1, 3, 4]
#   [2566/2735] 16339_Quotes(doc): target at [6] | cited: [0, 1, 2, 3, 8]
#   [2567/2735] 16339_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2568/2735] 16339_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2569/2735] 16339_TechnicalTerms(doc): target at [4] | cited: [0, 1, 9, 2, 3]
#   [2570/2735] 16339_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [2571/2735] 16339_doc: target at [4] | cited: [0, 1, 9, 2, 5]
#   [2572/2735] 16829_Authoritative(doc): target at [7] | cited: [0, 1, 2]
#   [2573/2735] 16829_CQ(doc): target at [4] | cited: [0, 1, 5, 8, 9]
#   [2574/2735] 16829_CQS(doc): target at [5] | cited: [0, 1, 2, 9, 7]
#   [2575/2735] 16829_CS(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [2576/2735] 16829_Citations(doc): target at [6] | cited: [0, 1, 2, 8]
#   [2577/2735] 16829_ContentImprovement(doc): target at [6] | cited: [0, 1, 2]
#   [2578/2735] 16829_FC(doc): target at [4] | cited: []
#   [2579/2735] 16829_FCQ(doc): target at [5] | cited: [0, 1, 3, 2, 8]
#   [2580/2735] 16829_FCQS(doc): target at [9] | cited: [0, 1, 4, 7, 9]
#   [2581/2735] 16829_FCS(doc): target at [5] | cited: [0, 1, 4, 9, 2]
#   [2582/2735] 16829_FQ(doc): target at [4] | cited: [0, 1, 2]
#   [2583/2735] 16829_FQS(doc): target at [7] | cited: [0, 1, 9, 2, 8]
#   [2584/2735] 16829_FS(doc): target at [4] | cited: [0, 1, 2, 8, 9]
#   [2585/2735] 16829_Fluency(doc): target at [5] | cited: [0, 1, 4, 8]
#   [2586/2735] 16829_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 5, 9]
#   [2587/2735] 16829_QS(doc): target at [7] | cited: [0, 5, 9, 1, 2]
#   [2588/2735] 16829_Quotes(doc): target at [6] | cited: [0, 1, 2, 4, 9]
#   [2589/2735] 16829_SimpleLanguage(doc): target at [5] | cited: [0, 1, 5, 9, 6]
#   [2590/2735] 16829_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2591/2735] 16829_TechnicalTerms(doc): target at [5] | cited: [0, 1, 7, 8, 2]
#   [2592/2735] 16829_UniqueWords(doc): target at [4] | cited: [0, 1, 7, 9]
#   [2593/2735] 16829_doc: target at [4] | cited: [0, 1, 2, 4, 8]
#   [2594/2735] 16981_Authoritative(doc): target at [5] | cited: [0, 5, 2, 3, 6]
#   [2595/2735] 16981_CQ(doc): target at [5] | cited: [0, 5, 2, 3, 6]
#   [2596/2735] 16981_CQS(doc): target at [5] | cited: [0, 5, 2, 3, 6]
#   [2597/2735] 16981_CS(doc): target at [5] | cited: []
#   [2598/2735] 16981_Citations(doc): target at [5] | cited: [0, 5, 1, 2, 8]
#   [2599/2735] 16981_ContentImprovement(doc): target at [6] | cited: [0, 9, 2, 3, 5]
#   [2600/2735] 16981_FC(doc): target at [6] | cited: [1, 9, 2, 3, 0]
#   [2601/2735] 16981_FCQ(doc): target at [6] | cited: [0, 1, 6, 9, 2]
#   [2602/2735] 16981_FCQS(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2603/2735] 16981_FCS(doc): target at [6] | cited: [0, 6, 2, 5, 7]
#   [2604/2735] 16981_FQ(doc): target at [6] | cited: [0, 6, 9, 2, 3]
#   [2605/2735] 16981_FQS(doc): target at [5] | cited: [0, 5, 2, 6, 3]
#   [2606/2735] 16981_FS(doc): target at [6] | cited: [0, 6, 2, 3, 4]
#   [2607/2735] 16981_Fluency(doc): target at [5] | cited: [0, 9, 2, 3, 5]
#   [2608/2735] 16981_LLMstxt(doc): target at [8] | cited: [0, 8, 2, 4, 5]
#   [2609/2735] 16981_QS(doc): target at [5] | cited: [0, 5, 9, 2, 3]
#   [2610/2735] 16981_Quotes(doc): target at [6] | cited: [0, 6, 9, 2, 3]
#   [2611/2735] 16981_SimpleLanguage(doc): target at [5] | cited: [0, 5, 2, 3, 6]
#   [2612/2735] 16981_Statistics(doc): target at [6] | cited: [1, 9, 2, 7, 3]
#   [2613/2735] 16981_TechnicalTerms(doc): target at [6] | cited: [0, 6, 2, 3, 7]
#   [2614/2735] 16981_UniqueWords(doc): target at [6] | cited: [1, 9, 2, 5, 4]
#   [2615/2735] 16981_doc: target at [5] | cited: [0, 5, 2, 3, 6]
#   [2616/2735] 17599_Authoritative(doc): target at [5] | cited: [0, 2, 3, 5, 6]
#   [2617/2735] 17599_CQ(doc): target at [3] | cited: [0, 3, 5, 1, 2]
#   [2618/2735] 17599_CQS(doc): target at [5] | cited: [0, 5, 6, 1, 2]
#   [2619/2735] 17599_CS(doc): target at [4] | cited: [0, 4, 5, 1, 7]
#   [2620/2735] 17599_Citations(doc): target at [3] | cited: [0, 2, 1, 3, 4]
#   [2621/2735] 17599_ContentImprovement(doc): target at [9] | cited: [0, 2, 7, 8, 3]
#   [2622/2735] 17599_FC(doc): target at [2] | cited: [0, 2, 1, 5, 7]
#   [2623/2735] 17599_FCQ(doc): target at [3] | cited: [1, 8, 5, 4, 7]
#   [2624/2735] 17599_FCQS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [2625/2735] 17599_FCS(doc): target at [0] | cited: [0, 2, 3, 7, 8]
#   [2626/2735] 17599_FQ(doc): target at [0] | cited: [0, 5, 1, 3, 6]
#   [2627/2735] 17599_FQS(doc): target at [0] | cited: [0, 5, 2, 7, 8]
#   [2628/2735] 17599_FS(doc): target at [0] | cited: [0, 5, 2, 3, 6]
#   [2629/2735] 17599_Fluency(doc): target at [4] | cited: [0, 4, 5, 1, 6]
#   [2630/2735] 17599_LLMstxt(doc): target at [6] | cited: [1, 2, 7, 8, 0]
#   [2631/2735] 17599_QS(doc): target at [6] | cited: [0, 2, 3, 7, 8]
#   [2632/2735] 17599_Quotes(doc): target at [6] | cited: [0, 2, 3, 1, 4]
#   [2633/2735] 17599_SimpleLanguage(doc): target at [5] | cited: [1, 7, 8, 0, 5]
#   [2634/2735] 17599_Statistics(doc): target at [6] | cited: [0, 6, 1, 2, 8]
#   [2635/2735] 17599_TechnicalTerms(doc): target at [6] | cited: [0, 5, 6, 1, 7]
#   [2636/2735] 17599_UniqueWords(doc): target at [4] | cited: [0, 4, 1, 2, 3]
#   [2637/2735] 17599_doc: target at [7] | cited: [0, 7, 1, 2, 5]
#   [2638/2735] 17606_Authoritative(doc): target at [7] | cited: [0, 1, 2, 3, 8]
#   [2639/2735] 17606_CQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2640/2735] 17606_CQS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [2641/2735] 17606_CS(doc): target at [8] | cited: [0, 9, 2, 7, 8]
#   [2642/2735] 17606_Citations(doc): target at [1] | cited: [1, 2, 9, 4, 3]
#   [2643/2735] 17606_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2644/2735] 17606_FC(doc): target at [7] | cited: [0, 1, 2, 4, 9]
#   [2645/2735] 17606_FCQ(doc): target at [8] | cited: [0, 1, 2, 9, 5]
#   [2646/2735] 17606_FCQS(doc): target at [8] | cited: [0, 1, 2, 9, 5]
#   [2647/2735] 17606_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [2648/2735] 17606_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2649/2735] 17606_FQS(doc): target at [8] | cited: [0, 6, 1, 2, 3]
#   [2650/2735] 17606_FS(doc): target at [7] | cited: [0, 1, 2, 9, 3]
#   [2651/2735] 17606_Fluency(doc): target at [6] | cited: [8, 9, 3, 1, 4]
#   [2652/2735] 17606_LLMstxt(doc): target at [5] | cited: [0, 1, 2, 9, 3]
#   [2653/2735] 17606_QS(doc): target at [6] | cited: [0, 1, 8, 5, 7]
#   [2654/2735] 17606_Quotes(doc): target at [6] | cited: [1, 0, 8, 7, 4]
#   [2655/2735] 17606_SimpleLanguage(doc): target at [2] | cited: [0, 1, 3, 9]
#   [2656/2735] 17606_Statistics(doc): target at [8] | cited: [0, 1, 9, 6, 4]
#   [2657/2735] 17606_TechnicalTerms(doc): target at [8] | cited: [2, 9, 1, 7, 4]
#   [2658/2735] 17606_UniqueWords(doc): target at [8] | cited: [0, 3, 9, 2, 7]
#   [2659/2735] 17606_doc: target at [6] | cited: [0, 1, 5, 7, 9]
#   [2660/2735] 17636_Authoritative(doc): target at [0] | cited: [0, 1, 2, 3, 9]
#   [2661/2735] 17636_CQ(doc): target at [5] | cited: [0, 1, 3, 4, 5]
#   [2662/2735] 17636_CQS(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [2663/2735] 17636_CS(doc): target at [1] | cited: [0, 1, 2, 3, 7]
#   [2664/2735] 17636_Citations(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [2665/2735] 17636_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [2666/2735] 17636_FC(doc): target at [6] | cited: [0, 1, 2, 4, 6]
#   [2667/2735] 17636_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [2668/2735] 17636_FCQS(doc): target at [4] | cited: [0, 1, 8, 3, 7]
#   [2669/2735] 17636_FCS(doc): target at [8] | cited: [0, 1, 2, 4, 9]
#   [2670/2735] 17636_FQ(doc): target at [5] | cited: [0, 1, 2, 3, 7]
#   [2671/2735] 17636_FQS(doc): target at [5] | cited: [0, 1, 2, 8, 4]
#   [2672/2735] 17636_FS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2673/2735] 17636_Fluency(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [2674/2735] 17636_LLMstxt(doc): target at [9] | cited: [0, 1, 8, 3, 6]
#   [2675/2735] 17636_QS(doc): target at [4] | cited: [0, 1, 2, 5, 7]
#   [2676/2735] 17636_Quotes(doc): target at [4] | cited: [0, 1, 2, 4, 7]
#   [2677/2735] 17636_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [2678/2735] 17636_Statistics(doc): target at [1] | cited: [0, 1, 3, 2, 7]
#   [2679/2735] 17636_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 5, 6]
#   [2680/2735] 17636_UniqueWords(doc): target at [7] | cited: [0, 3, 1, 6, 7]
#   [2681/2735] 17636_doc: target at [4] | cited: [0, 1, 2, 9, 4]
#   [2682/2735] 17656_Authoritative(doc): target at [7] | cited: [0, 1, 2, 3]
#   [2683/2735] 17656_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2684/2735] 17656_CQS(doc): target at [7] | cited: [0, 1, 2, 6, 5]
#   [2685/2735] 17656_CS(doc): target at [7] | cited: [0, 1, 2, 7, 3]
#   [2686/2735] 17656_Citations(doc): target at [7] | cited: [0, 1, 3, 4, 8]
#   [2687/2735] 17656_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2688/2735] 17656_FC(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2689/2735] 17656_FCQ(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2690/2735] 17656_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2691/2735] 17656_FCS(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2692/2735] 17656_FQ(doc): target at [9] | cited: [0, 3, 1, 2, 9]
#   [2693/2735] 17656_FQS(doc): target at [8] | cited: [0, 1, 8, 2, 6]
#   [2694/2735] 17656_FS(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2695/2735] 17656_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2696/2735] 17656_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [2697/2735] 17656_QS(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [2698/2735] 17656_Quotes(doc): target at [5] | cited: [0, 1, 2, 3]
#   [2699/2735] 17656_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2700/2735] 17656_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2701/2735] 17656_TechnicalTerms(doc): target at [7] | cited: [0, 1, 7, 2, 8]
#   [2702/2735] 17656_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2703/2735] 17656_doc: target at [5] | cited: [0, 1, 2, 7, 6]
#   [2704/2735] 18937_Authoritative(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [2705/2735] 18937_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 9]
#   [2706/2735] 18937_CQS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2707/2735] 18937_CS(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [2708/2735] 18937_Citations(doc): target at [2] | cited: [0, 1, 2, 9, 3]
#   [2709/2735] 18937_ContentImprovement(doc): target at [4] | cited: [0, 1, 9, 7, 3]
#   [2710/2735] 18937_FC(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [2711/2735] 18937_FCQ(doc): target at [4] | cited: [0, 5, 1, 2, 3]
#   [2712/2735] 18937_FCQS(doc): target at [5] | cited: [0, 5, 1, 9, 2]
#   [2713/2735] 18937_FCS(doc): target at [3] | cited: [0, 1, 2, 4, 9]
#   [2714/2735] 18937_FQ(doc): target at [5] | cited: [0, 1, 2, 6, 9]
#   [2715/2735] 18937_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [2716/2735] 18937_FS(doc): target at [4] | cited: [0, 9, 2, 3, 1]
#   [2717/2735] 18937_Fluency(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [2718/2735] 18937_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2719/2735] 18937_QS(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [2720/2735] 18937_Quotes(doc): target at [4] | cited: [0, 1, 3, 2, 9]
#   [2721/2735] 18937_SimpleLanguage(doc): target at [4] | cited: [0, 1, 3, 2, 9]
#   [2722/2735] 18937_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2723/2735] 18937_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2724/2735] 18937_UniqueWords(doc): target at [4] | cited: [0, 3, 1, 2, 6]
#   [2725/2735] 18937_doc: target at [4] | cited: [0, 1, 2, 9, 7]
#   [2726/2735] 18938_Authoritative(doc): target at [8] | cited: [1, 0, 4, 5, 8]
#   [2727/2735] 18938_CQ(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [2728/2735] 18938_CQS(doc): target at [6] | cited: [0, 1, 4]
#   [2729/2735] 18938_CS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2730/2735] 18938_Citations(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2731/2735] 18938_ContentImprovement(doc): target at [7] | cited: [0, 4, 1, 2, 5]
#   [2732/2735] 18938_FC(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2733/2735] 18938_FCQ(doc): target at [8] | cited: [0, 1, 4, 8, 5]
#   [2734/2735] 18938_FCQS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2735/2735] 18938_FCS(doc): target at [5] | cited: [0, 1, 5, 4, 9]
# ============================================================
# GENERATION COMPLETE
# Started:    12:48:04
# Finished:   22:10:43
# Total time: 9:22:38
# Results:    2734 rows saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation_results_A.parquet

# %% [markdown]
# ## Inspect Results

# %%
df_results = pd.read_parquet(output_path)

INSPECT_QUERY_ID = df_results["query_id"].iloc[0]  # <- change to inspect other runs

row = df_results[df_results["query_id"] == INSPECT_QUERY_ID].iloc[0]

print(f"Run (query_id):    {row['query_id']}")
print(f"Original query:    {row['original_query_id']}")
print(f"Method:            {row['method']}")
print(f"Query:             {row['query']}")
print(f"Num docs:          {row['num_docs']}")
print(f"Target position:   {row['target_new_position']} (0-based)")
print(f"Citation order:    {row['citation_order']}")
print(f"Target cited:      {'YES' if row['target_new_position'] in row['citation_order'] else 'NO'}")
print(f"\n--- LLM Response ---")
print(row["llm_response"][:800])
# Out:
# Run (query_id):    100162_Authoritative(doc)
# Original query:    100162
# Method:            Authoritative(doc)
# Query:             table lamps for bedroom
# Num docs:          10
# Target position:   7 (0-based)
# Citation order:    [0 5 9 1 3 8 4 7]
# Target cited:      YES
#
# --- LLM Response ---
# When searching for the perfect table lamp for your bedroom, there are several well-designed options featuring various innovative functionalities and styles. Here are some of the top choices based on their features and benefits:
#
# 1. **Touch Control Table Lamp with USB Ports**: This lamp offers a modern design with a touch control feature allowing users to adjust brightness between three levels (low, medium, high) with just a tap. It also includes two USB charging ports, making it convenient to charge devices regardless of whether the lamp is on or off. The lamp is equipped with a 6W LED bulb which is energy efficient, consuming up to 90% less energy than traditional incandescent bulbs. This option not only provides functional lighting but also enhances the décor of your space with its styli

# %% [markdown]
# ## Merge Results
#
# **Run only after all 4 notebooks (A, B, C, D) are complete.**

# %%
# Merge all 4 parquet files into one
NOTEBOOK_IDS = ["A", "B", "C", "D"]
dfs = []
for nb in NOTEBOOK_IDS:
    path = os.path.join(data_dir, f"generation_results_{nb}.parquet")
    if os.path.exists(path):
        dfs.append(pd.read_parquet(path))
        print(f"Loaded generation_results_{nb}.parquet ({len(dfs[-1])} rows)")
    else:
        print(f"WARNING: generation_results_{nb}.parquet not found — skipping")

merged = pd.concat(dfs, ignore_index=True)
merged_path = os.path.join(data_dir, "generation_results.parquet")
merged.to_parquet(merged_path, index=False)
print(f"\nMerged {len(merged)} rows into generation_results.parquet")
# Out:
# Loaded generation_results_A.parquet (2734 rows)
# Loaded generation_results_B.parquet (2735 rows)
# Loaded generation_results_C.parquet (2734 rows)
# Loaded generation_results_D.parquet (2735 rows)
#
# Merged 10938 rows into generation_results.parquet

# %% [markdown]
# ## Summary

# %%
# Load merged parquet
merged_path = os.path.join(data_dir, "generation_results.parquet")
df_results = pd.read_parquet(merged_path)

print(f"Total runs done:   {len(df_results)}")
print(f"Total runs expected: {len(all_run_ids_full)}")
print(f"Remaining:         {len(all_run_ids_full) - len(df_results)}")
print()

# Find missing runs
done_set = set(df_results["query_id"].tolist())
missing = [r for r in all_run_ids_full if r not in done_set]
print(f"Missing runs ({len(missing)}):")
for r in missing:
    print(f"  {r}")
print()

# Citation rate per method
df_results["target_cited"] = df_results.apply(
    lambda row: 1 if row["target_new_position"] in row["citation_order"] else 0, axis=1
)

citation_rates = df_results.groupby("method")["target_cited"].mean().sort_values(ascending=False)
print("Citation rate per method (% runs where target was cited):")
for method, rate in citation_rates.items():
    bar = "\u2588" * int(rate * 20) + "\u2591" * (20 - int(rate * 20))
    print(f"  {method:30} [{bar}] {rate:.1%}")
# Out:
# Total runs done:   10938
# Total runs expected: 10940
# Remaining:         2
#
# Missing runs (2):
#   103863_ContentImprovement(doc)
#   50937_CS(doc)
#
# Citation rate per method (% runs where target was cited):
#   CS(doc)                        [█████████████░░░░░░░] 69.3%
#   Authoritative(doc)             [█████████████░░░░░░░] 68.0%
#   Fluency(doc)                   [█████████████░░░░░░░] 66.9%
#   TechnicalTerms(doc)            [█████████████░░░░░░░] 66.3%
#   QS(doc)                        [█████████████░░░░░░░] 65.6%
#   CQS(doc)                       [█████████████░░░░░░░] 65.4%
#   ContentImprovement(doc)        [█████████████░░░░░░░] 65.3%
#   CQ(doc)                        [████████████░░░░░░░░] 64.9%
#   UniqueWords(doc)               [████████████░░░░░░░░] 64.1%
#   Citations(doc)                 [████████████░░░░░░░░] 63.5%
#   FCQ(doc)                       [████████████░░░░░░░░] 63.5%
#   SimpleLanguage(doc)            [████████████░░░░░░░░] 63.4%
#   FCQS(doc)                      [████████████░░░░░░░░] 63.4%
#   FC(doc)                        [████████████░░░░░░░░] 62.8%
#   FQ(doc)                        [████████████░░░░░░░░] 62.6%
#   Quotes(doc)                    [████████████░░░░░░░░] 62.4%
#   FQS(doc)                       [████████████░░░░░░░░] 62.4%
#   doc                            [████████████░░░░░░░░] 62.3%
#   FS(doc)                        [████████████░░░░░░░░] 61.3%
#   FCS(doc)                       [████████████░░░░░░░░] 60.8%
#   LLMstxt(doc)                   [███████████░░░░░░░░░] 55.0%
#   Statistics(doc)                [█████████░░░░░░░░░░░] 45.4%

# %%
# Process the 2 missing runs
MISSING_RUNS = ["103863_ContentImprovement(doc)", "50937_CS(doc)"]

for query_id in MISSING_RUNS:
    group = df[df["query_id"] == query_id]
    query_text        = group["query"].iloc[0]
    original_query_id = group["original_query_id"].iloc[0]
    method            = group["method"].iloc[0]

    docs, target_new_position = build_context(group)

    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    response, _    = llm.generate(messages)
    citation_order = extract_citation_order(response.content)

    print(f"{query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    # Append to merged parquet
    df_results = pd.read_parquet(merged_path)
    new_row = pd.DataFrame([{
        "query_id":            query_id,
        "original_query_id":   original_query_id,
        "method":              method,
        "query":               query_text,
        "target_new_position": target_new_position,
        "num_docs":            len(docs),
        "citation_order":      citation_order,
        "llm_response":        response.content,
    }])
    df_results = pd.concat([df_results, new_row], ignore_index=True)
    df_results.to_parquet(merged_path, index=False)
    print(f"  Saved to {merged_path}")
# Out:
# 103863_ContentImprovement(doc): target at [5] | cited: [0, 3, 4, 2, 1]
#   Saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation_results.parquet
# 50937_CS(doc): target at [6] | cited: [0, 3, 5, 7, 1]
#   Saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation_results.parquet

# %%
# Load merged parquet
merged_path = os.path.join(data_dir, "generation_results.parquet")
df_results = pd.read_parquet(merged_path)

print(f"Total runs done:   {len(df_results)}")
print(f"Total runs expected: {len(all_run_ids_full)}")
print(f"Remaining:         {len(all_run_ids_full) - len(df_results)}")
print()

# Find missing runs
done_set = set(df_results["query_id"].tolist())
missing = [r for r in all_run_ids_full if r not in done_set]
print(f"Missing runs ({len(missing)}):")
for r in missing:
    print(f"  {r}")
print()

# Citation rate per method
df_results["target_cited"] = df_results.apply(
    lambda row: 1 if row["target_new_position"] in row["citation_order"] else 0, axis=1
)

citation_rates = df_results.groupby("method")["target_cited"].mean().sort_values(ascending=False)
print("Citation rate per method (% runs where target was cited):")
for method, rate in citation_rates.items():
    bar = "\u2588" * int(rate * 20) + "\u2591" * (20 - int(rate * 20))
    print(f"  {method:30} [{bar}] {rate:.1%}")
# Out:
# Total runs done:   10940
# Total runs expected: 10940
# Remaining:         0
#
# Missing runs (0):
#
# Citation rate per method (% runs where target was cited):
#   CS(doc)                        [█████████████░░░░░░░] 69.4%
#   Authoritative(doc)             [█████████████░░░░░░░] 68.0%
#   Fluency(doc)                   [█████████████░░░░░░░] 66.9%
#   TechnicalTerms(doc)            [█████████████░░░░░░░] 66.3%
#   QS(doc)                        [█████████████░░░░░░░] 65.6%
#   CQS(doc)                       [█████████████░░░░░░░] 65.4%
#   ContentImprovement(doc)        [█████████████░░░░░░░] 65.2%
#   CQ(doc)                        [████████████░░░░░░░░] 64.9%
#   UniqueWords(doc)               [████████████░░░░░░░░] 64.1%
#   Citations(doc)                 [████████████░░░░░░░░] 63.5%
#   FCQ(doc)                       [████████████░░░░░░░░] 63.5%
#   SimpleLanguage(doc)            [████████████░░░░░░░░] 63.4%
#   FCQS(doc)                      [████████████░░░░░░░░] 63.4%
#   FC(doc)                        [████████████░░░░░░░░] 62.8%
#   FQ(doc)                        [████████████░░░░░░░░] 62.6%
#   Quotes(doc)                    [████████████░░░░░░░░] 62.4%
#   FQS(doc)                       [████████████░░░░░░░░] 62.4%
#   doc                            [████████████░░░░░░░░] 62.3%
#   FS(doc)                        [████████████░░░░░░░░] 61.3%
#   FCS(doc)                       [████████████░░░░░░░░] 60.8%
#   LLMstxt(doc)                   [███████████░░░░░░░░░] 55.0%
#   Statistics(doc)                [█████████░░░░░░░░░░░] 45.4%
