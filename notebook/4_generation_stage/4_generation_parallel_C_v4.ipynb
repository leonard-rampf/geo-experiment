# %% [markdown]
# # Generation Stage — Notebook C (50%–75%)
#
# Generates LLM responses for each query-method combination using GPT-4o-mini. For each run, the retrieved documents are passed to the LLM in retrieval order as numbered search results, and the LLM generates a product recommendation with inline citations. Since the generation is time-consuming, the workload is split across four parallel notebooks (A–D), each processing its own share of all runs.
#
# **Input:**
# - `data/retail/retrieval/20260413_retrieval_results_geo_v2.csv` — retrieval results per query-method combination
#
# **Output:**
# - `data/retail/generation/4_generation_results_C_v4.parquet` — generation results for this notebook's range
#
# ## Parallel Setup
# | Notebook | Range |
# |---|---|
# | A | 0% – 25% |
# | B | 25% – 50% |
# | C | 50% – 75% |
# | D | 75% – 100% |
#
# ## Structure
# 1. **Setup** — imports and paths
# 2. **Data Preparation** — loads retrieval CSV and identifies runs with/without target
# 3. **Helper Functions** — prompt builder, citation extractor
# 4. **Parameters** — LLM model, output path, run assignment
# 5. **Generation** — runs all assigned query-method combinations, saves incrementally
# 6. **Inspect Results** — verifies output for a sample run
#
# > Merge Results and Summary are run in Notebook A after all four notebooks complete.

# %% [markdown]
# ## 1. Setup
#
# Imports required libraries and defines file paths relative to the project root.

# %%
# Library imports
import json
import os
import re
import sys
import time
from datetime import datetime

import pandas as pd
import numpy as np

# Go up two levels to project root
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, "..", ".."))

# Add src/ to path so OpenAIHelper can be imported
sys.path.insert(0, os.path.join(project_root, "src"))


from llms import OpenAIHelper

# Load API key from config.json
config_path = os.path.join(project_root, "config.json")
with open(config_path, "r") as f:
    config = json.load(f)
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

data_dir = os.path.join(project_root, "data", "retail")

print("Setup complete.")
print(f"Project root: {project_root}")
# Out:
# Setup complete.
# Project root: /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment

# %% [markdown]
# ## 2. Data Preparation
#
# Loads the retrieval CSV and parses the compound `query_id` (format: `{original_query_id}_{method}`) into its components. Identifies which runs have a target document in the retrieval results and which do not — runs without a target are skipped during generation.

# %%
# Load the retrieval CSV — one row per document per query_id
# query_id format: "{original_query_id}_{method}"
retrieval_csv_path = os.path.join(data_dir, "retrieval/20260413_retrieval_results_geo_v2.csv")
df = pd.read_csv(retrieval_csv_path)

# Extract original_query_id (numeric) and method name from compound query_id
df["original_query_id"] = df["query_id"].str.extract(r"^(\d+)_")
df["method"]            = df["query_id"].str.extract(r"^\d+_(.+)$")

# Identify runs where the target document is missing from the retrieval results
# These runs are skipped during generation (no valid citation position can be computed)
target_per_run = df.groupby("query_id")["is_target"].sum()
runs_with_target    = set(target_per_run[target_per_run == 1].index)
runs_without_target = set(target_per_run[target_per_run == 0].index)

# Save runs without target for documentation and reproducibility
runs_without_target_path = os.path.join(data_dir, "generation/4_generation_runs_without_target_v3.json")
with open(runs_without_target_path, "w") as f:
    json.dump(sorted(list(runs_without_target)), f, indent=4)

print(f"Total rows:              {len(df)}")
print(f"Unique runs (query_ids): {df['query_id'].nunique()}")
print(f"Unique original queries: {df['original_query_id'].nunique()}")
print(f"Unique methods:          {df['method'].nunique()}")
print(f"Runs with target:        {len(runs_with_target)}")
print(f"Runs without target:     {len(runs_without_target)} — saved to generation/4_generation_runs_without_target_v3.json")
print()
print("Methods found:")
for m in sorted(df['method'].unique()):
    print(f"  {m}")
# Out:
# Total rows:              109875
# Unique runs (query_ids): 11000
# Unique original queries: 500
# Unique methods:          22
# Runs with target:        10985
# Runs without target:     15 — saved to generation/4_generation_runs_without_target_v3.json
#
# Methods found:
#   Authoritative(doc)
#   CQ(doc)
#   CQS(doc)
#   CS(doc)
#   Citations(doc)
#   ContentImprovement(doc)
#   FC(doc)
#   FCQ(doc)
#   FCQS(doc)
#   FCS(doc)
#   FQ(doc)
#   FQS(doc)
#   FS(doc)
#   Fluency(doc)
#   LLMstxt(doc)
#   QS(doc)
#   Quotes(doc)
#   SimpleLanguage(doc)
#   Statistics(doc)
#   TechnicalTerms(doc)
#   UniqueWords(doc)
#   doc

# %% [markdown]
# ## 3. Helper Functions
#
# Defines the developer prompt and three helper functions used during generation:
# - `build_context` — sorts retrieved documents by rank and identifies the 0-based target position
# - `build_user_prompt` — formats the query and numbered document list into the LLM user prompt
# - `extract_citation_order` — parses inline citations from the LLM response and returns them as a 0-based index list in order of first appearance

# %%
# System prompt for the LLM — instructs it to act as a product recommender, recommend multiple products, and cite each product with exactly one inline reference [1].
DEVELOPER_PROMPT = """Your are a product recommender system for an online marketplace. Write an accurate and concise answer for the given user question, using only the provided summarized web search results. The answer should be correct, high-quality, and written by an expert using an unbiased and journalistic tone. The answer should be informative, interesting, and engaging. The answer's logic and reasoning should be rigorous and defensible. Each search result represents exactly one product. The cited search result should fully support all the information about that product. Search results need to be cited using [index], for example [1]. Recommend multiple products, each based on exactly one search result. Do not stack multiple citations for a single product."""

# Document type label used in the user prompt
DOC_TYPE = "Product Description"


def build_context(group):
    """
    Takes all rows for one query_id, sorts by rank, re-numbers 1..N.
    Returns:
        docs: list of doc_text in retrieval order
        target_new_position: 0-based position of target doc after re-numbering
    """
    group = group.sort_values("rank").reset_index(drop=True)
    docs = group["doc_text"].tolist()

    # Find 0-based position of the target document
    target_new_position = None
    for i, row in group.iterrows():
        if row["is_target"] == 1:
            target_new_position = i  # 0-based
            break

    return docs, target_new_position


def build_user_prompt(query, docs):
    """
    Builds the user prompt for the LLM.
    docs: list of doc_text strings, numbered 1..N
    """
    sources = ""
    for i, doc_text in enumerate(docs, start=1):
        sources += f"[{i}] {DOC_TYPE}: {doc_text}\n\n"
    return f"Question: {query}\n\nSearch Results:\n{sources}"


def extract_citation_order(response_text):
    """
    Extracts citation indices in order of first appearance.
    0-based: [1] in text -> index 0, [2] -> index 1, etc.
    e.g. "...product [2] is great [1][2]..." -> [1, 0]
    """
    citations = re.findall(r"\[(\d+)\]", response_text)
    seen = []
    for c in citations:
        idx = int(c) - 1  # 0-based
        if idx not in seen:
            seen.append(idx)
    return seen


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## 4. Parameters
#
# Sets the LLM model, output path, and LLM inference parameters. Automatically assigns this notebook's share of all runs (50%–75%), loads already completed runs from the output parquet to support safe resume after interruption, and initialises the LLM client.

# %%
# LLM model used for response generation
LLM_NAME = "gpt-4o-mini-2024-07-18"

# Notebook ID — A processes 0%–25% of all runs
NOTEBOOK_ID = "C"

# Output file for this notebook's results — separate from B, C, D to allow parallel execution
output_path = os.path.join(data_dir, "generation/4_generation_results_C_v4.parquet")

# Based on Vertex AI / Gemini default inference parameters:
# https://docs.cloud.google.com/vertex-ai/generative-ai/docs/model-reference/inference?hl=de
TEMPERATURE       = 1.0
TOP_P             = 0.95
SEED              = 42
FREQUENCY_PENALTY = 0.0
PRESENCE_PENALTY  = 0.0

# Assign this notebook's quarter of all runs sorted alphabetically by query_id
all_run_ids_full = sorted(runs_with_target)
total = len(all_run_ids_full)
start_idx = int(total * 50/100)
end_idx   = int(total * 75/100)
all_run_ids = all_run_ids_full[start_idx:end_idx]

# Load already completed runs to support safe resume after interruption
if os.path.exists(output_path):
    df_done = pd.read_parquet(output_path)
    done_keys = set(df_done["query_id"].tolist())
    already_done = len(done_keys)
else:
    done_keys = set()
    already_done = 0

llm = OpenAIHelper(LLM_NAME)

remaining = len(all_run_ids) - already_done
print(f"Notebook:      {NOTEBOOK_ID}")
print(f"LLM:           {LLM_NAME}")
print(f"Range:         50%–75% ({start_idx}–{end_idx} of {total})")
print(f"Runs in range: {len(all_run_ids)}")
print(f"Already done:  {already_done}")
print(f"Remaining:     {remaining}")
# Out:
# Notebook:      C
# LLM:           gpt-4o-mini-2024-07-18
# Range:         50%–75% (5492–8238 of 10985)
# Runs in range: 2746
# Already done:  0
# Remaining:     2746

# %% [markdown]
# ## 5. Generation
#
# Iterates over all assigned runs and generates one LLM response per query-method combination. For each run, the retrieved documents are sorted by rank, passed to the LLM as numbered search results, and the response is parsed for inline citations. Results are saved incrementally after each run — safe to interrupt and resume. Runs without a target document in the retrieval results are skipped. Failed runs are retried once after a 10-second wait.

# %%
# Load existing results if the output file already exists
# Allows safe resume without reprocessing completed runs
if os.path.exists(output_path):
    results_df = pd.read_parquet(output_path)
    results = results_df.to_dict("records")
else:
    results = []

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%H:%M:%S')}")
print(f"Total runs to process: {len(all_run_ids)}")
print()

for i, query_id in enumerate(all_run_ids):

    # Skip runs already completed in a previous session
    if query_id in done_keys:
        continue

    # Load all documents for this run
    group = df[df["query_id"] == query_id]
    query_text         = group["query"].iloc[0]
    original_query_id  = group["original_query_id"].iloc[0]
    method             = group["method"].iloc[0]

    # Sort docs by retrieval rank and find target position
    docs, target_new_position = build_context(group)

    # Skip runs where the target document is not in the retrieval results
    if target_new_position is None:
        print(f"  [{i+1}] {query_id}: no target — skipping")
        continue

    # Build LLM prompt with numbered search results
    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    try:
        # Generate LLM response and extract citation order
        response, _ = llm.generate(messages)
        response_text    = response.content
        citation_order   = extract_citation_order(response_text)

        # Store result and save incrementally — no work lost on crash or interruption
        results.append({
            "query_id":            query_id,
            "original_query_id":   original_query_id,
            "method":              method,
            "query":               query_text,
            "target_new_position": target_new_position,
            "num_docs":            len(docs),
            "citation_order":      citation_order,
            "llm_response":        response_text,
        })
        done_keys.add(query_id)
        pd.DataFrame(results).to_parquet(output_path, index=False)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    except Exception as e:
        # First failure — wait 10 seconds and retry once (handles rate limits)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: ERROR — {e}")
        time.sleep(10)
        try:
            response, _    = llm.generate(messages)
            response_text  = response.content
            citation_order = extract_citation_order(response_text)
            results.append({
                "query_id":            query_id,
                "original_query_id":   original_query_id,
                "method":              method,
                "query":               query_text,
                "target_new_position": target_new_position,
                "num_docs":            len(docs),
                "citation_order":      citation_order,
                "llm_response":        response_text,
            })
            done_keys.add(query_id)
            pd.DataFrame(results).to_parquet(output_path, index=False)
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: done (retry OK)")
        except Exception as e2:
            # Second failure — skip this run and continue with the next
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: FAILED — {e2}")

# Summary
end_time = datetime.now()
elapsed  = end_time - start_time
print(f"{'='*60}")
print(f"GENERATION COMPLETE")
print(f"Started:    {start_time.strftime('%H:%M:%S')}")
print(f"Finished:   {end_time.strftime('%H:%M:%S')}")
print(f"Total time: {str(elapsed).split('.')[0]}")
print(f"Results:    {len(results)} rows saved to {output_path}")
# Out:
# Started at: 21:43:48
# Total runs to process: 2746
#
#   [1174/2746] 57597_FCQ(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1175/2746] 57597_FCQS(doc): target at [5] | cited: [0, 1, 2, 3, 6]
#   [1176/2746] 57597_FCS(doc): target at [4] | cited: [0, 1, 2, 7, 6]
#   [1177/2746] 57597_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [1178/2746] 57597_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [1179/2746] 57597_FS(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [1180/2746] 57597_Fluency(doc): target at [2] | cited: [0, 1, 2, 3, 7]
#   [1181/2746] 57597_LLMstxt(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [1182/2746] 57597_QS(doc): target at [2] | cited: [0, 1, 7, 4]
#   [1183/2746] 57597_Quotes(doc): target at [2] | cited: [0, 1, 2, 4, 7]
#   [1184/2746] 57597_SimpleLanguage(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1185/2746] 57597_Statistics(doc): target at [2] | cited: [0, 1, 3, 4, 6]
#   [1186/2746] 57597_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 3, 7]
#   [1187/2746] 57597_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1188/2746] 57597_doc: target at [1] | cited: [0, 1, 2, 3, 7]
#   [1189/2746] 57618_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1190/2746] 57618_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1191/2746] 57618_CQS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [
doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1291/2746] 58269_LLMstxt(doc): target at [3] | cited: [0, 1, 3, 4]
#   [1292/2746] 58269_QS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1293/2746] 58269_Quotes(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [1294/2746] 58269_SimpleLanguage(doc): target at [3] | cited: [0, 1, 3, 4, 9]
#   [1295/2746] 58269_Statistics(doc): target at [1] | cited: [0, 1, 2, 4, 9]
#   [1296/2746] 58269_TechnicalTerms(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1297/2746] 58269_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1298/2746] 58269_doc: target at [3] | cited: [0, 1, 3, 4, 5]
#   [1299/2746] 58302_CQ(doc): target at [7] | cited: [0, 1, 3, 9, 8]
#   [1300/2746] 58302_CQS(doc): target at [8] | cited: [0, 2, 3, 4, 7]
#   [1301/2746] 58302_CS(doc): target at [7] | cited: [0, 2, 1, 8, 9]
#   [1302/2746] 58302_Citations(doc): target at [7] | cited: [0, 2, 8, 3, 9]
#   [1303/2746] 58302_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [1304/2746] 58302_FC(doc): target at [7] | cited: [0, 3, 4, 9]
#   [1305/2746] 58302_FCQ(doc): target at [8] | cited: [0, 2, 1, 3, 4]
#   [1306/2746] 58302_FCQS(doc): target at [9] | cited: [0, 2, 1, 3, 4]
#   [1307/2746] 58302_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1308/2746] 58302_FQ(doc): target at [8] | cited: [0, 2, 3, 7, 9]
#   [1309/2746] 58302_FQS(doc): target at [7] | cited: [0, 2, 3, 8, 9]
#   [1310/2746] 58302_FS(doc): target at [7] | cited: [0, 2, 6, 8, 9]
#   [1311/2746] 58302_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [1312/2746] 58302_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1313/2746] 58302_QS(doc): target at [7] | cited: [0, 1, 3, 2]
#   [1314/2746] 58302_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1315/2746] 58302_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1316/2746] 58302_Statistics(doc): target at [7] | cited: [0, 3, 4, 1, 2]
#   [1317/2746] 58302_TechnicalTerms(doc): target at [7] | cited: [0, 3, 1, 2, 6]
#   [1318/2746] 58302_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1319/2746] 58302_doc: target at [7] | cited: [0, 1, 2, 3, 4]
#   [1320/2746] 58542_Authoritative(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [1321/2746] 58542_CQ(doc): target at [2] | cited: [0, 1, 3, 6, 7]
#   [1322/2746] 58542_CQS(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [1323/2746] 58542_CS(doc): target at [1] | cited: [0, 1, 2, 7, 5]
#   [1324/2746] 58542_Citations(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [1325/2746] 58542_ContentImprovement(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [1326/2746] 58542_FC(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [1327/2746] 58542_FCQ(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [1328/2746] 58542_FCQS(doc): target at [0] | cited: [0, 1, 2, 5, 7]
(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1418/2746] 59913_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1419/2746] 59913_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1420/2746] 59913_FS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1421/2746] 59913_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1422/2746] 59913_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1423/2746] 59913_QS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1424/2746] 59913_Quotes(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1425/2746] 59913_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1426/2746] 59913_Statistics(doc): target at [9] | cited: [0, 1, 2, 4, 9]
#   [1427/2746] 59913_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [1428/2746] 59913_UniqueWords(doc): target at [6] | cited: [0, 1, 2, 7]
#   [1429/2746] 59913_doc: target at [6] | cited: [0, 1, 2, 3, 9]
#   [1430/2746] 60075_Authoritative(doc): target at [1] | cited: [0, 1, 3, 4, 6]
#   [1431/2746] 60075_CQ(doc): target at [0] | cited: [0, 3, 7, 1, 2]
#   [1432/2746] 60075_CQS(doc): target at [0] | cited: [0, 4, 2, 3, 7]
#   [1433/2746] 60075_CS(doc): target at [0] | cited: [0, 1, 2, 6, 7]
#   [1434/2746] 60075_Citations(doc): target at [2] | cited: [0, 1, 2, 3, 6]
#   [1435/2746] 60075_ContentImprovement(doc): target at [0] | cited: [0, 1, 3, 6, 8]
#   [1436/2746] 60075_FC(doc): target at [5] | cited: [0, 1, 3, 6, 5]
#   [1437/2746] 60075_FCQ(doc): target at [1] | cited: [0, 1, 5, 4, 6]
#   [1438/2746] 60075_FCQS(doc): target at [0] | cited: [0, 2, 6, 4, 7]
#   [1439/2746] 60075_FCS(doc): target at [0] | cited: [0, 2, 4, 6]
#   [1440/2746] 60075_FQ(doc): target at [1] | cited: [0, 1, 2, 4, 9]
#   [1441/2746] 60075_FQS(doc): target at [3] | cited: [0, 1, 3, 4, 6]
#   [1442/2746] 60075_FS(doc): target at [1] | cited: [0, 1, 2, 6]
#   [1443/2746] 60075_Fluency(doc): target at [0] | cited: [0, 1, 2, 5, 8]
#   [1444/2746] 60075_LLMstxt(doc): target at [1] | cited: [0, 1, 2, 3, 8]
#   [1445/2746] 60075_QS(doc): target at [0] | cited: [0, 1, 6, 7, 4]
#   [1446/2746] 60075_Quotes(doc): target at [0] | cited: [0, 2, 6, 4, 7]
#   [1447/2746] 60075_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 8, 7]
#   [1448/2746] 60075_Statistics(doc): target at [2] | cited: [0, 1, 6, 7, 4]
#   [1449/2746] 60075_TechnicalTerms(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [1450/2746] 60075_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 5, 7]
#   [1451/2746] 60075_doc: target at [1] | cited: [0, 1, 4, 6, 7]
#   [1452/2746] 60234_Authoritative(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [1453/2746] 60234_CQ(doc): target at [0] | cited: [0, 1, 6, 4, 5]
#   [1454/2746] 60234_CQS(doc): target at [1] | cited: [0, 1, 4, 5, 8]
#   [1455/2746] 60234_CS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1456/2746] 60234_Citations(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [1457/2746] 60234_ContentImprovement(doc): target at [0] | cited: [0, 1, 3, 4, 5]
#   [1458/2746] 60234_FC(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1459/2746] 60234_FCQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1460/2746] 60234_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1461/2746] 60234_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [1462/2746] 60234_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1463/2746] 60234_FQS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [1464/2746] 60234_FS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1465/2746] 60234_Fluency(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1466/2746] 60234_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1467/2746] 60234_QS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1468/2746] 60234_Quotes(doc): target at [0] | cited: [0, 1, 3, 4, 6]
#   [1469/2746] 60234_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1470/2746] 60234_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1471/2746] 60234_TechnicalTerms(doc): target at [0] | cited: [0, 1, 3, 4, 5]
#   [1472/2746] 60234_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [1473/2746] 60234_doc: target at [1] | cited: [0, 1, 2, 3, 4]
#   [1474/2746] 60237_Authoritative(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [1475/2746] 60237_CQ(doc): target at [0] | cited: [0, 1, 2, 3, 6]
#   [1476/2746] 60237_CQS(doc): target at [3] | cited: [0, 1, 2, 4, 9]
#   [1477/2746] 60237_CS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1478/2746] 60237_Citations(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1479/2746] 60237_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 4, 9]
#   [1480/2746] 60237_FC(doc): target at [5] | cited: [0, 1, 3, 8, 9]
#   [1481/2746] 60237_FCQ(doc): target at [3] | cited: [0, 1, 2, 9, 6]
#   [1482/2746] 60237_FCQS(doc): target at [5] | cited: [0, 1, 3, 7, 9]
#   [1483/2746] 60237_FCS(doc): target at [2] | cited: [0, 1, 3, 6, 8]
#   [1484/2746] 60237_FQ(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1485/2746] 60237_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1486/2746] 60237_FS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1487/2746] 60237_Fluency(doc): target at [0] | cited: [0, 1, 2, 3, 8]
#   [1488/2746] 60237_LLMstxt(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1489/2746] 60237_QS(doc): target at [2] | cited: [0, 1, 2, 4, 9]
#   [1490/2746] 60237_Quotes(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1491/2746] 60237_SimpleLanguage(doc): target at [2] | cited: [0, 1, 3, 5, 8]
#   [1492/2746] 60237_Statistics(doc): target at [2] | cited: [0, 1, 3, 4, 8]
#   [1493/2746] 60237_TechnicalTerms(doc): target at [1] | cited: [0, 1, 2, 3, 6]
#   [1494/2746] 60237_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 4, 8]
#   [1495/2746] 60237_doc: target at [1] | cited: [0, 2, 4, 6, 8]
#   [1496/2746] 60271_Authoritative(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1497/2746] 60271_CQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1498/2746] 60271_CQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1499/2746] 60271_CS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1500/2746] 60271_Citations(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [1501/2746] 60271_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 7, 8]
#   [1502/2746] 60271_FC(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1503/2746] 60271_FCQ(doc): target at [7] | cited: [0, 1, 2, 3, 8]
#   [1504/2746] 60271_FCQS(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [1505/2746] 60271_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [1506/2746] 60271_FQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1507/2746] 60271_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1508/2746] 60271_FS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1509/2746] 60271_Fluency(doc): target at [5] | cited: [0, 1, 2, 3, 8]
#   [1510/2746] 60271_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1511/2746] 60271_QS(doc): target at [0] | cited: [0, 1, 2, 3, 8]
#   [1512/2746] 60271_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1513/2746] 60271_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1514/2746] 60271_Statistics(doc): target at [8] | cited: [0, 1, 2, 6, 7]
#   [1515/2746] 60271_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1516/2746] 60271_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1517/2746] 60271_doc: target at [4] | cited: [0, 1, 2, 3, 7]
#   [1518/2746] 60421_Authoritative(doc): target at [2] | cited: [0, 1, 2, 6, 9]
#   [1519/2746] 60421_CQ(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [1520/2746] 60421_CQS(doc): target at [6] | cited: [0, 1, 5, 6, 7]
#   [1521/2746] 60421_CS(doc): target at [6] | cited: [0, 1, 5, 6, 9]
#   [1522/2746] 60421_Citations(doc): target at [5] | cited: [0, 1, 6, 3, 7]
#   [1523/2746] 60421_ContentImprovement(doc): target at [6] | cited: [0, 1, 5, 6, 9]
#   [1524/2746] 60421_FC(doc): target at [6] | cited: [0, 1, 5, 6, 7]
#   [1525/2746] 60421_FCQ(doc): target at [2] | cited: [0, 1, 2, 6, 9]
#   [1526/2746] 60421_FCQS(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [1527/2746] 60421_FCS(doc): target at [5] | cited: [0, 1, 5, 8, 9]
#   [1528/2746] 60421_FQ(doc): target at [8] | cited: [0, 1, 5, 6, 3]
#   [1529/2746] 60421_FQS(doc): target at [8] | cited: [0, 1, 5, 6, 9]
#   [1530/2746] 60421_FS(doc): target at [6] | cited: [0, 1, 5, 6, 9]
#   [1531/2746] 60421_Fluency(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [1532/2746] 60421_LLMstxt(doc): target at [9] | cited: [0, 1, 5, 6, 3]
#   [1533/2746] 60421_QS(doc): target at [8] | cited: [0, 1, 5, 6, 8]
#   [1534/2746] 60421_Quotes(doc): target at [6] | cited: [0, 1, 5, 6, 7]
#   [1535/2746] 60421_SimpleLanguage(doc): target at [6] | cited: [0, 1, 5, 6, 7]
#   [1536/2746] 60421_Statistics(doc): target at [6] | cited: [0, 1, 5, 6, 9]
#   [1537/2746] 60421_TechnicalTerms(doc): target at [6] | cited: [0, 1, 5, 6, 9]
#   [1538/2746] 60421_UniqueWords(doc): target at [6] | cited: [0, 1, 2, 6, 7]
#   [1539/2746] 60421_doc: target at [5] | cited: [0, 1, 5, 6, 9]
#   [1540/2746] 60423_Authoritative(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1541/2746] 60423_CQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1542/2746] 60423_CQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1543/2746] 60423_CS(doc): target at [9] | cited: [0, 1, 5, 4, 8]
#   [1544/2746] 60423_Citations(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1545/2746] 60423_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1546/2746] 60423_FC(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1547/2746] 60423_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1548/2746] 60423_FCQS(doc): target at [9] | cited: [0, 1, 4, 6, 8]
#   [1549/2746] 60423_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [
doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1668/2746] 60951_Statistics(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1669/2746] 60951_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1670/2746] 60951_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1671/2746] 60951_doc: target at [2] | cited: [0, 1, 2, 3, 7]
#   [1672/2746] 60985_Authoritative(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [1673/2746] 60985_CQ(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1674/2746] 60985_CQS(doc): target at [9] | cited: [0, 1, 2, 6, 8]
#   [1675/2746] 60985_CS(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [1676/2746] 60985_Citations(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1677/2746] 60985_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1678/2746] 60985_FC(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1679/2746] 60985_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [1680/2746] 60985_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1681/2746] 60985_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1682/2746] 60985_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1683/2746] 60985_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [1684/2746] 60985_FS(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [1685/2746] 60985_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1686/2746] 60985_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1687/2746] 60985_QS(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [1688/2746] 60985_Quotes(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1689/2746] 60985_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [1690/2746] 60985_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1691/2746] 60985_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [1692/2746] 60985_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1693/2746] 60985_doc: target at [9] | cited: [0, 1, 2, 3, 7]
#   [1694/2746] 61005_Authoritative(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [1695/2746] 61005_CQ(doc): target at [9] | cited: [0, 1, 2, 5, 8]
#   [1696/2746] 61005_CQS(doc): target at [7] | cited: [0, 1, 2, 5, 9]
#   [1697/2746] 61005_CS(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [1698/2746] 61005_Citations(doc): target at [7] | cited: [0, 1, 2, 5, 9]
#   [1699/2746] 61005_ContentImprovement(doc): target at [7] | cited: [0, 1, 5, 2, 6]
#   [1700/2746] 61005_FC(doc): target at [6] | cited: [0, 1, 2, 5, 9]
#   [1701/2746] 61005_FCQ(doc): target at [7] | cited: [0, 1, 2, 6, 3]
#   [1702/2746] 61005_FCQS(doc): target at [6] | cited: [0, 1, 2, 5, 9]
#   [1703/2746] 61005_FCS(doc): target at [6] | cited: [0, 1, 5, 9]
#   [1704/2746] 61005_FQ(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   
#   [1746/2746] 6152_FCQS(doc): target at [8] | cited: [0, 1, 2, 5, 9]
#   [1747/2746] 6152_FCS(doc): target at [8] | cited: [0, 1, 5, 9]
#   [1748/2746] 6152_FQ(doc): target at [9] | cited: [0, 1, 4, 8]
#   [1749/2746] 6152_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [1750/2746] 6152_FS(doc): target at [8] | cited: [0, 1, 5, 9]
#   [1751/2746] 6152_Fluency(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [1752/2746] 6152_LLMstxt(doc): target at [3] | cited: [0, 1, 3, 9]
#   [1753/2746] 6152_QS(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [1754/2746] 6152_Quotes(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [1755/2746] 6152_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1756/2746] 6152_Statistics(doc): target at [6] | cited: [0, 1, 2, 5, 9]
#   [1757/2746] 6152_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [1758/2746] 6152_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 5, 9]
#   [1759/2746] 6152_doc: target at [6] | cited: [0, 1, 2, 9, 8]
#   [1760/2746] 6158_Authoritative(doc): target at [0] | cited: [1, 2, 4, 5, 8]
#   [1761/2746] 6158_CQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1762/2746] 6158_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1763/2746] 6158_CS(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [1764/2746] 6158_Citations(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [1765/2746] 6158_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1766/2746] 6158_FC(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1767/2746] 6158_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1768/2746] 6158_FCQS(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [1769/2746] 6158_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1770/2746] 6158_FQ(doc): target at [7] | cited: [0, 2, 8, 4, 5]
#   [1771/2746] 6158_FQS(doc): target at [9] | cited: [0, 1, 3, 4, 7]
#   [1772/2746] 6158_FS(doc): target at [2] | cited: [0, 1, 2, 4, 5]
#   [1773/2746] 6158_Fluency(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [1774/2746] 6158_LLMstxt(doc): target at [9] | cited: [0, 1, 3, 4, 7]
#   [1775/2746] 6158_QS(doc): target at [7] | cited: [0, 1, 3, 4, 8]
#   [1776/2746] 6158_Quotes(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [1777/2746] 6158_SimpleLanguage(doc): target at [6] | cited: [0, 1, 3, 4, 8]
#   [1778/2746] 6158_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [1779/2746] 6158_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [1780/2746] 6158_UniqueWords(doc): target at [7] | cited: [0, 1, 3, 4, 8]
#   [1781/2746] 6158_doc: target at [7] | cited: [0, 1, 3, 4, 8]
#   [1782/2746] 61764_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [1783/2746] 61764_CQ(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   
(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1828/2746] 62208_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [1829/2746] 62208_CS(doc): target at [8] | cited: [0, 1, 2, 3, 6]
#   [1830/2746] 62208_Citations(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [1831/2746] 62208_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1832/2746] 62208_FC(doc): target at [8] | cited: [0, 1, 3, 7, 8]
#   [1833/2746] 62208_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [1834/2746] 62208_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1835/2746] 62208_FCS(doc): target at [8] | cited: [0, 1, 3, 5, 8]
#   [1836/2746] 62208_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1837/2746] 62208_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1838/2746] 62208_FS(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [1839/2746] 62208_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 5]
# ...
#   [2529/2746] 72526_doc: target at [9] | cited: [0, 1, 2, 5, 6]
#   [2530/2746] 7259_Authoritative(doc): target at [7] | cited: [0, 1, 3, 4, 5]
#   [2531/2746] 7259_CQ(doc): target at [7] | cited: [0, 1, 3, 4, 5]
#   [2532/2746] 7259_CQS(doc): target at [7] | cited: [0, 1, 3, 4, 6]
#   [2533/2746] 7259_CS(doc): target at [7] | cited: [0, 1, 3, 4, 5]
#   [2534/2746] 7259_Citations(doc): target at [7] | cited: [0, 1, 3, 4, 6]
#   [2535/2746] 7259_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2536/2746] 7259_FC(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2537/2746] 7259_FCQ(doc): target at [8] | cited: [0, 1, 3, 4, 6]
#   [2538/2746] 7259_FCQS(doc): target at [7] | cited: [0, 1, 3, 5, 6]
#   [2539/2746] 7259_FCS(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2540/2746] 7259_FQ(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2541/2746] 7259_FQS(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [2542/2746] 7259_FS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2543/2746] 7259_Fluency(doc): target at [7] | cited: [0, 1, 3, 6, 5]
#   [2544/2746] 7259_LLMstxt(doc): target at [9] | cited: [0, 1, 3, 4, 5]
#   [2545/2746] 7259_QS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2546/2746] 7259_Quotes(doc): target at [7] | cited: [0, 1, 3, 4, 6]
#   [2547/2746] 7259_SimpleLanguage(doc): target at [7] | cited: [0, 1, 3, 4, 6]
#   [2548/2746] 7259_Statistics(doc): target at [9] | cited: [0, 1, 3, 4, 5]
#   [2549/2746] 7259_TechnicalTerms(doc): target at [7] | cited: [0, 1, 3, 5, 6]
#   [2550/2746] 7259_UniqueWords(doc): target at [7] | cited: [0, 1, 3, 4, 5]
#   [2551/2746] 7259_doc: target at [6] | cited: [0, 1, 2, 4, 5]
#   [2552/2746] 72660_Authoritative(doc): target at [4] | cited: [0, 4, 1, 8, 9]
#   [2553/2746] 72660_CQ(doc): target at [5] | cited: [0, 1, 2, 9]
#   [2554/2746] 72660_CQS(doc): target at [5] | cited: [0, 1, 5, 9]
#   [2555/2746] 72660_CS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2556/2746] 72660_Citations(doc): target at [5] | cited: [0, 1, 2, 9, 8]
#   [2557/2746] 72660_ContentImprovement(doc): target at [5] | cited: [0, 1, 2, 9]
#   [2558/2746] 72660_FC(doc): target at [8] | cited: [0, 1, 2, 4, 9]
#   [2559/2746] 72660_FCQ(doc): target at [8] | cited: [0, 1, 2, 9, 8]
#   [2560/2746] 72660_FCQS(doc): target at [6] | cited: [0, 1, 6, 9, 7]
#   [2561/2746] 72660_FCS(doc): target at [8] | cited: [0, 1, 2, 6, 9]
#   [2562/2746] 72660_FQ(doc): target at [8] | cited: [0, 1, 2, 9, 6]
#   [2563/2746] 72660_FQS(doc): target at [8] | cited: [0, 8, 6, 9, 3]
#   [2564/2746] 72660_FS(doc): target at [8] | cited: [0, 8, 1, 9, 7]
#   [2565/2746] 72660_Fluency(doc): target at [5] | cited: [0, 1, 2, 9, 8]
#   [2566/2746] 72660_LLMstxt(doc): target at [8] | cited: [0, 1, 3, 9, 6]
#   [2567/2746] 72660_QS(doc): target at [5] | cited: [0, 1, 5, 9]
#   [2568/2746] 72660_Quotes(doc): target at [5] | cited: [0, 1, 2, 9, 7]
#   [2569/2746] 72660_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [2570/2746] 72660_Statistics(doc): target at [6] | cited: [0, 1, 2, 9]
#   [2571/2746] 72660_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [2572/2746] 72660_UniqueWords(doc): target at [5] | cited: [0, 2, 1, 9, 3]
#   [2573/2746] 72660_doc: target at [2] | cited: [0, 2, 7, 9, 1]
#   [2574/2746] 72662_Authoritative(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2575/2746] 72662_CQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2576/2746] 72662_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2577/2746] 72662_CS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2578/2746] 72662_Citations(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2579/2746] 72662_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2580/2746] 72662_FC(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2581/2746] 72662_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2582/2746] 72662_FCQS(doc): target at [8] | cited: [0, 1, 3, 2, 4]
#   [2583/2746] 72662_FCS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2584/2746] 72662_FQ(doc): target at [8] | cited: [0, 2, 3, 1, 4]
#   [2585/2746] 72662_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2586/2746] 72662_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2587/2746] 72662_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2588/2746] 72662_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [2589/2746] 72662_QS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2590/2746] 72662_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2591/2746] 72662_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [2592/2746] 72662_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2593/2746] 72662_TechnicalTerms(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2594/2746] 72662_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2595/2746] 72662_doc: target at [5] | cited: [0, 1, 2, 3, 4]
#   [2596/2746] 73868_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 7]
#   [2597/2746] 73868_CQ(doc): target at [2] | cited: [0, 1, 8, 6, 9]
#   [2598/2746] 73868_CQS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   
SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2636/2746] 7411_Statistics(doc): target at [0] | cited: [0, 1, 8, 6, 7]
#   [2637/2746] 7411_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2638/2746] 7411_UniqueWords(doc): target at [0] | cited: [0, 1, 6, 5, 8]
#   [2639/2746] 7411_doc: target at [0] | cited: [0, 1, 2, 3, 4]
#   [2640/2746] 74158_Authoritative(doc): target at [8] | cited: [0, 1, 7, 8, 2]
#   [2641/2746] 74158_CQ(doc): target at [7] | cited: [0, 1, 7, 8, 3]
#   [2642/2746] 74158_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2643/2746] 74158_CS(doc): target at [8] | cited: [0, 1, 3, 2, 8]
#   [2644/2746] 74158_Citations(doc): target at [8] | cited: [0, 7, 3, 8]
#   [2645/2746] 74158_ContentImprovement(doc): target at [8] | cited: [0, 1, 4, 8, 2]
#   [2646/2746] 74158_FC(doc): target at [9] | cited: [0, 1, 7, 2, 3]
#   [2647/2746] 74158_FCQ(doc): target at [8] | cited: [0, 1, 4, 8, 7]
#   [2648/2746] 74158_FCQS(doc): target at [9] | cited: [0, 1, 3, 7]
#   [2649/2746] 74158_FCS(doc): target at [9] | cited: [0, 1, 7, 9, 2]
#   [2650/2746] 74158_FQ(doc): target at [8] | cited: [0, 1, 7, 8, 3]
#   [2651/2746] 74158_FQS(doc): target at [8] | cited: [0, 1, 2, 7, 8]
#   [2652/2746] 74158_FS(doc): target at [8] | cited: [0, 1, 7, 8, 9]
#   [2653/2746] 74158_Fluency(doc): target at [8] | cited: [1, 7, 8, 3, 2]
#   [2654/2746] 74158_LLMstxt(doc): target at [7] | cited: [0, 1, 7, 8, 9]
#   [2655/2746] 74158_QS(doc): target at [8] | cited: [0, 1, 7, 8, 9]
#   [2656/2746] 74158_Quotes(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [2657/2746] 74158_SimpleLanguage(doc): target at [7] | cited: [0, 1, 7, 4]
#   [2658/2746] 74158_Statistics(doc): target at [9] | cited: [0, 1, 7, 3, 4]
#   [2659/2746] 74158_TechnicalTerms(doc): target at [7] | cited: [0, 1, 7, 8, 9]
#   [2660/2746] 74158_UniqueWords(doc): target at [8] | cited: [0, 1, 7, 8, 2]
#   [2661/2746] 74158_doc: target at [8] | cited: [0, 4, 8, 3]
#   [2662/2746] 74167_Authoritative(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2663/2746] 74167_CQ(doc): target at [8] | cited: [0, 1, 5, 6, 4]
#   [2664/2746] 74167_CQS(doc): target at [8] | cited: [0, 1, 4, 5, 7]
#   [2665/2746] 74167_CS(doc): target at [8] | cited: [0, 1, 4, 5, 7]
#   [2666/2746] 74167_Citations(doc): target at [8] | cited: [0, 1, 5, 4, 7]
#   [2667/2746] 74167_ContentImprovement(doc): target at [8] | cited: [0, 1, 4, 6, 5]
#   [2668/2746] 74167_FC(doc): target at [9] | cited: [0, 1, 4, 6, 7]
#   [2669/2746] 74167_FCQ(doc): target at [9] | cited: [0, 1, 6, 7, 5]
#   [2670/2746] 74167_FCQS(doc): target at [9] | cited: [0, 1, 4, 5, 6]
#   [2671/2746] 74167_FCS(doc): target at [9] | cited: [0, 1, 5, 6, 7]
#   [2672/2746] 74167_FQ(doc): target at [9] | cited: [0, 1, 4, 5, 6]
#   [2673/2746] 74167_FQS(doc): target at [8] | cited: [0, 1, 5, 4, 6]
#   [2674/2746] 74167_FS(doc): target at [9] | cited: [0, 1, 4, 7]
#   [2675/2746] 74167_Fluency(doc): target at [9] | cited: [0, 1, 4, 5, 6]
#   [2676/2746] 74167_LLMstxt(doc): target at [9] | cited: [0, 1, 4, 5, 6]
#   [2677/2746] 74167_QS(doc): target at [8] | cited: [0, 1, 4, 5, 6]
#   [2678/2746] 74167_Quotes(doc): target at [8] | cited: [0, 1, 4, 5, 6]
#   [2679/2746] 74167_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2680/2746] 74167_Statistics(doc): target at [8] | cited: [0, 1, 4, 6, 7]
#   [2681/2746] 74167_TechnicalTerms(doc): target at [8] | cited: [0, 1, 4, 5, 6]
#   [2682/2746] 74167_UniqueWords(doc): target at [9] | cited: [0, 1, 5, 7, 4]
#   [2683/2746] 74167_doc: target at [8] | cited: [0, 1, 4, 7, 6]
#   [2684/2746] 74246_Authoritative(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [2685/2746] 74246_CQ(doc): target at [9] | cited: [0, 1, 6, 5]
#   [2686/2746] 74246_CQS(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2687/2746] 74246_CS(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2688/2746] 74246_Citations(doc): target at [9] | cited: [0, 1, 2, 5, 6]
#   [2689/2746] 74246_ContentImprovement(doc): target at [9] | cited: [0, 1, 6, 4, 7]
#   [2690/2746] 74246_FC(doc): target at [9] | cited: [0, 1, 6, 5, 2]
#   [2691/2746] 74246_FCQ(doc): target at [9] | cited: [0, 3, 4, 6, 7]
#   [2692/2746] 74246_FCQS(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2693/2746] 74246_FCS(doc): target at [9] | cited: [0, 1, 6, 5, 4]
#   [2694/2746] 74246_FQ(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2695/2746] 74246_FQS(doc): target at [8] | cited: [0, 1, 5, 3, 4]
#   [2696/2746] 74246_FS(doc): target at [9] | cited: [0, 1, 6, 2, 5]
#   [2697/2746] 74246_Fluency(doc): target at [9] | cited: [0, 6, 5, 2, 3]
#   [2698/2746] 74246_LLMstxt(doc): target at [9] | cited: [0, 1, 6, 5, 4]
#   [2699/2746] 74246_QS(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2700/2746] 74246_Quotes(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2701/2746] 74246_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2702/2746] 74246_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [2703/2746] 74246_TechnicalTerms(doc): target at [9] | cited: [0, 3, 6, 5, 4]
#   [2704/2746] 74246_UniqueWords(doc): target at [7] | cited: [0, 6, 4, 3, 5]
#   [2705/2746] 74246_doc: target at [8] | cited: [0, 1, 6, 4, 5]
#   [2706/2746] 7438_Authoritative(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [2707/2746] 7438_CQ(doc): target at [0] | cited: [0, 1, 2, 5, 9]
#   [2708/2746] 7438_CQS(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [2709/2746] 7438_CS(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [2710/2746] 7438_Citations(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [2711/2746] 7438_ContentImprovement(doc): target at [0] | cited: [0, 1, 2, 4, 6]
#   [2712/2746] 7438_FC(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2713/2746] 7438_FCQ(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2714/2746] 7438_FCQS(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [2715/2746] 7438_FCS(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2716/2746] 7438_FQ(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2717/2746] 7438_FQS(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2718/2746] 7438_FS(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [2719/2746] 7438_Fluency(doc): target at [0] | cited: [0, 1, 2, 5, 9]
#   [2720/2746] 7438_LLMstxt(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2721/2746] 7438_QS(doc): target at [0] | cited: [0, 1, 5]
#   [2722/2746] 7438_Quotes(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [2723/2746] 7438_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 5, 4]
#   [2724/2746] 7438_Statistics(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2725/2746] 7438_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [2726/2746] 7438_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 5, 9]
#   [2727/2746] 7438_doc: target at [0] | cited: [0, 1, 2, 4, 5]
#   [2728/2746] 74897_Authoritative(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [2729/2746] 74897_CQ(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [2730/2746] 74897_CQS(doc): target at [2] | cited: [0, 2, 9, 3, 8]
#   [2731/2746] 74897_CS(doc): target at [2] | cited: [0, 2, 9, 3, 8]
#   [2732/2746] 74897_Citations(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [2733/2746] 74897_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [2734/2746] 74897_FC(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [2735/2746] 74897_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 9]
#   [2736/2746] 74897_FCQS(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [2737/2746] 74897_FCS(doc): target at [3] | cited: [0, 3, 9, 5, 2]
#   [2738/2746] 74897_FQ(doc): target at [2] | cited: [0, 1, 2, 3, 9]
#   [2739/2746] 74897_FQS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [2740/2746] 74897_FS(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [2741/2746] 74897_Fluency(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [2742/2746] 74897_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 6, 7]
#   [2743/2746] 74897_QS(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [2744/2746] 74897_Quotes(doc): target at [2] | cited: [0, 1, 2, 7, 8]
#   [2745/2746] 74897_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [2746/2746] 74897_Statistics(doc): target at [2] | cited: [0, 2, 3, 9]
# ============================================================
# GENERATION COMPLETE
# Started:    21:43:48
# Finished:   02:22:54
# Total time: 4:39:06
# Results:    2746 rows saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation/4_generation_results_C_v4.parquet

# %% [markdown]
# ## 6. Inspect Results
#
# Loads this notebook's parquet file and prints a summary for a single run. Change `INSPECT_QUERY_ID` to inspect any specific run.

# %%
# Load this notebook's parquet file for inspection
df_results = pd.read_parquet(output_path)

# Change INSPECT_QUERY_ID to inspect a specific run
INSPECT_QUERY_ID = df_results["query_id"].iloc[0]

row = df_results[df_results["query_id"] == INSPECT_QUERY_ID].iloc[0]

print(f"Run (query_id):    {row['query_id']}")
print(f"Original query:    {row['original_query_id']}")
print(f"Method:            {row['method']}")
print(f"Query:             {row['query']}")
print(f"Num docs:          {row['num_docs']}")
print(f"Target position:   {row['target_new_position']} (0-based)")
print(f"Citation order:    {row['citation_order']}")
print(f"Target cited:      {'YES' if row['target_new_position'] in row['citation_order'] else 'NO'}")
print(f"\n--- LLM Response ---")
print(row["llm_response"][:800])
# Out:
# Run (query_id):    47826_TechnicalTerms(doc)
# Original query:    47826
# Method:            TechnicalTerms(doc)
# Query:             guardian torch light
# Num docs:          10
# Target position:   8 (0-based)
# Citation order:    [0 1 2 3 5 6]
# Target cited:      NO
#
# --- LLM Response ---
# If you're looking for a reliable guardian torch light for outdoor security, consider the following options:
#
# 1. **Guardian Torch Security Lights Motion Outdoor Spotlight** - This solar-powered spotlight features a 120° infrared motion sensor that activates five ultra-bright LEDs when movement is detected. Its IP65 waterproof rating ensures durability outdoors, and the easy installation process allows you to set it up in just minutes. It operates on dusk to dawn technology, making it an excellent choice for home defense and nighttime illumination [1].
#
# 2. **Guardian Tech Security Torch LED Spotlight (4-Pack)** - The updated 2020 model of this solar motion detector light is designed to be three times brighter than previous versions, delivering robust security without the hassle of wiring or
