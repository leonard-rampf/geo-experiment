# %% [markdown]
# # Notebook 4B — Generation Stage (Range 25%–50%)
#
# Processes 25%–50% of all runs.
# Run A, B, C, D in parallel — each writes to its own parquet file.
#
# **Input:** `data/retail/retrieval/20260413_retrieval_results_geo_v2.csv`
#
# **Output:** `data/retail/generation/4_generation_results_B_v4.parquet`
#
# ## Instructions
# 1. Run **Setup**
# 2. Run **Data Preparation**
# 3. Run **Helper Functions**
# 4. Run **Parameters** — range is set automatically
# 5. Run **Generation**
# 6. Run **Inspect Results**
# 7. Run **Summary**
# 8. After all 4 notebooks finish: run **Merge Results** in any one notebook

# %% [markdown]
# ## Setup

# %%
# Library imports
import json
import os
import re
import sys
import time
from datetime import datetime

import pandas as pd
import numpy as np

# Go up two levels to project root
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, "..", ".."))

# Add src/ to path so OpenAIHelper can be imported
sys.path.insert(0, os.path.join(project_root, "src"))


from llms import OpenAIHelper

# Load API key from config.json
config_path = os.path.join(project_root, "config.json")
with open(config_path, "r") as f:
    config = json.load(f)
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

data_dir = os.path.join(project_root, "data", "retail")

print("Setup complete.")
print(f"Project root: {project_root}")
# Out:
# Setup complete.
# Project root: /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment

# %% [markdown]
# ## Data Preparation
#
# Load the retrieval CSV and extract `original_query_id` and `method` from `query_id`.
# Example: `50881_Fluency(doc)` → `original_query_id=50881`, `method=Fluency(doc)`

# %%
# Load the retrieval CSV — one row per document per query_id
# query_id format: "{original_query_id}_{method}"
retrieval_csv_path = os.path.join(data_dir, "retrieval/20260413_retrieval_results_geo_v2.csv")
df = pd.read_csv(retrieval_csv_path)

# Extract original_query_id (numeric) and method name from compound query_id
df["original_query_id"] = df["query_id"].str.extract(r"^(\d+)_")
df["method"]            = df["query_id"].str.extract(r"^\d+_(.+)$")

# Identify runs where the target document is missing from the retrieval results
# These runs are skipped during generation (no valid citation position can be computed)
target_per_run = df.groupby("query_id")["is_target"].sum()
runs_with_target    = set(target_per_run[target_per_run == 1].index)
runs_without_target = set(target_per_run[target_per_run == 0].index)

# Save runs without target for documentation and reproducibility
runs_without_target_path = os.path.join(data_dir, "generation/4_generation_runs_without_target_v3.json")
with open(runs_without_target_path, "w") as f:
    json.dump(sorted(list(runs_without_target)), f, indent=4)

print(f"Total rows:              {len(df)}")
print(f"Unique runs (query_ids): {df['query_id'].nunique()}")
print(f"Unique original queries: {df['original_query_id'].nunique()}")
print(f"Unique methods:          {df['method'].nunique()}")
print(f"Runs with target:        {len(runs_with_target)}")
print(f"Runs without target:     {len(runs_without_target)} — saved to generation/4_generation_runs_without_target_v3.json")
print()
print("Methods found:")
for m in sorted(df['method'].unique()):
    print(f"  {m}")
# Out:
# Total rows:              109875
# Unique runs (query_ids): 11000
# Unique original queries: 500
# Unique methods:          22
# Runs with target:        10985
# Runs without target:     15 — saved to generation/4_generation_runs_without_target_v3.json
#
# Methods found:
#   Authoritative(doc)
#   CQ(doc)
#   CQS(doc)
#   CS(doc)
#   Citations(doc)
#   ContentImprovement(doc)
#   FC(doc)
#   FCQ(doc)
#   FCQS(doc)
#   FCS(doc)
#   FQ(doc)
#   FQS(doc)
#   FS(doc)
#   Fluency(doc)
#   LLMstxt(doc)
#   QS(doc)
#   Quotes(doc)
#   SimpleLanguage(doc)
#   Statistics(doc)
#   TechnicalTerms(doc)
#   UniqueWords(doc)
#   doc

# %% [markdown]
# ## Helper Functions

# %%
# System prompt for the LLM — instructs it to act as a product recommender, recommend multiple products, and cite each product with exactly one inline reference [1].
DEVELOPER_PROMPT = """Your are a product recommender system for an online marketplace. Write an accurate and concise answer for the given user question, using only the provided summarized web search results. The answer should be correct, high-quality, and written by an expert using an unbiased and journalistic tone. The answer should be informative, interesting, and engaging. The answer's logic and reasoning should be rigorous and defensible. Each search result represents exactly one product. The cited search result should fully support all the information about that product. Search results need to be cited using [index], for example [1]. Recommend multiple products, each based on exactly one search result. Do not stack multiple citations for a single product."""

# Document type label used in the user prompt
DOC_TYPE = "Product Description"


def build_context(group):
    """
    Takes all rows for one query_id, sorts by rank, re-numbers 1..N.
    Returns:
        docs: list of doc_text in retrieval order
        target_new_position: 0-based position of target doc after re-numbering
    """
    group = group.sort_values("rank").reset_index(drop=True)
    docs = group["doc_text"].tolist()

    # Find 0-based position of the target document
    target_new_position = None
    for i, row in group.iterrows():
        if row["is_target"] == 1:
            target_new_position = i  # 0-based
            break

    return docs, target_new_position


def build_user_prompt(query, docs):
    """
    Builds the user prompt for the LLM.
    docs: list of doc_text strings, numbered 1..N
    """
    sources = ""
    for i, doc_text in enumerate(docs, start=1):
        sources += f"[{i}] {DOC_TYPE}: {doc_text}\n\n"
    return f"Question: {query}\n\nSearch Results:\n{sources}"


def extract_citation_order(response_text):
    """
    Extracts citation indices in order of first appearance.
    0-based: [1] in text -> index 0, [2] -> index 1, etc.
    e.g. "...product [2] is great [1][2]..." -> [1, 0]
    """
    citations = re.findall(r"\[(\d+)\]", response_text)
    seen = []
    for c in citations:
        idx = int(c) - 1  # 0-based
        if idx not in seen:
            seen.append(idx)
    return seen


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## Parameters

# %%
# LLM model used for response generation
LLM_NAME = "gpt-4o-mini-2024-07-18"

# Notebook ID — A processes 0%–25% of all runs
NOTEBOOK_ID = "B"

# Output file for this notebook's results — separate from B, C, D to allow parallel execution
output_path = os.path.join(data_dir, "generation/4_generation_results_B_v4.parquet")

# Based on Vertex AI / Gemini default inference parameters:
# https://docs.cloud.google.com/vertex-ai/generative-ai/docs/model-reference/inference?hl=de
TEMPERATURE       = 1.0
TOP_P             = 0.95
SEED              = 42
FREQUENCY_PENALTY = 0.0
PRESENCE_PENALTY  = 0.0

# Assign this notebook's quarter of all runs sorted alphabetically by query_id
all_run_ids_full = sorted(runs_with_target)
total = len(all_run_ids_full)
start_idx = int(total * 25/100)
end_idx   = int(total * 50/100)
all_run_ids = all_run_ids_full[start_idx:end_idx]

# Load already completed runs to support safe resume after interruption
if os.path.exists(output_path):
    df_done = pd.read_parquet(output_path)
    done_keys = set(df_done["query_id"].tolist())
    already_done = len(done_keys)
else:
    done_keys = set()
    already_done = 0

llm = OpenAIHelper(LLM_NAME)

remaining = len(all_run_ids) - already_done
print(f"Notebook:      {NOTEBOOK_ID}")
print(f"LLM:           {LLM_NAME}")
print(f"Range:         25%–50% ({start_idx}–{end_idx} of {total})")
print(f"Runs in range: {len(all_run_ids)}")
print(f"Already done:  {already_done}")
print(f"Remaining:     {remaining}")
# Out:
# Notebook:      B
# LLM:           gpt-4o-mini-2024-07-18
# Range:         25%–50% (2746–5492 of 10985)
# Runs in range: 2746
# Already done:  0
# Remaining:     2746

# %% [markdown]
# ## Generation
#
# For each run (query_id):
# 1. Sort docs by rank and re-number 1..N
# 2. Build LLM prompt
# 3. Generate response with inline citations
# 4. Extract citation order
# 5. Save incrementally
#
# Runs without a target doc are skipped.
# Safe to interrupt and resume.

# %%
# Load existing results if the output file already exists
# Allows safe resume without reprocessing completed runs
if os.path.exists(output_path):
    results_df = pd.read_parquet(output_path)
    results = results_df.to_dict("records")
else:
    results = []

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%H:%M:%S')}")
print(f"Total runs to process: {len(all_run_ids)}")
print()

for i, query_id in enumerate(all_run_ids):

    # Skip runs already completed in a previous session
    if query_id in done_keys:
        continue

    # Load all documents for this run
    group = df[df["query_id"] == query_id]
    query_text         = group["query"].iloc[0]
    original_query_id  = group["original_query_id"].iloc[0]
    method             = group["method"].iloc[0]

    # Sort docs by retrieval rank and find target position
    docs, target_new_position = build_context(group)

    # Skip runs where the target document is not in the retrieval results
    if target_new_position is None:
        print(f"  [{i+1}] {query_id}: no target — skipping")
        continue

    # Build LLM prompt with numbered search results
    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    try:
        # Generate LLM response and extract citation order
        response, _ = llm.generate(messages)
        response_text    = response.content
        citation_order   = extract_citation_order(response_text)

        # Store result and save incrementally — no work lost on crash or interruption
        results.append({
            "query_id":            query_id,
            "original_query_id":   original_query_id,
            "method":              method,
            "query":               query_text,
            "target_new_position": target_new_position,
            "num_docs":            len(docs),
            "citation_order":      citation_order,
            "llm_response":        response_text,
        })
        done_keys.add(query_id)
        pd.DataFrame(results).to_parquet(output_path, index=False)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    except Exception as e:
        # First failure — wait 10 seconds and retry once (handles rate limits)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: ERROR — {e}")
        time.sleep(10)
        try:
            response, _    = llm.generate(messages)
            response_text  = response.content
            citation_order = extract_citation_order(response_text)
            results.append({
                "query_id":            query_id,
                "original_query_id":   original_query_id,
                "method":              method,
                "query":               query_text,
                "target_new_position": target_new_position,
                "num_docs":            len(docs),
                "citation_order":      citation_order,
                "llm_response":        response_text,
            })
            done_keys.add(query_id)
            pd.DataFrame(results).to_parquet(output_path, index=False)
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: done (retry OK)")
        except Exception as e2:
            # Second failure — skip this run and continue with the next
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: FAILED — {e2}")

# Summary
end_time = datetime.now()
elapsed  = end_time - start_time
print(f"{'='*60}")
print(f"GENERATION COMPLETE")
print(f"Started:    {start_time.strftime('%H:%M:%S')}")
print(f"Finished:   {end_time.strftime('%H:%M:%S')}")
print(f"Total time: {str(elapsed).split('.')[0]}")
print(f"Results:    {len(results)} rows saved to {output_path}")
# Out:
# Started at: 21:43:41
# Total runs to process: 2746
#
#   [1258/2746] 35340_Citations(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [1259/2746] 35340_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [1260/2746] 35340_FC(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1261/2746] 35340_FCQ(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1262/2746] 35340_FCQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1263/2746] 35340_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1264/2746] 35340_FQ(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [1265/2746] 35340_FQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1266/2746] 35340_FS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1267/2746] 35340_Fluency(doc): target at [0] | cited: [0, 1, 4, 3, 5]
#   [1268/2746] 35340_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [1269/2746] 35340_QS(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [1270/2746] 35340_Quotes(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1271/2746] 35340_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1272/2746] 35340_Statistics(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1273/2746] 35340_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1274/2746] 35340_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 4, 7]
#   [1275/2746] 35340_doc: target at [1] | cited: [0, 1, 2, 3, 4]
#   [1276/2746] 35342_Authoritative(doc): target at [5] | cited: [0, 1, 2, 4, 3]
#   [1277/2746] 35342_CQ(doc): target at [6] | cited: [0, 1, 4, 6, 3]
#   [1278/2746] 35342_CQS(doc): target at [5] | cited: [0, 1, 2, 4, 3]
#   [1279/2746] 35342_CS(doc): target at [5] | cited: [0, 1, 4, 5, 6]
#   [1280/2746] 35342_Citations(doc): target at [5] | cited: [0, 1, 4, 5, 8]
#   [1281/2746] 35342_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 4, 3]
#   [1282/2746] 35342_FC(doc): target at [8] | cited: [0, 1, 4, 5, 7]
#   [1283/2746] 35342_FCQ(doc): target at [8] | cited: [0, 1, 4, 2, 7]
#   [1284/2746] 35342_FCQS(doc): target at [6] | cited: [0, 1, 6, 4, 3]
#   [1285/2746] 35342_FCS(doc): target at [9] | cited: [0, 1, 4, 2, 5]
#   [1286/2746] 35342_FQ(doc): target at [6] | cited: [0, 1, 6, 4, 5]
#   [1287/2746] 35342_FQS(doc): target at [8] | cited: [0, 1, 4, 2, 5]
#   [1288/2746] 35342_FS(doc): target at [8] | cited: [0, 1, 2, 4, 7]
#   [1289/2746] 35342_Fluency(doc): target at [6] | cited: [0, 1, 2, 4, 3]
#   [1290/2746] 35342_LLMstxt(doc): target at [8] | cited: [0, 1, 4, 8, 5]
#   [1291/2746] 35342_QS(doc): target at [5] | cited: [0, 1, 2, 4, 8]
#   [1292/2746] 35342_Quotes(doc): target at [5] | cited: [0, 1, 2, 4, 3]
#   [1293/2746] 35342_SimpleLanguage(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [1294/2746] 35342_Statistics(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [1295/2746] 35342_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 4, 3]
#   [1296/2746] 35342_UniqueWords(doc): target at [5] | cited: [0, 1, 2, 4, 6]
#   [1297/2746] 35342_doc: target at [5] | cited: [0, 1, 4, 5, 6]
#   [1298/2746] 35455_Authoritative(doc): target at [4] | cited: [0, 1, 3, 7, 4]
#   [1299/2746] 35455_CQ(doc): target at [3] | cited: [0, 1, 3, 4, 6]
#   [1300/2746] 35455_CQS(doc): target at [7] | cited: [0, 1, 4, 3, 7]
#   [1301/2746] 35455_CS(doc): target at [5] | cited: [0, 1, 5, 4, 2]
#   [1302/2746] 35455_Citations(doc): target at [4] | cited: [0, 1, 5, 4, 7]
#   [1303/2746] 35455_ContentImprovement(doc): target at [7] | cited: [0, 3, 6, 7, 1]
#   [1304/2746] 35455_FC(doc): target at [7] | cited: [0, 1, 3, 4, 7]
#   [1305/2746] 35455_FCQ(doc): target at [7] | cited: [0, 1, 3, 5, 7]
#   [1306/2746] 35455_FCQS(doc): target at [7] | cited: [0, 2, 6, 5, 7]
#   [1307/2746] 35455_FCS(doc): target at [7] | cited: [0, 1, 3, 4, 7]
#   [1308/2746] 35455_FQ(doc): target at [7] | cited: [0, 1, 4, 7, 9]
#   [1309/2746] 35455_FQS(doc): target at [5] | cited: [0, 1, 4, 5, 6]
#   [1310/2746] 35455_FS(doc): target at [3] | cited: [0, 3, 6, 4, 9]
#   [1311/2746] 35455_Fluency(doc): target at [4] | cited: [0, 1, 3, 4, 6]
#   [1312/2746] 35455_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1313/2746] 35455_QS(doc): target at [0] | cited: [0, 1, 2, 6, 9]
#   [1314/2746] 35455_Quotes(doc): target at [5] | cited: [0, 1, 5, 4, 9]
#   [1315/2746] 35455_SimpleLanguage(doc): target at [3] | cited: [0, 1, 3, 6, 4]
#   [1316/2746] 35455_Statistics(doc): target at [8] | cited: [0, 1, 4, 5, 8]
#   [1317/2746] 35455_TechnicalTerms(doc): target at [3] | cited: [0, 5, 4, 3]
#   [1318/2746] 35455_UniqueWords(doc): target at [4] | cited: [0, 3, 7, 4]
#   [1319/2746] 35455_doc: target at [3] | cited: [0, 3, 4, 7]
#   [1320/2746] 35574_Authoritative(doc): target at [9] | cited: [0, 2, 1, 3, 5]
#   [1321/2746] 35574_CQ(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1322/2746] 35574_CQS(doc): target at [9] | cited: [0, 2, 1, 3, 5]
#   [1323/2746] 35574_CS(doc): target at [9] | cited: [0, 1, 3, 2, 5]
#   [1324/2746] 35574_Citations(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1325/2746] 35574_ContentImprovement(doc): target at [9] | cited: [0, 2, 4, 6, 5]
#   [1326/2746] 35574_FC(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1327/2746] 35574_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1328/2746] 35574_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1329/2746] 35574_FCS(doc): target at [9] | cited: [0, 1, 2, 5, 6]
#   [1330/2746] 35574_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1331/2746] 35574_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1332/2746] 35574_FS(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [1333/2746] 35574_Fluency(doc): target at [9] | cited: [0, 1, 3, 6, 2]
#   [1334/2746] 35574_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1335/2746] 35574_QS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1336/2746] 35574_Quotes(doc): target at [9] | cited: [0, 1, 2, 5, 3]
#   [1337/2746] 35574_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1338/2746] 35574_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1339/2746] 35574_TechnicalTerms(doc): target at [9] | cited: [0, 1, 3, 2, 5]
#   [1340/2746] 35574_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1341/2746] 35574_doc: target at [9] | cited: [0, 1, 4, 3, 6]
#   [1342/2746] 35675_Authoritative(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1343/2746] 35675_CQ(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [1344/2746] 35675_CQS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1345/2746] 35675_CS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [1346/2746] 35675_Citations(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1347/2746] 35675_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1348/2746] 35675_FC(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1349/2746] 35675_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1350/2746] 35675_FCQS(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1351/2746] 35675_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1352/2746] 35675_FQ(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1353/2746] 35675_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1354/2746] 35675_FS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1355/2746] 35675_Fluency(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1356/2746] 35675_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [1357/2746] 35675_QS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1358/2746] 35675_Quotes(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [1359/2746] 35675_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1360/2746] 35675_Statistics(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1361/2746] 35675_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1362/2746] 35675_UniqueWords(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [1363/2746] 35675_doc: target at [7] | cited: [0, 1, 2, 3, 4]
#   [1364/2746] 3582_Authoritative(doc): target at [7] | cited: [0, 2, 3, 4]
#   [1365/2746] 3582_CQ(doc): target at [7] | cited: [0, 2, 3, 4]
#   [1366/2746] 3582_CQS(doc): target at [7] | cited: [0, 2, 3, 4]
#   [1367/2746] 3582_CS(doc): target at [3] | cited: [0, 2, 4, 5]
#   [1368/2746] 3582_Citations(doc): target at [3] | cited: [0, 2, 4, 5, 6]
#   [1369/2746] 3582_ContentImprovement(doc): target at [7] | cited: [0, 2, 3, 4]
#   [1370/2746] 3582_FC(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1371/2746] 3582_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [1372/2746] 3582_FCQS(doc): target at [9] | cited: [0, 2, 3, 9, 6]
#   [1373/2746] 3582_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [1374/2746] 3582_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [1375/2746] 3582_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [1376/2746] 3582_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1377/2746] 3582_Fluency(doc): target at [7] | cited: [0, 2, 3, 4]
#   [1378/2746] 3582_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1379/2746] 3582_QS(doc): target at [7] | cited: [0, 2, 3, 1]
#   [1380/2746] 3582_Quotes(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [1381/2746] 3582_SimpleLanguage(doc): target at [5] | cited: [0, 6, 3, 4]
#   [1382/2746] 3582_Statistics(doc): target at [7] | cited: [0, 2, 3, 4]
#   [1383/2746] 3582_TechnicalTerms(doc): target at [7] | cited: [0, 2, 3, 1, 4]
#   [1384/2746] 3582_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3]
#   [1385/2746] 3582_doc: target at [4] | cited: [0, 2, 3]
#   [1386/2746] 36099_Authoritative(doc): target at [4] | cited: [0, 1, 2, 5, 8]
#   [1387/2746] 36099_CQ(doc): target at [4] | cited: [2, 1, 7, 8, 4]
#   [1388/2746] 36099_CQS(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [1389/2746] 36099_CS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [
#   [1433/2746] 36104_CS(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [1434/2746] 36104_Citations(doc): target at [0] | cited: [0, 1, 2, 6, 5]
#   [1435/2746] 36104_ContentImprovement(doc): target at [1] | cited: [0, 1, 2, 5, 6]
#   [1436/2746] 36104_FC(doc): target at [5] | cited: [0, 1, 4, 5, 6]
#   [1437/2746] 36104_FCQ(doc): target at [7] | cited: [0, 1, 4, 5, 7]
#   [1438/2746] 36104_FCQS(doc): target at [5] | cited: [0, 1, 5, 6, 4]
#   [1439/2746] 36104_FCS(doc): target at [4] | cited: [0, 1, 5, 4, 6]
#   [1440/2746] 36104_FQ(doc): target at [7] | cited: [0, 1, 4, 5, 7]
#   [1441/2746] 36104_FQS(doc): target at [7] | cited: [0, 1, 4, 5, 7]
#   [1442/2746] 36104_FS(doc): target at [7] | cited: [0, 1, 4, 5, 7]
#   [1443/2746] 36104_Fluency(doc): target at [2] | cited: [0, 1, 2, 6, 5]
#   [1444/2746] 36104_LLMstxt(doc): target at [9] | cited: [0, 1, 5, 4, 7]
#   [1445/2746] 36104_QS(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [1446/2746] 36104_Quotes(doc): target at [2] | cited: [0, 1, 2, 5, 6]
#   [1447/2746] 36104_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [1448/2746] 36104_Statistics(doc): target at [2] | cited: [0, 1, 2, 5, 6]
#   [1449/2746] 36104_TechnicalTerms(doc): target at [1] | cited: [0, 1, 2, 6, 5]
#   [1450/2746] 36104_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [1451/2746] 36104_doc: target at [0] | cited: [0, 1, 2, 6, 5]
#   [1452/2746] 36665_Authoritative(doc): target at [8] | cited: [0, 1, 2, 7, 9]
#   [1453/2746] 36665_CQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1454/2746] 36665_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [1455/2746] 36665_CS(doc): target at [8] | cited: [0, 3, 9, 2, 4]
#   [1456/2746] 36665_Citations(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1457/2746] 36665_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [1458/2746] 36665_FC(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [1459/2746] 36665_FCQ(doc): target at [9] | cited: [0, 2, 3, 1, 4]
#   [1460/2746] 36665_FCQS(doc): target at [8] | cited: [0, 1, 3, 2, 4]
#   [1461/2746] 36665_FCS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1462/2746] 36665_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1463/2746] 36665_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [1464/2746] 36665_FS(doc): target at [7] | cited: [0, 1, 3, 4, 9]
#   [1465/2746] 36665_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1466/2746] 36665_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 9, 4]
#   [1467/2746] 36665_QS(doc): target at [9] | cited: [0, 1, 4, 7, 8]
#   [1468/2746] 36665_Quotes(doc): target at [8] | cited: [0, 1, 8, 2, 3]
#   [1469/2746] 36665_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 4, 9]
#   [1470/2746] 36665_Statistics(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [1471/2746] 36665_TechnicalTerms(doc): target at [8] | cited: [0, 1, 2, 4, 7]
#   [1472/2746] 36665_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 4, 7]
#   [1473/2746] 36665_doc: target at [7] | cited: [0, 2, 3, 4, 5]
#   [1474/2746] 37013_Authoritative(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [
doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1560/2746] 37125_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 3, 8]
#   [1561/2746] 37125_doc: target at [0] | cited: [0, 1, 2, 3, 4]
#   [1562/2746] 37166_Authoritative(doc): target at [7] | cited: [1, 2, 3, 4]
#   [1563/2746] 37166_CQ(doc): target at [7] | cited: []
#   [1564/2746] 37166_CQS(doc): target at [7] | cited: [0, 3, 4, 5]
#   [1565/2746] 37166_CS(doc): target at [7] | cited: [0, 1, 2]
#   [1566/2746] 37166_Citations(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1567/2746] 37166_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3]
#   [1568/2746] 37166_FC(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [1569/2746] 37166_FCQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1570/2746] 37166_FCQS(doc): target at [7] | cited: [1, 2, 3, 4]
#   [1571/2746] 37166_FCS(doc): target at [7] | cited: [1, 2, 3, 0, 4]
#   [1572/2746] 37166_FQ(doc): target at [7] | cited: [0, 2, 3, 4, 6]
#   [1573/2746] 37166_FQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1574/2746] 37166_FS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1575/2746] 37166_Fluency(doc): target at [2] | cited: [0, 1, 3, 4, 5]
#   [1576/2746] 37166_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [1577/2746] 37166_QS(doc): target at [6] | cited: [0, 1, 2, 5]
#   [1578/2746] 37166_Quotes(doc): target at [7] | cited: [6, 2, 3, 4, 0]
#   [1579/2746] 37166_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1580/2746] 37166_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [1581/2746] 37166_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1582/2746] 37166_UniqueWords(doc): target at [7] | cited: [1, 2, 3, 0]
#   [1583/2746] 37166_doc: target at [8] | cited: [1, 2, 3, 0, 4]
#   [1584/2746] 37206_Authoritative(doc): target at [2] | cited: [0, 2, 4, 8, 9]
#   [1585/2746] 37206_CQ(doc): target at [4] | cited: [0, 1, 2, 5, 8]
#   [1586/2746] 37206_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [1587/2746] 37206_CS(doc): target at [2] | cited: [0, 2, 3, 6, 9]
#   [1588/2746] 37206_Citations(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [1589/2746] 37206_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [1590/2746] 37206_FC(doc): target at [1] | cited: [0, 1, 2, 3, 8]
#   [1591/2746] 37206_FCQ(doc): target at [8] | cited: [0, 1, 3, 8, 5]
#   [1592/2746] 37206_FCQS(doc): target at [6] | cited: [0, 1, 6, 3, 9]
#   [1593/2746] 37206_FCS(doc): target at [1] | cited: [0, 1, 2, 3, 8]
#   [1594/2746] 37206_FQ(doc): target at [1] | cited: [0, 1, 2, 4, 8]
#   [1595/2746] 37206_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [1596/2746] 37206_FS(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [1597/2746] 37206_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [1598/2746] 37206_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [1599/2746] 37206_QS(doc): target at [5] | cited: [0, 1, 5, 4, 8]
#   [1600/2746] 37206_Quotes(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1601/2746] 37206_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 8]
#   [1602/2746] 37206_Statistics(doc): target at [2] | cited: [0, 1, 5, 7, 9]
#   [1603/2746] 37206_TechnicalTerms(doc): target at [3] | cited: [0, 1, 4, 5, 9]
#   [1604/2746] 37206_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [1605/2746] 37206_doc: target at [0] | cited: [0, 1, 2, 3, 5]
#   [1606/2746] 37230_Authoritative(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [1607/2746] 37230_CQ(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [1608/2746] 37230_CQS(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [1609/2746] 37230_CS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [
ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 7, 8]
#   [1854/2746] 39205_FC(doc): target at [7] | cited: [0, 1, 2, 4, 7]
#   [1855/2746] 39205_FCQ(doc): target at [7] | cited: [0, 1, 3, 5, 7]
#   [1856/2746] 39205_FCQS(doc): target at [7] | cited: [0, 1, 3, 7, 8]
#   [1857/2746] 39205_FCS(doc): target at [7] | cited: [0, 1, 3, 5, 7]
#   [1858/2746] 39205_FQ(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [1859/2746] 39205_FQS(doc): target at [7] | cited: [0, 1, 3, 7, 5]
#   [1860/2746] 39205_FS(doc): target at [7] | cited: [0, 1, 3, 7, 8]
#   [1861/2746] 39205_Fluency(doc): target at [7] | cited: [0, 1, 3, 5, 7]
#   [1862/2746] 39205_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 4, 6]
#   [1863/2746] 39205_QS(doc): target at [2] | cited: [0, 1, 2, 5, 7]
#   [1864/2746] 39205_Quotes(doc): target at [2] | cited: [0, 1, 2, 4, 8]
#   [1865/2746] 39205_SimpleLanguage(doc): target at [6] | cited: [0, 1, 3, 5, 6]
#   [1866/2746] 39205_Statistics(doc): target at [7] | cited: [0, 4, 6, 7, 8]
#   [1867/2746] 39205_TechnicalTerms(doc): target at [7] | cited: [0, 1, 3, 5, 8]
#   [1868/2746] 39205_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 4, 6]
#   [1869/2746] 39205_doc: target at [5] | cited: [0, 1, 3, 5, 6]
#   [1870/2746] 39241_Authoritative(doc): target at [1] | cited: [1, 5, 6, 7, 8]
#   [1871/2746] 39241_CQ(doc): target at [3] | cited: [2, 1, 8, 7, 6]
#   [1872/2746] 39241_CQS(doc): target at [3] | cited: [1, 3, 4, 7, 8]
#   [1873/2746] 39241_CS(doc): target at [4] | cited: [4, 1, 3, 7, 8]
#   [1874/2746] 39241_Citations(doc): target at [3] | cited: [3, 2, 5, 7, 8]
#   [1875/2746] 39241_ContentImprovement(doc): target at [2] | cited: [2, 1, 4, 7, 6]
#   [1876/2746] 39241_FC(doc): target at [7] | cited: [0, 8, 3, 5, 6]
#   [1877/2746] 39241_FCQ(doc): target at [9] | cited: [1, 4, 3, 5, 6]
#   [1878/2746] 39241_FCQS(doc): target at [8] | cited: [0, 9, 5, 6, 4]
#   [1879/2746] 39241_FCS(doc): target at [1] | cited: [1, 3, 7, 6, 8]
#   [1880/2746] 39241_FQ(doc): target at [2] | cited: [0, 8, 7, 6, 5]
#   [1881/2746] 39241_FQS(doc): target at [9] | cited: [1, 2, 6, 5, 7]
#   [1882/2746] 39241_FS(doc): target at [7] | cited: [1, 8, 5, 6, 4]
#   [1883/2746] 39241_Fluency(doc): target at [2] | cited: [0, 3, 8, 5, 7]
#   [1884/2746] 39241_LLMstxt(doc): target at [8] | cited: [8, 2, 1, 5, 6]
#   [1885/2746] 39241_QS(doc): target at [3] | cited: [1, 2, 6, 8, 7]
#   [1886/2746] 39241_Quotes(doc): target at [1] | cited: [1, 2, 4, 8, 9]
#   [1887/2746] 39241_SimpleLanguage(doc): target at [4] | cited: [4, 3, 2, 6, 8]
#   [1888/2746] 39241_Statistics(doc): target at [3] | cited: [2, 1, 6, 5, 7]
#   [1889/2746] 39241_TechnicalTerms(doc): target at [3] | cited: [2, 4, 6, 7, 8]
#   [1890/2746] 39241_UniqueWords(doc): target at [3] | cited: [2, 1, 6, 7, 8]
#   [1891/2746] 39241_doc: target at [2] | cited: [0, 6, 4, 5, 7]
#   [1892/2746] 39263_Authoritative(doc): target at [9] | cited: [0, 1, 5, 7, 6]
#   [1893/2746] 39263_CQ(doc): target at [9] | cited: [0, 1, 9, 7, 8]
#   [1894/2746] 39263_CQS(doc): target at [7] | cited: [0, 1, 8, 5, 6]
#   [1895/2746] 39263_CS(doc): target at [9] | cited: [0, 1, 7, 4, 5]
#   [1896/2746] 39263_Citations(doc): target at [8] | cited: [0, 1, 9, 5, 4]
#   [1897/2746] 39263_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 5, 8]
#   [1898/2746] 39263_FC(doc): target at [9] | cited: [0, 1, 7, 4, 5]
#   [1899/2746] 39263_FCQ(doc): target at [7] | cited: [0, 1, 5, 4, 8]
#   [1900/2746] 39263_FCQS(doc): target at [9] | cited: [0, 1, 7, 4, 5]
#   [1901/2746] 39263_FCS(doc): target at [9] | cited: [0, 1, 7, 5, 9]
#   [1902/2746] 39263_FQ(doc): target at [9] | cited: [0, 1, 7, 3]
#   [1903/2746] 39263_FQS(doc): target at [7] | cited: [0, 1, 5, 8, 6]
#   [1904/2746] 39263_FS(doc): target at [9] | cited: [0, 1, 7, 4, 5]
#   [1905/2746] 39263_Fluency(doc): target at [9] | cited: [0, 1, 7, 6, 5]
#   [1906/2746] 39263_LLMstxt(doc): target at [7] | cited: [0, 3, 2, 8, 6]
#   [1907/2746] 39263_QS(doc): target at [9] | cited: [0, 1, 7, 6]
#   [1908/2746] 39263_Quotes(doc): target at [9] | cited: [0, 1, 3, 7]
#   [1909/2746] 39263_SimpleLanguage(doc): target at [7] | cited: [0, 1, 5, 4, 8]
#   [1910/2746] 39263_Statistics(doc): target at [8] | cited: [0, 1, 7, 4]
#   [1911/2746] 39263_TechnicalTerms(doc): target at [9] | cited: [0, 1, 5, 7, 4]
#   [1912/2746] 39263_UniqueWords(doc): target at [9] | cited: [0, 1, 7, 4, 5]
#   [1913/2746] 39263_doc: target at [9] | cited: [0, 1, 7, 9, 4]
#   [1914/2746] 39276_Authoritative(doc): target at [4] | cited: [0, 2, 3, 6, 8]
#   [1915/2746] 39276_CQ(doc): target at [5] | cited: [0, 1, 4, 9, 8]
#   [1916/2746] 39276_CQS(doc): target at [0] | cited: [0, 1, 2, 6, 9]
#   [1917/2746] 39276_CS(doc): target at [4] | cited: [0, 1, 2, 9, 6]
#   [1918/2746] 39276_Citations(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [1919/2746] 39276_ContentImprovement(doc): target at [5] | cited: [0, 1, 2, 6, 9]
#   [1920/2746] 39276_FC(doc): target at [4] | cited: [0, 1, 2, 7, 8]
#   [1921/2746] 39276_FCQ(doc): target at [1] | cited: [0, 1, 2, 3, 9]
#   [1922/2746] 39276_FCQS(doc): target at [2] | cited: [0, 1, 2, 8, 9]
#   [1923/2746] 39276_FCS(doc): target at [7] | cited: [0, 1, 3, 5, 8]
#   [1924/2746] 39276_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [1925/2746] 39276_FQS(doc): target at [9] | cited: [0, 1, 2, 3,
doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2613/2746] 45355_SimpleLanguage(doc): target at [4] | cited: [0, 2, 1, 3, 8]
#   [2614/2746] 45355_Statistics(doc): target at [2] | cited: [0, 2, 1, 3, 4]
#   [2615/2746] 45355_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 7, 6]
#   [2616/2746] 45355_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 6, 4]
#   [2617/2746] 45355_doc: target at [4] | cited: [0, 1, 5, 8, 7]
#   [2618/2746] 46301_Authoritative(doc): target at [2] | cited: [0, 2, 3, 4, 8]
#   [2619/2746] 46301_CQ(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2620/2746] 46301_CQS(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2621/2746] 46301_CS(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2622/2746] 46301_Citations(doc): target at [8] | cited: [0, 2, 3, 5, 8]
#   [2623/2746] 46301_ContentImprovement(doc): target at [8] | cited: [0, 2, 3, 7, 9]
#   [2624/2746] 46301_FC(doc): target at [8] | cited: [0, 2, 3, 8, 9]
#   [2625/2746] 46301_FCQ(doc): target at [7] | cited: [0, 2, 3, 8, 9]
#   [2626/2746] 46301_FCQS(doc): target at [8] | cited: [0, 2, 3, 7, 9]
#   [2627/2746] 46301_FCS(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2628/2746] 46301_FQ(doc): target at [3] | cited: [0, 2, 3, 4, 8]
#   [2629/2746] 46301_FQS(doc): target at [7] | cited: [0, 2, 3, 4, 8]
#   [2630/2746] 46301_FS(doc): target at [3] | cited: [0, 2, 3, 4, 8]
#   [2631/2746] 46301_Fluency(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2632/2746] 46301_LLMstxt(doc): target at [7] | cited: [0, 2, 3, 8, 9]
#   [2633/2746] 46301_QS(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2634/2746] 46301_Quotes(doc): target at [8] | cited: [0, 2, 3, 4, 7]
#   [2635/2746] 46301_SimpleLanguage(doc): target at [7] | cited: [0, 2, 3, 8, 9]
#   [2636/2746] 46301_Statistics(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2637/2746] 46301_TechnicalTerms(doc): target at [7] | cited: [0, 2, 3, 8, 9]
#   [2638/2746] 46301_UniqueWords(doc): target at [8] | cited: [0, 2, 3, 7, 9]
#   [2639/2746] 46301_doc: target at [8] | cited: [0, 2, 3, 7, 9]
#   [2640/2746] 46597_Authoritative(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2641/2746] 46597_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2642/2746] 46597_CQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2643/2746] 46597_CS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2644/2746] 46597_Citations(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2645/2746] 46597_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2646/2746] 46597_FC(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2647/2746] 46597_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2648/2746] 46597_FCQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2649/2746] 46597_FCS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2650/2746] 46597_FQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2651/2746] 46597_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2652/2746] 46597_FS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2653/2746] 46597_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2654/2746] 46597_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2655/2746] 46597_QS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2656/2746] 46597_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2657/2746] 46597_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2658/2746] 46597_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2659/2746] 46597_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2660/2746] 46597_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2661/2746] 46597_doc: target at [7] | cited: [0, 1, 2, 3, 4]
#   [2662/2746] 46744_Authoritative(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2663/2746] 46744_CQ(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2664/2746] 46744_CQS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2665/2746] 46744_CS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2666/2746] 46744_Citations(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2667/2746] 46744_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2668/2746] 46744_FC(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2669/2746] 46744_FCQ(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2670/2746] 46744_FCQS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2671/2746] 46744_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2672/2746] 46744_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2673/2746] 46744_FQS(doc): target at [6] | cited: [0, 1, 2, 4, 9]
#   [2674/2746] 46744_FS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2675/2746] 46744_Fluency(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2676/2746] 46744_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2677/2746] 46744_QS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2678/2746] 46744_Quotes(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2679/2746] 46744_SimpleLanguage(doc): target at [0] | cited: [5, 1, 2, 3, 6]
#   [2680/2746] 46744_Statistics(doc): target at [9] | cited: [0, 1, 2, 5, 4]
#   [2681/2746] 46744_TechnicalTerms(doc): target at [6] | cited: [0, 1, 3, 2, 4]
#   [2682/2746] 46744_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2683/2746] 46744_doc: target at [6] | cited: [0, 1, 2, 3, 4]
#   [2684/2746] 4755_Authoritative(doc): target at [4] | cited: [0, 1, 2, 6, 4]
#   [2685/2746] 4755_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [2686/2746] 4755_CQS(doc): target at [7] | cited: [0, 1, 2, 7, 8]
#   [2687/2746] 4755_CS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [2688/2746] 4755_Citations(doc): target at [4] | cited: [0, 1, 2, 4, 6]
#   [2689/2746] 4755_ContentImprovement(doc): target at [2] | cited: [0, 1, 2, 3, 6]
#   [2690/2746] 4755_FC(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [2691/2746] 4755_FCQ(doc): target at [7] | cited: [0, 1, 2, 5, 6]
#   [2692/2746] 4755_FCQS(doc): target at [7] | cited: [0, 1, 2, 5, 9]
#   [2693/2746] 4755_FCS(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [2694/2746] 4755_FQ(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [2695/2746] 4755_FQS(doc): target at [7] | cited: [0, 1, 2, 5, 6]
#   [2696/2746] 4755_FS(doc): target at [7] | cited: [0, 1, 2, 7, 5]
#   [2697/2746] 4755_Fluency(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [2698/2746] 4755_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [2699/2746] 4755_QS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [2700/2746] 4755_Quotes(doc): target at [7] | cited: [0, 1, 2, 7, 6]
#   [2701/2746] 4755_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 6, 4]
#   [2702/2746] 4755_Statistics(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [2703/2746] 4755_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 6, 7]
#   [2704/2746] 4755_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 5, 6]
#   [2705/2746] 4755_doc: target at [6] | cited: [0, 1, 2, 5, 6]
#   [2706/2746] 47662_Authoritative(doc): target at [1] | cited: [0, 1, 2, 3, 6]
#   [2707/2746] 47662_CQ(doc): target at [8] | cited: [0, 1, 2, 6, 7]
#   [2708/2746] 47662_CQS(doc): target at [7] | cited: [0, 1, 6, 7, 8]
#   [2709/2746] 47662_CS(doc): target at [8] | cited: [0, 1, 2, 7, 8]
#   [2710/2746] 47662_Citations(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2711/2746] 47662_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [2712/2746] 47662_FC(doc): target at [7] | cited: [0, 1, 4, 6, 9]
#   [2713/2746] 47662_FCQ(doc): target at [7] | cited: [0, 2, 6, 4, 5]
#   [2714/2746] 47662_FCQS(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2715/2746] 47662_FCS(doc): target at [2] | cited: [0, 1, 3, 7, 9]
#   [2716/2746] 47662_FQ(doc): target at [7] | cited: [0, 1, 2, 6, 5]
#   [2717/2746] 47662_FQS(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [2718/2746] 47662_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2719/2746] 47662_Fluency(doc): target at [8] | cited: [0, 1, 2, 6, 7]
#   [2720/2746] 47662_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 8, 6]
#   [2721/2746] 47662_QS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [2722/2746] 47662_Quotes(doc): target at [7] | cited: [0, 1, 2, 6, 4]
#   [2723/2746] 47662_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2724/2746] 47662_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2725/2746] 47662_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 6, 4]
#   [2726/2746] 47662_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 6, 8]
#   [2727/2746] 47662_doc: target at [7] | cited: [0, 1, 6, 5]
#   [2728/2746] 47826_Authoritative(doc): target at [8] | cited: [0, 1, 4, 6, 7]
#   [2729/2746] 47826_CQ(doc): target at [9] | cited: [0, 1, 2, 5, 6]
#   [2730/2746] 47826_CQS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2731/2746] 47826_CS(doc): target at [8] | cited: [0, 1, 3, 6, 7]
#   [2732/2746] 47826_Citations(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2733/2746] 47826_ContentImprovement(doc): target at [8] | cited: [0, 1, 3, 2, 5]
#   [2734/2746] 47826_FC(doc): target at [8] | cited: [0, 1, 3, 5, 6]
#   [2735/2746] 47826_FCQ(doc): target at [8] | cited: [0, 1, 6, 5, 9]
#   [2736/2746] 47826_FCQS(doc): target at [8] | cited: [0, 1, 6, 8, 9]
#   [2737/2746] 47826_FCS(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2738/2746] 47826_FQ(doc): target at [8] | cited: [0, 1, 2, 5, 6]
#   [2739/2746] 47826_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [2740/2746] 47826_FS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2741/2746] 47826_Fluency(doc): target at [8] | cited: [0, 1, 6, 5, 9]
#   [2742/2746] 47826_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 7, 5]
#   [2743/2746] 47826_QS(doc): target at [8] | cited: [0, 1, 2, 6, 8]
#   [2744/2746] 47826_Quotes(doc): target at [8] | cited: [0, 1, 2, 6, 8]
#   [2745/2746] 47826_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2746/2746] 47826_Statistics(doc): target at [8] | cited: [0, 1, 2, 5, 6]
# ============================================================
# GENERATION COMPLETE
# Started:    21:43:41
# Finished:   02:01:48
# Total time: 4:18:06
# Results:    2746 rows saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation/4_generation_results_B_v4.parquet

# %% [markdown]
# ## Inspect Results

# %%
# Load this notebook's parquet file for inspection
df_results = pd.read_parquet(output_path)

# Change INSPECT_QUERY_ID to inspect a specific run
INSPECT_QUERY_ID = df_results["query_id"].iloc[0]

row = df_results[df_results["query_id"] == INSPECT_QUERY_ID].iloc[0]

print(f"Run (query_id):    {row['query_id']}")
print(f"Original query:    {row['original_query_id']}")
print(f"Method:            {row['method']}")
print(f"Query:             {row['query']}")
print(f"Num docs:          {row['num_docs']}")
print(f"Target position:   {row['target_new_position']} (0-based)")
print(f"Citation order:    {row['citation_order']}")
print(f"Target cited:      {'YES' if row['target_new_position'] in row['citation_order'] else 'NO'}")
print(f"\n--- LLM Response ---")
print(row["llm_response"][:800])
# Out:
# Run (query_id):    18938_UniqueWords(doc)
# Original query:    18938
# Method:            UniqueWords(doc)
# Query:             bouncy house for kids outdoor large
# Num docs:          10
# Target position:   8 (0-based)
# Citation order:    [0 1 4 5 9]
# Target cited:      NO
#
# --- LLM Response ---
# If you're looking for a large inflatable bouncy house for outdoor use, here are several excellent options that cater to children's fun while ensuring safety and durability.
#
# 1. **OTTARO Bounce House**: This inflatable castle features a slide and a ball pit, made from heavy-duty, non-toxic 420D Oxford materials. It can hold up to three children at a time with a total weight limit of 220 lbs, making it a great choice for backyard play. The setup is quick, taking less than two minutes to inflate, and it includes safety netting for added protection [1].
#
# 2. **BOUNTECH Inflatable Bounce House**: This versatile 6-in-1 design includes a slide, climbing wall, basketball rim, and a ball pit, providing endless entertainment for kids aged 3-10. It can accommodate three children with a combined weight

# %% [markdown]
# ## Merge Results
#
# **Run only after all 4 notebooks (A, B, C, D) are complete.**

# %%
# Merge all four notebook parquet files into one combined file
# Run only after notebooks A, B, C, D have all completed
NOTEBOOK_IDS = ["A", "B", "C", "D"]
dfs = []
for nb in NOTEBOOK_IDS:
    path = os.path.join(data_dir, f"generation/4_generation_results_{nb}_v4.parquet")
    if os.path.exists(path):
        dfs.append(pd.read_parquet(path))
        print(f"Loaded 4_generation_results_{nb}_v4.parquet ({len(dfs[-1])} rows)")
    else:
        print(f"WARNING: 4_generation_results_{nb}_v4.parquet not found — skipping")

# Concatenate all four subsets into one merged DataFrame
merged      = pd.concat(dfs, ignore_index=True)
merged_path = os.path.join(data_dir, "generation/4_generation_results_v4.parquet")
merged.to_parquet(merged_path, index=False)
print(f"\nMerged {len(merged)} rows into 4_generation_results_v4.parquet")

# %% [markdown]
# ## Summary

# %%
# Load merged parquet and verify completeness
# Expected: total rows == total runs with target across all 4 notebooks
merged_path = os.path.join(data_dir, "generation/4_generation_results_v4.parquet")
df_results  = pd.read_parquet(merged_path)

print(f"Total runs done:     {len(df_results)}")
print(f"Total runs expected: {len(all_run_ids_full)}")
print(f"Missing runs:        {len(all_run_ids_full) - len(df_results)}")
print()
print(f"Unique methods: {df_results['method'].nunique()}")
print(f"Unique queries: {df_results['original_query_id'].nunique()}")
