# %% [markdown]
# # Notebook 4A — Generation Stage (Range 0%–25%)
#
# Processes 0%–25% of all runs.
# Run A, B, C, D in parallel — each writes to its own parquet file.
#
# **Input:** `data/retail/retrieval/20260413_retrieval_results_geo_v2.csv`
#
# **Output:** `data/retail/generation/4_generation_results_A_v2.parquet`
#
# ## Instructions
# 1. Run **Setup**
# 2. Run **Data Preparation**
# 3. Run **Helper Functions**
# 4. Run **Parameters** — range is set automatically
# 5. Run **Generation**
# 6. Run **Inspect Results**
# 7. Run **Summary**
# 8. After all 4 notebooks finish: run **Merge Results** in any one notebook

# %% [markdown]
# ## Setup

# %%
# Library imports
import json
import os
import re
import sys
import time
from datetime import datetime

import pandas as pd
import numpy as np

# Go up two levels to project root
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, "..", ".."))

# Add src/ to path so OpenAIHelper can be imported
sys.path.insert(0, os.path.join(project_root, "src"))


from llms import OpenAIHelper

# Load API key from config.json
config_path = os.path.join(project_root, "config.json")
with open(config_path, "r") as f:
    config = json.load(f)
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

data_dir = os.path.join(project_root, "data", "retail")

print("Setup complete.")
print(f"Project root: {project_root}")
# Out:
# Setup complete.
# Project root: /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment

# %% [markdown]
# ## Data Preparation
#
# Load the retrieval CSV and extract `original_query_id` and `method` from `query_id`.
# Example: `50881_Fluency(doc)` → `original_query_id=50881`, `method=Fluency(doc)`

# %%
# Load the retrieval CSV — one row per document per query_id
# query_id format: "{original_query_id}_{method}"
retrieval_csv_path = os.path.join(data_dir, "retrieval/20260413_retrieval_results_geo_v2.csv")
df = pd.read_csv(retrieval_csv_path)

# Extract original_query_id (numeric) and method name from compound query_id
df["original_query_id"] = df["query_id"].str.extract(r"^(\d+)_")
df["method"]            = df["query_id"].str.extract(r"^\d+_(.+)$")

# Identify runs where the target document is missing from the retrieval results
# These runs are skipped during generation (no valid citation position can be computed)
target_per_run = df.groupby("query_id")["is_target"].sum()
runs_with_target    = set(target_per_run[target_per_run == 1].index)
runs_without_target = set(target_per_run[target_per_run == 0].index)

# Save runs without target for documentation and reproducibility
runs_without_target_path = os.path.join(data_dir, "generation/4_generation_runs_without_target_v2.json")
with open(runs_without_target_path, "w") as f:
    json.dump(sorted(list(runs_without_target)), f, indent=4)

print(f"Total rows:              {len(df)}")
print(f"Unique runs (query_ids): {df['query_id'].nunique()}")
print(f"Unique original queries: {df['original_query_id'].nunique()}")
print(f"Unique methods:          {df['method'].nunique()}")
print(f"Runs with target:        {len(runs_with_target)}")
print(f"Runs without target:     {len(runs_without_target)} — saved to generation/4_generation_runs_without_target_v2.json")
print()
print("Methods found:")
for m in sorted(df['method'].unique()):
    print(f"  {m}")
# Out:
# Total rows:              109875
# Unique runs (query_ids): 11000
# Unique original queries: 500
# Unique methods:          22
# Runs with target:        10985
# Runs without target:     15 — saved to generation/4_generation_runs_without_target_v2.json
#
# Methods found:
#   Authoritative(doc)
#   CQ(doc)
#   CQS(doc)
#   CS(doc)
#   Citations(doc)
#   ContentImprovement(doc)
#   FC(doc)
#   FCQ(doc)
#   FCQS(doc)
#   FCS(doc)
#   FQ(doc)
#   FQS(doc)
#   FS(doc)
#   Fluency(doc)
#   LLMstxt(doc)
#   QS(doc)
#   Quotes(doc)
#   SimpleLanguage(doc)
#   Statistics(doc)
#   TechnicalTerms(doc)
#   UniqueWords(doc)
#   doc

# %% [markdown]
# ## Helper Functions

# %%
# System prompt for the LLM — instructs it to act as a product recommender and to cite every sentence with inline references [1], [2], etc.
DEVELOPER_PROMPT = """Your are a product recommender system for an online marketplace. Write an accurate and concise answer for the given user question, using _only_ the provided summarized web search results. The answer should be correct, high-quality, and written by an expert using an unbiased and journalistic tone. The answer should be informative, interesting, and engaging. The answer's logic and reasoning should be rigorous and defensible. Every sentence in the answer should be _immediately followed_ by an in-line citation to the search result(s). The cited search result(s) should fully support _all_ the information in the sentence. Search results need to be cited using [index]. When citing several search results, use [1][2][3] format rather than [1, 2, 3]. You can use multiple search results to respond comprehensively while avoiding irrelevant search results."""

# Document type label used in the user prompt
DOC_TYPE = "Product Description"


def build_context(group):
    """
    Takes all rows for one query_id, sorts by rank, re-numbers 1..N.
    Returns:
        docs: list of doc_text in retrieval order
        target_new_position: 0-based position of target doc after re-numbering
    """
    group = group.sort_values("rank").reset_index(drop=True)
    docs = group["doc_text"].tolist()

    # Find 0-based position of the target document
    target_new_position = None
    for i, row in group.iterrows():
        if row["is_target"] == 1:
            target_new_position = i  # 0-based
            break

    return docs, target_new_position


def build_user_prompt(query, docs):
    """
    Builds the user prompt for the LLM.
    docs: list of doc_text strings, numbered 1..N
    """
    sources = ""
    for i, doc_text in enumerate(docs, start=1):
        sources += f"[{i}] {DOC_TYPE}: {doc_text}\n\n"
    return f"Question: {query}\n\nSearch Results:\n{sources}"


def extract_citation_order(response_text):
    """
    Extracts citation indices in order of first appearance.
    0-based: [1] in text -> index 0, [2] -> index 1, etc.
    e.g. "...product [2] is great [1][2]..." -> [1, 0]
    """
    citations = re.findall(r"\[(\d+)\]", response_text)
    seen = []
    for c in citations:
        idx = int(c) - 1  # 0-based
        if idx not in seen:
            seen.append(idx)
    return seen


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## Parameters

# %%
# LLM model used for response generation
LLM_NAME = "gpt-4o-mini-2024-07-18"

# Notebook ID — A processes 0%–25% of all runs
NOTEBOOK_ID = "A"

# Output file for this notebook's results — separate from B, C, D to allow parallel execution
output_path = os.path.join(data_dir, "generation/4_generation_results_A_v2.parquet")

# Based on Vertex AI / Gemini default inference parameters:
# https://docs.cloud.google.com/vertex-ai/generative-ai/docs/model-reference/inference?hl=de
TEMPERATURE       = 1.0
TOP_P             = 0.95
SEED              = 42
FREQUENCY_PENALTY = 0.0
PRESENCE_PENALTY  = 0.0

# Assign this notebook's quarter of all runs sorted alphabetically by query_id
all_run_ids_full = sorted(runs_with_target)
total = len(all_run_ids_full)
start_idx = int(total * 0/100)
end_idx   = int(total * 25/100)
all_run_ids = all_run_ids_full[start_idx:end_idx]

# Load already completed runs to support safe resume after interruption
if os.path.exists(output_path):
    df_done = pd.read_parquet(output_path)
    done_keys = set(df_done["query_id"].tolist())
    already_done = len(done_keys)
else:
    done_keys = set()
    already_done = 0

llm = OpenAIHelper(LLM_NAME)

remaining = len(all_run_ids) - already_done
print(f"Notebook:      {NOTEBOOK_ID}")
print(f"LLM:           {LLM_NAME}")
print(f"Range:         0%–25% ({start_idx}–{end_idx} of {total})")
print(f"Runs in range: {len(all_run_ids)}")
print(f"Already done:  {already_done}")
print(f"Remaining:     {remaining}")
print(f"Estimated time: ~{remaining * 9.5 / 3600:.1f} hours")
print(f"Estimated cost: ~${remaining * 0.0003:.2f}")
# Out:
# Notebook:      A
# LLM:           gpt-4o-mini-2024-07-18
# Range:         0%–25% (0–2746 of 10985)
# Runs in range: 2746
# Already done:  47
# Remaining:     2699
# Estimated time: ~7.1 hours
# Estimated cost: ~$0.81

# %% [markdown]
# ## Generation
#
# For each run (query_id):
# 1. Sort docs by rank and re-number 1..N
# 2. Build LLM prompt
# 3. Generate response with inline citations
# 4. Extract citation order
# 5. Save incrementally
#
# Runs without a target doc are skipped.
# Safe to interrupt and resume.

# %%
# Load existing results if the output file already exists
# Allows safe resume without reprocessing completed runs
if os.path.exists(output_path):
    results_df = pd.read_parquet(output_path)
    results = results_df.to_dict("records")
else:
    results = []

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%H:%M:%S')}")
print(f"Total runs to process: {len(all_run_ids)}")
print()

for i, query_id in enumerate(all_run_ids):

    # Skip runs already completed in a previous session
    if query_id in done_keys:
        continue

    # Load all documents for this run
    group = df[df["query_id"] == query_id]
    query_text         = group["query"].iloc[0]
    original_query_id  = group["original_query_id"].iloc[0]
    method             = group["method"].iloc[0]

    # Sort docs by retrieval rank and find target position
    docs, target_new_position = build_context(group)

    # Skip runs where the target document is not in the retrieval results
    if target_new_position is None:
        print(f"  [{i+1}] {query_id}: no target — skipping")
        continue

    # Build LLM prompt with numbered search results
    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    try:
        # Generate LLM response and extract citation order
        response, _ = llm.generate(messages)
        response_text    = response.content
        citation_order   = extract_citation_order(response_text)

        # Store result and save incrementally — no work lost on crash or interruption
        results.append({
            "query_id":            query_id,
            "original_query_id":   original_query_id,
            "method":              method,
            "query":               query_text,
            "target_new_position": target_new_position,
            "num_docs":            len(docs),
            "citation_order":      citation_order,
            "llm_response":        response_text,
        })
        done_keys.add(query_id)
        pd.DataFrame(results).to_parquet(output_path, index=False)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    except Exception as e:
        # First failure — wait 10 seconds and retry once (handles rate limits)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: ERROR — {e}")
        time.sleep(10)
        try:
            response, _    = llm.generate(messages)
            response_text  = response.content
            citation_order = extract_citation_order(response_text)
            results.append({
                "query_id":            query_id,
                "original_query_id":   original_query_id,
                "method":              method,
                "query":               query_text,
                "target_new_position": target_new_position,
                "num_docs":            len(docs),
                "citation_order":      citation_order,
                "llm_response":        response_text,
            })
            done_keys.add(query_id)
            pd.DataFrame(results).to_parquet(output_path, index=False)
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: done (retry OK)")
        except Exception as e2:
            # Second failure — skip this run and continue with the next
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: FAILED — {e2}")

# Summary
end_time = datetime.now()
elapsed  = end_time - start_time
print(f"{'='*60}")
print(f"GENERATION COMPLETE")
print(f"Started:    {start_time.strftime('%H:%M:%S')}")
print(f"Finished:   {end_time.strftime('%H:%M:%S')}")
print(f"Total time: {str(elapsed).split('.')[0]}")
print(f"Results:    {len(results)} rows saved to {output_path}")
# Out:
# Started at: 10:20:55
# Total runs to process: 2746
#
#   [48/2746] 100255_CS(doc): target at [5] | cited: [0, 2, 1, 5, 9]
#   [49/2746] 100255_Citations(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [50/2746] 100255_ContentImprovement(doc): target at [3] | cited: [0, 8, 1, 2, 6]
#   [51/2746] 100255_FC(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [52/2746] 100255_FCQ(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [53/2746] 100255_FCQS(doc): target at [6] | cited: [0, 2, 3, 4, 5]
#   [54/2746] 100255_FCS(doc): target at [6] | cited: []
#   [55/2746] 100255_FQ(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [56/2746] 100255_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [57/2746] 100255_FS(doc): target at [6] | cited: [0, 1, 2, 5, 3]
#   [58/2746] 100255_Fluency(doc): target at [2] | cited: [0, 2, 3, 4, 5]
#   [59/2746] 100255_LLMstxt(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [60/2746] 100255_QS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [61/2746] 100255_Quotes(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [62/2746] 100255_SimpleLanguage(doc): target at [2] | cited: [0, 8, 2, 4, 1]
#   [63/2746] 100255_Statistics(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [64/2746] 100255_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [65/2746] 100255_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 8, 9]
#   [66/2746] 100255_doc: target at [1] | cited: [0, 1, 2, 3, 4]
#   [67/2746] 100275_Authoritative(doc): target at [8] | cited: [0, 1, 2, 6, 7]
#   [68/2746] 100275_CQ(doc): target at [8] | cited: [1, 2, 8, 4, 6]
#   [69/2746] 100275_CQS(doc): target at [8] | cited: [0, 2, 8, 1, 6]
#   [70/2746] 100275_CS(doc): target at [8] | cited: [0, 1, 3, 4, 7]
#   [71/2746] 100275_Citations(doc): target at [8] | cited: [0, 2, 8, 1, 3]
#   [72/2746] 100275_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 5, 8]
#   [73/2746] 100275_FC(doc): target at [8] | cited: [0, 2, 1, 4, 3]
#   [74/2746] 100275_FCQ(doc): target at [9] | cited: [0, 2, 9, 1, 5]
#   [75/2746] 100275_FCQS(doc): target at [8] | cited: [0, 2, 8, 4, 1]
#   [76/2746] 100275_FCS(doc): target at [8] | cited: [0, 3, 1, 4, 2]
#   [77/2746] 100275_FQ(doc): target at [9] | cited: [0, 1, 5, 4, 2]
#   [78/2746] 100275_FQS(doc): target at [9] | cited: [0, 1, 9, 2, 5]
#   [79/2746] 100275_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [80/2746] 100275_Fluency(doc): target at [7] | cited: [0, 1, 3, 4, 2]
#   [81/2746] 100275_LLMstxt(doc): target at [8] | cited: [0, 1, 8, 5, 4]
#   [82/2746] 100275_QS(doc): target at [8] | cited: [0, 3, 1, 4, 2]
#   [83/2746] 100275_Quotes(doc): target at [8] | cited: [0, 1, 2, 6, 9]
#   [84/2746] 100275_SimpleLanguage(doc): target at [8] | cited: [0, 5, 1, 4, 2]
#   [85/2746] 100275_Statistics(doc): target at [8] | cited: [0, 1, 3, 2, 5]
#   [86/2746] 100275_TechnicalTerms(doc): target at [8] | cited: [0, 1, 3, 8, 6]
#   [87/2746] 100275_UniqueWords(doc): target at [8] | cited: [0, 3, 1, 5, 2]
#   [88/2746] 100275_doc: target at [5] | cited: [0, 2, 3, 1, 4]
#   [89/2746] 100344_Authoritative(doc): target at [8] | cited: [0, 1, 3, 8, 6]
#   [90/2746] 100344_CQ(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [91/2746] 100344_CQS(doc): target at [8] | cited: [0, 1, 3, 4, 6]
#   [92/2746] 100344_CS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [93/2746] 100344_Citations(doc): target at [8] | cited: [0, 1, 3, 4]
#   [94/2746] 100344_ContentImprovement(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [95/2746] 100344_FC(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [96/2746] 100344_FCQ(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [97/2746] 100344_FCQS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [98/2746] 100344_FCS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [99/2746] 100344_FQ(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [100/2746] 100344_FQS(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [101/2746] 100344_FS(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [102/2746] 100344_Fluency(doc): target at [8] | cited: [0, 1, 4, 7, 8]
#   [103/2746] 100344_LLMstxt(doc): target at [9] | cited: [0, 1, 3, 4, 8]
#   [104/2746] 100344_QS(doc): target at [8] | cited: [0, 1, 3, 4, 6]
#   [105/2746] 100344_Quotes(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [106/2746] 100344_SimpleLanguage(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [107/2746] 100344_Statistics(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [108/2746] 100344_TechnicalTerms(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [109/2746] 100344_UniqueWords(doc): target at [8] | cited: [0, 1, 3, 4, 8]
#   [110/2746] 100344_doc: target at [8] | cited: [0, 1, 3, 4, 8]
#   [111/2746] 100479_Authoritative(doc): target at [8] | cited: [0, 1, 2, 4, 3]
#   [112/2746] 100479_CQ(doc): target at [9] | cited: [0, 1, 3, 5, 2]
#   [113/2746] 100479_CQS(doc): target at [8] | cited: [0, 6, 4, 1, 2]
#   [114/2746] 100479_CS(doc): target at [9] | cited: [0, 1, 4, 3, 6]
#   [115/2746] 100479_Citations(doc): target at [8] | cited: [0, 1, 2, 3]
#   [116/2746] 100479_ContentImprovement(doc): target at [9] | cited: [0, 2, 7, 8, 6]
#   [117/2746] 100479_FC(doc): target at [9] | cited: [0, 1, 3, 2, 4]
#   [118/2746] 100479_FCQ(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [119/2746] 100479_FCQS(doc): target at [9] | cited: [0, 1, 8]
#   [120/2746] 100479_FCS(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [121/2746] 100479_FQ(doc): target at [9] | cited: [0, 1, 2, 5]
#   [122/2746] 100479_FQS(doc): target at [9] | cited: [0, 1, 6, 8]
#   [123/2746] 100479_FS(doc): target at [9] | cited: [0, 2, 1, 7, 4]
#   [124/2746] 100479_Fluency(doc): target at [9] | cited: [0, 1, 2]
#   [125/2746] 100479_LLMstxt(doc): target at [9] | cited: [0, 4, 6, 8, 5]
#   [126/2746] 100479_QS(doc): target at [9] | cited: [0, 4, 1, 5, 6]
#   [127/2746] 100479_Quotes(doc): target at [8] | cited: [0, 1, 2, 4, 3]
#   [128/2746] 100479_SimpleLanguage(doc): target at [1] | cited: []
#   [129/2746] 100479_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [130/2746] 100479_TechnicalTerms(doc): target at [9] | cited: [0, 1, 7, 4, 3]
#   [131/2746] 100479_UniqueWords(doc): target at [9] | cited: [1, 0, 8, 9, 6]
#   [132/2746] 100479_doc: target at [9] | cited: [0, 1, 2, 3, 6]
#   [133/2746] 100631_Authoritative(doc): target at [0] | cited: [0, 1, 6, 3, 4]
#   [134/2746] 100631_CQ(doc): target at [0] | cited: [0, 1, 3, 5, 9]
#   [135/2746] 100631_CQS(doc): target at [0] | cited: [0, 2, 1, 3, 4]
#   [136/2746] 100631_CS(doc): target at [0] | cited: [0, 2, 3, 4, 1]
#   [137/2746] 100631_Citations(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [138/2746] 100631_ContentImprovement(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [139/2746] 100631_FC(doc): target at [7] | cited: [0, 5, 1, 4, 2]
#   [140/2746] 100631_FCQ(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [141/2746] 100631_FCQS(doc): target at [7] | cited: [0, 5, 1, 7, 2]
#   [142/2746] 100631_FCS(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [143/2746] 100631_FQ(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [144/2746] 100631_FQS(doc): target at [1] | cited: [0, 6, 1, 2, 3]
#   [145/2746] 100631_FS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [146/2746] 100631_Fluency(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [147/2746] 100631_LLMstxt(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [148/2746] 100631_QS(doc): target at [0] | cited: [0, 1, 3, 4, 2]
#   [149/2746] 100631_Quotes(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [150/2746] 100631_SimpleLanguage(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [151/2746] 100631_Statistics(doc): target at [6] | cited: [0, 5, 1, 6, 2]
#   [152/2746] 100631_TechnicalTerms(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [153/2746] 100631_UniqueWords(doc): target at [0] | cited: [0, 2, 1, 6, 3]
#   [154/2746] 100631_doc: target at [0] | cited: [2, 0, 3, 4, 7]
#   [155/2746] 100638_Authoritative(doc): target at [9] | cited: [1, 2, 3, 0, 4]
#   [156/2746] 100638_CQ(doc): target at [9] | cited: [2, 3, 0, 7, 4]
#   [157/2746] 100638_CQS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [158/2746] 100638_CS(doc): target at [9] | cited: [0, 2, 1, 8, 3]
#   [159/2746] 100638_Citations(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [160/2746] 100638_ContentImprovement(doc): target at [9] | cited: [0, 1, 3, 9, 2]
#   [161/2746] 100638_FC(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [162/2746] 100638_FCQ(doc): target at [9] | cited: [0, 4, 1, 2, 3]
#   [163/2746] 100638_FCQS(doc): target at [9] | cited: [0, 7, 1, 2, 3]
#   [164/2746] 100638_FCS(doc): target at [9] | cited: [1, 2, 3, 0, 7]
#   [165/2746] 100638_FQ(doc): target at [8] | cited: [0, 7, 1, 2, 3]
#   [166/2746] 100638_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [167/2746] 100638_FS(doc): target at [9] | cited: [0, 4, 1, 2, 3]
#   [168/2746] 100638_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [169/2746] 100638_LLMstxt(doc): target at [9] | cited: [0, 3, 4, 7, 6]
#   [170/2746] 100638_QS(doc): target at [5] | cited: [0, 8, 1, 2, 3]
#   [171/2746] 100638_Quotes(doc): target at [9] | cited: [1, 2, 0, 7, 4]
#   [172/2746] 100638_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [173/2746] 100638_Statistics(doc): target at [9] | cited: [0, 8, 3, 4, 5]
#   [174/2746] 100638_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [175/2746] 100638_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [176/2746] 100638_doc: target at [9] | cited: [0, 7, 1, 2, 3]
#   [177/2746] 100685_Authoritative(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [178/2746] 100685_CQ(doc): target at [0] | cited: [0, 3, 2, 1, 4]
#   [179/2746] 100685_CQS(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [180/2746] 100685_CS(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [181/2746] 100685_Citations(doc): target at [0] | cited: [0, 3, 1, 2, 7]
#   [182/2746] 100685_ContentImprovement(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [183/2746] 100685_FC(doc): target at [4] | cited: [0, 1, 2, 4, 3]
#   [184/2746] 100685_FCQ(doc): target at [3] | cited: [0, 1, 2, 6, 4]
#   [185/2746] 100685_FCQS(doc): target at [1] | cited: [0, 1, 2, 5, 7]
#   [186/2746] 100685_FCS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [187/2746] 100685_FQ(doc): target at [1] | cited: [0, 1, 3, 2, 5]
#   [188/2746] 100685_FQS(doc): target at [3] | cited: [0, 2, 6, 1, 4]
#   [189/2746] 100685_FS(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [190/2746] 100685_Fluency(doc): target at [1] | cited: [0, 1, 3, 2, 4]
#   [191/2746] 100685_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 5, 3]
#   [192/2746] 100685_QS(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [193/2746] 100685_Quotes(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [194/2746] 100685_SimpleLanguage(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [195/2746] 100685_Statistics(doc): target at [1] | cited: [0, 1, 3, 2, 6]
#   [196/2746] 100685_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [197/2746] 100685_UniqueWords(doc): target at [0] | cited: [0, 3, 6, 1, 2]
#   [198/2746] 100685_doc: target at [0] | cited: [0, 3, 6, 1, 2]
#   [199/2746] 101512_Authoritative(doc): target at [4] | cited: [0, 1, 2, 7, 3]
#   [200/2746] 101512_CQ(doc): target at [6] | cited: [0, 1, 2, 4, 3]
#   [201/2746] 101512_CQS(doc): target at [6] | cited: [0, 8, 1, 2, 4]
#   [202/2746] 101512_CS(doc): target at [6] | cited: [0, 1, 2, 4, 3]
#   [203/2746] 101512_Citations(doc): target at [4] | cited: [8, 9, 1, 2, 5]
#   [204/2746] 101512_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [205/2746] 101512_FC(doc): target at [6] | cited: [0, 8, 9, 1, 2]
#   [206/2746] 101512_FCQ(doc): target at [6] | cited: [0, 8, 1, 7, 4]
#   [207/2746] 101512_FCQS(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [208/2746] 101512_FCS(doc): target at [6] | cited: [0, 9, 1, 2, 7]
#   [209/2746] 101512_FQ(doc): target at [6] | cited: [0, 8, 9, 1, 2]
#   [210/2746] 101512_FQS(doc): target at [6] | cited: [8, 9, 1, 2, 4]
#   [211/2746] 101512_FS(doc): target at [6] | cited: [0, 1, 2, 7, 4]
#   [212/2746] 101512_Fluency(doc): target at [6] | cited: [0, 1, 4, 6, 2]
#   [213/2746] 101512_LLMstxt(doc): target at [4] | cited: [0, 8, 9, 1, 2]
#   [214/2746] 101512_QS(doc): target at [6] | cited: [0, 8, 1, 2, 7]
#   [215/2746] 101512_Quotes(doc): target at [4] | cited: [0, 8, 9, 1, 2]
#   [216/2746] 101512_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [217/2746] 101512_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [218/2746] 101512_TechnicalTerms(doc): target at [4] | cited: [0, 9, 1, 2, 4]
#   [219/2746] 101512_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [220/2746] 101512_doc: target at [4] | cited: [0, 1, 2, 4, 5]
#   [221/2746] 102578_Authoritative(doc): target at [1] | cited: [0, 1, 2, 5, 9]
#   [222/2746] 102578_CQ(doc): target at [1] | cited: [0, 1, 2, 5, 9]
#   [223/2746] 102578_CQS(doc): target at [2] | cited: [0, 5, 8, 1, 2]
#   [224/2746] 102578_CS(doc): target at [2] | cited: [0, 2, 5, 3, 8]
#   [225/2746] 102578_Citations(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [226/2746] 102578_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [227/2746] 102578_FC(doc): target at [1] | cited: []
#   [228/2746] 102578_FCQ(doc): target at [3] | cited: [0, 1, 2, 4, 6]
#   [229/2746] 102578_FCQS(doc): target at [3] | cited: [0, 3, 9, 1, 2]
#   [230/2746] 102578_FCS(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [231/2746] 102578_FQ(doc): target at [3] | cited: [0, 1, 3, 5, 9]
#   [232/2746] 102578_FQS(doc): target at [5] | cited: [0, 1, 5, 4, 9]
#   [233/2746] 102578_FS(doc): target at [5] | cited: [0, 1, 5, 3, 6]
#   [234/2746] 102578_Fluency(doc): target at [3] | cited: [0, 2, 5, 1, 3]
#   [235/2746] 102578_LLMstxt(doc): target at [9] | cited: [0, 1, 9, 3, 5]
#   [236/2746] 102578_QS(doc): target at [1] | cited: [0, 1, 2, 8, 4]
#   [237/2746] 102578_Quotes(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [238/2746] 102578_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [239/2746] 102578_Statistics(doc): target at [5] | cited: [1, 5, 0, 2, 6]
#   [240/2746] 102578_TechnicalTerms(doc): target at [1] | cited: [0, 1, 2, 5, 9]
#   [241/2746] 102578_UniqueWords(doc): target at [3] | cited: [0, 1, 5, 9, 3]
#   [242/2746] 102578_doc: target at [1] | cited: [0, 1, 2, 4, 6]
#   [243/2746] 10331_Authoritative(doc): target at [3] | cited: [0, 1, 4, 5, 9]
#   [244/2746] 10331_CQ(doc): target at [3] | cited: [0, 4, 8, 1, 2]
#   [245/2746] 10331_CQS(doc): target at [3] | cited: [0, 4, 1, 2]
#   [246/2746] 10331_CS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [247/2746] 10331_Citations(doc): target at [3] | cited: [0, 1, 4, 5, 8]
#   [248/2746] 10331_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 5, 9]
#   [249/2746] 10331_FC(doc): target at [4] | cited: [0, 1, 2, 5, 6]
#   [250/2746] 10331_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [251/2746] 10331_FCQS(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [252/2746] 10331_FCS(doc): target at [3] | cited: [0, 1, 9]
#   [253/2746] 10331_FQ(doc): target at [6] | cited: [0, 3, 4, 1, 9]
#   [254/2746] 10331_FQS(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [255/2746] 10331_FS(doc): target at [3] | cited: [0, 1, 5, 8, 3]
#   [256/2746] 10331_Fluency(doc): target at [4] | cited: [0, 1, 3, 5, 2]
#   [257/2746] 10331_LLMstxt(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [258/2746] 10331_QS(doc): target at [3] | cited: [0, 3, 4, 1, 2]
#   [259/2746] 10331_Quotes(doc): target at [3] | cited: [0, 4, 8, 5, 1]
#   [260/2746] 10331_SimpleLanguage(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [261/2746] 10331_Statistics(doc): target at [4] | cited: [0, 5, 1, 2, 3]
#   [262/2746] 10331_TechnicalTerms(doc): target at [5] | cited: [0, 4, 1, 3, 5]
#   [263/2746] 10331_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 5, 9]
#   [264/2746] 10331_doc: target at [3] | cited: [0, 1, 2, 3]
#   [265/2746] 103379_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [266/2746] 103379_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [267/2746] 103379_CQS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [268/2746] 103379_CS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [269/2746] 103379_Citations(doc): target at [3] | cited: [0, 1, 2, 4, 6]
#   [270/2746] 103379_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [271/2746] 103379_FC(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [272/2746] 103379_FCQ(doc): target at [3] | cited: [0, 1, 2, 4, 3]
#   [273/2746] 103379_FCQS(doc): target at [3] | cited: []
#   [274/2746] 103379_FCS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [275/2746] 103379_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [276/2746] 103379_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [277/2746] 103379_FS(doc): target at [3] | cited: [0, 1, 2, 4, 7]
#   [278/2746] 103379_Fluency(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [279/2746] 103379_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [280/2746] 103379_QS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [281/2746] 103379_Quotes(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [282/2746] 103379_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [283/2746] 103379_Statistics(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [284/2746] 103379_TechnicalTerms(doc): target at [3] | cited: [0, 1, 2, 4, 3]
#   [285/2746] 103379_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [286/2746] 103379_doc: target at [3] | cited: [0, 1, 2, 3, 4]
#   [287/2746] 103782_Authoritative(doc): target at [1] | cited: [1, 2, 3, 6, 4]
#   [288/2746] 103782_CQ(doc): target at [0] | cited: [0, 3, 2, 6, 5]
#   [289/2746] 103782_CQS(doc): target at [1] | cited: [0, 4, 6, 1, 2]
#   [290/2746] 103782_CS(doc): target at [0] | cited: [0, 2, 6, 7, 8]
#   [291/2746] 103782_Citations(doc): target at [3] | cited: [0, 4, 1, 5, 3]
#   [292/2746] 103782_ContentImprovement(doc): target at [4] | cited: [0, 4, 2, 7, 8]
#   [293/2746] 103782_FC(doc): target at [4] | cited: [0, 2, 3, 5, 8]
#   [294/2746] 103782_FCQ(doc): target at [5] | cited: [0, 3, 6, 2, 8]
#   [295/2746] 103782_FCQS(doc): target at [5] | cited: [0, 3, 6, 4, 8]
#   [296/2746] 103782_FCS(doc): target at [5] | cited: [0, 9, 1, 2, 7]
#   [297/2746] 103782_FQ(doc): target at [5] | cited: [0, 4, 2, 3, 5]
#   [298/2746] 103782_FQS(doc): target at [6] | cited: [0, 4, 7, 9, 6]
#   [299/2746] 103782_FS(doc): target at [5] | cited: [0, 2, 8, 5, 9]
#   [300/2746] 103782_Fluency(doc): target at [3] | cited: [1, 5, 6, 4, 9]
#   [301/2746] 103782_LLMstxt(doc): target at [6] | cited: [8, 2, 5, 6, 9]
#   [302/2746] 103782_QS(doc): target at [3] | cited: [0, 4, 6, 1, 3]
#   [303/2746] 103782_Quotes(doc): target at [3] | cited: [0, 2, 3, 9, 4]
#   [304/2746] 103782_SimpleLanguage(doc): target at [3] | cited: [0, 2, 6, 3, 8]
#   [305/2746] 103782_Statistics(doc): target at [5] | cited: [0, 2, 3, 7, 9]
#   [306/2746] 103782_TechnicalTerms(doc): target at [1] | cited: [4, 7, 1, 6, 9]
#   [307/2746] 103782_UniqueWords(doc): target at [1] | cited: [0, 2, 5, 1, 3]
#   [308/2746] 103782_doc: target at [0] | cited: [0, 1, 6, 4, 8]
#   [309/2746] 103863_Authoritative(doc): target at [0] | cited: [0, 1, 4, 2, 9]
#   [310/2746] 103863_CQ(doc): target at [0] | cited: [0, 1, 5, 9, 3]
#   [311/2746] 103863_CQS(doc): target at [0] | cited: [0, 1, 4, 5, 3]
#   [312/2746] 103863_CS(doc): target at [0] | cited: [0, 1, 4, 6, 3]
#   [313/2746] 103863_Citations(doc): target at [0] | cited: [5, 6, 9, 1, 3]
#   [314/2746] 103863_ContentImprovement(doc): target at [5] | cited: [0, 1, 3, 6, 2]
#   [315/2746] 103863_FC(doc): target at [6] | cited: [0, 2, 3, 1, 4]
#   [316/2746] 103863_FCQ(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [317/2746] 103863_FCQS(doc): target at [1] | cited: [0, 5, 6, 3, 7]
#   [318/2746] 103863_FCS(doc): target at [1] | cited: [0, 5, 9, 4, 2]
#   [319/2746] 103863_FQ(doc): target at [2] | cited: [0, 4, 6, 3, 7]
#   [320/2746] 103863_FQS(doc): target at [6] | cited: [0, 2, 3, 4, 1]
#   [321/2746] 103863_FS(doc): target at [1] | cited: [0, 4, 6, 3, 7]
#   [322/2746] 103863_Fluency(doc): target at [0] | cited: [4, 9, 1, 3, 2]
#   [323/2746] 103863_LLMstxt(doc): target at [5] | cited: [0, 2, 3, 1, 9]
#   [324/2746] 103863_QS(doc): target at [0] | cited: [0, 4, 9, 1, 2]
#   [325/2746] 103863_Quotes(doc): target at [0] | cited: [0, 4, 1, 3, 2]
#   [326/2746] 103863_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [327/2746] 103863_Statistics(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [328/2746] 103863_TechnicalTerms(doc): target at [1] | cited: [0, 3, 4, 6, 1]
#   [329/2746] 103863_UniqueWords(doc): target at [0] | cited: [0, 1, 5, 2, 3]
#   [330/2746] 103863_doc: target at [0] | cited: [0, 4, 5, 9, 1]
#   [331/2746] 104055_Authoritative(doc): target at [1] | cited: [0, 2, 3, 7, 1]
#   [332/2746] 104055_CQ(doc): target at [1] | cited: [0, 1, 2, 3, 6]
#   [333/2746] 104055_CQS(doc): target at [1] | cited: [0, 2, 3, 1, 7]
#   [334/2746] 104055_CS(doc): target at [1] | cited: [0, 3, 1, 5, 7]
#   [335/2746] 104055_Citations(doc): target at [1] | cited: [0, 2, 3, 1, 4]
#   [336/2746] 104055_ContentImprovement(doc): target at [2] | cited: [1, 2, 3, 6, 0]
#   [337/2746] 104055_FC(doc): target at [1] | cited: [0, 1, 7, 9, 2]
#   [338/2746] 104055_FCQ(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [339/2746] 104055_FCQS(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [340/2746] 104055_FCS(doc): target at [1] | cited: [1, 5, 0, 3, 4]
#   [341/2746] 104055_FQ(doc): target at [1] | cited: [0, 1, 3, 4, 2]
#   [342/2746] 104055_FQS(doc): target at [2] | cited: [2, 0, 3, 1, 7]
#   [343/2746] 104055_FS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [344/2746] 104055_Fluency(doc): target at [2] | cited: [0, 1, 4, 7, 2]
#   [345/2746] 104055_LLMstxt(doc): target at [9] | cited: [0, 1, 6, 3, 2]
#   [346/2746] 104055_QS(doc): target at [1] | cited: [0, 1, 2, 3, 7]
#   [347/2746] 104055_Quotes(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [348/2746] 104055_SimpleLanguage(doc): target at [1] | cited: [0, 1, 2, 3, 6]
#   [349/2746] 104055_Statistics(doc): target at [2] | cited: [2, 0, 3, 1]
#   [350/2746] 104055_TechnicalTerms(doc): target at [1] | cited: [0, 8, 1, 3, 4]
#   [351/2746] 104055_UniqueWords(doc): target at [2] | cited: [0, 2, 5, 1, 3]
#   [352/2746] 104055_doc: target at [1] | cited: [0, 2, 4, 1, 5]
#   [353/2746] 104590_Authoritative(doc): target at [2] | cited: [0, 2, 5, 1, 3]
#   [354/2746] 104590_CQ(doc): target at [6] | cited: [0, 3, 1, 5, 2]
#   [355/2746] 104590_CQS(doc): target at [2] | cited: [0, 2, 1, 8]
#   [356/2746] 104590_CS(doc): target at [2] | cited: [0, 1, 2, 8, 7]
#   [357/2746] 104590_Citations(doc): target at [2] | cited: [0, 2, 5, 1, 8]
#   [358/2746] 104590_ContentImprovement(doc): target at [2] | cited: [0, 2, 1, 8, 4]
#   [359/2746] 104590_FC(doc): target at [5] | cited: [0, 5, 8, 1, 4]
#   [360/2746] 104590_FCQ(doc): target at [2] | cited: [0, 2, 5, 1, 8]
#   [361/2746] 104590_FCQS(doc): target at [4] | cited: [0, 4, 5, 1, 8]
#   [362/2746] 104590_FCS(doc): target at [4] | cited: [0, 4, 5, 1, 8]
#   [363/2746] 104590_FQ(doc): target at [4] | cited: [0, 1, 2, 4, 7]
#   [364/2746] 104590_FQS(doc): target at [4] | cited: [0, 4, 1, 6]
#   [365/2746] 104590_FS(doc): target at [1] | cited: [0, 1, 5, 2, 8]
#   [366/2746] 104590_Fluency(doc): target at [2] | cited: [0, 4, 2, 1, 8]
#   [367/2746] 104590_LLMstxt(doc): target at [4] | cited: [1, 4, 2, 8, 5]
#   [368/2746] 104590_QS(doc): target at [1] | cited: [0, 1, 2, 5, 9]
#   [369/2746] 104590_Quotes(doc): target at [2] | cited: [0, 2, 4, 1, 3]
#   [370/2746] 104590_SimpleLanguage(doc): target at [2] | cited: [1, 2, 3, 8, 7]
#   [371/2746] 104590_Statistics(doc): target at [3] | cited: [0, 3, 1, 6, 4]
#   [372/2746] 104590_TechnicalTerms(doc): target at [2] | cited: [0, 2, 1, 8, 5]
#   [373/2746] 104590_UniqueWords(doc): target at [2] | cited: [0, 5, 2, 1, 8]
#   [374/2746] 104590_doc: target at [2] | cited: [0, 2, 1, 8, 3]
#   [375/2746] 104865_Authoritative(doc): target at [3] | cited: [0, 2, 3, 4, 5]
#   [376/2746] 104865_CQ(doc): target at [5] | cited: [0, 2, 1, 9, 3]
#   [377/2746] 104865_CQS(doc): target at [5] | cited: [0, 2, 3, 1, 5]
#   [378/2746] 104865_CS(doc): target at [5] | cited: [0, 2, 1, 3, 5]
#   [379/2746] 104865_Citations(doc): target at [4] | cited: [0, 2, 1, 9, 7]
#   [380/2746] 104865_ContentImprovement(doc): target at [2] | cited: [0, 3, 1, 2, 5]
#   [381/2746] 104865_FC(doc): target at [5] | cited: [0, 2, 7, 1, 9]
#   [382/2746] 104865_FCQ(doc): target at [5] | cited: [0, 2, 3, 1, 7]
#   [383/2746] 104865_FCQS(doc): target at [5] | cited: [0, 2, 3, 1, 9]
#   [384/2746] 104865_FCS(doc): target at [2] | cited: [0, 3, 4, 2, 5]
#   [385/2746] 104865_FQ(doc): target at [6] | cited: [0, 2, 3, 4, 1]
#   [386/2746] 104865_FQS(doc): target at [6] | cited: [0, 2, 3, 1, 9]
#   [387/2746] 104865_FS(doc): target at [5] | cited: [0, 2, 1, 3, 4]
#   [388/2746] 104865_Fluency(doc): target at [5] | cited: [0, 2, 3, 1, 9]
#   [389/2746] 104865_LLMstxt(doc): target at [2] | cited: [0, 3, 4, 1, 9]
#   [390/2746] 104865_QS(doc): target at [4] | cited: [0, 2, 1, 9, 7]
#   [391/2746] 104865_Quotes(doc): target at [5] | cited: [0, 2, 1, 9, 7]
#   [392/2746] 104865_SimpleLanguage(doc): target at [2] | cited: [0, 3, 4, 1, 9]
#   [393/2746] 104865_Statistics(doc): target at [7] | cited: [0, 4, 5, 1, 3]
#   [394/2746] 104865_TechnicalTerms(doc): target at [0] | cited: [0, 4, 1, 3, 2]
#   [395/2746] 104865_UniqueWords(doc): target at [5] | cited: []
#   [396/2746] 104865_doc: target at [4] | cited: [0, 2, 1, 9]
#   [397/2746] 104931_Authoritative(doc): target at [6] | cited: [0, 1, 5, 8, 6]
#   [398/2746] 104931_CQ(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [399/2746] 104931_CQS(doc): target at [6] | cited: [0, 1, 3, 6, 7]
#   [400/2746] 104931_CS(doc): target at [6] | cited: [1, 2, 0, 5, 6]
#   [401/2746] 104931_Citations(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [402/2746] 104931_ContentImprovement(doc): target at [6] | cited: [1, 5, 3, 0, 2]
#   [403/2746] 104931_FC(doc): target at [6] | cited: [0, 1, 2, 6, 5]
#   [404/2746] 104931_FCQ(doc): target at [6] | cited: [0, 2, 1, 6, 5]
#   [405/2746] 104931_FCQS(doc): target at [6] | cited: [0, 1, 2, 5, 3]
#   [406/2746] 104931_FCS(doc): target at [6] | cited: [1, 3, 5, 7, 4]
#   [407/2746] 104931_FQ(doc): target at [6] | cited: [0, 2, 1, 5, 6]
#   [408/2746] 104931_FQS(doc): target at [6] | cited: [1, 2, 5, 3, 4]
#   [409/2746] 104931_FS(doc): target at [6] | cited: [0, 2, 5, 1, 3]
#   [410/2746] 104931_Fluency(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [411/2746] 104931_LLMstxt(doc): target at [9] | cited: [0, 1, 3, 5, 4]
#   [412/2746] 104931_QS(doc): target at [6] | cited: [0, 1, 6, 5, 8]
#   [413/2746] 104931_Quotes(doc): target at [6] | cited: [0, 1, 5, 7, 4]
#   [414/2746] 104931_SimpleLanguage(doc): target at [6] | cited: [0, 1, 2, 5, 4]
#   [415/2746] 104931_Statistics(doc): target at [6] | cited: [0, 6, 1, 5, 8]
#   [416/2746] 104931_TechnicalTerms(doc): target at [6] | cited: [0, 1, 5, 3, 6]
#   [417/2746] 104931_UniqueWords(doc): target at [6] | cited: [0, 2, 1, 3, 5]
#   [418/2746] 104931_doc: target at [6] | cited: [0, 1, 5, 8, 2]
#   [419/2746] 105061_Authoritative(doc): target at [7] | cited: [0, 1, 2, 6, 3]
#   [420/2746] 105061_CQ(doc): target at [6] | cited: [0, 1, 5, 9, 4]
#   [421/2746] 105061_CQS(doc): target at [6] | cited: [0, 1, 2, 5, 7]
#   [422/2746] 105061_CS(doc): target at [6] | cited: [0, 2, 3, 1, 4]
#   [423/2746] 105061_Citations(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [424/2746] 105061_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [425/2746] 105061_FC(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [426/2746] 105061_FCQ(doc): target at [1] | cited: [0, 2, 1, 6, 5]
#   [427/2746] 105061_FCQS(doc): target at [6] | cited: [0, 1, 2, 5, 6]
#   [428/2746] 105061_FCS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [429/2746] 105061_FQ(doc): target at [6] | cited: [0, 1, 2, 5]
#   [430/2746] 105061_FQS(doc): target at [6] | cited: [0, 2, 3, 1, 4]
#   [431/2746] 105061_FS(doc): target at [1] | cited: [1, 3, 4, 2, 5]
#   [432/2746] 105061_Fluency(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [433/2746] 105061_LLMstxt(doc): target at [9] | cited: [0, 3, 1, 2, 6]
#   [434/2746] 105061_QS(doc): target at [6] | cited: [0, 3, 1, 2, 5]
#   [435/2746] 105061_Quotes(doc): target at [6] | cited: [0, 2, 1, 5, 7]
#   [436/2746] 105061_SimpleLanguage(doc): target at [6] | cited: [0, 2, 1, 3, 5]
#   [437/2746] 105061_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [438/2746] 105061_TechnicalTerms(doc): target at [1] | cited: [0, 3, 2, 1, 6]
#   [439/2746] 105061_UniqueWords(doc): target at [8] | cited: [0, 3, 1, 2, 5]
#   [440/2746] 105061_doc: target at [7] | cited: [0, 3, 2, 1, 4]
#   [441/2746] 105517_Authoritative(doc): target at [8] | cited: [0, 1, 6, 7, 2]
#   [442/2746] 105517_CQ(doc): target at [8] | cited: [0, 6, 8, 7, 9]
#   [443/2746] 105517_CQS(doc): target at [8] | cited: [0, 8, 7, 9]
#   [444/2746] 105517_CS(doc): target at [8] | cited: [0, 4, 6, 2, 8]
#   [445/2746] 105517_Citations(doc): target at [8] | cited: [0, 1, 2, 8, 7]
#   [446/2746] 105517_ContentImprovement(doc): target at [8] | cited: [9, 0, 8, 4]
#   [447/2746] 105517_FC(doc): target at [8] | cited: [0, 2, 7, 4, 8]
#   [448/2746] 105517_FCQ(doc): target at [7] | cited: [0, 1, 3, 6, 5]
#   [449/2746] 105517_FCQS(doc): target at [2] | cited: [0, 2, 7, 8]
#   [450/2746] 105517_FCS(doc): target at [8] | cited: [0, 5, 6, 8, 7]
#   [451/2746] 105517_FQ(doc): target at [8] | cited: [6, 7, 8, 0, 9]
#   [452/2746] 105517_FQS(doc): target at [8] | cited: [0, 6, 7, 8, 9]
#   [453/2746] 105517_FS(doc): target at [9] | cited: [0, 8, 2, 4, 5]
#   [454/2746] 105517_Fluency(doc): target at [8] | cited: [0, 8, 9, 4, 6]
#   [455/2746] 105517_LLMstxt(doc): target at [9] | cited: [2, 9, 4, 8]
#   [456/2746] 105517_QS(doc): target at [8] | cited: [0, 6, 8, 7, 9]
#   [457/2746] 105517_Quotes(doc): target at [8] | cited: [6, 8, 9, 0]
#   [458/2746] 105517_SimpleLanguage(doc): target at [7] | cited: [0, 6, 7, 8, 9]
#   [459/2746] 105517_Statistics(doc): target at [9] | cited: [0, 7, 6, 9, 2]
#   [460/2746] 105517_TechnicalTerms(doc): target at [8] | cited: [0, 6, 9, 2, 8]
#   [461/2746] 105517_UniqueWords(doc): target at [8] | cited: [0, 6, 7, 8, 9]
#   [462/2746] 105517_doc: target at [8] | cited: [0, 7, 5, 6, 8]
#   [463/2746] 105770_Authoritative(doc): target at [7] | cited: [0, 2, 3, 5, 7]
#   [464/2746] 105770_CQ(doc): target at [7] | cited: [0, 3, 4, 2, 9]
#   [465/2746] 105770_CQS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [466/2746] 105770_CS(doc): target at [7] | cited: [0, 2, 5, 3, 1]
#   [467/2746] 105770_Citations(doc): target at [7] | cited: [0, 3, 4, 5, 1]
#   [468/2746] 105770_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [469/2746] 105770_FC(doc): target at [7] | cited: [0, 1, 3, 6, 2]
#   [470/2746] 105770_FCQ(doc): target at [7] | cited: [0, 4, 7, 2, 3]
#   [471/2746] 105770_FCQS(doc): target at [7] | cited: [0, 2, 1, 4, 3]
#   [472/2746] 105770_FCS(doc): target at [7] | cited: [0, 2, 4, 5, 3]
#   [473/2746] 105770_FQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [474/2746] 105770_FQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [475/2746] 105770_FS(doc): target at [7] | cited: [0, 1, 3, 4, 2]
#   [476/2746] 105770_Fluency(doc): target at [7] | cited: [0, 2, 1, 3, 5]
#   [477/2746] 105770_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 5, 7]
#   [478/2746] 105770_QS(doc): target at [7] | cited: [1, 7, 4, 6, 3]
#   [479/2746] 105770_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [480/2746] 105770_SimpleLanguage(doc): target at [7] | cited: [0, 1, 3, 2, 4]
#   [481/2746] 105770_Statistics(doc): target at [7] | cited: [0, 3, 6, 1, 5]
#   [482/2746] 105770_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [483/2746] 105770_UniqueWords(doc): target at [7] | cited: [0, 1, 4, 6, 2]
#   [484/2746] 105770_doc: target at [7] | cited: [0, 1, 3, 4, 5]
#   [485/2746] 105809_Authoritative(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [486/2746] 105809_CQ(doc): target at [7] | cited: [0, 1, 4, 2, 3]
#   [487/2746] 105809_CQS(doc): target at [9] | cited: [0, 1, 2, 3]
#   [488/2746] 105809_CS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [489/2746] 105809_Citations(doc): target at [7] | cited: [0, 2, 1, 4, 3]
#   [490/2746] 105809_ContentImprovement(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [491/2746] 105809_FC(doc): target at [9] | cited: [0, 1, 6, 2, 3]
#   [492/2746] 105809_FCQ(doc): target at [9] | cited: [0, 2, 1, 7, 4]
#   [493/2746] 105809_FCQS(doc): target at [9] | cited: [0, 2, 1, 3, 4]
#   [494/2746] 105809_FCS(doc): target at [7] | cited: [0, 1, 2, 4, 3]
#   [495/2746] 105809_FQ(doc): target at [7] | cited: [0, 2, 1, 4, 3]
#   [496/2746] 105809_FQS(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [497/2746] 105809_FS(doc): target at [7] | cited: [0, 1, 4, 2]
#   [498/2746] 105809_Fluency(doc): target at [7] | cited: [0, 2, 1, 6, 3]
#   [499/2746] 105809_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [500/2746] 105809_QS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [501/2746] 105809_Quotes(doc): target at [7] | cited: [0, 1, 2, 4, 9]
#   [502/2746] 105809_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [503/2746] 105809_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [504/2746] 105809_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 4]
#   [505/2746] 105809_UniqueWords(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [506/2746] 105809_doc: target at [7] | cited: [0, 1, 2, 4, 5]
#   [507/2746] 105896_Authoritative(doc): target at [1] | cited: [0, 5, 6, 4, 9]
#   [508/2746] 105896_CQ(doc): target at [1] | cited: [0, 1, 3, 7, 5]
#   [509/2746] 105896_CQS(doc): target at [0] | cited: [0, 2, 1, 3, 7]
#   [510/2746] 105896_CS(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [511/2746] 105896_Citations(doc): target at [0] | cited: [0, 1, 7, 5, 8]
#   [512/2746] 105896_ContentImprovement(doc): target at [0] | cited: [0, 1, 6, 2, 4]
#   [513/2746] 105896_FC(doc): target at [2] | cited: [0, 4, 3, 1, 5]
#   [514/2746] 105896_FCQ(doc): target at [6] | cited: [0, 4, 5, 1, 3]
#   [515/2746] 105896_FCQS(doc): target at [6] | cited: [0, 1, 5, 6, 7]
#   [516/2746] 105896_FCS(doc): target at [6] | cited: [0, 5, 1, 7, 4]
#   [517/2746] 105896_FQ(doc): target at [7] | cited: [0, 5, 6, 4, 9]
#   [518/2746] 105896_FQS(doc): target at [6] | cited: [0, 5, 7]
#   [519/2746] 105896_FS(doc): target at [2] | cited: [0, 6, 7, 1, 5]
#   [520/2746] 105896_Fluency(doc): target at [2] | cited: [0, 6, 1, 3, 7]
#   [521/2746] 105896_LLMstxt(doc): target at [0] | cited: [0, 1, 2, 7, 8]
#   [522/2746] 105896_QS(doc): target at [0] | cited: [0, 1, 5, 7]
#   [523/2746] 105896_Quotes(doc): target at [0] | cited: [0, 2, 5, 3, 6]
#   [524/2746] 105896_SimpleLanguage(doc): target at [0] | cited: [0, 3, 6, 2, 7]
#   [525/2746] 105896_Statistics(doc): target at [2] | cited: [0, 1, 6, 9, 5]
#   [526/2746] 105896_TechnicalTerms(doc): target at [2] | cited: [0, 6, 1, 5, 7]
#   [527/2746] 105896_UniqueWords(doc): target at [0] | cited: [1, 6, 0, 3, 7]
#   [528/2746] 105896_doc: target at [0] | cited: [0, 1, 3, 6, 2]
#   [529/2746] 106226_Authoritative(doc): target at [6] | cited: [0, 1, 2, 6, 4]
#   [530/2746] 106226_CQ(doc): target at [6] | cited: [0, 1, 3, 6, 8]
#   [531/2746] 106226_CQS(doc): target at [6] | cited: [0, 1, 3, 6, 7]
#   [532/2746] 106226_CS(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [533/2746] 106226_Citations(doc): target at [5] | cited: [0, 1, 2, 5, 8]
#   [534/2746] 106226_ContentImprovement(doc): target at [6] | cited: [0, 1, 6, 2, 3]
#   [535/2746] 106226_FC(doc): target at [0] | cited: [0, 3, 8, 1, 4]
#   [536/2746] 106226_FCQ(doc): target at [6] | cited: [0, 2, 3, 8, 7]
#   [537/2746] 106226_FCQS(doc): target at [6] | cited: [0, 1, 3, 6, 7]
#   [538/2746] 106226_FCS(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [539/2746] 106226_FQ(doc): target at [6] | cited: [0, 3, 1, 8, 5]
#   [540/2746] 106226_FQS(doc): target at [6] | cited: [0, 1, 4, 8, 2]
#   [541/2746] 106226_FS(doc): target at [6] | cited: [0, 1, 4, 3, 7]
#   [542/2746] 106226_Fluency(doc): target at [5] | cited: [0, 1, 3, 5]
#   [543/2746] 106226_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [544/2746] 106226_QS(doc): target at [5] | cited: [0, 1, 2, 8, 5]
#   [545/2746] 106226_Quotes(doc): target at [6] | cited: [0, 1, 7, 6, 3]
#   [546/2746] 106226_SimpleLanguage(doc): target at [3] | cited: [0, 3, 4, 7, 1]
#   [547/2746] 106226_Statistics(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [548/2746] 106226_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 4, 8]
#   [549/2746] 106226_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 3, 7]
#   [550/2746] 106226_doc: target at [1] | cited: [1, 3, 6, 2, 5]
#   [551/2746] 106227_Authoritative(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [552/2746] 106227_CQ(doc): target at [6] | cited: [0, 2, 1, 8, 5]
#   [553/2746] 106227_CQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [554/2746] 106227_CS(doc): target at [7] | cited: [0, 1, 3, 2, 4]
#   [555/2746] 106227_Citations(doc): target at [7] | cited: [0, 8, 6, 7]
#   [556/2746] 106227_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [557/2746] 106227_FC(doc): target at [6] | cited: [1, 2, 3, 4, 8]
#   [558/2746] 106227_FCQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [559/2746] 106227_FCQS(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [560/2746] 106227_FCS(doc): target at [6] | cited: [0, 1, 5, 3, 7]
#   [561/2746] 106227_FQ(doc): target at [6] | cited: [0, 2, 3, 5, 7]
#   [562/2746] 106227_FQS(doc): target at [6] | cited: [1, 2, 8, 0, 4]
#   [563/2746] 106227_FS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [564/2746] 106227_Fluency(doc): target at [8] | cited: [0, 3, 7, 8, 2]
#   [565/2746] 106227_LLMstxt(doc): target at [9] | cited: [0, 1, 5, 7, 2]
#   [566/2746] 106227_QS(doc): target at [7] | cited: [0, 6, 8, 3, 5]
#   [567/2746] 106227_Quotes(doc): target at [7] | cited: [0, 2, 3, 1, 4]
#   [568/2746] 106227_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 4, 3]
#   [569/2746] 106227_Statistics(doc): target at [7] | cited: [0, 1, 3, 5, 2]
#   [570/2746] 106227_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [571/2746] 106227_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [572/2746] 106227_doc: target at [6] | cited: [0, 1, 2, 8, 7]
#   [573/2746] 106228_Authoritative(doc): target at [7] | cited: [0, 1, 7]
#   [574/2746] 106228_CQ(doc): target at [7] | cited: [0, 1, 7, 8, 6]
#   [575/2746] 106228_CQS(doc): target at [7] | cited: [1, 2, 3, 6, 7]
#   [576/2746] 106228_CS(doc): target at [7] | cited: [0, 1, 7, 6]
#   [577/2746] 106228_Citations(doc): target at [3] | cited: [0, 1, 4, 3]
#   [578/2746] 106228_ContentImprovement(doc): target at [7] | cited: [0, 1, 7, 8, 6]
#   [579/2746] 106228_FC(doc): target at [7] | cited: [0, 1, 8, 7]
#   [580/2746] 106228_FCQ(doc): target at [7] | cited: [0, 1, 6, 7, 8]
#   [581/2746] 106228_FCQS(doc): target at [7] | cited: [0, 1, 8, 7, 5]
#   [582/2746] 106228_FCS(doc): target at [7] | cited: [0, 1, 3, 6]
#   [583/2746] 106228_FQ(doc): target at [7] | cited: [0, 7, 1, 4, 2]
#   [584/2746] 106228_FQS(doc): target at [8] | cited: [0, 1, 7, 8, 6]
#   [585/2746] 106228_FS(doc): target at [7] | cited: [0, 1, 8, 7, 2]
#   [586/2746] 106228_Fluency(doc): target at [7] | cited: [0, 1, 3, 8, 7]
#   [587/2746] 106228_LLMstxt(doc): target at [3] | cited: [0, 1, 3, 4, 8]
#   [588/2746] 106228_QS(doc): target at [6] | cited: [0, 1, 3, 6, 8]
#   [589/2746] 106228_Quotes(doc): target at [5] | cited: [0, 1, 8, 5, 7]
#   [590/2746] 106228_SimpleLanguage(doc): target at [7] | cited: [0, 1, 7, 9, 8]
#   [591/2746] 106228_Statistics(doc): target at [7] | cited: [0, 1, 7, 8, 6]
#   [592/2746] 106228_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 8, 7]
#   [593/2746] 106228_UniqueWords(doc): target at [7] | cited: [0, 2, 1, 3, 8]
#   [594/2746] 106228_doc: target at [3] | cited: [0, 1, 3, 4, 8]
#   [595/2746] 106325_Authoritative(doc): target at [9] | cited: [0]
#   [596/2746] 106325_CQ(doc): target at [9] | cited: [0, 1, 2]
#   [597/2746] 106325_CQS(doc): target at [9] | cited: [0, 2, 1]
#   [598/2746] 106325_CS(doc): target at [8] | cited: [0, 8]
#   [599/2746] 106325_Citations(doc): target at [9] | cited: [1, 2, 4]
#   [600/2746] 106325_ContentImprovement(doc): target at [8] | cited: [0, 1, 2]
#   [601/2746] 106325_FC(doc): target at [9] | cited: [0]
#   [602/2746] 106325_FCQ(doc): target at [9] | cited: [0]
#   [603/2746] 106325_FCQS(doc): target at [9] | cited: [1]
#   [604/2746] 106325_FCS(doc): target at [9] | cited: [0, 1, 2]
#   [605/2746] 106325_FQ(doc): target at [9] | cited: [0, 1, 8]
#   [606/2746] 106325_FQS(doc): target at [8] | cited: [0, 2, 1]
#   [607/2746] 106325_FS(doc): target at [9] | cited: [0, 1]
#   [608/2746] 106325_Fluency(doc): target at [9] | cited: [0]
#   [609/2746] 106325_LLMstxt(doc): target at [8] | cited: [1, 8]
#   [610/2746] 106325_QS(doc): target at [9] | cited: [1]
#   [611/2746] 106325_Quotes(doc): target at [8] | cited: [0]
#   [612/2746] 106325_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2]
#   [613/2746] 106325_Statistics(doc): target at [9] | cited: [0]
#   [614/2746] 106325_TechnicalTerms(doc): target at [9] | cited: [1]
#   [615/2746] 106325_UniqueWords(doc): target at [9] | cited: [0, 1]
#   [616/2746] 106325_doc: target at [9] | cited: [1]
#   [617/2746] 106340_Authoritative(doc): target at [2] | cited: [0, 1, 2, 3, 5]
#   [618/2746] 106340_CQ(doc): target at [2] | cited: [0, 1, 3, 5, 8]
#   [619/2746] 106340_CQS(doc): target at [2] | cited: [0, 2, 4, 1, 3]
#   [620/2746] 106340_CS(doc): target at [1] | cited: [0, 8, 5, 9]
#   [621/2746] 106340_Citations(doc): target at [2] | cited: [0, 2, 1, 3, 5]
#   [622/2746] 106340_ContentImprovement(doc): target at [2] | cited: [0, 3, 8, 9, 5]
#   [623/2746] 106340_FC(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [624/2746] 106340_FCQ(doc): target at [4] | cited: [0, 2, 1, 3, 5]
#   [625/2746] 106340_FCQS(doc): target at [2] | cited: [0, 1, 8, 9, 4]
#   [626/2746] 106340_FCS(doc): target at [2] | cited: [0, 2, 8, 9, 1]
#   [627/2746] 106340_FQ(doc): target at [2] | cited: [0, 8, 2, 5, 3]
#   [628/2746] 106340_FQS(doc): target at [5] | cited: [0, 5, 8, 2, 4]
#   [629/2746] 106340_FS(doc): target at [5] | cited: [0, 5, 7, 8, 9]
#   [630/2746] 106340_Fluency(doc): target at [2] | cited: [0, 2, 1, 5, 9]
#   [631/2746] 106340_LLMstxt(doc): target at [7] | cited: [0, 1, 2, 6, 8]
#   [632/2746] 106340_QS(doc): target at [1] | cited: [0, 1, 5, 8, 4]
#   [633/2746] 106340_Quotes(doc): target at [1] | cited: [0, 1, 2, 8, 3]
#   [634/2746] 106340_SimpleLanguage(doc): target at [1] | cited: [0, 7, 4, 9, 8]
#   [635/2746] 106340_Statistics(doc): target at [2] | cited: [0, 1, 3, 4, 8]
#   [636/2746] 106340_TechnicalTerms(doc): target at [2] | cited: [0, 3, 4, 8, 5]
#   [637/2746] 106340_UniqueWords(doc): target at [2] | cited: [0, 4, 3, 7, 8]
#   [638/2746] 106340_doc: target at [1] | cited: [0, 8, 4, 5, 9]
#   [639/2746] 106580_Authoritative(doc): target at [3] | cited: [0, 1, 2, 5, 3]
#   [640/2746] 106580_CQ(doc): target at [3] | cited: [0, 1, 2, 7, 3]
#   [641/2746] 106580_CQS(doc): target at [3] | cited: [0, 1, 2]
#   [642/2746] 106580_CS(doc): target at [2] | cited: [0, 1, 2, 3]
#   [643/2746] 106580_Citations(doc): target at [3] | cited: [0, 2, 1, 3, 4]
#   [644/2746] 106580_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [645/2746] 106580_FC(doc): target at [3] | cited: [0, 1, 3, 2]
#   [646/2746] 106580_FCQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [647/2746] 106580_FCQS(doc): target at [3] | cited: [0, 2, 1, 3, 4]
#   [648/2746] 106580_FCS(doc): target at [3] | cited: [0, 2, 1, 6, 8]
#   [649/2746] 106580_FQ(doc): target at [3] | cited: [0, 1, 4, 2, 3]
#   [650/2746] 106580_FQS(doc): target at [0] | cited: [1, 2, 3, 4, 0]
#   [651/2746] 106580_FS(doc): target at [3] | cited: [0, 1, 2, 3]
#   [652/2746] 106580_Fluency(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [653/2746] 106580_LLMstxt(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [654/2746] 106580_QS(doc): target at [3] | cited: [0, 1, 2, 3]
#   [655/2746] 106580_Quotes(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [656/2746] 106580_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3]
#   [657/2746] 106580_Statistics(doc): target at [3] | cited: [0, 1, 2, 4]
#   [658/2746] 106580_TechnicalTerms(doc): target at [3] | cited: [0, 2, 1]
#   [659/2746] 106580_UniqueWords(doc): target at [3] | cited: [0, 1, 3, 8, 2]
#   [660/2746] 106580_doc: target at [3] | cited: [0, 1, 2, 3, 4]
#   [661/2746] 107018_Authoritative(doc): target at [0] | cited: [0, 1, 4, 2, 3]
#   [662/2746] 107018_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [663/2746] 107018_CQS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [664/2746] 107018_CS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [665/2746] 107018_Citations(doc): target at [3] | cited: [0, 1, 3, 4]
#   [666/2746] 107018_ContentImprovement(doc): target at [3] | cited: [0, 1, 2, 6, 3]
#   [667/2746] 107018_FC(doc): target at [1] | cited: [0, 1, 2, 5, 6]
#   [668/2746] 107018_FCQ(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [669/2746] 107018_FCQS(doc): target at [3] | cited: [0, 1, 2, 3]
#   [670/2746] 107018_FCS(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [671/2746] 107018_FQ(doc): target at [2] | cited: [0, 1, 3, 2, 4]
#   [672/2746] 107018_FQS(doc): target at [2] | cited: [3, 1, 0, 2, 4]
#   [673/2746] 107018_FS(doc): target at [3] | cited: [0, 1, 2, 4]
#   [674/2746] 107018_Fluency(doc): target at [3] | cited: [0, 1, 2, 4, 5]
#   [675/2746] 107018_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [676/2746] 107018_QS(doc): target at [0] | cited: [0, 1, 4, 2, 3]
#   [677/2746] 107018_Quotes(doc): target at [1] | cited: [0, 1, 2]
#   [678/2746] 107018_SimpleLanguage(doc): target at [3] | cited: [0, 4, 1, 3, 2]
#   [679/2746] 107018_Statistics(doc): target at [4] | cited: [0, 1, 2, 4]
#   [680/2746] 107018_TechnicalTerms(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [681/2746] 107018_UniqueWords(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [682/2746] 107018_doc: target at [3] | cited: [0, 1, 2, 3]
#   [683/2746] 10701_Authoritative(doc): target at [6] | cited: [0, 1, 2]
#   [684/2746] 10701_CQ(doc): target at [5] | cited: [0, 1, 2]
#   [685/2746] 10701_CQS(doc): target at [5] | cited: [0, 1, 2, 3]
#   [686/2746] 10701_CS(doc): target at [5] | cited: [0, 1]
#   [687/2746] 10701_Citations(doc): target at [5] | cited: [0, 1, 2]
#   [688/2746] 10701_ContentImprovement(doc): target at [7] | cited: [0, 1, 2]
#   [689/2746] 10701_FC(doc): target at [7] | cited: [0, 1, 2, 3]
#   [690/2746] 10701_FCQ(doc): target at [5] | cited: [0, 1, 2]
#   [691/2746] 10701_FCQS(doc): target at [5] | cited: [0, 1, 2]
#   [692/2746] 10701_FCS(doc): target at [5] | cited: [0, 1, 2]
#   [693/2746] 10701_FQ(doc): target at [4] | cited: [0, 1, 2]
#   [694/2746] 10701_FQS(doc): target at [4] | cited: [0, 2, 1]
#   [695/2746] 10701_FS(doc): target at [8] | cited: [0, 1, 2]
#   [696/2746] 10701_Fluency(doc): target at [5] | cited: [0, 1, 2]
#   [697/2746] 10701_LLMstxt(doc): target at [9] | cited: [0, 1, 2]
#   [698/2746] 10701_QS(doc): target at [6] | cited: [0, 1, 2]
#   [699/2746] 10701_Quotes(doc): target at [4] | cited: [0, 1, 2, 3]
#   [700/2746] 10701_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2]
#   [701/2746] 10701_Statistics(doc): target at [8] | cited: []
#   [702/2746] 10701_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2]
#   [703/2746] 10701_UniqueWords(doc): target at [7] | cited: [0, 2, 1]
#   [704/2746] 10701_doc: target at [3] | cited: [0, 1, 2]
#   [705/2746] 107145_Authoritative(doc): target at [1] | cited: [0, 1, 2]
#   [706/2746] 107145_CQ(doc): target at [1] | cited: [0, 1]
#   [707/2746] 107145_CQS(doc): target at [1] | cited: [0, 1]
#   [708/2746] 107145_CS(doc): target at [0] | cited: [0, 1]
#   [709/2746] 107145_Citations(doc): target at [1] | cited: [0, 1, 7, 9]
#   [710/2746] 107145_ContentImprovement(doc): target at [1] | cited: [0, 1, 3, 9]
#   [711/2746] 107145_FC(doc): target at [1] | cited: [0, 1]
#   [712/2746] 107145_FCQ(doc): target at [1] | cited: [0, 1]
#   [713/2746] 107145_FCQS(doc): target at [1] | cited: [0, 1, 5, 9]
#   [714/2746] 107145_FCS(doc): target at [1] | cited: [0, 1, 5, 7]
#   [715/2746] 107145_FQ(doc): target at [1] | cited: [0, 1, 5]
#   [716/2746] 107145_FQS(doc): target at [1] | cited: [0, 1, 9]
#   [717/2746] 107145_FS(doc): target at [1] | cited: [0, 1, 9]
#   [718/2746] 107145_Fluency(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [719/2746] 107145_LLMstxt(doc): target at [1] | cited: [0, 1]
#   [720/2746] 107145_QS(doc): target at [1] | cited: [0, 1]
#   [721/2746] 107145_Quotes(doc): target at [1] | cited: [0, 1, 7, 9]
#   [722/2746] 107145_SimpleLanguage(doc): target at [0] | cited: [0, 1, 5]
# ...
#   [2530/2746] 16033_CQ(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [2531/2746] 16033_CQS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2532/2746] 16033_CS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2533/2746] 16033_Citations(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2534/2746] 16033_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2535/2746] 16033_FC(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2536/2746] 16033_FCQ(doc): target at [9] | cited: [0, 4, 2, 3, 5]
#   [2537/2746] 16033_FCQS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2538/2746] 16033_FCS(doc): target at [9] | cited: [0, 4, 2, 1, 3]
#   [2539/2746] 16033_FQ(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2540/2746] 16033_FQS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2541/2746] 16033_FS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2542/2746] 16033_Fluency(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2543/2746] 16033_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [2544/2746] 16033_QS(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2545/2746] 16033_Quotes(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2546/2746] 16033_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2547/2746] 16033_Statistics(doc): target at [9] | cited: [0, 4, 2, 7, 3]
#   [2548/2746] 16033_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 4, 3]
#   [2549/2746] 16033_UniqueWords(doc): target at [9] | cited: [0, 1, 4, 2, 3]
#   [2550/2746] 16033_doc: target at [9] | cited: [0, 1, 2, 4, 3]
#   [2551/2746] 16339_Authoritative(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [2552/2746] 16339_CQ(doc): target at [7] | cited: [0, 1, 2, 8, 4]
#   [2553/2746] 16339_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [2554/2746] 16339_CS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2555/2746] 16339_Citations(doc): target at [5] | cited: [0, 1, 9, 2, 7]
#   [2556/2746] 16339_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2557/2746] 16339_FC(doc): target at [6] | cited: [0, 1, 3, 4, 9]
#   [2558/2746] 16339_FCQ(doc): target at [4] | cited: [0, 1, 2, 8, 5]
#   [2559/2746] 16339_FCQS(doc): target at [6] | cited: [0, 1, 2, 3, 7]
#   [2560/2746] 16339_FCS(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2561/2746] 16339_FQ(doc): target at [7] | cited: [0, 8, 1, 2, 3]
#   [2562/2746] 16339_FQS(doc): target at [7] | cited: [0, 9, 1, 2, 3]
#   [2563/2746] 16339_FS(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [2564/2746] 16339_Fluency(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2565/2746] 16339_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [2566/2746] 16339_QS(doc): target at [6] | cited: [0, 9, 1, 2, 3]
#   [2567/2746] 16339_Quotes(doc): target at [6] | cited: [0, 1, 2, 3, 8]
#   [2568/2746] 16339_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2569/2746] 16339_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 9]
#   [2570/2746] 16339_TechnicalTerms(doc): target at [4] | cited: [0, 1, 9, 2, 3]
#   [2571/2746] 16339_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [2572/2746] 16339_doc: target at [4] | cited: [0, 1, 9, 2, 5]
#   [2573/2746] 16829_Authoritative(doc): target at [7] | cited: [0, 1, 4, 9, 5]
#   [2574/2746] 16829_CQ(doc): target at [4] | cited: [0, 1, 2, 5, 8]
#   [2575/2746] 16829_CQS(doc): target at [5] | cited: [0, 1, 2, 7]
#   [2576/2746] 16829_CS(doc): target at [6] | cited: [0, 1, 8]
#   [2577/2746] 16829_Citations(doc): target at [6] | cited: [0, 1, 2]
#   [2578/2746] 16829_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 6, 8]
#   [2579/2746] 16829_FC(doc): target at [4] | cited: [0, 1, 2, 7]
#   [2580/2746] 16829_FCQ(doc): target at [5] | cited: [0, 1, 2, 4, 8]
#   [2581/2746] 16829_FCQS(doc): target at [9] | cited: [0, 1, 9]
#   [2582/2746] 16829_FCS(doc): target at [5] | cited: [0, 1, 2, 4, 9]
#   [2583/2746] 16829_FQ(doc): target at [4] | cited: [0, 1, 2, 4, 6]
#   [2584/2746] 16829_FQS(doc): target at [7] | cited: [0, 1, 6, 9, 2]
#   [2585/2746] 16829_FS(doc): target at [4] | cited: [0, 1, 2, 7, 9]
#   [2586/2746] 16829_Fluency(doc): target at [5] | cited: [0, 1, 3, 4, 8]
#   [2587/2746] 16829_LLMstxt(doc): target at [9] | cited: [0, 1, 5, 8]
#   [2588/2746] 16829_QS(doc): target at [7] | cited: [0, 9, 5, 3]
#   [2589/2746] 16829_Quotes(doc): target at [6] | cited: [0, 1, 2]
#   [2590/2746] 16829_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 7, 9]
#   [2591/2746] 16829_Statistics(doc): target at [9] | cited: [0, 1, 2, 4, 7]
#   [2592/2746] 16829_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 4, 7]
#   [2593/2746] 16829_UniqueWords(doc): target at [4] | cited: [0, 1, 4, 8]
#   [2594/2746] 16829_doc: target at [4] | cited: [0, 1, 2, 8, 9]
#   [2595/2746] 16981_Authoritative(doc): target at [5] | cited: [0, 5, 9, 2, 3]
#   [2596/2746] 16981_CQ(doc): target at [5] | cited: [0, 1, 5, 2, 6]
#   [2597/2746] 16981_CQS(doc): target at [5] | cited: [0, 1, 9, 5, 2]
#   [2598/2746] 16981_CS(doc): target at [5] | cited: [0, 5, 9, 2, 3]
#   [2599/2746] 16981_Citations(doc): target at [5] | cited: [0, 5, 2, 3, 6]
#   [2600/2746] 16981_ContentImprovement(doc): target at [6] | cited: [0, 6, 7, 2, 3]
#   [2601/2746] 16981_FC(doc): target at [6] | cited: [0, 6, 2, 3, 7]
#   [2602/2746] 16981_FCQ(doc): target at [6] | cited: [0, 6, 2, 3, 5]
#   [2603/2746] 16981_FCQS(doc): target at [6] | cited: [1, 9, 2, 3, 5]
#   [2604/2746] 16981_FCS(doc): target at [6] | cited: [0, 9, 3, 7, 2]
#   [2605/2746] 16981_FQ(doc): target at [6] | cited: [0, 1, 9, 2, 3]
#   [2606/2746] 16981_FQS(doc): target at [5] | cited: [0, 9, 2, 3, 6]
#   [2607/2746] 16981_FS(doc): target at [6] | cited: [1, 9, 3, 2, 4]
#   [2608/2746] 16981_Fluency(doc): target at [5] | cited: [0, 5, 2, 3, 6]
#   [2609/2746] 16981_LLMstxt(doc): target at [8] | cited: [0, 8, 2, 5, 3]
#   [2610/2746] 16981_QS(doc): target at [5] | cited: [0, 5, 2, 8, 3]
#   [2611/2746] 16981_Quotes(doc): target at [6] | cited: [0, 2, 3, 7, 5]
#   [2612/2746] 16981_SimpleLanguage(doc): target at [5] | cited: [0, 1, 5, 2, 3]
#   [2613/2746] 16981_Statistics(doc): target at [6] | cited: [0, 1, 9, 2, 3]
#   [2614/2746] 16981_TechnicalTerms(doc): target at [6] | cited: [0, 6, 2, 4, 3]
#   [2615/2746] 16981_UniqueWords(doc): target at [6] | cited: [0, 1, 9, 2, 3]
#   [2616/2746] 16981_doc: target at [5] | cited: [0, 1, 5, 9, 2]
#   [2617/2746] 17599_Authoritative(doc): target at [5] | cited: [0, 2, 3, 8, 9]
#   [2618/2746] 17599_CQ(doc): target at [3] | cited: [0, 3, 5, 1, 2]
#   [2619/2746] 17599_CQS(doc): target at [5] | cited: [0, 5, 6, 1, 2]
#   [2620/2746] 17599_CS(doc): target at [4] | cited: [1, 2, 3, 6, 0]
#   [2621/2746] 17599_Citations(doc): target at [3] | cited: [0, 2, 1, 3, 6]
#   [2622/2746] 17599_ContentImprovement(doc): target at [9] | cited: [0, 2, 7, 8, 3]
#   [2623/2746] 17599_FC(doc): target at [2] | cited: [1, 0, 2, 4, 3]
#   [2624/2746] 17599_FCQ(doc): target at [3] | cited: [0, 3, 6, 1, 2]
#   [2625/2746] 17599_FCQS(doc): target at [1] | cited: [0, 4, 3, 8, 9]
#   [2626/2746] 17599_FCS(doc): target at [0] | cited: [0, 5, 2, 3, 6]
#   [2627/2746] 17599_FQ(doc): target at [0] | cited: [0, 1, 3, 6, 7]
#   [2628/2746] 17599_FQS(doc): target at [0] | cited: [0, 2, 6, 9, 7]
#   [2629/2746] 17599_FS(doc): target at [0] | cited: [0, 5, 2, 4, 3]
#   [2630/2746] 17599_Fluency(doc): target at [4] | cited: [0, 4, 1, 6, 2]
#   [2631/2746] 17599_LLMstxt(doc): target at [6] | cited: [0, 3, 1, 2, 7]
#   [2632/2746] 17599_QS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2633/2746] 17599_Quotes(doc): target at [6] | cited: [0, 2, 3, 1, 4]
#   [2634/2746] 17599_SimpleLanguage(doc): target at [5] | cited: [1, 0, 3, 5, 7]
#   [2635/2746] 17599_Statistics(doc): target at [6] | cited: [0, 1, 2, 5, 3]
#   [2636/2746] 17599_TechnicalTerms(doc): target at [6] | cited: [0, 6, 1, 2, 8]
#   [2637/2746] 17599_UniqueWords(doc): target at [4] | cited: [0, 5, 1, 7, 2]
#   [2638/2746] 17599_doc: target at [7] | cited: [1, 5, 6, 3, 4]
#   [2639/2746] 17606_Authoritative(doc): target at [7] | cited: [0, 1, 2, 4, 9]
#   [2640/2746] 17606_CQ(doc): target at [8] | cited: [0, 1, 9, 3, 5]
#   [2641/2746] 17606_CQS(doc): target at [7] | cited: [0, 8, 9, 2, 6]
#   [2642/2746] 17606_CS(doc): target at [8] | cited: [0, 1, 2, 6, 4]
#   [2643/2746] 17606_Citations(doc): target at [1] | cited: [1, 8, 2, 4, 9]
#   [2644/2746] 17606_ContentImprovement(doc): target at [8] | cited: [0, 1, 7, 2, 9]
#   [2645/2746] 17606_FC(doc): target at [7] | cited: [0, 1, 4, 9, 6]
#   [2646/2746] 17606_FCQ(doc): target at [8] | cited: [0, 1, 2, 9, 3]
#   [2647/2746] 17606_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [2648/2746] 17606_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [2649/2746] 17606_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2650/2746] 17606_FQS(doc): target at [8] | cited: [0, 6, 1, 2, 9]
#   [2651/2746] 17606_FS(doc): target at [7] | cited: [0, 1, 8, 2, 3]
#   [2652/2746] 17606_Fluency(doc): target at [6] | cited: [1, 3, 7, 9, 4]
#   [2653/2746] 17606_LLMstxt(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [2654/2746] 17606_QS(doc): target at [6] | cited: [0, 1, 8, 9, 7]
#   [2655/2746] 17606_Quotes(doc): target at [6] | cited: [0, 1, 3, 5, 7]
#   [2656/2746] 17606_SimpleLanguage(doc): target at [2] | cited: [0, 1, 3, 2, 7]
#   [2657/2746] 17606_Statistics(doc): target at [8] | cited: [1, 4, 0, 2, 3]
#   [2658/2746] 17606_TechnicalTerms(doc): target at [8] | cited: [0, 2, 9, 3, 6]
#   [2659/2746] 17606_UniqueWords(doc): target at [8] | cited: [0, 7, 3, 9, 5]
#   [2660/2746] 17606_doc: target at [6] | cited: [0, 1, 8, 9, 2]
#   [2661/2746] 17636_Authoritative(doc): target at [0] | cited: [0, 1, 9, 2, 5]
#   [2662/2746] 17636_CQ(doc): target at [5] | cited: [0, 1, 3, 4, 5]
#   [2663/2746] 17636_CQS(doc): target at [4] | cited: [0, 1, 2, 8, 9]
#   [2664/2746] 17636_CS(doc): target at [1] | cited: [0, 1, 2, 3, 7]
#   [2665/2746] 17636_Citations(doc): target at [5] | cited: [0, 1, 2, 7, 8]
#   [2666/2746] 17636_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 4, 7]
#   [2667/2746] 17636_FC(doc): target at [6] | cited: [0, 1, 2, 6, 8]
#   [2668/2746] 17636_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [2669/2746] 17636_FCQS(doc): target at [4] | cited: [0, 1, 8, 7, 3]
#   [2670/2746] 17636_FCS(doc): target at [8] | cited: [0, 1, 2, 4, 8]
#   [2671/2746] 17636_FQ(doc): target at [5] | cited: [0, 1, 2, 3, 7]
#   [2672/2746] 17636_FQS(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [2673/2746] 17636_FS(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [2674/2746] 17636_Fluency(doc): target at [4] | cited: [0, 1, 2, 4, 3]
#   [2675/2746] 17636_LLMstxt(doc): target at [9] | cited: [3, 9, 6, 7, 1]
#   [2676/2746] 17636_QS(doc): target at [4] | cited: [0, 1, 2, 4, 5]
#   [2677/2746] 17636_Quotes(doc): target at [4] | cited: [0, 1, 2, 4, 7]
#   [2678/2746] 17636_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 5, 7]
#   [2679/2746] 17636_Statistics(doc): target at [1] | cited: [1, 2, 3, 5, 8]
#   [2680/2746] 17636_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [2681/2746] 17636_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2682/2746] 17636_doc: target at [4] | cited: [0, 1, 2, 4, 8]
#   [2683/2746] 17656_Authoritative(doc): target at [7] | cited: [0, 1, 2, 4, 8]
#   [2684/2746] 17656_CQ(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2685/2746] 17656_CQS(doc): target at [7] | cited: [0, 1, 2, 6, 5]
#   [2686/2746] 17656_CS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2687/2746] 17656_Citations(doc): target at [7] | cited: [0, 1, 2, 8, 5]
#   [2688/2746] 17656_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 6, 5]
#   [2689/2746] 17656_FC(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2690/2746] 17656_FCQ(doc): target at [9] | cited: [0, 1, 2, 6, 5]
#   [2691/2746] 17656_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2692/2746] 17656_FCS(doc): target at [8] | cited: [0, 1, 2, 6, 7]
#   [2693/2746] 17656_FQ(doc): target at [9] | cited: [0, 3, 5, 1, 4]
#   [2694/2746] 17656_FQS(doc): target at [8] | cited: [0, 8, 2, 6]
#   [2695/2746] 17656_FS(doc): target at [8] | cited: [0, 1, 2, 6, 5]
#   [2696/2746] 17656_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 6]
#   [2697/2746] 17656_LLMstxt(doc): target at [9] | cited: [0, 9, 2, 4]
#   [2698/2746] 17656_QS(doc): target at [2] | cited: [0, 1, 2, 3, 7]
#   [2699/2746] 17656_Quotes(doc): target at [5] | cited: [0, 1, 5, 2, 7]
#   [2700/2746] 17656_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [2701/2746] 17656_Statistics(doc): target at [4] | cited: [0, 1, 8]
#   [2702/2746] 17656_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2]
#   [2703/2746] 17656_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 4, 3]
#   [2704/2746] 17656_doc: target at [5] | cited: [0, 1, 2, 7, 6]
#   [2705/2746] 18937_Authoritative(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [2706/2746] 18937_CQ(doc): target at [3] | cited: [0, 9, 1, 2, 4]
#   [2707/2746] 18937_CQS(doc): target at [4] | cited: [0, 1, 2, 9, 7]
#   [2708/2746] 18937_CS(doc): target at [4] | cited: [0, 2, 1, 3, 9]
#   [2709/2746] 18937_Citations(doc): target at [2] | cited: [0, 1, 9, 7, 8]
#   [2710/2746] 18937_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 3, 9]
#   [2711/2746] 18937_FC(doc): target at [5] | cited: [0, 1, 2, 3, 8]
#   [2712/2746] 18937_FCQ(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [2713/2746] 18937_FCQS(doc): target at [5] | cited: [0, 1, 2, 3, 6]
#   [2714/2746] 18937_FCS(doc): target at [3] | cited: [1, 0, 9, 2, 4]
#   [2715/2746] 18937_FQ(doc): target at [5] | cited: [0, 5, 1, 2, 3]
#   [2716/2746] 18937_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2717/2746] 18937_FS(doc): target at [4] | cited: [0, 2, 5, 1, 3]
#   [2718/2746] 18937_Fluency(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [2719/2746] 18937_LLMstxt(doc): target at [4] | cited: [0, 1, 3, 9, 7]
#   [2720/2746] 18937_QS(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [2721/2746] 18937_Quotes(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2722/2746] 18937_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2723/2746] 18937_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2724/2746] 18937_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [2725/2746] 18937_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [2726/2746] 18937_doc: target at [4] | cited: [0, 1, 9, 3]
#   [2727/2746] 18938_Authoritative(doc): target at [8] | cited: [0, 1, 4, 5, 9]
#   [2728/2746] 18938_CQ(doc): target at [6] | cited: [1, 0, 2, 4, 5]
#   [2729/2746] 18938_CQS(doc): target at [6] | cited: [1, 0, 2, 4, 5]
#   [2730/2746] 18938_CS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2731/2746] 18938_Citations(doc): target at [7] | cited: [1, 0, 5, 9]
#   [2732/2746] 18938_ContentImprovement(doc): target at [7] | cited: [0, 2, 1, 5, 6]
#   [2733/2746] 18938_FC(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2734/2746] 18938_FCQ(doc): target at [8] | cited: [0, 1, 5, 8]
#   [2735/2746] 18938_FCQS(doc): target at [7] | cited: [0, 1, 5, 6, 9]
#   [2736/2746] 18938_FCS(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [2737/2746] 18938_FQ(doc): target at [8] | cited: [1, 0, 4, 5, 8]
#   [2738/2746] 18938_FQS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2739/2746] 18938_FS(doc): target at [7] | cited: [0, 1, 5, 7]
#   [2740/2746] 18938_Fluency(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [2741/2746] 18938_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2742/2746] 18938_QS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [2743/2746] 18938_Quotes(doc): target at [7] | cited: [0, 2, 3, 1, 5]
#   [2744/2746] 18938_SimpleLanguage(doc): target at [7] | cited: [0, 1, 4, 5, 6]
#   [2745/2746] 18938_Statistics(doc): target at [6] | cited: [0, 7, 1, 2, 3]
#   [2746/2746] 18938_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 4, 5]
# ============================================================
# GENERATION COMPLETE
# Started:    10:20:55
# Finished:   18:50:24
# Total time: 8:29:29
# Results:    2746 rows saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation/4_generation_results_A_v2.parquet

# %% [markdown]
# ## Inspect Results

# %%
# Load this notebook's parquet file for inspection
df_results = pd.read_parquet(output_path)

# Change INSPECT_QUERY_ID to inspect a specific run
INSPECT_QUERY_ID = df_results["query_id"].iloc[0]

row = df_results[df_results["query_id"] == INSPECT_QUERY_ID].iloc[0]

print(f"Run (query_id):    {row['query_id']}")
print(f"Original query:    {row['original_query_id']}")
print(f"Method:            {row['method']}")
print(f"Query:             {row['query']}")
print(f"Num docs:          {row['num_docs']}")
print(f"Target position:   {row['target_new_position']} (0-based)")
print(f"Citation order:    {row['citation_order']}")
print(f"Target cited:      {'YES' if row['target_new_position'] in row['citation_order'] else 'NO'}")
print(f"\n--- LLM Response ---")
print(row["llm_response"][:800])
# Out:
# Run (query_id):    100162_Authoritative(doc)
# Original query:    100162
# Method:            Authoritative(doc)
# Query:             table lamps for bedroom
# Num docs:          10
# Target position:   7 (0-based)
# Citation order:    [0 5 1 4 7 3 8]
# Target cited:      YES
#
# --- LLM Response ---
# When considering table lamps for a bedroom, there are numerous options that cater to various needs and aesthetic preferences. Here are some top recommendations based on recent options available:
#
# 1. **Touch Control Table Lamp with USB Ports**: This modern lamp features a touch control system that allows you to easily adjust the brightness through three levels – low, medium, and high, making it perfect for different activities such as reading or creating a cozy atmosphere in the bedroom. Additionally, it is equipped with two USB charging ports which enable convenient device charging without needing to reach for an outlet, regardless of whether the lamp is on or off [1][6].
#
# 2. **HAITRAL Bedside Table Lamps Set of 2**: This set features two stylish lamps made from a combination of high-qual

# %% [markdown]
# ## Merge Results
#
# **Run only after all 4 notebooks (A, B, C, D) are complete.**

# %%
# Merge all four notebook parquet files into one combined file
# Run only after notebooks A, B, C, D have all completed
NOTEBOOK_IDS = ["A", "B", "C", "D"]
dfs = []
for nb in NOTEBOOK_IDS:
    path = os.path.join(data_dir, f"generation/4_generation_results_{nb}_v2.parquet")
    if os.path.exists(path):
        dfs.append(pd.read_parquet(path))
        print(f"Loaded 4_generation_results_{nb}_v2.parquet ({len(dfs[-1])} rows)")
    else:
        print(f"WARNING: 4_generation_results_{nb}_v2.parquet not found — skipping")

# Concatenate all four subsets into one merged DataFrame
merged      = pd.concat(dfs, ignore_index=True)
merged_path = os.path.join(data_dir, "generation/4_generation_results_v2.parquet")
merged.to_parquet(merged_path, index=False)
print(f"\nMerged {len(merged)} rows into 4_generation_results_v2.parquet")
# Out:
# Loaded 4_generation_results_A_v2.parquet (2746 rows)
# Loaded 4_generation_results_B_v2.parquet (2746 rows)
# Loaded 4_generation_results_C_v2.parquet (2746 rows)
# Loaded 4_generation_results_D_v2.parquet (2747 rows)
#
# Merged 10985 rows into 4_generation_results_v2.parquet

# %% [markdown]
# ## Summary

# %%
# Load merged parquet and verify completeness
# Expected: total rows == total runs with target across all 4 notebooks
merged_path = os.path.join(data_dir, "generation/4_generation_results_v2.parquet")
df_results  = pd.read_parquet(merged_path)

print(f"Total runs done:     {len(df_results)}")
print(f"Total runs expected: {len(all_run_ids_full)}")
print(f"Missing runs:        {len(all_run_ids_full) - len(df_results)}")
print()
print(f"Unique methods: {df_results['method'].nunique()}")
print(f"Unique queries: {df_results['original_query_id'].nunique()}")
# Out:
# Total runs done:     10985
# Total runs expected: 10985
# Missing runs:        0
#
# Unique methods: 22
# Unique queries: 500
