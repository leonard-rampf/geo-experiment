# %% [markdown]
# # Notebook 4C — Generation Stage (Range 50%–75%)
#
# Processes 50%–75% of all runs.
# Run A, B, C, D in parallel — each writes to its own parquet file.
#
# **Input:** `data/retail/retrieval/20260413_retrieval_results_geo_v2.csv`
#
# **Output:** `data/retail/generation/4_generation_results_C_v2.parquet`
#
# ## Instructions
# 1. Run **Setup**
# 2. Run **Data Preparation**
# 3. Run **Helper Functions**
# 4. Run **Parameters** — range is set automatically
# 5. Run **Generation**
# 6. Run **Inspect Results**
# 7. Run **Summary**
# 8. After all 4 notebooks finish: run **Merge Results** in any one notebook

# %% [markdown]
# ## Setup

# %%
# Library imports
import json
import os
import re
import sys
import time
from datetime import datetime

import pandas as pd
import numpy as np

# Go up two levels to project root
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, "..", ".."))

# Add src/ to path so OpenAIHelper can be imported
sys.path.insert(0, os.path.join(project_root, "src"))


from llms import OpenAIHelper

# Load API key from config.json
config_path = os.path.join(project_root, "config.json")
with open(config_path, "r") as f:
    config = json.load(f)
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

data_dir = os.path.join(project_root, "data", "retail")

print("Setup complete.")
print(f"Project root: {project_root}")
# Out:
# Setup complete.
# Project root: /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment

# %% [markdown]
# ## Data Preparation
#
# Load the retrieval CSV and extract `original_query_id` and `method` from `query_id`.
# Example: `50881_Fluency(doc)` → `original_query_id=50881`, `method=Fluency(doc)`

# %%
# Load the retrieval CSV — one row per document per query_id
# query_id format: "{original_query_id}_{method}"
retrieval_csv_path = os.path.join(data_dir, "retrieval/20260413_retrieval_results_geo_v2.csv")
df = pd.read_csv(retrieval_csv_path)

# Extract original_query_id (numeric) and method name from compound query_id
df["original_query_id"] = df["query_id"].str.extract(r"^(\d+)_")
df["method"]            = df["query_id"].str.extract(r"^\d+_(.+)$")

# Identify runs where the target document is missing from the retrieval results
# These runs are skipped during generation (no valid citation position can be computed)
target_per_run = df.groupby("query_id")["is_target"].sum()
runs_with_target    = set(target_per_run[target_per_run == 1].index)
runs_without_target = set(target_per_run[target_per_run == 0].index)

# Save runs without target for documentation and reproducibility
runs_without_target_path = os.path.join(data_dir, "generation/4_generation_runs_without_target_v2.json")
with open(runs_without_target_path, "w") as f:
    json.dump(sorted(list(runs_without_target)), f, indent=4)

print(f"Total rows:              {len(df)}")
print(f"Unique runs (query_ids): {df['query_id'].nunique()}")
print(f"Unique original queries: {df['original_query_id'].nunique()}")
print(f"Unique methods:          {df['method'].nunique()}")
print(f"Runs with target:        {len(runs_with_target)}")
print(f"Runs without target:     {len(runs_without_target)} — saved to generation/4_generation_runs_without_target_v2.json")
print()
print("Methods found:")
for m in sorted(df['method'].unique()):
    print(f"  {m}")
# Out:
# Total rows:              109875
# Unique runs (query_ids): 11000
# Unique original queries: 500
# Unique methods:          22
# Runs with target:        10985
# Runs without target:     15 — saved to generation/4_generation_runs_without_target_v2.json
#
# Methods found:
#   Authoritative(doc)
#   CQ(doc)
#   CQS(doc)
#   CS(doc)
#   Citations(doc)
#   ContentImprovement(doc)
#   FC(doc)
#   FCQ(doc)
#   FCQS(doc)
#   FCS(doc)
#   FQ(doc)
#   FQS(doc)
#   FS(doc)
#   Fluency(doc)
#   LLMstxt(doc)
#   QS(doc)
#   Quotes(doc)
#   SimpleLanguage(doc)
#   Statistics(doc)
#   TechnicalTerms(doc)
#   UniqueWords(doc)
#   doc

# %% [markdown]
# ## Helper Functions

# %%
# System prompt for the LLM — instructs it to act as a product recommender and to cite every sentence with inline references [1], [2], etc.
DEVELOPER_PROMPT = """Your are a product recommender system for an online marketplace. Write an accurate and concise answer for the given user question, using _only_ the provided summarized web search results. The answer should be correct, high-quality, and written by an expert using an unbiased and journalistic tone. The answer should be informative, interesting, and engaging. The answer's logic and reasoning should be rigorous and defensible. Every sentence in the answer should be _immediately followed_ by an in-line citation to the search result(s). The cited search result(s) should fully support _all_ the information in the sentence. Search results need to be cited using [index]. When citing several search results, use [1][2][3] format rather than [1, 2, 3]. You can use multiple search results to respond comprehensively while avoiding irrelevant search results."""

# Document type label used in the user prompt
DOC_TYPE = "Product Description"


def build_context(group):
    """
    Takes all rows for one query_id, sorts by rank, re-numbers 1..N.
    Returns:
        docs: list of doc_text in retrieval order
        target_new_position: 0-based position of target doc after re-numbering
    """
    group = group.sort_values("rank").reset_index(drop=True)
    docs = group["doc_text"].tolist()

    # Find 0-based position of the target document
    target_new_position = None
    for i, row in group.iterrows():
        if row["is_target"] == 1:
            target_new_position = i  # 0-based
            break

    return docs, target_new_position


def build_user_prompt(query, docs):
    """
    Builds the user prompt for the LLM.
    docs: list of doc_text strings, numbered 1..N
    """
    sources = ""
    for i, doc_text in enumerate(docs, start=1):
        sources += f"[{i}] {DOC_TYPE}: {doc_text}\n\n"
    return f"Question: {query}\n\nSearch Results:\n{sources}"


def extract_citation_order(response_text):
    """
    Extracts citation indices in order of first appearance.
    0-based: [1] in text -> index 0, [2] -> index 1, etc.
    e.g. "...product [2] is great [1][2]..." -> [1, 0]
    """
    citations = re.findall(r"\[(\d+)\]", response_text)
    seen = []
    for c in citations:
        idx = int(c) - 1  # 0-based
        if idx not in seen:
            seen.append(idx)
    return seen


print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## Parameters

# %%
# LLM model used for response generation
LLM_NAME = "gpt-4o-mini-2024-07-18"

# Notebook ID — A processes 0%–25% of all runs
NOTEBOOK_ID = "C"

# Output file for this notebook's results — separate from B, C, D to allow parallel execution
output_path = os.path.join(data_dir, "generation/4_generation_results_C_v2.parquet")

# Based on Vertex AI / Gemini default inference parameters:
# https://docs.cloud.google.com/vertex-ai/generative-ai/docs/model-reference/inference?hl=de
TEMPERATURE       = 1.0
TOP_P             = 0.95
SEED              = 42
FREQUENCY_PENALTY = 0.0
PRESENCE_PENALTY  = 0.0

# Assign this notebook's quarter of all runs sorted alphabetically by query_id
all_run_ids_full = sorted(runs_with_target)
total = len(all_run_ids_full)
start_idx = int(total * 50/100)
end_idx   = int(total * 75/100)
all_run_ids = all_run_ids_full[start_idx:end_idx]

# Load already completed runs to support safe resume after interruption
if os.path.exists(output_path):
    df_done = pd.read_parquet(output_path)
    done_keys = set(df_done["query_id"].tolist())
    already_done = len(done_keys)
else:
    done_keys = set()
    already_done = 0

llm = OpenAIHelper(LLM_NAME)

remaining = len(all_run_ids) - already_done
print(f"Notebook:      {NOTEBOOK_ID}")
print(f"LLM:           {LLM_NAME}")
print(f"Range:         50%–75% ({start_idx}–{end_idx} of {total})")
print(f"Runs in range: {len(all_run_ids)}")
print(f"Already done:  {already_done}")
print(f"Remaining:     {remaining}")
print(f"Estimated time: ~{remaining * 9.5 / 3600:.1f} hours")
print(f"Estimated cost: ~${remaining * 0.0003:.2f}")
# Out:
# Notebook:      C
# LLM:           gpt-4o-mini-2024-07-18
# Range:         50%–75% (5492–8238 of 10985)
# Runs in range: 2746
# Already done:  32
# Remaining:     2714
# Estimated time: ~7.2 hours
# Estimated cost: ~$0.81

# %% [markdown]
# ## Generation
#
# For each run (query_id):
# 1. Sort docs by rank and re-number 1..N
# 2. Build LLM prompt
# 3. Generate response with inline citations
# 4. Extract citation order
# 5. Save incrementally
#
# Runs without a target doc are skipped.
# Safe to interrupt and resume.

# %%
# Load existing results if the output file already exists
# Allows safe resume without reprocessing completed runs
if os.path.exists(output_path):
    results_df = pd.read_parquet(output_path)
    results = results_df.to_dict("records")
else:
    results = []

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%H:%M:%S')}")
print(f"Total runs to process: {len(all_run_ids)}")
print()

for i, query_id in enumerate(all_run_ids):

    # Skip runs already completed in a previous session
    if query_id in done_keys:
        continue

    # Load all documents for this run
    group = df[df["query_id"] == query_id]
    query_text         = group["query"].iloc[0]
    original_query_id  = group["original_query_id"].iloc[0]
    method             = group["method"].iloc[0]

    # Sort docs by retrieval rank and find target position
    docs, target_new_position = build_context(group)

    # Skip runs where the target document is not in the retrieval results
    if target_new_position is None:
        print(f"  [{i+1}] {query_id}: no target — skipping")
        continue

    # Build LLM prompt with numbered search results
    user_prompt = build_user_prompt(query_text, docs)
    messages = [
        {"role": "system", "content": DEVELOPER_PROMPT},
        {"role": "user",   "content": user_prompt},
    ]

    try:
        # Generate LLM response and extract citation order
        response, _ = llm.generate(messages)
        response_text    = response.content
        citation_order   = extract_citation_order(response_text)

        # Store result and save incrementally — no work lost on crash or interruption
        results.append({
            "query_id":            query_id,
            "original_query_id":   original_query_id,
            "method":              method,
            "query":               query_text,
            "target_new_position": target_new_position,
            "num_docs":            len(docs),
            "citation_order":      citation_order,
            "llm_response":        response_text,
        })
        done_keys.add(query_id)
        pd.DataFrame(results).to_parquet(output_path, index=False)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: target at [{target_new_position}] | cited: {citation_order[:5]}")

    except Exception as e:
        # First failure — wait 10 seconds and retry once (handles rate limits)
        print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: ERROR — {e}")
        time.sleep(10)
        try:
            response, _    = llm.generate(messages)
            response_text  = response.content
            citation_order = extract_citation_order(response_text)
            results.append({
                "query_id":            query_id,
                "original_query_id":   original_query_id,
                "method":              method,
                "query":               query_text,
                "target_new_position": target_new_position,
                "num_docs":            len(docs),
                "citation_order":      citation_order,
                "llm_response":        response_text,
            })
            done_keys.add(query_id)
            pd.DataFrame(results).to_parquet(output_path, index=False)
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: done (retry OK)")
        except Exception as e2:
            # Second failure — skip this run and continue with the next
            print(f"  [{i+1}/{len(all_run_ids)}] {query_id}: FAILED — {e2}")

# Summary
end_time = datetime.now()
elapsed  = end_time - start_time
print(f"{'='*60}")
print(f"GENERATION COMPLETE")
print(f"Started:    {start_time.strftime('%H:%M:%S')}")
print(f"Finished:   {end_time.strftime('%H:%M:%S')}")
print(f"Total time: {str(elapsed).split('.')[0]}")
print(f"Results:    {len(results)} rows saved to {output_path}")
# Out:
# Started at: 10:21:30
# Total runs to process: 2746
#
#   [33/2746] 4943_FCQS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [34/2746] 4943_FCS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [35/2746] 4943_FQ(doc): target at [1] | cited: [0, 1, 3, 4, 5]
#   [36/2746] 4943_FQS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [37/2746] 4943_FS(doc): target at [0] | cited: []
#   [38/2746] 4943_Fluency(doc): target at [0] | cited: [0, 1, 2, 3]
#   [39/2746] 4943_LLMstxt(doc): target at [8] | cited: [0, 8, 1, 2, 3]
#   [40/2746] 4943_QS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [41/2746] 4943_Quotes(doc): target at [0] | cited: [0, 1, 2, 3, 8]
#   [42/2746] 4943_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [43/2746] 4943_Statistics(doc): target at [0] | cited: [0, 1, 2, 5, 4]
#   [44/2746] 4943_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [45/2746] 4943_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [46/2746] 4943_doc: target at [0] | cited: [0, 1, 2, 3, 4]
#   [47/2746] 49604_Authoritative(doc): target at [6] | cited: [0, 1, 3]
#   [48/2746] 49604_CQ(doc): target at [6] | cited: [0, 1, 7, 3, 4]
#   [49/2746] 49604_CQS(doc): target at [6] | cited: [0, 1, 4, 3, 7]
#   [50/2746] 49604_CS(doc): target at [6] | cited: [0, 1, 4, 3, 7]
#   [51/2746] 49604_Citations(doc): target at [7] | cited: [0, 1, 2, 4, 3]
#   [52/2746] 49604_ContentImprovement(doc): target at [7] | cited: [0, 1, 3, 5, 4]
#   [53/2746] 49604_FC(doc): target at [7] | cited: [0, 1, 2, 6, 5]
#   [54/2746] 49604_FCQ(doc): target at [6] | cited: [0, 1, 4, 3]
#   [55/2746] 49604_FCQS(doc): target at [7] | cited: [0, 1, 2, 6, 3]
#   [56/2746] 49604_FCS(doc): target at [7] | cited: [0, 1, 3, 4, 5]
#   [57/2746] 49604_FQ(doc): target at [7] | cited: [0, 1, 6, 3, 4]
#   [58/2746] 49604_FQS(doc): target at [6] | cited: [0, 1, 7, 4, 3]
#   [59/2746] 49604_FS(doc): target at [7] | cited: [0, 1, 3, 4, 6]
#   [60/2746] 49604_Fluency(doc): target at [7] | cited: [0, 1, 4, 3, 8]
#   [61/2746] 49604_LLMstxt(doc): target at [2] | cited: [0, 1, 7, 4]
#   [62/2746] 49604_QS(doc): target at [6] | cited: [0, 1, 7, 3]
#   [63/2746] 49604_Quotes(doc): target at [7] | cited: [0, 1, 4, 3, 6]
#   [64/2746] 49604_SimpleLanguage(doc): target at [6] | cited: [0, 1, 2, 4]
#   [65/2746] 49604_Statistics(doc): target at [7] | cited: [0, 1, 2, 3, 9]
#   [66/2746] 49604_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [67/2746] 49604_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [68/2746] 49604_doc: target at [7] | cited: [0, 1, 4, 3, 6]
#   [69/2746] 49611_Authoritative(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [70/2746] 49611_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 7]
#   [71/2746] 49611_CQS(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [72/2746] 49611_CS(doc): target at [6] | cited: [0, 1, 2, 3, 6]
#   [73/2746] 49611_Citations(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [74/2746] 49611_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [75/2746] 49611_FC(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [76/2746] 49611_FCQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [77/2746] 49611_FCQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [78/2746] 49611_FCS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [79/2746] 49611_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [80/2746] 49611_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [81/2746] 49611_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [82/2746] 49611_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [83/2746] 49611_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [84/2746] 49611_QS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [85/2746] 49611_Quotes(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [86/2746] 49611_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [87/2746] 49611_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [88/2746] 49611_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [89/2746] 49611_UniqueWords(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [90/2746] 49611_doc: target at [5] | cited: [0, 1, 2, 3, 4]
#   [91/2746] 4965_Authoritative(doc): target at [5] | cited: [0, 1, 2, 5, 3]
#   [92/2746] 4965_CQ(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [93/2746] 4965_CQS(doc): target at [5] | cited: [0, 5, 1, 4, 2]
#   [94/2746] 4965_CS(doc): target at [5] | cited: [0, 5, 1, 2, 3]
#   [95/2746] 4965_Citations(doc): target at [5] | cited: [0, 1, 2, 4, 5]
#   [96/2746] 4965_ContentImprovement(doc): target at [5] | cited: [0, 5, 1, 2, 3]
#   [97/2746] 4965_FC(doc): target at [0] | cited: [0, 1, 2, 6, 3]
#   [98/2746] 4965_FCQ(doc): target at [5] | cited: [0, 5, 1, 2, 3]
#   [99/2746] 4965_FCQS(doc): target at [4] | cited: [0, 1, 2, 4, 3]
#   [100/2746] 4965_FCS(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [101/2746] 4965_FQ(doc): target at [9] | cited: [0, 9, 1, 2, 3]
#   [102/2746] 4965_FQS(doc): target at [5] | cited: [0, 1, 2, 5, 6]
#   [103/2746] 4965_FS(doc): target at [5] | cited: [0, 1, 2, 5, 6]
#   [104/2746] 4965_Fluency(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [105/2746] 4965_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [106/2746] 4965_QS(doc): target at [5] | cited: [0, 1, 2, 5, 3]
#   [107/2746] 4965_Quotes(doc): target at [6] | cited: [0, 6, 1, 2, 4]
#   [108/2746] 4965_SimpleLanguage(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [109/2746] 4965_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [110/2746] 4965_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 4, 6]
#   [111/2746] 4965_UniqueWords(doc): target at [6] | cited: [0, 6, 1, 2, 3]
#   [112/2746] 4965_doc: target at [5] | cited: [0, 5, 1, 2, 3]
#   [113/2746] 49892_Authoritative(doc): target at [5] | cited: [0, 3, 7, 5, 8]
#   [114/2746] 49892_CQ(doc): target at [5] | cited: [0, 1, 7, 8, 9]
#   [115/2746] 49892_CQS(doc): target at [5] | cited: [0, 2, 8, 9]
#   [116/2746] 49892_CS(doc): target at [9] | cited: [0, 6, 1, 2, 7]
#   [117/2746] 49892_Citations(doc): target at [0] | cited: [0, 1, 2, 4, 9]
#   [118/2746] 49892_ContentImprovement(doc): target at [1] | cited: [0, 1, 7, 5, 4]
#   [119/2746] 49892_FC(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [120/2746] 49892_FCQ(doc): target at [6] | cited: [0, 9, 1, 4, 8]
#   [121/2746] 49892_FCQS(doc): target at [5] | cited: [0, 1, 2, 7, 4]
#   [122/2746] 49892_FCS(doc): target at [5] | cited: []
#   [123/2746] 49892_FQ(doc): target at [6] | cited: [0, 2, 4, 3, 8]
#   [124/2746] 49892_FQS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [125/2746] 49892_FS(doc): target at [9] | cited: [0, 1, 6, 2, 4]
#   [126/2746] 49892_Fluency(doc): target at [9] | cited: [0, 1, 4, 6, 7]
#   [127/2746] 49892_LLMstxt(doc): target at [2] | cited: []
#   [128/2746] 49892_QS(doc): target at [6] | cited: [0, 1, 2, 5, 8]
#   [129/2746] 49892_Quotes(doc): target at [2] | cited: [0, 1, 2, 4, 7]
#   [130/2746] 49892_SimpleLanguage(doc): target at [8] | cited: [0, 1, 4, 2, 6]
#   [131/2746] 49892_Statistics(doc): target at [6] | cited: [0, 1, 7, 2, 3]
#   [132/2746] 49892_TechnicalTerms(doc): target at [6] | cited: [0, 9, 1, 5, 7]
#   [133/2746] 49892_UniqueWords(doc): target at [6] | cited: [0, 1, 3, 4, 8]
#   [134/2746] 49892_doc: target at [5] | cited: [0, 1, 3, 9]
#   [135/2746] 49894_Authoritative(doc): target at [2] | cited: [0, 2, 1, 3, 7]
#   [136/2746] 49894_CQ(doc): target at [0] | cited: [0, 7, 1, 9, 2]
#   [137/2746] 49894_CQS(doc): target at [1] | cited: [0, 1, 5, 2, 3]
#   [138/2746] 49894_CS(doc): target at [3] | cited: [0, 1, 9, 2, 5]
#   [139/2746] 49894_Citations(doc): target at [2] | cited: [0, 1, 5, 7, 4]
#   [140/2746] 49894_ContentImprovement(doc): target at [1] | cited: [0, 5, 1, 7, 2]
#   [141/2746] 49894_FC(doc): target at [3] | cited: [0, 3, 8, 1, 9]
#   [142/2746] 49894_FCQ(doc): target at [9] | cited: [0, 4, 1, 3, 5]
#   [143/2746] 49894_FCQS(doc): target at [2] | cited: [0, 2, 5, 6, 1]
#   [144/2746] 49894_FCS(doc): target at [3] | cited: [0, 1, 3, 8, 4]
#   [145/2746] 49894_FQ(doc): target at [3] | cited: [0, 1, 3, 2, 4]
#   [146/2746] 49894_FQS(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [147/2746] 49894_FS(doc): target at [3] | cited: [4, 5, 7, 2, 3]
#   [148/2746] 49894_Fluency(doc): target at [1] | cited: [0, 1, 7, 2, 5]
#   [149/2746] 49894_LLMstxt(doc): target at [9] | cited: [0, 1, 9, 2, 5]
#   [150/2746] 49894_QS(doc): target at [3] | cited: [0, 1, 2, 3, 7]
#   [151/2746] 49894_Quotes(doc): target at [0] | cited: [1, 2, 0, 7, 6]
#   [152/2746] 49894_SimpleLanguage(doc): target at [2] | cited: [0, 1, 4, 3, 7]
#   [153/2746] 49894_Statistics(doc): target at [2] | cited: [0, 1, 7, 4, 3]
#   [154/2746] 49894_TechnicalTerms(doc): target at [1] | cited: [0, 1, 7, 2, 3]
#   [155/2746] 49894_UniqueWords(doc): target at [1] | cited: [0, 1, 7, 2, 6]
#   [156/2746] 49894_doc: target at [0] | cited: [1, 2, 4, 3, 9]
#   [157/2746] 50300_Authoritative(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [158/2746] 50300_CQ(doc): target at [0] | cited: [0, 1, 2, 7, 5]
#   [159/2746] 50300_CQS(doc): target at [0] | cited: [0, 1]
#   [160/2746] 50300_CS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [161/2746] 50300_Citations(doc): target at [0] | cited: [0, 1]
#   [162/2746] 50300_ContentImprovement(doc): target at [0] | cited: [0, 1, 7]
#   [163/2746] 50300_FC(doc): target at [2] | cited: [0, 2, 1]
#   [164/2746] 50300_FCQ(doc): target at [1] | cited: [0, 1, 7, 4, 3]
#   [165/2746] 50300_FCQS(doc): target at [2] | cited: [0, 2, 3, 4, 7]
#   [166/2746] 50300_FCS(doc): target at [2] | cited: [0, 2, 5, 1, 3]
#   [167/2746] 50300_FQ(doc): target at [2] | cited: [0, 2, 1, 3]
#   [168/2746] 50300_FQS(doc): target at [9] | cited: [0, 4, 9, 6]
#   [169/2746] 50300_FS(doc): target at [2] | cited: [0, 2, 1, 3]
#   [170/2746] 50300_Fluency(doc): target at [0] | cited: [0, 1, 4, 7, 2]
#   [171/2746] 50300_LLMstxt(doc): target at [3] | cited: [0, 3, 4, 1, 5]
#   [172/2746] 50300_QS(doc): target at [0] | cited: [0, 1, 5]
#   [173/2746] 50300_Quotes(doc): target at [0] | cited: [0, 1]
#   [174/2746] 50300_SimpleLanguage(doc): target at [1] | cited: [0, 1, 4, 7, 2]
#   [175/2746] 50300_Statistics(doc): target at [0] | cited: [0, 4, 7, 2, 3]
#   [176/2746] 50300_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 4, 7]
#   [177/2746] 50300_UniqueWords(doc): target at [0] | cited: [0, 1, 4, 7]
#   [178/2746] 50300_doc: target at [1] | cited: [0, 1, 7, 4]
#   [179/2746] 50359_Authoritative(doc): target at [7] | cited: [0, 2, 7, 5, 9]
#   [180/2746] 50359_CQ(doc): target at [9] | cited: [0, 5, 1, 2, 4]
#   [181/2746] 50359_CQS(doc): target at [8] | cited: [0, 3, 8, 1, 5]
#   [182/2746] 50359_CS(doc): target at [6] | cited: [0, 4, 1, 3, 5]
#   [183/2746] 50359_Citations(doc): target at [8] | cited: [0, 1, 9, 2, 5]
#   [184/2746] 50359_ContentImprovement(doc): target at [8] | cited: [0, 2, 1, 9, 7]
#   [185/2746] 50359_FC(doc): target at [8] | cited: [0, 3, 8, 1, 2]
#   [186/2746] 50359_FCQ(doc): target at [8] | cited: [0, 3, 2, 4, 5]
#   [187/2746] 50359_FCQS(doc): target at [8] | cited: [0, 1, 4, 2, 3]
#   [188/2746] 50359_FCS(doc): target at [9] | cited: [0, 4, 1, 5, 6]
#   [189/2746] 50359_FQ(doc): target at [6] | cited: [0, 2, 1, 5, 3]
#   [190/2746] 50359_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [191/2746] 50359_FS(doc): target at [9] | cited: [0, 1, 4, 2, 3]
#   [192/2746] 50359_Fluency(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [193/2746] 50359_LLMstxt(doc): target at [9] | cited: [0, 4, 1, 2, 3]
#   [194/2746] 50359_QS(doc): target at [8] | cited: [0, 1, 3, 7, 9]
#   [195/2746] 50359_Quotes(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [196/2746] 50359_SimpleLanguage(doc): target at [7] | cited: [0, 1, 3, 4, 2]
#   [197/2746] 50359_Statistics(doc): target at [9] | cited: [0, 1, 6, 2, 3]
#   [198/2746] 50359_TechnicalTerms(doc): target at [8] | cited: [0, 3, 8, 1, 4]
#   [199/2746] 50359_UniqueWords(doc): target at [7] | cited: [0, 4, 5, 8, 1]
#   [200/2746] 50359_doc: target at [1] | cited: [0, 1, 3, 2, 9]
#   [201/2746] 50426_Authoritative(doc): target at [0] | cited: [0, 4, 1, 2, 3]
#   [202/2746] 50426_CQ(doc): target at [6] | cited: [0, 1, 3, 4, 8]
#   [203/2746] 50426_CQS(doc): target at [5] | cited: [0, 1, 5, 7, 8]
#   [204/2746] 50426_CS(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [205/2746] 50426_Citations(doc): target at [5] | cited: [3, 4, 5, 0, 2]
#   [206/2746] 50426_ContentImprovement(doc): target at [5] | cited: [0, 6, 3, 4, 8]
#   [207/2746] 50426_FC(doc): target at [5] | cited: [3, 4, 5, 6, 7]
#   [208/2746] 50426_FCQ(doc): target at [5] | cited: [4, 5, 0, 2, 8]
#   [209/2746] 50426_FCQS(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [210/2746] 50426_FCS(doc): target at [5] | cited: [0, 1, 3, 4, 8]
#   [211/2746] 50426_FQ(doc): target at [5] | cited: [3, 4, 1, 2, 6]
#   [212/2746] 50426_FQS(doc): target at [9] | cited: [0, 1, 3, 4, 7]
#   [213/2746] 50426_FS(doc): target at [9] | cited: [0, 4, 9, 7, 6]
#   [214/2746] 50426_Fluency(doc): target at [5] | cited: [3, 4, 5, 0, 2]
#   [215/2746] 50426_LLMstxt(doc): target at [9] | cited: [0, 4, 9, 1, 2]
#   [216/2746] 50426_QS(doc): target at [1] | cited: [0, 1, 4, 5, 6]
#   [217/2746] 50426_Quotes(doc): target at [5] | cited: [0, 4, 1, 6, 8]
#   [218/2746] 50426_SimpleLanguage(doc): target at [5] | cited: [0, 4, 1, 3, 9]
#   [219/2746] 50426_Statistics(doc): target at [5] | cited: [0, 1, 2, 8, 3]
#   [220/2746] 50426_TechnicalTerms(doc): target at [5] | cited: [0, 1, 3, 4, 8]
#   [221/2746] 50426_UniqueWords(doc): target at [1] | cited: [0, 1, 4, 7, 3]
#   [222/2746] 50426_doc: target at [5] | cited: [0, 1, 3, 5, 9]
#   [223/2746] 50469_Authoritative(doc): target at [0] | cited: [0, 1, 2, 8, 9]
#   [224/2746] 50469_CQ(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [225/2746] 50469_CQS(doc): target at [0] | cited: [0, 1, 2, 8, 9]
#   [226/2746] 50469_CS(doc): target at [0] | cited: [0, 1, 2, 4, 3]
#   [227/2746] 50469_Citations(doc): target at [0] | cited: [0, 1, 2, 3, 9]
#   [228/2746] 50469_ContentImprovement(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [229/2746] 50469_FC(doc): target at [1] | cited: [0, 1, 2, 8, 7]
#   [230/2746] 50469_FCQ(doc): target at [1] | cited: [0, 1, 2, 3, 9]
#   [231/2746] 50469_FCQS(doc): target at [1] | cited: [0, 1, 2, 5, 8]
#   [232/2746] 50469_FCS(doc): target at [1] | cited: [0, 1, 2, 8, 9]
#   [233/2746] 50469_FQ(doc): target at [1] | cited: [0, 1, 2, 5, 8]
#   [234/2746] 50469_FQS(doc): target at [1] | cited: [0, 1, 2, 4, 7]
#   [235/2746] 50469_FS(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [236/2746] 50469_Fluency(doc): target at [0] | cited: [0, 1, 2, 8, 9]
#   [237/2746] 50469_LLMstxt(doc): target at [1] | cited: [0, 1, 2, 8, 5]
#   [238/2746] 50469_QS(doc): target at [0] | cited: [0, 1, 2, 3, 9]
#   [239/2746] 50469_Quotes(doc): target at [0] | cited: [0, 1, 2, 3, 5]
#   [240/2746] 50469_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 3, 8]
#   [241/2746] 50469_Statistics(doc): target at [0] | cited: [0, 1, 2, 3, 9]
#   [242/2746] 50469_TechnicalTerms(doc): target at [0] | cited: [0, 1, 2, 8, 9]
#   [243/2746] 50469_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 8, 9]
#   [244/2746] 50469_doc: target at [0] | cited: [0, 1, 2, 3, 4]
#   [245/2746] 50517_Authoritative(doc): target at [5] | cited: [0, 6, 1, 2, 3]
#   [246/2746] 50517_CQ(doc): target at [4] | cited: [0, 5, 2, 4]
#   [247/2746] 50517_CQS(doc): target at [5] | cited: [0, 2, 6, 1, 7]
#   [248/2746] 50517_CS(doc): target at [3] | cited: [0, 1, 4, 3, 7]
#   [249/2746] 50517_Citations(doc): target at [5] | cited: [0, 6, 3, 2, 5]
#   [250/2746] 50517_ContentImprovement(doc): target at [5] | cited: [0, 4, 1, 2, 5]
#   [251/2746] 50517_FC(doc): target at [9] | cited: [1, 6, 4, 2, 9]
#   [252/2746] 50517_FCQ(doc): target at [7] | cited: []
#   [253/2746] 50517_FCQS(doc): target at [3] | cited: [0, 1, 4, 3, 7]
#   [254/2746] 50517_FCS(doc): target at [6] | cited: [0, 3, 4, 1, 2]
#   [255/2746] 50517_FQ(doc): target at [9] | cited: [1, 0, 2, 6, 8]
#   [256/2746] 50517_FQS(doc): target at [1] | cited: [0, 1, 6, 3]
#   [257/2746] 50517_FS(doc): target at [4] | cited: [0, 1, 5, 2, 9]
#   [258/2746] 50517_Fluency(doc): target at [3] | cited: []
#   [259/2746] 50517_LLMstxt(doc): target at [4] | cited: [0, 6, 3, 8, 2]
#   [260/2746] 50517_QS(doc): target at [3] | cited: [0, 5, 1, 3, 7]
#   [261/2746] 50517_Quotes(doc): target at [3] | cited: [0, 1, 4, 3, 7]
#   [262/2746] 50517_SimpleLanguage(doc): target at [3] | cited: [0, 4, 5, 1, 3]
#   [263/2746] 50517_Statistics(doc): target at [6] | cited: [0, 3, 1, 6]
#   [264/2746] 50517_TechnicalTerms(doc): target at [4] | cited: [0, 5, 4, 2, 7]
#   [265/2746] 50517_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 4, 6]
#   [266/2746] 50517_doc: target at [3] | cited: [1, 0, 4, 3, 7]
#   [267/2746] 50689_Authoritative(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [268/2746] 50689_CQ(doc): target at [4] | cited: [0, 1, 8, 2, 7]
#   [269/2746] 50689_CQS(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [270/2746] 50689_CS(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [271/2746] 50689_Citations(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [272/2746] 50689_ContentImprovement(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [273/2746] 50689_FC(doc): target at [4] | cited: [0, 1, 8]
#   [274/2746] 50689_FCQ(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [275/2746] 50689_FCQS(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [276/2746] 50689_FCS(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [277/2746] 50689_FQ(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [278/2746] 50689_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [279/2746] 50689_FS(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [280/2746] 50689_Fluency(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [281/2746] 50689_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 7]
#   [282/2746] 50689_QS(doc): target at [4] | cited: []
#   [283/2746] 50689_Quotes(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [284/2746] 50689_SimpleLanguage(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [285/2746] 50689_Statistics(doc): target at [5] | cited: [0, 1, 2, 3, 9]
#   [286/2746] 50689_TechnicalTerms(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [287/2746] 50689_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [288/2746] 50689_doc: target at [4] | cited: [0, 1, 2, 3, 8]
#   [289/2746] 50881_Authoritative(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [290/2746] 50881_CQ(doc): target at [3] | cited: [1, 3, 5, 8, 0]
#   [291/2746] 50881_CQS(doc): target at [9] | cited: [1, 2, 3, 4, 5]
#   [292/2746] 50881_CS(doc): target at [3] | cited: [0, 1, 3, 4, 5]
#   [293/2746] 50881_Citations(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [294/2746] 50881_ContentImprovement(doc): target at [7] | cited: [0, 1, 3, 7, 4]
#   [295/2746] 50881_FC(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [296/2746] 50881_FCQ(doc): target at [3] | cited: [1, 3, 4, 0, 6]
#   [297/2746] 50881_FCQS(doc): target at [3] | cited: [1, 2, 3, 4, 5]
#   [298/2746] 50881_FCS(doc): target at [3] | cited: [0, 1, 2, 3, 6]
#   [299/2746] 50881_FQ(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [300/2746] 50881_FQS(doc): target at [3] | cited: [0, 1, 3, 2, 6]
#   [301/2746] 50881_FS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [302/2746] 50881_Fluency(doc): target at [4] | cited: [0, 1, 2, 7, 6]
#   [303/2746] 50881_LLMstxt(doc): target at [5] | cited: [0, 1, 5, 6, 7]
#   [304/2746] 50881_QS(doc): target at [4] | cited: [0, 1, 7, 2, 3]
#   [305/2746] 50881_Quotes(doc): target at [3] | cited: [0, 1, 3, 5, 4]
#   [306/2746] 50881_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [307/2746] 50881_Statistics(doc): target at [9] | cited: [0, 2, 7, 1, 3]
#   [308/2746] 50881_TechnicalTerms(doc): target at [5] | cited: [4, 5, 8, 1, 3]
#   [309/2746] 50881_UniqueWords(doc): target at [2] | cited: [0, 1, 6, 7, 9]
#   [310/2746] 50881_doc: target at [3] | cited: [0, 2, 6, 9, 1]
#   [311/2746] 50937_Authoritative(doc): target at [4] | cited: [0, 1, 2, 3, 7]
#   [312/2746] 50937_CQ(doc): target at [6] | cited: [0, 3, 1, 2, 4]
#   [313/2746] 50937_CQS(doc): target at [4] | cited: [0, 3, 6, 7, 1]
#   [314/2746] 50937_CS(doc): target at [6] | cited: [0, 3, 7, 4, 5]
#   [315/2746] 50937_Citations(doc): target at [4] | cited: [0, 3, 1, 2, 5]
#   [316/2746] 50937_ContentImprovement(doc): target at [8] | cited: [0, 3, 5, 6, 1]
#   [317/2746] 50937_FC(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [318/2746] 50937_FCQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [319/2746] 50937_FCQS(doc): target at [4] | cited: [0, 3, 1, 2, 5]
#   [320/2746] 50937_FCS(doc): target at [7] | cited: [0, 5, 6, 7, 9]
#   [321/2746] 50937_FQ(doc): target at [4] | cited: [0, 7, 6, 1, 9]
#   [322/2746] 50937_FQS(doc): target at [7] | cited: [0, 3, 1, 2, 4]
#   [323/2746] 50937_FS(doc): target at [4] | cited: [0, 3, 1, 2, 4]
#   [324/2746] 50937_Fluency(doc): target at [2] | cited: [0, 6, 1, 3, 5]
#   [325/2746] 50937_LLMstxt(doc): target at [4] | cited: [0, 3, 7, 1, 4]
#   [326/2746] 50937_QS(doc): target at [4] | cited: []
#   [327/2746] 50937_Quotes(doc): target at [4] | cited: [0, 3, 6, 1, 4]
#   [328/2746] 50937_SimpleLanguage(doc): target at [4] | cited: [0, 3, 6, 1, 2]
#   [329/2746] 50937_Statistics(doc): target at [6] | cited: [0, 7, 1, 2, 4]
#   [330/2746] 50937_TechnicalTerms(doc): target at [4] | cited: [0, 3, 1, 9, 5]
#   [331/2746] 50937_UniqueWords(doc): target at [6] | cited: [0, 5, 1, 6, 4]
#   [332/2746] 50937_doc: target at [4] | cited: [0, 3, 7, 6, 1]
#   [333/2746] 50943_Authoritative(doc): target at [6] | cited: [0, 1, 2, 6, 4]
#   [334/2746] 50943_CQ(doc): target at [2] | cited: [0, 1, 4, 9, 7]
#   [335/2746] 50943_CQS(doc): target at [6] | cited: [0, 1, 3, 7, 9]
#   [336/2746] 50943_CS(doc): target at [6] | cited: [0, 1, 3, 9, 6]
#   [337/2746] 50943_Citations(doc): target at [2] | cited: [0, 1, 2, 4, 9]
#   [338/2746] 50943_ContentImprovement(doc): target at [9] | cited: [0, 6, 2, 3]
#   [339/2746] 50943_FC(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [340/2746] 50943_FCQ(doc): target at [9] | cited: [0, 3, 4, 9, 2]
#   [341/2746] 50943_FCQS(doc): target at [9] | cited: [0, 1, 4, 9, 6]
#   [342/2746] 50943_FCS(doc): target at [9] | cited: [0, 1, 6, 9, 8]
#   [343/2746] 50943_FQ(doc): target at [9] | cited: [0, 1, 4, 9, 7]
#   [344/2746] 50943_FQS(doc): target at [2] | cited: [0, 1, 2, 8, 9]
#   [345/2746] 50943_FS(doc): target at [9] | cited: [0, 1, 3, 8, 9]
#   [346/2746] 50943_Fluency(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [347/2746] 50943_LLMstxt(doc): target at [4] | cited: [0, 3, 2, 7, 9]
#   [348/2746] 50943_QS(doc): target at [7] | cited: [0, 1, 6, 9, 2]
#   [349/2746] 50943_Quotes(doc): target at [2] | cited: [0, 1, 5, 9, 6]
#   [350/2746] 50943_SimpleLanguage(doc): target at [7] | cited: [6, 1, 4, 5, 9]
#   [351/2746] 50943_Statistics(doc): target at [6] | cited: [0, 1, 3, 4, 9]
#   [352/2746] 50943_TechnicalTerms(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [353/2746] 50943_UniqueWords(doc): target at [6] | cited: [0, 1, 9, 5, 7]
#   [354/2746] 50943_doc: target at [6] | cited: [0, 1, 2, 3, 6]
#   [355/2746] 50973_Authoritative(doc): target at [3] | cited: [0, 1, 5, 2, 8]
#   [356/2746] 50973_CQ(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [357/2746] 50973_CQS(doc): target at [5] | cited: [0, 1, 4, 9, 6]
#   [358/2746] 50973_CS(doc): target at [4] | cited: [0, 1, 2, 5, 9]
#   [359/2746] 50973_Citations(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [360/2746] 50973_ContentImprovement(doc): target at [4] | cited: [0, 1, 4, 9, 5]
#   [361/2746] 50973_FC(doc): target at [6] | cited: [0, 1, 4, 2, 3]
#   [362/2746] 50973_FCQ(doc): target at [6] | cited: [0, 1, 4, 8, 2]
#   [363/2746] 50973_FCQS(doc): target at [6] | cited: [0, 1, 2, 4, 9]
#   [364/2746] 50973_FCS(doc): target at [7] | cited: [0, 1, 4, 2, 9]
#   [365/2746] 50973_FQ(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [366/2746] 50973_FQS(doc): target at [6] | cited: [0, 1, 4, 8, 3]
#   [367/2746] 50973_FS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [368/2746] 50973_Fluency(doc): target at [6] | cited: [0, 1, 2, 4, 9]
#   [369/2746] 50973_LLMstxt(doc): target at [7] | cited: [0, 1, 4, 2, 8]
#   [370/2746] 50973_QS(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [371/2746] 50973_Quotes(doc): target at [3] | cited: [0, 1, 3, 5, 9]
#   [372/2746] 50973_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 3, 5]
#   [373/2746] 50973_Statistics(doc): target at [6] | cited: [0, 1, 4, 2, 8]
#   [374/2746] 50973_TechnicalTerms(doc): target at [6] | cited: [0, 1, 4, 2, 3]
#   [375/2746] 50973_UniqueWords(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [376/2746] 50973_doc: target at [3] | cited: [0, 1, 2, 5, 9]
#   [377/2746] 51059_Authoritative(doc): target at [2] | cited: [0, 1, 2, 4, 8]
#   [378/2746] 51059_CQ(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [379/2746] 51059_CQS(doc): target at [2] | cited: [0, 1, 2, 3, 8]
#   [380/2746] 51059_CS(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [381/2746] 51059_Citations(doc): target at [2] | cited: [0, 1, 2, 4, 8]
#   [382/2746] 51059_ContentImprovement(doc): target at [2] | cited: [0, 1, 9, 3, 2]
#   [383/2746] 51059_FC(doc): target at [2] | cited: [0, 1, 6, 5, 9]
#   [384/2746] 51059_FCQ(doc): target at [2] | cited: [0, 2, 1, 5, 7]
#   [385/2746] 51059_FCQS(doc): target at [2] | cited: [0, 2, 3, 4, 7]
#   [386/2746] 51059_FCS(doc): target at [2] | cited: [0, 5, 9, 1, 2]
#   [387/2746] 51059_FQ(doc): target at [2] | cited: [0, 2, 1, 7, 8]
#   [388/2746] 51059_FQS(doc): target at [2] | cited: [0, 1, 3, 2, 5]
#   [389/2746] 51059_FS(doc): target at [2] | cited: [0, 5, 2, 8, 1]
#   [390/2746] 51059_Fluency(doc): target at [2] | cited: [0, 1, 2, 5, 9]
#   [391/2746] 51059_LLMstxt(doc): target at [9] | cited: [0, 1, 2]
#   [392/2746] 51059_QS(doc): target at [2] | cited: [0, 1, 4, 8]
#   [393/2746] 51059_Quotes(doc): target at [2] | cited: [0, 8, 1, 2, 6]
#   [394/2746] 51059_SimpleLanguage(doc): target at [2] | cited: [0, 1, 2, 4, 8]
#   [395/2746] 51059_Statistics(doc): target at [2] | cited: [0, 1, 3, 5, 4]
#   [396/2746] 51059_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [397/2746] 51059_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 7, 4]
#   [398/2746] 51059_doc: target at [2] | cited: [0, 1, 2, 8, 3]
#   [399/2746] 51222_Authoritative(doc): target at [1] | cited: [1, 2, 0, 4]
#   [400/2746] 51222_CQ(doc): target at [1] | cited: [1, 0, 2, 4, 6]
#   [401/2746] 51222_CQS(doc): target at [1] | cited: [1, 2, 4, 0, 8]
#   [402/2746] 51222_CS(doc): target at [1] | cited: [1, 0, 2, 4, 5]
#   [403/2746] 51222_Citations(doc): target at [1] | cited: [1, 0, 3, 4, 7]
#   [404/2746] 51222_ContentImprovement(doc): target at [1] | cited: [1, 2, 4, 7, 6]
#   [405/2746] 51222_FC(doc): target at [1] | cited: [1, 0, 2, 4, 6]
#   [406/2746] 51222_FCQ(doc): target at [0] | cited: [0, 1, 2, 4, 6]
#   [407/2746] 51222_FCQS(doc): target at [1] | cited: [0, 1, 2, 4, 7]
#   [408/2746] 51222_FCS(doc): target at [1] | cited: [1, 0, 2, 6, 7]
#   [409/2746] 51222_FQ(doc): target at [1] | cited: [1, 2, 4, 6, 7]
#   [410/2746] 51222_FQS(doc): target at [1] | cited: [1, 0, 6, 2, 4]
#   [411/2746] 51222_FS(doc): target at [1] | cited: [1, 0, 2, 4, 3]
#   [412/2746] 51222_Fluency(doc): target at [1] | cited: [1, 0, 2, 3, 6]
#   [413/2746] 51222_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [414/2746] 51222_QS(doc): target at [1] | cited: [1, 0, 2, 4, 6]
#   [415/2746] 51222_Quotes(doc): target at [1] | cited: [1, 5, 4, 6]
#   [416/2746] 51222_SimpleLanguage(doc): target at [1] | cited: [0, 1, 2, 4, 7]
#   [417/2746] 51222_Statistics(doc): target at [6] | cited: [1, 2, 3, 6, 5]
#   [418/2746] 51222_TechnicalTerms(doc): target at [1] | cited: [1, 2, 4, 3]
#   [419/2746] 51222_UniqueWords(doc): target at [1] | cited: [1, 0, 2, 4, 6]
#   [420/2746] 51222_doc: target at [1] | cited: [1, 3, 6, 4, 2]
#   [421/2746] 51385_Authoritative(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [422/2746] 51385_CQ(doc): target at [6] | cited: [0, 2, 1, 3, 7]
#   [423/2746] 51385_CQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [424/2746] 51385_CS(doc): target at [8] | cited: [0, 1, 3, 2, 5]
#   [425/2746] 51385_Citations(doc): target at [6] | cited: [0, 1, 2, 4, 8]
#   [426/2746] 51385_ContentImprovement(doc): target at [7] | cited: [0, 2, 1, 3, 6]
#   [427/2746] 51385_FC(doc): target at [8] | cited: [0, 3, 1, 2, 4]
#   [428/2746] 51385_FCQ(doc): target at [8] | cited: [0, 1, 2, 5, 7]
#   [429/2746] 51385_FCQS(doc): target at [1] | cited: [0, 1, 7, 5, 4]
#   [430/2746] 51385_FCS(doc): target at [1] | cited: [0, 2, 1, 3, 4]
#   [431/2746] 51385_FQ(doc): target at [7] | cited: [0, 1, 2, 8, 6]
#   [432/2746] 51385_FQS(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [433/2746] 51385_FS(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [434/2746] 51385_Fluency(doc): target at [8] | cited: []
#   [435/2746] 51385_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [436/2746] 51385_QS(doc): target at [7] | cited: [0, 2, 1, 3, 9]
#   [437/2746] 51385_Quotes(doc): target at [6] | cited: [0, 1, 3, 7, 4]
#   [438/2746] 51385_SimpleLanguage(doc): target at [7] | cited: [0, 3, 1, 2, 4]
#   [439/2746] 51385_Statistics(doc): target at [7] | cited: []
#   [440/2746] 51385_TechnicalTerms(doc): target at [6] | cited: [0, 1, 2, 5, 4]
#   [441/2746] 51385_UniqueWords(doc): target at [1] | cited: [0, 1, 2, 3, 5]
#   [442/2746] 51385_doc: target at [7] | cited: [0, 1, 2, 3, 5]
#   [443/2746] 51713_Authoritative(doc): target at [2] | cited: [0, 1, 2, 7, 8]
#   [444/2746] 51713_CQ(doc): target at [4] | cited: [0, 1, 3, 4, 5]
#   [445/2746] 51713_CQS(doc): target at [1] | cited: [0, 2, 8, 1, 4]
#   [446/2746] 51713_CS(doc): target at [1] | cited: [0, 1, 2, 3, 4]
#   [447/2746] 51713_Citations(doc): target at [2] | cited: [0, 1, 2, 3, 4]
#   [448/2746] 51713_ContentImprovement(doc): target at [1] | cited: [0, 1, 2, 3, 8]
#   [449/2746] 51713_FC(doc): target at [8] | cited: [0, 3, 5, 7, 1]
#   [450/2746] 51713_FCQ(doc): target at [6] | cited: [0, 1, 5, 7, 8]
#   [451/2746] 51713_FCQS(doc): target at [6] | cited: [0, 1, 2, 4, 8]
#   [452/2746] 51713_FCS(doc): target at [6] | cited: [0, 5, 8, 1, 7]
#   [453/2746] 51713_FQ(doc): target at [8] | cited: [0, 1, 5, 7, 4]
#   [454/2746] 51713_FQS(doc): target at [8] | cited: [0, 3, 8, 1, 2]
#   [455/2746] 51713_FS(doc): target at [5] | cited: [0, 1, 3, 5, 2]
#   [456/2746] 51713_Fluency(doc): target at [4] | cited: [0, 1, 3, 4, 8]
#   [457/2746] 51713_LLMstxt(doc): target at [8] | cited: [0, 1, 5, 8, 2]
#   [458/2746] 51713_QS(doc): target at [3] | cited: [0, 1, 2, 6, 7]
#   [459/2746] 51713_Quotes(doc): target at [2] | cited: [0, 2, 4, 7, 5]
#   [460/2746] 51713_SimpleLanguage(doc): target at [1] | cited: [0, 2, 4, 1, 3]
#   [461/2746] 51713_Statistics(doc): target at [4] | cited: [0, 3, 8, 6, 7]
#   [462/2746] 51713_TechnicalTerms(doc): target at [1] | cited: [1, 4, 7, 0, 2]
#   [463/2746] 51713_UniqueWords(doc): target at [1] | cited: [0, 1, 3, 7, 8]
#   [464/2746] 51713_doc: target at [2] | cited: [0, 1, 2, 4, 3]
#   [465/2746] 51999_Authoritative(doc): target at [2] | cited: [0, 1, 2, 9, 3]
#   [466/2746] 51999_CQ(doc): target at [1] | cited: [0, 2, 1, 9, 3]
#   [467/2746] 51999_CQS(doc): target at [2] | cited: [0, 4, 1, 6, 3]
#   [468/2746] 51999_CS(doc): target at [1] | cited: [0, 1, 3, 4, 9]
#   [469/2746] 51999_Citations(doc): target at [0] | cited: [1, 8, 2, 4, 5]
#   [470/2746] 51999_ContentImprovement(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [471/2746] 51999_FC(doc): target at [5] | cited: [0, 2, 1, 5, 9]
#   [472/2746] 51999_FCQ(doc): target at [8] | cited: [0, 4, 1, 3, 5]
#   [473/2746] 51999_FCQS(doc): target at [2] | cited: [0, 8, 1, 7, 5]
#   [474/2746] 51999_FCS(doc): target at [0] | cited: [1, 3, 2, 4, 6]
#   [475/2746] 51999_FQ(doc): target at [2] | cited: [0, 5, 1, 3, 8]
#   [476/2746] 51999_FQS(doc): target at [3] | cited: [0, 1, 4, 6, 9]
#   [477/2746] 51999_FS(doc): target at [1] | cited: [0, 8, 3, 4, 6]
#   [478/2746] 51999_Fluency(doc): target at [5] | cited: [0, 1, 2, 3, 5]
#   [479/2746] 51999_LLMstxt(doc): target at [9] | cited: [1, 2, 3, 4, 8]
#   [480/2746] 51999_QS(doc): target at [3] | cited: [0, 5, 1, 2, 3]
#   [481/2746] 51999_Quotes(doc): target at [2] | cited: [0, 1, 3, 4, 6]
#   [482/2746] 51999_SimpleLanguage(doc): target at [3] | cited: [0, 2, 8, 4, 1]
#   [483/2746] 51999_Statistics(doc): target at [8] | cited: [0, 1, 3, 4, 5]
#   [484/2746] 51999_TechnicalTerms(doc): target at [2] | cited: [0, 1, 2, 9, 4]
#   [485/2746] 51999_UniqueWords(doc): target at [2] | cited: [0, 1, 2, 9, 4]
#   [486/2746] 51999_doc: target at [1] | cited: [0, 1, 9, 3, 4]
#   [487/2746] 52614_Authoritative(doc): target at [9] | cited: [0, 1, 3, 6, 7]
#   [488/2746] 52614_CQ(doc): target at [9] | cited: [0, 4, 1, 5, 3]
#   [489/2746] 52614_CQS(doc): target at [9] | cited: [0, 1, 3, 4]
#   [490/2746] 52614_CS(doc): target at [9] | cited: [0, 4, 1, 3, 6]
#   [491/2746] 52614_Citations(doc): target at [9] | cited: [0, 4, 1, 3, 7]
#   [492/2746] 52614_ContentImprovement(doc): target at [9] | cited: [0, 2, 3, 6, 7]
#   [493/2746] 52614_FC(doc): target at [9] | cited: [0, 3, 1, 4, 7]
#   [494/2746] 52614_FCQ(doc): target at [9] | cited: [0, 1, 3, 4, 6]
#   [495/2746] 52614_FCQS(doc): target at [9] | cited: [0, 4, 1, 3, 6]
#   [496/2746] 52614_FCS(doc): target at [9] | cited: [0, 3, 8, 1, 4]
#   [497/2746] 52614_FQ(doc): target at [9] | cited: [0, 1, 3, 8, 6]
#   [498/2746] 52614_FQS(doc): target at [9] | cited: [0, 4, 1, 3, 6]
#   [499/2746] 52614_FS(doc): target at [9] | cited: [0, 4, 1, 3, 6]
#   [500/2746] 52614_Fluency(doc): target at [9] | cited: [0, 1, 3, 9, 4]
#   [501/2746] 52614_LLMstxt(doc): target at [9] | cited: [0, 4, 1, 3, 7]
#   [502/2746] 52614_QS(doc): target at [9] | cited: [0, 4, 1, 3, 8]
#   [503/2746] 52614_Quotes(doc): target at [9] | cited: [0, 2, 4, 1, 3]
#   [504/2746] 52614_SimpleLanguage(doc): target at [9] | cited: [0, 1, 3, 4, 8]
#   [505/2746] 52614_Statistics(doc): target at [9] | cited: [0, 4, 1, 3, 6]
#   [506/2746] 52614_TechnicalTerms(doc): target at [9] | cited: [0, 4, 3, 8, 9]
#   [507/2746] 52614_UniqueWords(doc): target at [9] | cited: [0, 3, 1, 4, 8]
#   [508/2746] 52614_doc: target at [9] | cited: [0, 4, 1, 3, 6]
#   [509/2746] 52627_Authoritative(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [510/2746] 52627_CQ(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [511/2746] 52627_CQS(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [512/2746] 52627_CS(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [513/2746] 52627_Citations(doc): target at [9] | cited: [0, 1, 2, 6, 9]
#   [514/2746] 52627_ContentImprovement(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [515/2746] 52627_FC(doc): target at [8] | cited: [0, 1, 2, 6, 9]
#   [516/2746] 52627_FCQ(doc): target at [8] | cited: [0, 1, 2, 8, 9]
#   [517/2746] 52627_FCQS(doc): target at [8] | cited: [0, 1, 2, 4]
#   [518/2746] 52627_FCS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [519/2746] 52627_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [520/2746] 52627_FQS(doc): target at [8] | cited: [0, 1, 2, 6, 8]
#   [521/2746] 52627_FS(doc): target at [8] | cited: [0, 1, 2, 8]
#   [522/2746] 52627_Fluency(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [523/2746] 52627_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 8, 3]
#   [524/2746] 52627_QS(doc): target at [9] | cited: [0, 1, 2]
#   [525/2746] 52627_Quotes(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [526/2746] 52627_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [527/2746] 52627_Statistics(doc): target at [9] | cited: [0, 2, 1]
#   [528/2746] 52627_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 4, 6]
#   [529/2746] 52627_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [530/2746] 52627_doc: target at [9] | cited: [0, 1, 2, 9, 4]
#   [531/2746] 52630_Authoritative(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [532/2746] 52630_CQ(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [533/2746] 52630_CQS(doc): target at [7] | cited: [6, 1, 2, 4]
#   [534/2746] 52630_CS(doc): target at [7] | cited: [0, 1, 2, 4]
#   [535/2746] 52630_Citations(doc): target at [7] | cited: [0, 1, 2, 4, 3]
#   [536/2746] 52630_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [537/2746] 52630_FC(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [538/2746] 52630_FCQ(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [539/2746] 52630_FCQS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [540/2746] 52630_FCS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [541/2746] 52630_FQ(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [542/2746] 52630_FQS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [543/2746] 52630_FS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [544/2746] 52630_Fluency(doc): target at [7] | cited: [0, 1, 3, 2, 4]
#   [545/2746] 52630_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 4, 6]
#   [546/2746] 52630_QS(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [547/2746] 52630_Quotes(doc): target at [7] | cited: [0, 1, 3, 4, 6]
#   [548/2746] 52630_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [549/2746] 52630_Statistics(doc): target at [7] | cited: [0, 1, 6, 2, 4]
#   [550/2746] 52630_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [551/2746] 52630_UniqueWords(doc): target at [7] | cited: [0, 1, 4, 6]
#   [552/2746] 52630_doc: target at [7] | cited: [0, 1, 2, 4, 6]
#   [553/2746] 5283_Authoritative(doc): target at [4] | cited: [0, 1, 3, 5]
#   [554/2746] 5283_CQ(doc): target at [4] | cited: [5, 2, 3, 1, 8]
#   [555/2746] 5283_CQS(doc): target at [7] | cited: [2, 7, 1, 4, 5]
#   [556/2746] 5283_CS(doc): target at [4] | cited: [1, 5, 2]
#   [557/2746] 5283_Citations(doc): target at [4] | cited: [0, 1, 2, 7, 5]
#   [558/2746] 5283_ContentImprovement(doc): target at [7] | cited: [0, 1, 2, 7, 6]
#   [559/2746] 5283_FC(doc): target at [4] | cited: [0, 1, 2, 3, 5]
#   [560/2746] 5283_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [561/2746] 5283_FCQS(doc): target at [3] | cited: [1, 4, 5, 7]
#   [562/2746] 5283_FCS(doc): target at [2] | cited: [2, 1, 5, 0]
#   [563/2746] 5283_FQ(doc): target at [2] | cited: [1, 4, 2, 3, 5]
#   [564/2746] 5283_FQS(doc): target at [8] | cited: [0, 1, 3, 4, 7]
#   [565/2746] 5283_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [566/2746] 5283_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 7]
#   [567/2746] 5283_LLMstxt(doc): target at [9] | cited: [0, 1, 4, 2, 3]
#   [568/2746] 5283_QS(doc): target at [4] | cited: [1, 5, 3]
#   [569/2746] 5283_Quotes(doc): target at [5] | cited: [0, 1, 2, 4]
#   [570/2746] 5283_SimpleLanguage(doc): target at [7] | cited: [1, 2, 3, 4, 5]
#   [571/2746] 5283_Statistics(doc): target at [4] | cited: [2, 3, 1, 5, 7]
#   [572/2746] 5283_TechnicalTerms(doc): target at [7] | cited: [0, 1, 4, 2, 3]
#   [573/2746] 5283_UniqueWords(doc): target at [7] | cited: [0, 3, 5, 1, 4]
#   [574/2746] 5283_doc: target at [4] | cited: [1, 2, 3, 5]
#   [575/2746] 53269_Authoritative(doc): target at [5] | cited: [0, 1, 2, 6, 9]
#   [576/2746] 53269_CQ(doc): target at [6] | cited: [0, 1, 5, 8]
#   [577/2746] 53269_CQS(doc): target at [6] | cited: [0, 5, 1, 2, 3]
#   [578/2746] 53269_CS(doc): target at [6] | cited: [0, 7, 1, 2, 3]
#   [579/2746] 53269_Citations(doc): target at [0] | cited: [0, 1, 2, 3, 9]
#   [580/2746] 53269_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [581/2746] 53269_FC(doc): target at [8] | cited: [0, 3, 1, 2, 5]
#   [582/2746] 53269_FCQ(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [583/2746] 53269_FCQS(doc): target at [8] | cited: [0, 1, 2, 4, 5]
#   [584/2746] 53269_FCS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [585/2746] 53269_FQ(doc): target at [4] | cited: [0, 1, 2, 5, 7]
#   [586/2746] 53269_FQS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [587/2746] 53269_FS(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [588/2746] 53269_Fluency(doc): target at [6] | cited: []
#   [589/2746] 53269_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 5, 6]
#   [590/2746] 53269_QS(doc): target at [7] | cited: [0, 2, 6, 1, 3]
#   [591/2746] 53269_Quotes(doc): target at [6] | cited: [0, 1, 2, 4, 5]
#   [592/2746] 53269_SimpleLanguage(doc): target at [5] | cited: [0, 6, 1, 4, 2]
#   [593/2746] 53269_Statistics(doc): target at [8] | cited: [0, 1, 2, 9, 7]
#   [594/2746] 53269_TechnicalTerms(doc): target at [5] | cited: [0, 7, 2, 3, 9]
#   [595/2746] 53269_UniqueWords(doc): target at [5] | cited: [0, 1, 2, 4, 6]
#   [596/2746] 53269_doc: target at [4] | cited: [0, 1, 2, 3, 5]
#   [597/2746] 53270_Authoritative(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [598/2746] 53270_CQ(doc): target at [7] | cited: [0, 1, 3, 2, 6]
#   [599/2746] 53270_CQS(doc): target at [8] | cited: [0, 1, 2, 3, 7]
#   [600/2746] 53270_CS(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [601/2746] 53270_Citations(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [602/2746] 53270_ContentImprovement(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [603/2746] 53270_FC(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [604/2746] 53270_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [605/2746] 53270_FCQS(doc): target at [8] | cited: [0, 1, 6, 7, 2]
#   [606/2746] 53270_FCS(doc): target at [5] | cited: [0, 1, 2, 3, 4]
#   [607/2746] 53270_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [608/2746] 53270_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [609/2746] 53270_FS(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [610/2746] 53270_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [611/2746] 53270_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [612/2746] 53270_QS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [613/2746] 53270_Quotes(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [614/2746] 53270_SimpleLanguage(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [615/2746] 53270_Statistics(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [616/2746] 53270_TechnicalTerms(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [617/2746] 53270_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 3, 9]
#   [618/2746] 53270_doc: target at [8] | cited: [0, 1, 2, 3, 4]
#   [619/2746] 53281_Authoritative(doc): target at [9] | cited: [0, 1, 5, 3, 7]
#   [620/2746] 53281_CQ(doc): target at [9] | cited: [0, 1, 7, 9]
#   [621/2746] 53281_CQS(doc): target at [9] | cited: [0, 1, 6, 9, 3]
#   [622/2746] 53281_CS(doc): target at [9] | cited: [0, 1, 2, 3, 9]
#   [623/2746] 53281_Citations(doc): target at [9] | cited: [0, 1, 7, 9, 8]
#   [624/2746] 53281_ContentImprovement(doc): target at [9] | cited: [0, 1, 5, 7, 9]
#   [625/2746] 53281_FC(doc): target at [9] | cited: [0, 7, 9, 8, 1]
#   [626/2746] 53281_FCQ(doc): target at [9] | cited: [0, 1, 2, 9, 4]
#   [627/2746] 53281_FCQS(doc): target at [9] | cited: [0, 1, 2, 7, 9]
#   [628/2746] 53281_FCS(doc): target at [9] | cited: [0, 1, 4, 9]
#   [629/2746] 53281_FQ(doc): target at [9] | cited: [0, 1, 2, 7, 9]
#   [630/2746] 53281_FQS(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [631/2746] 53281_FS(doc): target at [5] | cited: [0, 2, 5, 8, 1]
#   [632/2746] 53281_Fluency(doc): target at [9] | cited: [0, 1, 2, 7]
#   [633/2746] 53281_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 7, 9]
#   [634/2746] 53281_QS(doc): target at [9] | cited: [0, 1, 2, 7, 9]
#   [635/2746] 53281_Quotes(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [636/2746] 53281_SimpleLanguage(doc): target at [9] | cited: [0, 1, 2, 8, 9]
#   [637/2746] 53281_Statistics(doc): target at [9] | cited: [0, 1, 2, 5, 7]
#   [638/2746] 53281_TechnicalTerms(doc): target at [9] | cited: [0, 1, 2, 3, 6]
#   [639/2746] 53281_UniqueWords(doc): target at [9] | cited: [0, 1, 2, 3, 8]
#   [640/2746] 53281_doc: target at [9] | cited: [0, 1, 2, 7, 9]
#   [641/2746] 53373_Authoritative(doc): target at [5] | cited: [0, 2, 6, 1, 3]
#   [642/2746] 53373_CQ(doc): target at [5] | cited: [0, 2, 4, 6, 7]
#   [643/2746] 53373_CQS(doc): target at [5] | cited: [0, 1, 8, 2, 5]
#   [644/2746] 53373_CS(doc): target at [7] | cited: [0, 9, 1, 2, 7]
#   [645/2746] 53373_Citations(doc): target at [6] | cited: [0, 1, 3, 8, 4]
#   [646/2746] 53373_ContentImprovement(doc): target at [0] | cited: [0, 6, 9, 2, 3]
#   [647/2746] 53373_FC(doc): target at [8] | cited: [0, 8, 1, 7, 2]
#   [648/2746] 53373_FCQ(doc): target at [5] | cited: [0, 1, 2, 6, 8]
#   [649/2746] 53373_FCQS(doc): target at [7] | cited: [0, 1, 8, 2, 4]
#   [650/2746] 53373_FCS(doc): target at [5] | cited: [0, 1, 2, 4, 8]
#   [651/2746] 53373_FQ(doc): target at [8] | cited: [0, 1, 3, 6, 8]
#   [652/2746] 53373_FQS(doc): target at [5] | cited: [0, 2, 8, 1, 4]
#   [653/2746] 53373_FS(doc): target at [5] | cited: [0, 1, 4, 2, 8]
#   [654/2746] 53373_Fluency(doc): target at [7] | cited: [0, 2, 8, 3, 4]
#   [655/2746] 53373_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 4, 5]
#   [656/2746] 53373_QS(doc): target at [6] | cited: [0, 1, 4, 8, 6]
#   [657/2746] 53373_Quotes(doc): target at [5] | cited: [0, 1, 2, 8, 4]
#   [658/2746] 53373_SimpleLanguage(doc): target at [6] | cited: [0, 4, 2, 7, 3]
#   [659/2746] 53373_Statistics(doc): target at [5] | cited: [0, 2, 6, 8, 5]
#   [660/2746] 53373_TechnicalTerms(doc): target at [0] | cited: [0, 5, 1, 4, 8]
#   [661/2746] 53373_UniqueWords(doc): target at [5] | cited: [0, 7, 2, 8, 3]
#   [662/2746] 53373_doc: target at [5] | cited: []
#   [663/2746] 53462_Authoritative(doc): target at [4] | cited: [1, 3, 4, 2, 5]
#   [664/2746] 53462_CQ(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [665/2746] 53462_CQS(doc): target at [5] | cited: [0, 1, 2, 3, 6]
#   [666/2746] 53462_CS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [667/2746] 53462_Citations(doc): target at [4] | cited: [0, 1, 2, 4, 6]
#   [668/2746] 53462_ContentImprovement(doc): target at [6] | cited: [0, 1, 2, 3, 5]
#   [669/2746] 53462_FC(doc): target at [3] | cited: [0, 1, 2, 3, 4]
#   [670/2746] 53462_FCQ(doc): target at [5] | cited: [0, 1, 2, 6, 9]
#   [671/2746] 53462_FCQS(doc): target at [6] | cited: [0, 1, 2, 3, 8]
#   [672/2746] 53462_FCS(doc): target at [4] | cited: [0, 1, 2, 3, 4]
#   [673/2746] 53462_FQ(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [674/2746] 53462_FQS(doc): target at [4] | cited: [0, 1, 9, 2, 4]
#   [675/2746] 53462_FS(doc): target at [6] | cited: [0, 1, 2, 8, 5]
#   [676/2746] 53462_Fluency(doc): target at [6] | cited: [0, 1, 2, 8, 5]
#   [677/2746] 53462_LLMstxt(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [678/2746] 53462_QS(doc): target at [4] | cited: [0, 1, 2, 4, 8]
#   [679/2746] 53462_Quotes(doc): target at [4] | cited: [0, 1, 2, 3, 8]
#   [680/2746] 53462_SimpleLanguage(doc): target at [3] | cited: [0, 1, 2, 6, 9]
#   [681/2746] 53462_Statistics(doc): target at [4] | cited: [0, 1, 2, 3, 6]
#   [682/2746] 53462_TechnicalTerms(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [683/2746] 53462_UniqueWords(doc): target at [4] | cited: [0, 1, 9, 2, 3]
#   [684/2746] 53462_doc: target at [4] | cited: [0, 1, 2, 8, 6]
#   [685/2746] 53789_Authoritative(doc): target at [0] | cited: [0, 6, 1, 5, 2]
#   [686/2746] 53789_CQ(doc): target at [6] | cited: [0, 1, 2, 5, 4]
#   [687/2746] 53789_CQS(doc): target at [0] | cited: [0, 1, 6, 2, 4]
#   [688/2746] 53789_CS(doc): target at [2] | cited: [0, 1, 2, 3, 7]
#   [689/2746] 53789_Citations(doc): target at [2] | cited: [1, 3, 2, 5, 4]
#   [690/2746] 53789_ContentImprovement(doc): target at [8] | cited: [0, 6, 2, 3, 7]
#   [691/2746] 53789_FC(doc): target at [8] | cited: [0, 1, 2, 4, 6]
#   [692/2746] 53789_FCQ(doc): target at [6] | cited: [0, 1, 3, 6, 4]
#   [693/2746] 53789_FCQS(doc): target at [6] | cited: [0, 1, 2, 5, 9]
#   [694/2746] 53789_FCS(doc): target at [7] | cited: [0, 1, 2, 6, 7]
#   [695/2746] 53789_FQ(doc): target at [7] | cited: [0, 1, 2, 4, 6]
#   [696/2746] 53789_FQS(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [697/2746] 53789_FS(doc): target at [7] | cited: [0, 1, 2, 4, 5]
#   [698/2746] 53789_Fluency(doc): target at [7] | cited: [0, 1, 4, 6, 2]
#   [699/2746] 53789_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 9, 3]
#   [700/2746] 53789_QS(doc): target at [7] | cited: [0, 1, 3, 4, 2]
#   [701/2746] 53789_Quotes(doc): target at [7] | cited: [0, 1, 6, 5, 8]
#   [702/2746] 53789_SimpleLanguage(doc): target at [2] | cited: [0, 2, 3, 4, 5]
#   [703/2746] 53789_Statistics(doc): target at [6] | cited: [0, 1, 5, 4, 7]
#   [704/2746] 53789_TechnicalTerms(doc): target at [6] | cited: [0, 1, 3, 5, 6]
#   [705/2746] 53789_UniqueWords(doc): target at [6] | cited: [0, 1, 3, 6, 5]
#   [706/2746] 53789_doc: target at [2] | cited: [0, 1, 5, 2, 4]
#   [707/2746] 53823_Authoritative(doc): target at [5] | cited: [0, 4, 6, 1, 5]
#   [708/2746] 53823_CQ(doc): target at [4] | cited: [0, 1, 5, 2, 4]
#   [709/2746] 53823_CQS(doc): target at [4] | cited: [0, 1, 5, 2, 4]
#   [710/2746] 53823_CS(doc): target at [4] | cited: [0, 1, 2, 5, 4]
#   [711/2746] 53823_Citations(doc): target at [3] | cited: [0, 3, 8, 4, 6]
#   [712/2746] 53823_ContentImprovement(doc): target at [5] | cited: [0, 1, 5, 2, 4]
# ...
#   [2529/2746] 72526_doc: target at [9] | cited: [0, 2, 1, 5, 6]
#   [2530/2746] 7259_Authoritative(doc): target at [7] | cited: [0, 1, 3, 4, 8]
#   [2531/2746] 7259_CQ(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2532/2746] 7259_CQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2533/2746] 7259_CS(doc): target at [7] | cited: [0, 1, 3, 4, 5]
#   [2534/2746] 7259_Citations(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2535/2746] 7259_ContentImprovement(doc): target at [7] | cited: [0, 8, 1, 2, 3]
#   [2536/2746] 7259_FC(doc): target at [9] | cited: [0, 1, 2, 3, 5]
#   [2537/2746] 7259_FCQ(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2538/2746] 7259_FCQS(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2539/2746] 7259_FCS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2540/2746] 7259_FQ(doc): target at [8] | cited: [0, 7, 1, 2, 8]
#   [2541/2746] 7259_FQS(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2542/2746] 7259_FS(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [2543/2746] 7259_Fluency(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [2544/2746] 7259_LLMstxt(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2545/2746] 7259_QS(doc): target at [7] | cited: [0, 1, 3, 2, 6]
#   [2546/2746] 7259_Quotes(doc): target at [7] | cited: [0, 2, 1, 3, 4]
#   [2547/2746] 7259_SimpleLanguage(doc): target at [7] | cited: [0, 1, 2, 3, 5]
#   [2548/2746] 7259_Statistics(doc): target at [9] | cited: [0, 1, 2, 3, 4]
#   [2549/2746] 7259_TechnicalTerms(doc): target at [7] | cited: [0, 1, 2, 5, 9]
#   [2550/2746] 7259_UniqueWords(doc): target at [7] | cited: [0, 1, 2, 3, 4]
#   [2551/2746] 7259_doc: target at [6] | cited: [0, 1, 2, 3, 4]
#   [2552/2746] 72660_Authoritative(doc): target at [4] | cited: [0, 4, 1, 2, 5]
#   [2553/2746] 72660_CQ(doc): target at [5] | cited: [0, 2, 4, 1, 3]
#   [2554/2746] 72660_CQS(doc): target at [5] | cited: [0, 1, 5, 3, 4]
#   [2555/2746] 72660_CS(doc): target at [6] | cited: [0, 1, 2, 6, 3]
#   [2556/2746] 72660_Citations(doc): target at [5] | cited: [0, 1, 2, 3, 6]
#   [2557/2746] 72660_ContentImprovement(doc): target at [5] | cited: [0, 3, 4, 1, 2]
#   [2558/2746] 72660_FC(doc): target at [8] | cited: [0, 2, 4, 1, 5]
#   [2559/2746] 72660_FCQ(doc): target at [8] | cited: [0, 4, 7, 1, 5]
#   [2560/2746] 72660_FCQS(doc): target at [6] | cited: [0, 2, 4, 1, 3]
#   [2561/2746] 72660_FCS(doc): target at [8] | cited: [0, 8, 2, 1, 3]
#   [2562/2746] 72660_FQ(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [2563/2746] 72660_FQS(doc): target at [8] | cited: [0, 2, 1, 3, 4]
#   [2564/2746] 72660_FS(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2565/2746] 72660_Fluency(doc): target at [5] | cited: [0, 2, 4, 3, 5]
#   [2566/2746] 72660_LLMstxt(doc): target at [8] | cited: [0, 1, 2, 8, 3]
#   [2567/2746] 72660_QS(doc): target at [5] | cited: [0, 2, 5, 8, 1]
#   [2568/2746] 72660_Quotes(doc): target at [5] | cited: [0, 2, 4, 1, 3]
#   [2569/2746] 72660_SimpleLanguage(doc): target at [5] | cited: [0, 4, 1, 2, 5]
#   [2570/2746] 72660_Statistics(doc): target at [6] | cited: [0, 1, 2, 3, 4]
#   [2571/2746] 72660_TechnicalTerms(doc): target at [5] | cited: [0, 3, 4, 1, 2]
#   [2572/2746] 72660_UniqueWords(doc): target at [5] | cited: [0, 1, 3, 5, 2]
#   [2573/2746] 72660_doc: target at [2] | cited: [0, 1, 4, 8, 5]
#   [2574/2746] 72662_Authoritative(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2575/2746] 72662_CQ(doc): target at [8] | cited: [0, 2, 3, 1, 4]
#   [2576/2746] 72662_CQS(doc): target at [8] | cited: [0, 2, 1, 4, 3]
#   [2577/2746] 72662_CS(doc): target at [8] | cited: [0, 4, 1, 2, 6]
#   [2578/2746] 72662_Citations(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2579/2746] 72662_ContentImprovement(doc): target at [7] | cited: [0, 1, 3, 5, 7]
#   [2580/2746] 72662_FC(doc): target at [8] | cited: [0, 2, 1, 3, 6]
#   [2581/2746] 72662_FCQ(doc): target at [8] | cited: [0, 2, 1, 3, 4]
#   [2582/2746] 72662_FCQS(doc): target at [8] | cited: [0, 1, 2, 4, 3]
#   [2583/2746] 72662_FCS(doc): target at [8] | cited: [0, 2, 3, 4, 5]
#   [2584/2746] 72662_FQ(doc): target at [8] | cited: [0, 2, 3, 1, 6]
#   [2585/2746] 72662_FQS(doc): target at [8] | cited: [0, 2, 1, 4, 3]
#   [2586/2746] 72662_FS(doc): target at [8] | cited: [0, 2, 3, 1, 4]
#   [2587/2746] 72662_Fluency(doc): target at [7] | cited: [0, 1, 2, 3, 6]
#   [2588/2746] 72662_LLMstxt(doc): target at [8] | cited: [0, 2, 1, 4, 3]
#   [2589/2746] 72662_QS(doc): target at [8] | cited: [0, 2, 1, 3, 6]
#   [2590/2746] 72662_Quotes(doc): target at [7] | cited: [0, 2, 1, 3, 8]
#   [2591/2746] 72662_SimpleLanguage(doc): target at [5] | cited: [0, 2, 1, 4, 5]
#   [2592/2746] 72662_Statistics(doc): target at [8] | cited: [0, 7, 1, 2, 5]
#   [2593/2746] 72662_TechnicalTerms(doc): target at [8] | cited: [0, 1, 2, 3, 4]
#   [2594/2746] 72662_UniqueWords(doc): target at [8] | cited: [0, 1, 2, 3, 5]
#   [2595/2746] 72662_doc: target at [5] | cited: [0, 1, 2, 3, 4]
#   [2596/2746] 73868_Authoritative(doc): target at [3] | cited: [1, 4, 0, 9, 8]
#   [2597/2746] 73868_CQ(doc): target at [2] | cited: [0, 1, 9, 8, 7]
#   [2598/2746] 73868_CQS(doc): target at [0] | cited: [0, 8, 9, 1, 2]
#   [2599/2746] 73868_CS(doc): target at [3] | cited: [0, 1, 3, 8, 6]
#   [2600/2746] 73868_Citations(doc): target at [3] | cited: [0, 4, 1, 3, 8]
#   [2601/2746] 73868_ContentImprovement(doc): target at [2] | cited: [0, 4, 7, 1, 8]
#   [2602/2746] 73868_FC(doc): target at [3] | cited: [0, 1, 4, 5, 9]
#   [2603/2746] 73868_FCQ(doc): target at [3] | cited: [0, 1, 4, 9, 6]
#   [2604/2746] 73868_FCQS(doc): target at [3] | cited: [0, 1, 4, 5, 8]
#   [2605/2746] 73868_FCS(doc): target at [3] | cited: [0, 5, 1, 3, 8]
#   [2606/2746] 73868_FQ(doc): target at [1] | cited: [0, 1, 8, 2, 4]
#   [2607/2746] 73868_FQS(doc): target at [3] | cited: [0, 4, 1, 5, 8]
#   [2608/2746] 73868_FS(doc): target at [3] | cited: [0, 4, 1, 7, 9]
#   [2609/2746] 73868_Fluency(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [2610/2746] 73868_LLMstxt(doc): target at [5] | cited: [1, 3, 4, 8, 0]
#   [2611/2746] 73868_QS(doc): target at [3] | cited: [0, 1, 2, 3, 8]
#   [2612/2746] 73868_Quotes(doc): target at [3] | cited: [0, 4, 6, 8, 9]
#   [2613/2746] 73868_SimpleLanguage(doc): target at [2] | cited: [3, 4, 6, 2, 8]
#   [2614/2746] 73868_Statistics(doc): target at [3] | cited: [0, 1, 6, 8, 9]
#   [2615/2746] 73868_TechnicalTerms(doc): target at [3] | cited: [0, 4, 1, 2, 9]
#   [2616/2746] 73868_UniqueWords(doc): target at [3] | cited: [0, 1, 5, 7, 8]
#   [2617/2746] 73868_doc: target at [3] | cited: [0, 1, 2, 8, 9]
#   [2618/2746] 7411_Authoritative(doc): target at [0] | cited: [0, 1, 5, 2, 7]
#   [2619/2746] 7411_CQ(doc): target at [0] | cited: [0, 1, 6, 4, 5]
#   [2620/2746] 7411_CQS(doc): target at [0] | cited: [0, 1, 6, 7, 5]
#   [2621/2746] 7411_CS(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2622/2746] 7411_Citations(doc): target at [0] | cited: [0, 1, 8, 4, 5]
#   [2623/2746] 7411_ContentImprovement(doc): target at [0] | cited: [0, 1, 6, 4, 8]
#   [2624/2746] 7411_FC(doc): target at [9] | cited: [0, 3, 4, 2, 9]
#   [2625/2746] 7411_FCQ(doc): target at [9] | cited: [0, 1, 2, 5, 9]
#   [2626/2746] 7411_FCQS(doc): target at [9] | cited: [0, 1, 3, 2, 5]
#   [2627/2746] 7411_FCS(doc): target at [9] | cited: [0, 5, 3, 6, 9]
#   [2628/2746] 7411_FQ(doc): target at [9] | cited: [0, 3, 6, 5, 9]
#   [2629/2746] 7411_FQS(doc): target at [9] | cited: [0, 3, 6, 5, 9]
#   [2630/2746] 7411_FS(doc): target at [0] | cited: [0, 1, 4, 5, 6]
#   [2631/2746] 7411_Fluency(doc): target at [0] | cited: [0, 1, 4, 7, 6]
#   [2632/2746] 7411_LLMstxt(doc): target at [9] | cited: [0, 3, 6, 5, 9]
#   [2633/2746] 7411_QS(doc): target at [0] | cited: [0, 1, 4, 5, 6]
#   [2634/2746] 7411_Quotes(doc): target at [0] | cited: [0, 1, 4, 7, 6]
#   [2635/2746] 7411_SimpleLanguage(doc): target at [0] | cited: [0, 1, 4, 5, 6]
#   [2636/2746] 7411_Statistics(doc): target at [0] | cited: [0, 1, 4, 7, 6]
#   [2637/2746] 7411_TechnicalTerms(doc): target at [0] | cited: [0, 1, 4, 7, 6]
#   [2638/2746] 7411_UniqueWords(doc): target at [0] | cited: [0, 1, 2, 3, 4]
#   [2639/2746] 7411_doc: target at [0] | cited: [0, 1, 4, 5, 7]
#   [2640/2746] 74158_Authoritative(doc): target at [8] | cited: [0, 2, 3, 7, 8]
#   [2641/2746] 74158_CQ(doc): target at [7] | cited: []
#   [2642/2746] 74158_CQS(doc): target at [8] | cited: [0, 2, 1, 7, 8]
#   [2643/2746] 74158_CS(doc): target at [8] | cited: [0, 1, 2, 3, 8]
#   [2644/2746] 74158_Citations(doc): target at [8] | cited: [0, 2, 7, 8, 1]
#   [2645/2746] 74158_ContentImprovement(doc): target at [8] | cited: [0, 2, 1, 3, 4]
#   [2646/2746] 74158_FC(doc): target at [9] | cited: [0, 2, 1, 7, 9]
#   [2647/2746] 74158_FCQ(doc): target at [8] | cited: [0, 2, 3, 1, 4]
#   [2648/2746] 74158_FCQS(doc): target at [9] | cited: [0, 2, 1, 7, 9]
#   [2649/2746] 74158_FCS(doc): target at [9] | cited: [0, 2, 6, 1, 3]
#   [2650/2746] 74158_FQ(doc): target at [8] | cited: [0, 3, 8, 7, 1]
#   [2651/2746] 74158_FQS(doc): target at [8] | cited: [0, 1, 2, 7, 8]
#   [2652/2746] 74158_FS(doc): target at [8] | cited: [0, 2, 1, 7, 8]
#   [2653/2746] 74158_Fluency(doc): target at [8] | cited: [1, 3, 7, 8, 2]
#   [2654/2746] 74158_LLMstxt(doc): target at [7] | cited: [0, 7, 8, 3]
#   [2655/2746] 74158_QS(doc): target at [8] | cited: [0, 2, 7, 8, 1]
#   [2656/2746] 74158_Quotes(doc): target at [9] | cited: [0, 2, 1, 7, 8]
#   [2657/2746] 74158_SimpleLanguage(doc): target at [7] | cited: [0, 2, 6, 1, 3]
#   [2658/2746] 74158_Statistics(doc): target at [9] | cited: [0, 2, 1, 7, 8]
#   [2659/2746] 74158_TechnicalTerms(doc): target at [7] | cited: [0, 3, 1, 7, 8]
#   [2660/2746] 74158_UniqueWords(doc): target at [8] | cited: [0, 2, 4, 1, 7]
#   [2661/2746] 74158_doc: target at [8] | cited: [0, 2, 4, 1, 6]
#   [2662/2746] 74167_Authoritative(doc): target at [9] | cited: [0, 3, 1, 4, 5]
#   [2663/2746] 74167_CQ(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2664/2746] 74167_CQS(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2665/2746] 74167_CS(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2666/2746] 74167_Citations(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2667/2746] 74167_ContentImprovement(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2668/2746] 74167_FC(doc): target at [9] | cited: [0, 2, 1, 4, 6]
#   [2669/2746] 74167_FCQ(doc): target at [9] | cited: [0, 2, 1, 4, 5]
#   [2670/2746] 74167_FCQS(doc): target at [9] | cited: [0, 2, 1, 4, 5]
#   [2671/2746] 74167_FCS(doc): target at [9] | cited: [0, 2, 1, 4, 5]
#   [2672/2746] 74167_FQ(doc): target at [9] | cited: [0, 2, 1, 5, 6]
#   [2673/2746] 74167_FQS(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2674/2746] 74167_FS(doc): target at [9] | cited: [0, 2, 1, 4, 5]
#   [2675/2746] 74167_Fluency(doc): target at [9] | cited: [0, 2, 1, 5, 6]
#   [2676/2746] 74167_LLMstxt(doc): target at [9] | cited: [0, 2, 1, 4, 5]
#   [2677/2746] 74167_QS(doc): target at [8] | cited: [0, 2, 1, 4, 7]
#   [2678/2746] 74167_Quotes(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2679/2746] 74167_SimpleLanguage(doc): target at [8] | cited: [0, 3, 1, 2, 4]
#   [2680/2746] 74167_Statistics(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2681/2746] 74167_TechnicalTerms(doc): target at [8] | cited: [0, 2, 1, 4, 5]
#   [2682/2746] 74167_UniqueWords(doc): target at [9] | cited: [0, 2, 1, 4, 5]
#   [2683/2746] 74167_doc: target at [8] | cited: [0, 2, 1, 6, 5]
#   [2684/2746] 74246_Authoritative(doc): target at [9] | cited: [0, 3, 6, 5, 2]
#   [2685/2746] 74246_CQ(doc): target at [9] | cited: [0, 2, 1, 3, 6]
#   [2686/2746] 74246_CQS(doc): target at [9] | cited: [0, 3, 6, 9, 2]
#   [2687/2746] 74246_CS(doc): target at [9] | cited: [0, 4, 1, 6, 7]
#   [2688/2746] 74246_Citations(doc): target at [9] | cited: [0, 6, 4, 5, 9]
#   [2689/2746] 74246_ContentImprovement(doc): target at [9] | cited: [0, 1, 6, 5, 7]
#   [2690/2746] 74246_FC(doc): target at [9] | cited: [0, 3, 6, 4]
#   [2691/2746] 74246_FCQ(doc): target at [9] | cited: [0, 6, 5, 9, 4]
#   [2692/2746] 74246_FCQS(doc): target at [9] | cited: [0, 4, 6, 5, 7]
#   [2693/2746] 74246_FCS(doc): target at [9] | cited: [0, 3, 5, 9, 6]
#   [2694/2746] 74246_FQ(doc): target at [9] | cited: [0, 4, 1, 2, 6]
#   [2695/2746] 74246_FQS(doc): target at [8] | cited: [0, 1, 2, 5, 8]
#   [2696/2746] 74246_FS(doc): target at [9] | cited: [0, 3, 6, 4, 5]
#   [2697/2746] 74246_Fluency(doc): target at [9] | cited: [0, 2, 1, 6, 5]
#   [2698/2746] 74246_LLMstxt(doc): target at [9] | cited: [0, 4, 1, 2, 6]
#   [2699/2746] 74246_QS(doc): target at [9] | cited: [0, 1, 4, 6, 7]
#   [2700/2746] 74246_Quotes(doc): target at [8] | cited: [0, 4, 6, 5, 3]
#   [2701/2746] 74246_SimpleLanguage(doc): target at [9] | cited: [0, 2, 6, 4, 1]
#   [2702/2746] 74246_Statistics(doc): target at [7] | cited: [0, 4, 6, 8]
#   [2703/2746] 74246_TechnicalTerms(doc): target at [9] | cited: [0, 6, 5, 7, 3]
#   [2704/2746] 74246_UniqueWords(doc): target at [7] | cited: [0, 1, 6, 5, 4]
#   [2705/2746] 74246_doc: target at [8] | cited: [0, 2, 6, 5, 7]
#   [2706/2746] 7438_Authoritative(doc): target at [0] | cited: [0, 3, 1, 5, 7]
#   [2707/2746] 7438_CQ(doc): target at [0] | cited: [0, 3, 1, 2, 5]
#   [2708/2746] 7438_CQS(doc): target at [0] | cited: [0, 1, 2, 4, 5]
#   [2709/2746] 7438_CS(doc): target at [0] | cited: [0, 1, 2, 4, 6]
#   [2710/2746] 7438_Citations(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [2711/2746] 7438_ContentImprovement(doc): target at [0] | cited: [0, 1, 2, 5, 7]
#   [2712/2746] 7438_FC(doc): target at [1] | cited: [0, 1, 2, 5, 6]
#   [2713/2746] 7438_FCQ(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2714/2746] 7438_FCQS(doc): target at [1] | cited: [0, 1, 5, 7, 4]
#   [2715/2746] 7438_FCS(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2716/2746] 7438_FQ(doc): target at [1] | cited: [0, 1, 2, 4, 5]
#   [2717/2746] 7438_FQS(doc): target at [1] | cited: [0, 1, 3, 5, 6]
#   [2718/2746] 7438_FS(doc): target at [1] | cited: [0, 1, 3, 2, 5]
#   [2719/2746] 7438_Fluency(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [2720/2746] 7438_LLMstxt(doc): target at [1] | cited: [0, 1, 3, 2, 5]
#   [2721/2746] 7438_QS(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [2722/2746] 7438_Quotes(doc): target at [0] | cited: [0, 1, 2, 5, 6]
#   [2723/2746] 7438_SimpleLanguage(doc): target at [0] | cited: [0, 1, 2, 5, 8]
#   [2724/2746] 7438_Statistics(doc): target at [1] | cited: [0, 1, 3, 2, 5]
#   [2725/2746] 7438_TechnicalTerms(doc): target at [0] | cited: [0, 1, 5, 6]
#   [2726/2746] 7438_UniqueWords(doc): target at [0] | cited: [0, 3, 1, 2, 4]
#   [2727/2746] 7438_doc: target at [0] | cited: [0, 3, 1, 2, 4]
#   [2728/2746] 74897_Authoritative(doc): target at [2] | cited: [0, 4, 2, 9, 3]
#   [2729/2746] 74897_CQ(doc): target at [2] | cited: [0, 4, 2, 9, 3]
#   [2730/2746] 74897_CQS(doc): target at [2] | cited: [0, 4, 2, 9, 3]
#   [2731/2746] 74897_CS(doc): target at [2] | cited: [0, 4, 1, 2, 9]
#   [2732/2746] 74897_Citations(doc): target at [2] | cited: [0, 4, 2, 9, 3]
#   [2733/2746] 74897_ContentImprovement(doc): target at [3] | cited: [0, 4, 1, 2, 3]
#   [2734/2746] 74897_FC(doc): target at [3] | cited: [0, 4, 3, 2, 1]
#   [2735/2746] 74897_FCQ(doc): target at [3] | cited: [0, 4, 1, 3, 9]
#   [2736/2746] 74897_FCQS(doc): target at [3] | cited: [0, 4, 1, 3, 9]
#   [2737/2746] 74897_FCS(doc): target at [3] | cited: [0, 4, 1, 3, 2]
#   [2738/2746] 74897_FQ(doc): target at [2] | cited: [0, 4, 2, 1, 9]
#   [2739/2746] 74897_FQS(doc): target at [3] | cited: [0, 1, 5, 3, 9]
#   [2740/2746] 74897_FS(doc): target at [2] | cited: [0, 4, 2, 9, 5]
#   [2741/2746] 74897_Fluency(doc): target at [2] | cited: [0, 4, 2, 7, 9]
#   [2742/2746] 74897_LLMstxt(doc): target at [8] | cited: [0, 3, 1, 2, 4]
#   [2743/2746] 74897_QS(doc): target at [2] | cited: [0, 4, 2, 9, 5]
#   [2744/2746] 74897_Quotes(doc): target at [2] | cited: [0, 4, 2, 1, 3]
#   [2745/2746] 74897_SimpleLanguage(doc): target at [2] | cited: [0, 1, 4, 2, 9]
#   [2746/2746] 74897_Statistics(doc): target at [2] | cited: [0, 4, 2, 9, 3]
# ============================================================
# GENERATION COMPLETE
# Started:    10:21:30
# Finished:   19:15:58
# Total time: 8:54:28
# Results:    2746 rows saved to /Users/leonardrampf/Library/CloudStorage/OneDrive-Personal/Dokumente/Universität/Nova SBE/Work Project/geo-experiment/data/retail/generation/4_generation_results_C_v2.parquet

# %% [markdown]
# ## Inspect Results

# %%
# Load this notebook's parquet file for inspection
df_results = pd.read_parquet(output_path)

# Change INSPECT_QUERY_ID to inspect a specific run
INSPECT_QUERY_ID = df_results["query_id"].iloc[0]

row = df_results[df_results["query_id"] == INSPECT_QUERY_ID].iloc[0]

print(f"Run (query_id):    {row['query_id']}")
print(f"Original query:    {row['original_query_id']}")
print(f"Method:            {row['method']}")
print(f"Query:             {row['query']}")
print(f"Num docs:          {row['num_docs']}")
print(f"Target position:   {row['target_new_position']} (0-based)")
print(f"Citation order:    {row['citation_order']}")
print(f"Target cited:      {'YES' if row['target_new_position'] in row['citation_order'] else 'NO'}")
print(f"\n--- LLM Response ---")
print(row["llm_response"][:800])
# Out:
# Run (query_id):    47826_TechnicalTerms(doc)
# Original query:    47826
# Method:            TechnicalTerms(doc)
# Query:             guardian torch light
# Num docs:          10
# Target position:   8 (0-based)
# Citation order:    [0 1 2 3 4]
# Target cited:      NO
#
# --- LLM Response ---
# The **Guardian Torch** refers to a solar-powered motion sensor light designed to enhance home security with convenient features. The Guardian Torch model offers unique features tailored for outdoor use, including a 120° infrared motion detector that activates five ultra-bright LED lights upon sensing movement, making it effective for nighttime security [1]. It operates on solar power, eliminating the need for wiring or battery replacements, and it has an IP65 water-resistant housing, which makes it durable against the elements [1].
#
# Additionally, the light features a **dusk to dawn activation**, allowing it to charge during the day and automatically activate when it gets dark, ensuring your home is well-lit at night [1][2]. Installation is straightforward, requiring only a few minutes to a

# %% [markdown]
# ## Merge Results
#
# **Run only after all 4 notebooks (A, B, C, D) are complete.**

# %%
# Merge all four notebook parquet files into one combined file
# Run only after notebooks A, B, C, D have all completed
NOTEBOOK_IDS = ["A", "B", "C", "D"]
dfs = []
for nb in NOTEBOOK_IDS:
    path = os.path.join(data_dir, f"generation/4_generation_results_{nb}_v2.parquet")
    if os.path.exists(path):
        dfs.append(pd.read_parquet(path))
        print(f"Loaded 4_generation_results_{nb}_v2.parquet ({len(dfs[-1])} rows)")
    else:
        print(f"WARNING: 4_generation_results_{nb}_v2.parquet not found — skipping")

# Concatenate all four subsets into one merged DataFrame
merged      = pd.concat(dfs, ignore_index=True)
merged_path = os.path.join(data_dir, "generation/4_generation_results_v2.parquet")
merged.to_parquet(merged_path, index=False)
print(f"\nMerged {len(merged)} rows into 4_generation_results_v2.parquet")

# %% [markdown]
# ## Summary

# %%
# Load merged parquet and verify completeness
# Expected: total rows == total runs with target across all 4 notebooks
merged_path = os.path.join(data_dir, "generation/4_generation_results_v2.parquet")
df_results  = pd.read_parquet(merged_path)

print(f"Total runs done:     {len(df_results)}")
print(f"Total runs expected: {len(all_run_ids_full)}")
print(f"Missing runs:        {len(all_run_ids_full) - len(df_results)}")
print()
print(f"Unique methods: {df_results['method'].nunique()}")
print(f"Unique queries: {df_results['original_query_id'].nunique()}")
